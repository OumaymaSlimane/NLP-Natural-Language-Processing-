# %% [markdown]
# <a href="https://colab.research.google.com/github/OumaymaSlimane/NLP-Natural-Language-Processing-/blob/master/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy #installation SpaCy pour l'analyse de texte (tokenisation, lemmatisation, reconnaissance d'entités nommées...)

# !python -m spacy download fr_core_news_sm # Téléchargement de  modèle linguistique français de petite taille pour SpaCy.
# Ce modèle est nécessaire pour le traitement de texte en français-->offre des fonctionnalités comme l'analyse syntaxique, la lemmatisation et la reconnaissance d'entités nommées.

# !pip install unidecode #pour supprimer l'accent
# !pip install pyspellchecker #pour correction des orthographes

#c'est l'installation des biblio
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 41.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from fr-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.1-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 35.6 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.1

# %%
import requests  # faire des requêtes Http

from bs4 import BeautifulSoup  # extraire et analyser du contenu HTML

import spacy  #le traitement du langage naturel (NLP)

import string  # pour supprimer ponctuation

from nltk.corpus import stopwords, wordnet as wn  # pour suppression des mots vides et gérer les synonymes les synonymes

import nltk

from unidecode import unidecode  # Pour supprimer les accents des caractères

# %%
# Télécharge les ressources nécessaires de NLTK : les mots vides (stopwords), la base de synonymes (wordnet) et les données supplémentaires pour WordNet (omw-1.4)

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Chargement du modèle français de spaCy
nlp = spacy.load("fr_core_news_sm")

# %%
# Chargement des mots vides
stop_words = set(stopwords.words('french'))

# %%
# Fonction pour extraire le contenu d'une page
#Fonction pour extraire le contenu structuré d'une page : envoie une requête à l'URL, analyse le HTML pour trouver le contenu principal, extrait les sections de titres (h2, h3) et leur contenu (paragraphes, listes),
# puis organise ces informations en une liste de dictionnaires contenant l'URL, le titre de la section et le texte de contenu , renvoie un message d'erreur si la requête échoue.

def extract_content(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        main_content = soup.find('div', {'id': 'mw-content-text'})

        # Extrait toutes les sections de niveau h2, h3, ainsi que les paragraphes et listes

        sections = main_content.find_all(['h2', 'h3', 'p', 'ul', 'ol'])

        documents = []
        current_section_title = None
        for section in sections:
            if section.name in ['h2', 'h3']:
                current_section_title = section.text.strip()
            elif section.name in ['p', 'ul', 'ol'] and current_section_title:
                current_section_content = section.text.strip()
                 # Ajoute le titre et le contenu de la section au document
                documents.append({
                    'url': url,
                    'title': current_section_title,
                    'content': current_section_content
                })
        return documents
    else:
        print(f"Erreur lors de la récupération de la page {url} : {response.status_code}")
        return []

# %%
#Une fonction défini pour corriger automatiquement les erreurs typographiques courantes dans des textes en français(des erreurs basiques pas complexes s'il existe )
# (dans mon cas je vais utiliser lemmatisation pour éviter ces problèmes .

from spellchecker import SpellChecker

# Initialiser SpellChecker pour le français
spell = SpellChecker(language='fr')

# Fonction pour corriger un mot en français
def correct_word(word):
    corrected_word = spell.correction(word)
    return corrected_word

# Exemple d'utilisation
word = "bonj"
print(f"Correction pour '{word}': {correct_word(word)}")
# Out:
# Correction pour 'bonj': bon

# %% [markdown]
# **Maintenat pré traitement de texte en une seule fonction:**
#
#
# 1.   **Suppression de la ponctuation et des chiffres**(car les chiffres ici ont un poids faible)
# 2.   **Analyse et tokenisation avec SpaCy** : segmente le texte en tokens /identifie également les entités nommées, comme les noms de personnes, lieux et dates, qui sont remplacées par des balises spécifiques (<PERSON>, <LOCATION>, <DATE>)/
#
#
# 3.   **Stop Words et mots indésirables**
# 4. **Lemmatisation:**L'objectif est de traiter les variantes linguistiques d'un même mot comme une seule entité

# %% [markdown]
# 5. **la plus imporante étape:**
#
#      **1/Prise du mot et recherche de son synonyme :** Pour chaque mot, on effectue une recherche de synonymes dans un dictionnaire de synonymes. On prend systématiquement le premier synonyme trouvé, et ce, quel que soit le type grammatical du mot d'origine (qu'il soit verbe, nom, adjectif, ou adverbe).
#
#       **2/Uniformisation avec un synonyme verbal :** Tous les mots sont normalisés en prenant un synonyme ayant la forme d'un verbe (premier synonyme trouvé dans la catégorie verbale). Cette uniformisation se fait de manière systématique pour tous les mots ayant un sens similaire.
#
#       **3/Obtention d'une même forme pour des mots différents mais synonymes :** Un autre mot ayant un sens similaire subira le même processus, ce qui signifie que plusieurs mots aux sens proches seront remplacés par le même mot sous une forme verbale unique. **Par exemple, "rapide" et "vite" pourraient tous deux être remplacés par le verbe "accélérer".-->Cette sélection permet de regrouper tous les mots synonymes sous une forme unique.**
#       **-----> : Cette uniformisation facilite ensuite une indexation plus précise basée sur le sens. Si plusieurs mots synonymes apparaissent dans un document, ils seront représentés par un même mot unique**

# %%
from nltk.corpus import wordnet as wn

# Fonction pour obtenir les synonymes en fonction du mot et de la catégorie grammaticale
def get_synonyms(word, pos):
    synonyms = set()

    # Utilise la catégorie grammaticale pour filtrer les synonymes
    wordnet_pos = None
    if pos == "NOUN":
        wordnet_pos = wn.NOUN
    elif pos == "VERB":
        wordnet_pos = wn.VERB
    elif pos == "ADJ":
        wordnet_pos = wn.ADJ
    elif pos == "ADV":
        wordnet_pos = wn.ADV

    # Recherche des synonymes dans WordNet avec la catégorie grammaticale spécifiée
    if wordnet_pos:
        for syn in wn.synsets(word, pos=wordnet_pos, lang='fra'):  # Recherche dans WordNet pour le français
            for lemma in syn.lemmas('fra'):
                synonyms.add(lemma.name())  # Ajoute le nom du synonyme dans l'ensemble des résultats

    return synonyms

# %%
# Fonction pour prétraiter les documents
def preprocess_documents(documents):
    processed_documents = []
    undesirable_words = ["l'", "d'", "s'", "s’", "d’", "l’","c’"] #pour éviter la confusion entre les formes de virgules car on trouve "d'" et "d’".


    for doc in documents:
        content_without_punctuation = ''.join(char for char in doc['content'] if char not in string.punctuation)
        content_normalized = ''.join(char if not char.isdigit() else ' ' for char in content_without_punctuation).lower() #le poids des nombre est faible on l'élimigne dés le débit et on convertit tout le texte en miniscule pour etre traité.


        doc_spacy = nlp(content_normalized)
        tokens = []

        # traitement des entités nommées : remplace les noms de personnes, lieux et dates par des balises spécifiques
        for ent in doc_spacy.ents:
            if ent.label_ == "PER":
                tokens.append("<PERSON>")
            elif ent.label_ == "LOC":
                tokens.append("<LOCATION>")
            elif ent.label_ == "DATE":
                tokens.append("<DATE>")
          # Tokenisation et normalisation des mots

        for token in doc_spacy:
          # filtre les stop words et un mot spécifique 'leurs' car 'leurs' n'a pas été supprimé avec les stops words

            if (token.text.lower() not in stop_words and token.text.lower() != 'leurs'):
                lemma = token.lemma_.lower().strip() #pour supprimer les espaces

                 # exclut les mots indésirables définis précédemment

                if lemma not in undesirable_words:
                    target_pos = "NOUN" if token.pos_ in ["VERB", "ADJ", "ADV"] else token.pos_
                    synonyms = get_synonyms(lemma,target_pos) # récupère les synonymes du mot

                    if synonyms:
                        standardized = next(iter(synonyms)) # prend le premier synonyme toujours
                        correct_word(standardized) # correction orthographique
                        standardized = unidecode(standardized)  # suppression des accents
                        tokens.append(standardized)
                    else:
                        if lemma:
                            correct_word(lemma)
                            lemma= unidecode(lemma)
                            tokens.append(lemma)
       # ajout de document traité (avec URL, titre, et tokens) à la liste des documents traités


        processed_documents.append({
            'url': doc['url'],
            'title': doc['title'],
            'tokens': tokens
        })

    return processed_documents

# %% [markdown]
# remarque : ici est considérée chaque article dans un site web un documents : (pour chaque site divisés sur plusieurs documents

# %%
# Fonction pour afficher les documents prétraités
def display_processed_documents(processed_documents):
    print("\nDocuments prétraités :\n")
    for proc_doc in processed_documents:
        print(f"Document : {proc_doc['title']} (URL: {proc_doc['url']})")
        print(f"Tokens prétraités : {proc_doc['tokens']}\n")

# %%
#  maintenat on applique les fonctions précédentes Liste des URL à traiter
urls = [
    "https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal",
    "https://fr.wikipedia.org/wiki/France",
    "https://fr.wikipedia.org/wiki/Technologie",
    "https://fr.wikipedia.org/wiki/Économie",
    "https://fr.wikipedia.org/wiki/Éducation"
]

# Exécution des fonctions
all_documents = []
for url in urls:
    all_documents.extend(extract_content(url))

processed_documents = preprocess_documents(all_documents)
display_processed_documents(processed_documents)
# Out:
# Documents prétraités :
#
# Document : Wikipédia (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<LOCATION>', 'lencyclopedie', 'ouvrir', 'supergrand', 'ameliorer']
#
# Document : Wikipédia (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['accueil', 'democratie', 'yak', 'contribuer', 'veine_porte', 'thematique', 'regle', 'fondateur', 'resume', 'laide', 'place', 'proposition']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'instantane', 'mcminnville', 'deux', 'instantane', 'presenter', 'comme', 'celui', 'dune', 'soucoupe', 'navette', 'prendre', 'may', 'fermier', 'saint_Paul', 'Trente', 'grace', 'entrer', 'mcminnville', 'Sheridan', 'loregon', 'nordouest', 'etatsuni']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['instantane', 'professionnel', 'lancer', 'theme', 'dupe', 'rien', 'identifier', 'soucoupe_volante', 'parmi', 'obtention', 'connu', 'sexualite', 'faire', 'lobjet', 'nombreux', 'argument', 'chez', 'ufologue', 'strictement_negatif', 'confier', 'cartouche', 'life', 'egarer', 'plusieurs', 'recuperation', 'pouvoir', 'finalement', 'retrouver', 'espace', 'news', 'register', 'journellement', 'espace']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<LOCATION>', 'certain', 'ufologue', 'cliche', 'representer', 'theme', 'artificiel', 'dapparence', 'metallique', 'discoidal', 'plusieurs', 'douze', 'Metre_ruban', 'diametre', 'situer', 'kilometre', 'lobjectif', 'deplacer', 'nirvana', 'nordest', 'vers', 'louest', 'comme', 'relate', 'Trente', 'description']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['si', 'femme', 'esprit', 'explorer', 'photographie', 'strictement_negatif', 'saccordent', 'signifier', 'ceuxci', 'nont', 'manipuler', 'retouche', 'femme', 'explorer', 'analyse_qualitative', 'esprit', 'conclure', 'cliche', 'preuve', 'simulation', 'theme', 'parallele', 'progeniture', 'haut', 'suspendre', 'ligne', 'voiture_electrique', 'ante', 'proche', 'lobjectif', 'analyse_qualitative', 'obtention', 'recent', 'rassembler', 'evidence', 'lexistence', '<<', 'ressemblance', 'extremement', 'haute', 'dun', 'ruban', 'en_suspens', '>>']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', 'jusqua', 'deceder', 'survenir', 'paul', 'Trente', 'avoir', 'toujours', 'defendre', 'sincerite', 'description', 'personnalite', 'confirmer', 'evelyn', 'femme', 'cadeau', 'flanc', 'momentla']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<LOCATION>', 'festival', 'consacrer', 'ovni', 'avoir', 'creer', 'mcminnville', 'apres', 'celui', 'Roswell', 'obtention', 'frequenter', 'etatsuni']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['lire', 'sequence']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['contenir', 'specificite', 'humour', 'contenir', 'survie', 'programm']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'novembre', 'etatsuni', 'donald', 'trump', 'photographie', 'remporter', 'lelection', 'presidentiel', 'republicain', 'obtenir', 'plupart', 'Senat', 'novembre', 'election', 'presidentiel', 'Palau', 'referendum', 'constitutionnel', 'qatar', 'novembre', 'Moldova', 'gouverneur', 'sortant', 'Maia', 'sandu', 'reelire', 'er', 'novembre', 'serbie', 'leffondrement', 'lauvent', 'gare', 'novi', 'sad', 'matiere', 'deceder', 'quatorze', 'moins-que-rien', 'blesse', 'gravement', 'trois', 'autre', 'Octobre', 'election', 'ensemble', 'Kang', 'printemps', 'respecter', 'premiere_vitesse', 'alternance', 'paysage', 'depuis', 'independance']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'tribulation', 'viol', 'mazan', 'guerre', 'israelhezbollah', 'guerre', 'israelhama', 'guerre', 'civil', 'Soudanais', 'intrusion', 'lukraine', 'Union_des_Republiques_Socialistes_Sovietiques', 'guerre', 'civil', 'Birmanie', 'guerre', 'meute', 'Hispaniola', 'coup_de_colere', 'anglophone', 'cameroun', 'guerre', 'kivu']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['Maitrise', 'tennis', 'feminin']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', 'novembre', 'hassan', 'akesbi', 'RAM', 'narayan', 'valeria', 'narbikova', 'novembre', 'geneviev', 'Grad', 'rachid', 'mekhloufi', 'antonio', 'dorleansbraganc', 'titinga', 'Frederic', 'pacerer', 'novembre', 'jacques', 'renoir', 'novembre', 'dorothy', 'allison', 'johanne', 'beutler', 'john', 'dempsey', 'john', 'nott', 'madeleine', 'riffaud', 'fabio', 'sartor', 'daniel', 'spoerri', 'tony', 'todd']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', 'hassan', 'akesbi', 'RAM', 'narayan', 'valeria', 'narbikova']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<PERSON>', 'geneviev', 'Grad', 'rachid', 'mekhloufi', 'antonio', 'dorleansbraganc', 'titinga', 'Frederic', 'pacerer']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', 'jacques', 'renoir']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', 'dorothy', 'allison', 'johanne', 'beutler', 'john', 'dempsey', 'john', 'nott', 'madeleine', 'riffaud', 'fabio', 'sartor', 'daniel', 'spoerri', 'tony', 'todd']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['novembre', 'wikinews', 'modifier']
#
# Document : Le saviez-vous ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<PERSON>', 'portrait', 'presumer', 'ensemble', 'barthelemy', "joubertc'", 'barthelemy', 'joubert', 'portrer', 'preferer', 'sieye', 'responsabilite', 'prendre', 'esprit', 'gifle', 'responsabilite', 'rassembler', 'propos', 'consideration', 'rotation', 'Republique_hellenique', 'antique', 'dispositif', 'avoir', 'supergrand', 'etre', 'grace', 'empecher', 'imitation', 'abandon', 'lors', 'epreuve', 'course', 'logo', 'peugeot', 'representer', 'Le_Lion', 'inspirer', 'armoirie', 'comtoiser', 'destiner', 'evidence', 'specificite', 'lame', 'sci', 'fabrication', 'ce', 'echanger', 'selon', 'explorer', 'college', 'tohoku', 'planetoide', 'semblable', 'celui', 'chicxulub', 'espace', 'impact', 'susceptible', 'provoquer', 'extinction', 'dinosaure', 'recouvrir', 'surface', 'grunge', 'janet', 'jagan', 'premiere_vitesse', 'autochtone', 'etatsuni', 'voter', 'gouverneur', 'republique', 'etatsuni', 'supergrand', 'trouver', 'dino', 'parmi', 'gens', 'rino', 'parmi', 'elephantides']
#
# Document : Le saviez-vous ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['archives', 'propos', 'programm', 'modifier']
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['wikipedia', 'propos', 'encyclopedie', 'collectif', 'ligne', 'universel', 'multilingue', 'fonction', 'regle', 'wiki', 'propos', 'vise', 'offrir', 'capacite', 'libremer', 'reutilisable', 'propos', 'verifiable', 'chacun', 'supergrand', 'modifier', 'ameliorer']
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', 'wikipedia', 'definir', 'regle', 'fondateur', 'capacite', 'sou', 'permission', 'creativ', 'common', 'bysa', 'supergrand', 'etre', 'copie', 'reutiliser', 'sou', 'permission', 'sou', 'qualification', 'den', 'respecter', 'forme', 'wikipedia', 'fournir', 'femme', 'capacite', 'gratuitement', 'sans', 'agent_publicitaire_publicitaire', 'sans', 'recourir', 'lexploitation', 'forme', 'travailleur', 'utilisateur']
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['redacteur', 'regle', 'wikipedia', 'benevole', 'coordination', 'lutte', 'lolo', 'dun', 'democratie', 'collaboratif', 'sans', 'leader']
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['chacun', 'supergrand', 'publier', 'immediatement', 'capacite', 'ligne', 'forme', 'respecter', 'regle', 'viande', 'etablir', 'pierre_angulaire', 'wikimedia', 'democratie', 'cas', 'verifiabilite', 'capacite', 'ladmissibilite', 'regle', 'maintien', 'attitude', 'liqueur']
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['nombreux', 'supplement', 'salut', 'reglementation', 'notamment', 'creer', 'regle', 'modifier', 'regle', 'inserer', 'effigie', "n'", 'barguigner', 'place', 'proposition', 'etre', 'cooperant', 'premiere_vitesse', 'notamment', 'propos', 'thematique', 'divers', 'espace', 'propos']
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['supplement', 'propos', 'servir', 'centraliser', 'remarque', 'remarque', 'permission', 'ameliorer', 'regle']
#
# Document : Éphéméride du 9 novembre (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<LOCATION>', 'gifle', 'detat', 'brumaire', 'aboutit', 'portee', 'supergrand', 'napoleon', 'bonaparte', 'permutation', 'consideration', 'consulat', 'propos', 'rotation', 'Daniel_Chester_French', 'demission', 'lempereur', 'allemand', 'guillaume', 'ii', 'proclamation', 'berlin', 'republique', 'controle', 'putsch', 'dadolf', 'hitler', 'Munich', 'nuit', 'cristal_de_roche', 'persecution', 'contre', 'Juive', 'organiser', 'gouvernement', 'nazi', 'RFA', 'baisse', 'bastingage', 'berlin', 'demolition', 'stari', 'most', 'bridge', 'xvie', 'cent', 'mostar', 'bosnieherzegovine', 'defenseur', 'defense', 'Croate', 'lors', 'guerre', 'bosnieherzegovine']
#
# Document : Éphéméride du 9 novembre (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['ephemerid', 'detailler', 'novembre', 'archive', 'modifier']
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['archives', 'voir', 'effigie']
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : ['effigie', 'specificite', 'wikimedia', 'common']
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens prétraités : []
#
# Document : Toponymie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'Francois-Anatole_Thibault', 'tire', 'souci', 'frank', 'phratrie', 'germanique', 'instituer', 'premiere_vitesse', 'pierre_angulaire', 'piedestal', 'gaule', 'police_romaine', 'souci', 'frank', 'venir', 'luimem', 'protogermanique', 'frankon', 'signifier', 'javelot', 'javelot', 'alors', 'peutetre', 'propos', 'frank', 'signifier', '<<', 'male', 'ouvrir', '>>']
#
# Document : Toponymie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'premiere_vitesse', 'occurence', 'propos', '<<', 'france', '>>', 'langue_ethnique', 'Daniel_Chester_French', 'face', 'xie', 'cent', 'notamment', 'song', 'roland', 'vers', 'construction', 'Latin', 'francia', 'deja', 'besoin', 'projet', 'anterieur', 'acception', 'etoile_variable']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'jeu', 'Europeenne', 'Francois-Anatole_Thibault', 'lancer', 'france', 'metropolitain', 'situer', 'lextremite', 'occidental', 'leurope', 'representation', 'rester', 'inchange', 'depuis', 'propos', 'minute', 'guerre', 'mondial', 'contrat', 'pari', 'border', 'ocean', 'nord', 'nord', 'calendrier', 'nordnordouest', 'ocean', 'celte', 'louestnordouest', 'golfe', 'Gascogne', 'louest', 'mer', 'mediterraner', 'sudest', 'frontiere', 'Mol', 'nordnordest', 'luxembourg', 'nordest', 'lallemagne', 'lestnordest', 'tamias', 'ballast', 'litalie', 'lestsudest', 'monaco', 'sudest', 'lespagne', 'Andorre', 'sudsudouest']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'limite', 'ballast', 'sudest', 'sudouest', 'district', 'metropolitain', 'etablir', 'sappuyant', 'course', 'deau', 'massif', 'montagneux', 'savoir', 'Rhin', 'jura', 'Geneve', 'alpe', 'pyreneesn', 'bien_que', 'quau', 'nordest', 'limite', 'degeler', 'introduction', 'nature']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'Francois-Anatole_Thibault', 'egalement', 'composer', 'nombreux', 'district', 'situer', 'dehors', 'continent', 'Europeenne', 'couramment', 'lancer', 'france', 'doutremer', 'permission', 'detr', 'cadeau', 'femme', 'Ocean', 'cosmos', 'sauf', 'locean', 'alopex_lagopus']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'district', 'regle', 'varier', 'ladministration', 'territorial', 'france', 'situer']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'Etats-Unis', 'nord', 'saintpierreetmiquelon', 'Etats-Unis', "Etats_confederes_d'Amerique", 'guyane', 'antille', 'Guadeloupe', 'martiniqu', 'saintbarthelemy', 'saintmartin', 'locean', 'ocean_Pacifique', 'nouvellecaledonie', 'Polynesie', 'Daniel_Chester_French', 'wallisetfutuna', 'ainsi', 'lile', 'clipperton', 'locean', 'Indus', 'session', 'mayotte', 'ainsi', 'Salamine_de_Chypre', 'eparse', 'Salamine_de_Chypre', 'kerguelen', 'larchipel', 'crozet', 'Salamine_de_Chypre', 'saintpaul', 'Amsterdam', 'former', 'grunge', 'austral', 'antarctiquer', 'Daniel_Chester_French', 'taaf', 'Antarctique', 'grunge', 'adelien', 'egalement', 'inclus', 'taaf']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'Francois-Anatole_Thibault', 'posseder', 'limite', 'terrestre', 'Altamira', 'Surinam', 'Guyana', 'ainsi', 'quavec', 'paysba', 'Salamine_de_Chypre', 'saintmartin', 'antille']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'longueur', 'sands', 'Francois-Anatole_Thibault', 'metropolitain', 'kilometre', 'atteindre', 'kilometre', 'inclure', 'district', 'doutremer']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'selon', 'linsee', 'Francois-Anatole_Thibault', 'metropolitain', 'couvrir', 'kilometre', 'bien_que', 'lign', 'prendre', 'directoire', 'femme', 'surface', 'jusqua', 'laisse', 'premiere_vitesse', 'ocean', 'comptabilise', 'surface', 'kilometre', 'constituer', 'valeur', 'officiel']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', 'disparite', 'similaire', 'apparaitre', 'surface', 'france', 'metropolitain', 'dom', 'setablit', 'kilometre', 'linsee', 'surface', 'cadastral', 'kilometre', 'lign', 'surface', 'geodesique', 'surface', 'Francois-Anatole_Thibault', 'entierete', 'comprendre', 'drom', 'com', 'tomn', 'hors', 'grunge', 'adelie', 'setablit', 'kilometre']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'Francois-Anatole_Thibault', 'e', 'obtention', 'grand', 'responsabilite', 'cosmos', 'surface', 'terrestre', 'cest', 'aussi', 'tierce', 'obtention', 'grand', 'paysage', 'deurop', 'apres', 'Union_des_Republiques_Socialistes_Sovietiques', 'lukraine', 'deuxieme', 'si', 'inclure', 'domaine', 'ultramarin', 'obtention', 'grand', 'lunion', 'Europeenne']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'district', 'metropolitain', 'france', 'offrir', 'grand', 'changer', 'densemble', 'topographique', 'scene', 'naturelsb', 'vaste', 'party', 'district', 'Europeenne', 'flux', 'france', 'soulever', 'lors', 'plusieurs', 'sequence', 'tectonique_des_plaques', 'notamment', 'surrection', 'hercynien', 'lere', 'Paleozoique', 'lorigine', 'massif', 'armoricain', 'echange', 'morvandiau', 'vosgien', 'ardennais', 'corseb', 'massif', 'alpin', 'pyreneen', 'jurassien', 'beaucoup', 'obtention', 'progeniture', 'possedent', 'forme', 'moins', 'erodeesb', '--', 'alpe', 'culminer', 'Metre_ruban', 'daltitude', 'montagne', 'espace', 'bien_de_consommation_courante', 'salamandre_tachetee', 'classer', 'comme', 'presenter', 'speculation', 'sismique', 'ceuxci', 'rester', 'moderer']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'massif', 'delimiter', 'plusieurs', 'bassin', 'sedimentaire', 'notamment', 'bassin', 'aquitain', 'sudouest', 'bassin', 'Parisien', 'nordb', '--', 'lever', 'comprendre', 'plusieurs', 'domaine', 'plancher', 'particulierement', 'fertile', 'notamment', 'plateal', 'limoneux', 'beauce', 'brieb', 'outre', 'divers', 'facon', 'salut', 'nature', 'Moi', 'val', 'Rhone', 'permettent', 'propos', 'aiseesb', 'sands', 'offrir', 'scene', 'assez', 'contraste', 'sagit', 'tantot', 'vigueur', 'massif', 'montagneux', 'hausser', 'dazur', 'cas', 'plaine', 'terminer', 'escarpement', 'hausser', 'dalbatr', 'general', 'plaine', 'sableux', 'plaine', 'languedocb']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'reseau_informatique', 'hydrographique', 'france', 'metropolitain', 'principalement', 'organiser', 'epervier', 'quatre', 'grand', 'fleuve', 'Loire', 'seine', 'Garonne', 'rhoneb', 'auxquels', 'supergrand', 'ajouter', 'meuse', 'Rhin', 'moins', 'important', 'Francois-Anatole_Thibault', 'medius', 'lechell', 'Europeenne', 'bassin', 'versant', 'Daniel_Chester_French', 'quatre', 'premiere_vitesse', 'couvre', 'obtention', 'district', 'metropolitainb']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'district', 'ultramarins', 'dispersion', 'different', 'Ocean', 'continent', 'presenter', 'femme', 'marque', 'topographique', 'specifique', 'repartition', 'toutefois', 'second', 'rotir', 'notamment', 'consideration', 'speculation', 'potentialite', 'forme', 'debut', 'linsularite', 'lexception', 'Guyana', 'majorite', 'Salamine_de_Chypre', 'dorigine', 'volcanique', 'sou', 'forme', 'darcs', 'volcanique', 'lier', 'subduction', 'Guadeloupe', 'martiniqu', 'saintbarthelemy', 'saintmartin', 'progeniture', 'antille', 'Salamine_de_Chypre', 'matthew', 'hunter', "Etats_confederes_d'Amerique", 'larc', 'Nouvelles-Hebrides', 'Salamine_de_Chypre', 'loyauter', 'nouvellecaledonie', 'chapelet', 'dile', 'former', 'initialement', 'epervier', 'second', 'chaud', 'lithosphere', 'oceanique', 'archipel', 'constitutif', 'Polynesie', 'Daniel_Chester_French', 'taaf', 'session', 'mayotte', 'larchipel', 'comore', 'clipperton', 'plateal', 'volcanique', 'issu', 'panache', 'mantellique', 'plaine', 'kerguelen', 'dont', 'grunge', 'emerge', 'former', 'larchipel', 'souci', 'celui', 'larchipel', 'crozet', 'taaf', 'constituant', 'jeu', 'immerger', 'dun', 'massif', 'montagneux', 'lithosphere', 'continental', 'saintpierreetmiquelon', 'ainsi', 'lier', 'lorogenese', 'appalache']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'age', 'obtention', 'moins', 'destrier', 'sequence', 'volcanique', 'provoquer', 'train', 'expliquer', 'grade_universitaire', 'divers', 'derosion', 'allegement', 'subsidence', 'train', 'ecueil', 'corallien', 'soumission', 'calcaire', 'acte_notarie', 'plusieurs', 'Salamine_de_Chypre', 'maintenir', 'reliquat', 'rocheux', 'obtention', 'moins', 'eleve', 'destrier', 'volcan', '<<', 'Salamine_de_Chypre', 'haute', '>>', 'sans', 'bord', 'corallienne', 'quils', 'inactif', 'majorite', 'Salamine_de_Chypre', 'haute', 'polynesi', 'Daniel_Chester_French', 'comme', 'Tahiti', 'Salamine_de_Chypre', 'matthew', 'hunter', 'nouvellecaledonie', 'wallisetfutuna', 'mayotte', 'Salamine_de_Chypre', 'kerguelen', 'taaf', 'potentiellement', 'obtention', 'lile', 'propriete', 'larchipel', 'crozet', 'taaf', 'obtention', 'soufriere', 'Basseterre', 'Guadeloupe', 'montagn', 'peler', 'martiniqu', 'piton', 'fournaise', 'session', 'mehetia', 'larchipel', 'guilde', 'Polynesie', 'Daniel_Chester_French', 'Salamine_de_Chypre', 'saintpaul', 'nouvelleamsterdam', 'taaf', 'cest', 'Salamine_de_Chypre', 'haute', 'trouver', 'second', 'culminant', 'loutremer', 'Daniel_Chester_French', 'deux', 'Moi', 'district', 'ultramarin', 'conservation', 'milieu', 'depasser', 'daltitude', 'session', 'culminer', 'piton', 'neige', 'Tahiti', 'montagne', 'orohena', 'atteindre']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<PERSON>', '<LOCATION>', 'Salamine_de_Chypre', 'obtention', 'destrier', 'emotion', 'dautre', 'prodige', 'geologique', 'allegement', 'beaucoup', 'moins', 'eleve', 'plancher', 'davantage', 'calcaire', 'supergrand', 'devenir', 'presquatoll', 'clipperton', 'potentiellement', 'fatu', 'huku', 'marquis', 'Polynesie', 'Daniel_Chester_French', 'atoll', 'surelever', 'grandeterre', 'mariegalant', 'desirade', 'Salamine_de_Chypre', 'petiteterre', 'Guadeloupe', 'saintmartin', 'saintbarthelemy', 'Salamine_de_Chypre', 'allegeance', 'aussi', 'lile', 'pin', 'nouvellecaledonie', 'alofi', 'wallisetfutuna', 'makatea', 'tuamotu', 'borabora', 'huahine', 'larchipel', 'guilde', 'Polynesie', 'Daniel_Chester_French', 'lile', 'tromelin', 'Salamine_de_Chypre', 'eparse', 'locean', 'Indus', 'taaf', 'atoll', 'nombreux', 'Polynesie', 'Daniel_Chester_French', 'egalement', 'ecueil', 'dentrecasteal', 'nouvellecaledonie', 'Salamine_de_Chypre', 'epars', 'locean', 'Indus', 'taaf']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['ailleurs', 'larchipel', 'nouvellecaledonie', 'presente', 'specificite', 'parmi', 'harmonie', 'ilien', 'loutremer', 'Daniel_Chester_French', 'navoir', 'aucun', 'lien', 'pratique', 'volcanique', 'former', 'accueil', 'dobduction', 'rideau', 'audessus', 'dune', 'jeu', 'grunge', 'emerge', 'microcontinent', 'zealandia', 'expliquer', 'aisance', 'pierre', 'ultramafique', 'peridotite', 'lalteration', 'lever', 'ni', 'grand', 'grunge', 'constituer', 'obtention', 'grand', 'Salamine_de_Chypre', 'Daniel_Chester_French', 'lensemble', 'Salamine_de_Chypre', 'prolonge', 'nordouest', 'belep', 'sudest', 'lile', 'pin', 'entourer', 'dun', 'obstacle', 'corail', 'kilometre', 'long', 'deuxieme', 'obtention', 'grand', 'harmonie', 'corallien', 'cosmos', 'apres', 'grand', 'obstacle', 'corail', 'delimiter', 'lun', 'obtention', 'grand', 'Lagune', 'cosmos', 'kilometre']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'Moi', 'district', 'continental', 'Francois-Anatole_Thibault', 'doutremer', 'Guyana', 'grunge', 'adelie', 'femme', 'deux', 'constituant', 'Craton', 'dage', 'precambrien', 'ou', 'predominer', 'pierre', 'metamorphique', 'respectivement', 'plaine', 'Guyana', 'celui', 'dantarctiqu', 'Oriental', 'sands', 'comme', 'plancher', 'immerge', 'possibilite', 'continental', 'femme', 'deux', 'presenter', 'egalement', 'second', 'rotir', 'detr', 'recouverte', 'grand', 'plupart', 'district', 'atmosphes', 'nature', 'specifique', 'tres', 'numero', 'emotion', 'pratique', 'homo_sapiens', 'biseau', 'amazonien', 'premiere_vitesse', 'linlandsi', 'lantarctique', 'minute']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'Francois-Anatole_Thibault', 'dispose', '1000000', 'kilometre', 'carre', 'deal', 'bleu_marine', 'sou', 'cour', 'trois', 'Ocean', 'outremer', 'constituer', 'deuxieme', 'obtention', 'vaste', 'espace', 'economie', 'exclusif', 'cosmos']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'mode', 'Francois-Anatole_Thibault', 'metropolitain', 'fortement', 'influence', 'lanticyclone', 'acore', 'egalement', 'gulf', 'stream', 'comme', 'debris', 'leurope', 'louest', 'disparite', 'regional', 'espace', 'assez', 'marque', 'Francois-Anatole_Thibault', 'metropolitain', 'connaitre', 'evenement', 'climatique', 'repondre', 'important', 'tempete', 'celle', 'decembre', 'abattre', 'arbre', 'biseau', 'francaisesb', 'canicule', 'canicule', 'Europeenne', 'avoir', 'faire', 'mortsb', 'propagateur', 'flux']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'distinguer', 'usuellemer', 'mode', 'oceanique', 'strict', 'tres', 'marque', 'louest', 'setend', 'Flandre_francaise', 'paysage', 'Basque', 'band', 'cotier', 'quelque', 'douze', 'kilometre', 'borne', 'difficile', 'definir', 'obtention', 'etroite', 'nord', "Etats_confederes_d'Amerique", 'obtention', 'general', 'Region_Bretagne', 'concerner', 'quasitotalite', 'mode', 'mode', 'oceanique', 'aquitain', 'sudouest', 'obtention', 'chaud', 'car', 'obtention', "Etats_confederes_d'Amerique", 'mode', 'facade', 'nordouest', 'oceanique', 'obtention', 'fraise', 'mode', 'oceanique', 'aquitain', 'lintensite', 'tempete', 'douest', 'beaucoup', 'obtention', 'fort', 'mode', 'oceanique', 'degrade', 'plaine', 'situer', 'centrenord', 'parfois', 'lancer', '<<', 'Parisien', '>>', 'car', 'correspondre', 'approximativement', 'bassin', 'Parisien', 'lequel', 'mode', 'oceanique', 'obtention', 'faiblement', 'altere', 'mode', 'semicontinental', 'nordest', 'centreest', 'alsac', 'plaine', 'saone', 'moyenrhone', 'plaine', 'dauphinois', 'auvergnat', 'savoyard', 'luimem', 'subdiviser', 'posseder', 'marque', 'encore', 'obtention', 'modifier', 'contiguite', 'massif', 'montagneux', 'mode', 'semicontinental', 'meridional', 'caracteriser', 'mode', 'chaud', 'exister', 'plaine', 'val', 'Rhone', 'epervier', 'lyon', 'ainsi', 'celle', 'forez', 'limagne', 'domaine', 'epervier', 'clermontferrand', 'connaitre', 'mode', 'leffet', 'foehn', 'opinion', 'geographique', 'demi', "Etats_confederes_d'Amerique", 'Francois-Anatole_Thibault', 'mode', 'semicontinental', 'Oriental', 'quant', 'cadeau', 'vignoble_de_Bourgogne', 'jusqual', 'Ardenne', 'plaine', 'basrelief', 'sands', 'meridional', 'Corse', 'ainsi', 'premiere_vitesse', 'val', 'Rhone', 'symetrie', 'soumettre', 'mode', 'Mediterranee', 'enfin', 'mode', 'montagnard', 'cadeau', 'principalement', 'haut', 'alpe', 'pyrener', 'massif', 'echange', 'vosge', 'jura', 'montagn', 'Corse']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'grand', 'jeu', 'Francois-Anatole_Thibault', 'doutremer', 'egalement', 'soumettre', 'mode', 'tropical', 'fort', 'disparitesb', 'auxquels', 'falloir', 'ajouter', 'mode', 'equatorial', 'Guyana', 'mode', 'subarctique', 'saintpierreetmiquelon', 'mode', 'oceanique', 'polaire', 'grunge', 'austral', 'antarctiquer', 'Daniel_Chester_French']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'fievre', "de_l'arithmetique", 'Francois-Anatole_Thibault', 'sest', 'eleve', 'grade_universitaire', "de_l'arithmetique", 'dizaine', 'course', 'xxe', 'siecleb', 'juin', 'verargue', 'thermometre', 'atteint', 'grade_universitaire', 'etablir', 'original', 'record', 'absolu', 'fievre', 'france', 'metropolitain', 'depuis', 'releve', 'exister']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'Francois-Anatole_Thibault', 'metropolitain', 'posseder', 'grand', 'changer', 'scene', 'plaine', 'agricole', 'boisee', 'chaine', 'lac', 'obtention', 'moins', 'eroder', 'sands', 'diversifier', 'val', 'meler', 'New_York', 'personnalite', 'Francois-Anatole_Thibault', 'doutremer', 'posseder', 'quant', 'important', 'biodiversite', 'cas', 'biseau', 'equatorial', 'guyanais', 'Lagune', 'nouvellecaledonie', 'Francois-Anatole_Thibault', 'paysage', 'obtention', 'boiser', 'deurop', 'occidental', 'biseau', 'occuper', 'district', 'metropolitain', 'surface', 'forestiere', 'ville', 'constituer', 'feuillu', 'conifere', 'peuplement', 'mixte', 'espace', 'moiteur', 'concerner', 'potentiellement', 'environ', 'quatrieme', 'surface', 'france', 'fortement', 'regresser', 'depuis', 'xixe', 'cent']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'scene', 'france', 'Loire', 'montsoreau', 'val', 'Loire', 'escarpement', 'detretat', 'Normandie', 'lac', 'timon', 'massif', 'vosge', 'alsac', 'chatenois', 'alsac', 'aiguill', 'dru', 'hautesavoie', 'carrefour', 'dusson', 'massif', 'echange', 'riviere', 'haute', 'montagn', 'hautemaurienn', 'gisement', 'lavande', 'Provence', 'atmosphes', 'moiteur', 'bourbe', 'poitevin', 'calanque', 'piana', 'Corse', 'sable', 'sainteann', 'Guadeloupe', 'biseau', 'tropical', 'amazonien', 'guyane', 'glacier', 'cuisiniere', 'Salamine_de_Chypre', 'kerguelen', 'dune_de_sable', 'pilat', 'nouvelleaquitaine', 'crete', 'van', 'lextremite', 'occidental', 'Region_Bretagne', 'calanqu', 'pierrestombee', 'cassis', 'scene', 'savane', 'niaouli', 'nord', 'hausser', 'Occident', 'grand', 'grunge', 'nouvellecaledonie']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'ce', 'difference', 'scene', 'ecosysteme', 'menacer', 'fragmentation', 'ecologique', 'atmosphes', 'responsabilite', 'dense', 'reseau_informatique', 'grande_route', 'pousser', 'horizontal', 'lurbanisation', 'quil', 'favoriser', 'lartificialisation', 'hausser', 'contamination', 'pipi', 'plancher', 'tierce', 'pipi', 'surface', 'tort', 'voire', 'tres', 'tort', 'specificite', 'principalement', 'matiere', 'contamination', 'industriellesb', 'contamination', 'agricole', 'lier', 'lusage', 'dengrai', 'viande', 'quant', 'lui', 'fortement', 'dommage', 'specificite', 'eau', 'phreatique', 'plusieurs', 'domaine', 'specifique', 'bretagneb', 'littoralisation', 'peuplement', 'activitesb', 'entrain', 'extension', 'densification', 'bati', 'cotesb', 'malgre', 'bill', 'sands', 'lintervention', 'conservatoire', 'littoralb', 'ainsi', 'specificite', 'inondable', 'certain', 'secteur', 'quant', 'base', 'transporteur', 'notamment', 'grande_route', 'elle', 'exposer', 'habitant', 'contamination', 'atmospherique', 'sonore', 'visuel', 'important']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'lempreint', 'copie_conforme', 'Francois-Anatole_Thibault', 'tonne', 'equivaloir', 'co', 'habiter', 'duree', 'obtention', 'important', 'et', 'demographique', 'quantite', 'mondial', 'obtention', 'eleve', "de_l'arithmetique", 'mondial', 'tonne', 'equivaloir', 'co', 'habiter', 'e', 'paysage', 'emetteur', 'dioxyde', 'copie_conforme', 'cumuler', 'depuis', 'Francois-Anatole_Thibault', 'lunion', 'Europeenne', 'engager', 'abaissement', 'television', 'net', 'dici', 'theme', 'television', 'territorial', 'gaz_naturel', 'propos', 'serre|serres', 'Francois-Anatole_Thibault', 'baisse', 'theme', 'Francois-Anatole_Thibault', 'deuxieme', 'paysage', 'emetteur', 'gaz_naturel', 'propos', 'serre|serres', 'mtco', 'e', 'lunion', 'Europeenne', 'derriere', 'lallemagne', 'mtco', 'e', 'television', 'habiter', 'tco', 'e', 'placent', 'e', 'rang', 'lui', 'subordonne', "de_l'arithmetique", 'lire', 'tco', 'e', 'celui', 'lallemagne', 'tco', 'e', 'Francois-Anatole_Thibault', 'biseau', 'grunge', 'agricole', 'raffinement', 'surface_en_herbe', 'constituer', 'dimportant', 'reserve', 'copie_conforme', 'capacite', 'biomasse', 'subsistance', 'biomasse', 'deceder', 'plancher', 'equanimite', 'france', 'metropolitain', 'secteur', 'utcatf', 'presente', 'davantage', 'dabsorption', 'co', 'demission', 'cest', 'salle', 'copie_conforme']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'trace', 'ecologique', 'habiter', 'hectare', 'global', 'hag', 'biocapacite', 'habitant', 'hag', 'Francois-Anatole_Thibault', 'penurie', 'ecologique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'fabrication', 'plastique', 'Francois-Anatole_Thibault', 'avoir', 'augmenter', 'entrer', 'chaque', 'annee', 'tonne', 'dechet', 'plastique', 'Daniel_Chester_French', 'deverser', 'Mediterranee', 'fleuve', 'egalement', 'atteindre', 'contamination', 'microplastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'voie', 'denquet', 'representation', 'indique', 'contamination', 'lair', 'representer', 'prix', 'annuel', 'bill', 'deuro', 'Francois-Anatole_Thibault']
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['supergrand', 'contrat', 'tenter', 'depuis', 'plusieurs', 'dizaine', 'repondre', 'defi', 'environnemental', 'qualification', 'nature', 'parc', 'national', 'ajouter', 'depuis', 'parc', 'nature', 'regional', 'meler', 'conservation', 'rassembler', 'valeur', 'patrimoine', 'nature', 'culturelc', 'couvrir', 'district', 'Daniel_Chester_French', 'six', 'administration_federale', 'leau', 'rassembler', "centre_d'achats", 'gerer', 'revetir', 'avenue', 'pipi', 'paysage', 'grange']
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', 'reseau_informatique', 'naturer', 'mettre', 'site', 'nature', 'seminaturel', 'lunion', 'Europeenne', 'grand', 'valeur', 'patrimonial', 'faune', 'vegetal', 'exceptionnel', 'quils', 'contenir', 'decembre', 'reseau_informatique', 'naturer', 'directoire', 'Francois-Anatole_Thibault', 'site', 'dont', 'site', 'marin', 'comprendre', 'espace', 'protection', 'special', 'zps', 'oiseau_aquatique', 'espace', 'special', 'conservation', 'zsc', 'habitat', 'espece']
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['surface', 'quantite', 'kilometre', 'representer', 'surface', 'terrestre', 'metropolitain', '1000000', 'dhectare', 'surface', 'bleu_marine', 'espace', 'economie', 'exclusif', '1000000', 'dhectare']
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['habkm', 'habkm', 'habkm', 'habkm', 'habkm', 'habkm', 'habkm']
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'Francois-Anatole_Thibault', 'metropolitain', 'marque', 'instabilite', 'spatial', 'multiple', 'dune_de_sable', 'symetrie', 'posseder', 'loriginaliter', 'davoir', 'capitale', 'six', 'duree', 'obtention', 'peupler', 'deuxieme', 'atmosphes', 'dattraction', 'paysn', 'regrouper', 'quatrieme', 'etudiantsi', 'quasitotalite', 'fauteuil', 'grand', 'compagnie', 'paysage', 'dautr', 'symetrie', 'ligne', 'havre', '-', 'marseill', 'souvent', 'considerer', 'comme', 'borne', 'entrer', 'Occident', 'duree', 'rester', 'agricole', 'profit', 'actuellement', 'dun', 'important', 'essor', 'demographique', 'economiquen', 'lindustrie', 'lurbanisation', 'destrier', 'aujourdhuiquand', 'declin', 'enfin', 'Ardenne', 'nordest', 'bruyere', 'sudouest', 'Poker_ferme', '<<', 'diagonal', 'lampadaire', 'densiter', '>>', 'caracteriser', 'peuplement', 'lampadaire', 'comparaison', 'debris', 'paysage', 'economie', 'souvent', 'difficulter']
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['apres', 'long', 'Exode', 'rural', 'xixe', 'cent', 'jusqu', 'deuxieme', 'demi', 'xxe', 'sieclen', 'solde', 'migratoire', 'paysage', 'Daniel_Chester_French', 'redevenir', 'positif', 'annee', 'lessentiel', 'pousser', 'urbain', 'faire', 'espace', 'periurbain', 'obtention', 'obtention', 'eloigner', 'lagglomerationcentren', 'bbs', 'cidessou', 'presente', 'classer', 'office', 'population', 'inclinaison', 'vingt', 'principale', 'espace', 'dattraction', 'New_York', 'cell', 'vingt', 'principale', 'unite', 'urbain', 'celui', 'vingt', 'principale', 'salamandre_tachetee']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'cas', 'etat', 'geographique', 'forme', 'carrefour', 'Europeenne', 'Francois-Anatole_Thibault', 'paysage', 'passageb', 'propos', 'salut', 'obliger', 'male', 'haler', 'circuler', 'facon', 'terrestre', 'entrer', 'peninsule', 'iberique', 'debris', 'leurope', 'ainsi', 'depuis', 'louverture', 'antre', 'sou', 'calendrier', 'entrer', 'royaumeuni', 'continentb', 'heritage', 'lhistoire', 'reseau_informatique', 'transporteur', 'Daniel_Chester_French', 'tres', 'centraliser', 'epervier', 'parisb', 'ce', 'centralisation', 'particulierement', 'fort', 'transporteur', 'ferroviaire', 'ante', 'si', 'debut', 'diminuer']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', 'transporteur', 'grande_route', 'clef', 'facon', 'transporteur', 'grace', 'Francois-Anatole_Thibault', 'representer', 'echange', 'voyager', 'echange', 'marchandisesn', 'Francois-Anatole_Thibault', 'directoire', 'pres', '1000000', 'kilometre', 'grande_route', 'dont', 'quasitotalite', 'revetir', 'depuis', 'dissemination', 'Francois-Anatole_Thibault', 'sest', 'doter', 'dun', 'reseau_informatique', 'autoroutier', 'etendre', 'totaliser', 'kilometre', 'depuis', 'quelque', 'dizaine', 'gouvernement', 'contrat', 'sattacher', 'reduire', 'malchance', 'meurtrier', 'grande_route', 'dont', 'principale', 'matiere', 'identifier', 'rapidite', 'lalcoolj', 'chasser', 'promouvoir', 'dautre', 'facon', 'transporteur', 'moins', 'pollution', 'auto', 'individuellei']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'reseau_informatique', 'ferre', 'national', 'datte', 'lessentiel', 'atmosphes', 'propos', 'xixe', 'cent', 'directoire', 'environ', 'kilometre', 'ligne', 'dont', 'obtention', 'demi', 'electrifier', 'kilometre', 'ligne', 'grand', 'rapidite', 'lessentiel', 'echange', 'gerer', 'guilde', 'anonyme', 'capitale', 'contrat', 'sncf', 'ligne', 'appartenir', 'letat', 'attribuer', 'sncf', 'reseau_informatique', 'filiale', 'guilde', 'depuis', 'annee', 'echange', 'voyager', 'augmenter', 'Francois-Anatole_Thibault', 'remerciement', 'portee', 'ursides', 'domaine', 'echange', 'regional', 'espace', 'surtout', 'remerciement', 'emergence', 'lextension', 'continuer', 'reseau_informatique', 'ligne', 'grand', 'rapidite', 'parcourir', 'tgv', 'ristourne', 'echange', 'cargo', 'constant', 'epuisement', 'ailleurs', 'principale', 'New_York', 'paysage', 'doter', 'dun', 'reseau_informatique', 'ferroviaire', 'urbain', 'male', 'metropolitain', 'pari', 'lyon', 'lille', 'marseill', 'toulous', 'reindeer', 'tramway', 'pari', 'lyon', 'marseill', 'nante', 'strasbourg', 'vins_de_Bordeaux', 'toulous', 'grenobl', 'Montpellier', 'Nice', 'notamment', 'rer', 'pari', 'metropolitain', 'pari', 'naitre', 'forme', 'lun', 'reseau_informatique', 'obtention', 'destrier', 'dense', 'cosmos']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', '<LOCATION>', 'transporteur', 'ante', 'particulierement', 'centraliser', 'deux', 'airport', 'Parisien', '--', 'roissycharlesdegaull', 'Orly', '--', 'accueillir', '1000000', 'passager', 'alors', 'premiere_vitesse', 'airport', 'regional', 'nicecote', 'dazur', 'accueillir', '1000000', 'airport', 'regional', 'propos', 'concurrencer', 'tgv', 'echange', 'national', 'bien_que', 'airport', 'Parisien', 'accueillent', 'quasitotalite', 'echange', 'longcourrierb', 'Francois-Anatole_Thibault', 'egalement', 'fauteuil', 'satellite', 'premiere_vitesse', 'compagnie', 'ante', 'mondial', 'numero', 'passager', 'transporte', 'air', 'franceklm', 'premiere_vitesse', 'producteur', 'aeronautique', 'civil', 'airbusb', 'deurope', 'deuxieme', 'cosmos']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'dautre', 'facon', 'transporteur', 'grace', 'Francois-Anatole_Thibault', 'obtention', 'marginal', 'echange', 'fluvial', 'assurer', 'symetrie', 'negligeable', 'echange', 'voyager', 'tres', 'secondaire', 'echange', 'haler', 'principalement', 'cas', 'linadaptation', 'dun', 'grand', 'jeu', 'reseau_informatique', 'echange', 'moderne', 'echange', 'maritime', 'important', 'caler', 'deuxieme', 'interface', 'mondial', 'echange', 'passager', 'concerner', 'cargo', 'maritime', 'interface', 'Dunkerque', 'havre', 'nante', '-', 'saintnazair', 'vins_de_Bordeaux', 'moins', 'important', 'rival', 'ocean', 'nord', 'comme', 'celui', 'Rotterdam', 'danver', 'hambourg', 'desormais', 'largement', 'devancer', 'celui', 'damsterdam', 'bremebremerhaven', 'interface', 'marseille', 'premiere_vitesse', 'rang', 'Daniel_Chester_French', 'echange', 'premiere_vitesse', 'terminus', 'deurop', 'croisiere', 'deuxieme', 'interface', 'Mediterranee', 'derriere', 'algesira', 'Espagne']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', 'depuis', 'reseau_informatique', 'urbain', 'avenue', 'cyclable', 'developper', 'ainsi', 'motocyclette', 'libreservice', 'plusieurs', 'New_York', 'paysi', 'specificite', 'amenagement', 'tres', 'inegal', 'selon', 'district', 'linfrastructure', 'cyclable', 'faire', 'pres', 'kilometre', 'dont', 'avenue', 'cyclable', 'comptabiliser', 'velo', 'veloroute', 'grande_route', 'grand', 'longueur', 'demi', 'foyer', 'posseder', 'bicyclette', 'environ', 'Daniel_Chester_French', 'grace', 'motocyclette', 'voie', 'domiciletravail', 'environ', 'population', 'ce', 'lampadaire', 'symetrie', 'sexpliqu', 'vulnerabilite', 'motocyclette', 'grande_route', 'cycliste', 'perdre', 'faune', 'erratum', 'dinfrastructure', 'suffisant', 'jeu', 'veloroute', 'Daniel_Chester_French', 'sintegr', 'reseau_informatique', 'Europeenne', 'nommer', 'eurovelo', 'propos', 'lancer', 'federation', 'cycliste', 'Europeenne', 'depuis', 'integre', 'propos', 'rtet', 'lunion', 'Europeenne', 'Francois-Anatole_Thibault', 'avenue', 'eurovelo', 'cadeau', 'permission', 'connecter', 'Francois-Anatole_Thibault', 'leurope', 'facon', 'cyclable', 'celer', 'permission', 'faire', 'dell', 'deuxieme', 'destination', 'mondial', 'cyclotourisme']
#
# Document : Histoire (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', '<PERSON>', '<LOCATION>', 'Francois-Anatole_Thibault', 'metropolitain', 'flux', 'occuper', 'obtention', 'grand', 'jeu', 'lancienne', 'gaul', 'celte', 'conquerir', 'jules', 'Atom_Heart_Mother', 'ier', 'cent', 'av', 'jc', 'tire', 'souci', 'frank', 'phratrie', 'germanique', 'sy', 'installer', 'conge', 've', 'cent', 'Francois-Anatole_Thibault', 'responsabilite', 'dont', 'lunification', 'destrier', 'lun', 'premiere_vitesse', 'paysage', 'lepoque', 'moderne', 'tenter', 'experimentation', 'democratique']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', 'controle', 'homo_sapiens', 'district', 'Francois-Anatole_Thibault', 'flux', 'remont', 'Paleolithique', 'subordonne', 'empreinte', 'obtention', 'destrier', 'faune', 'homo_sapiens', 'dater', 'dil', 'conservation', 'environ', 'baie', 'lhomme', 'alors', 'confronte', 'mode', 'rude', 'etoile_variable', 'marque', 'plusieurs', 'epoque', 'glaciaire', 'modifier', 'forme', 'viee', 'Francois-Anatole_Thibault', 'directoire', 'numero', 'important', 'Grotte#Culture', 'orner', 'Paleolithique', 'haut', 'dont', 'deux', 'obtention', 'celebre', 'Grotte#Culture', 'lascauxe', 'dordogne', 'environ', 'Grotte#Culture', 'chauvet', 'bridge', 'darc', 'environ']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['vers', 'propos', 'lever', 'epoque', 'glaciaire', 'mode', 'sadoucite', 'conge', 'environ', 'leurope', 'occidental', 'entrer', 'neolithique', 'habitant', 'sedentarisent', 'si', 'levolution', 'different', 'selon', 'regionse', 'apres', 'fort', 'pousser', 'demographique', 'agricole', 'iv', 'iii', 'millenaire', 'metallurgie', 'faire', 'cas', 'propos', 'iiie', 'millenaire', 'dabord', 'coutume', 'lor', 'laiton', 'bronze', 'pouvoir', 'celui', 'chaine', 'viiie', 'cent']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens prétraités : ['<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'Tsitsit', 'originaire', 'New_York', 'phocer', 'degeler', 'New_York', 'marseille', 'cor', 'mediterraneee', "un_point_c'est_tout", 'quelque', 'phratrie', 'celte', 'penetrer', 'district', 'Francois-Anatole_Thibault', 'flux', 'ce', 'job', 'generaliser', 'entierete', 'district', 'quentre', 've', 'iiie', 'cent', 'av', 'jce', 'concept', 'gaule', 'galatia', 'Tsitsit', 'apparaitre', 'alors', 'correspondre', 'district', 'peuplement', 'celte', 'compris', 'entrer', 'Rhin', 'pyrener', 'latlantiqu', 'mediterraneee']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# ...
#
# Document : Investir dans l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', '<PERSON>', 'ce', 'hypothese', 'douleur', 'cependant', 'expliquer', 'lattrer', 'filiere', 'educatif', 'privilegier', 'raffinement', 'ensemble', 'theme', 'celui', 'proposer', 'train', 'operationnel', 'humain', 'avoir', 'priori', 'obtention', 'mobilisable', 'echange', 'coutume', 'speculation', 'alternatif', 'hypothese', 'signalisation', 'avoir', 'donc', 'developper', 'annee', 'Canadiens_francais', 'michael', 'spence', 'retrouver', 'opinion', 'similaire', 'verticille', 'filtrage', 'assigner', 'cadre', 'educatif', 'kenneth', 'arrow']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['leducation', 'domaine', 'effectuer', 'college', 'contrat', 'college', 'detective', 'linstruction', 'residence', 'egalement', 'possible', 'debris', 'minorite', 'cependant', 'tension', 'developper']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['lhypothese', 'lexistence', 'dun', '<<', 'echange', 'educatif', '>>', 'tuyau', 'instabilite', 'decoupage', 'social', 'ecolier', 'gerance', 'scolaire', 'evoquer', 'composant', 'favoriser', 'lexistence', 'echange', 'dun', 'symetrie', 'capitale', 'financier', 'ex-mari', 'habitat', 'circonscription', 'aiser', 'proche', 'dun', 'college', 'considerer', 'comme', 'specificite', 'etou', 'option', 'payer', 'fraise', 'pedagogique', 'acceder', 'certain', 'gerance', 'priver', 'dautr', 'symetrie', 'capitale', 'culturel', 'savoir-faire', 'projet', 'acceder', 'meilleur', 'gerance', 'strate', 'notamment', 'la_soupe_au_canard', 'doptier', 'savoir', 'deux', 'composant', 'supergrand', 'etre', 'cumulatif']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['sembler', 'plusieurs', 'paysage', 'largent', 'important', 'reussite', 'educatif', 'donne', 'option', 'dacceder', 'recommandation', 'Moi', 'course', 'nuit', 'visiter', 'philologie', 'pratique', 'culturel', 'permission', 'payer', 'fraise', 'dentrer', 'gerance', 'selectif', 'primaire', 'secondaire', 'haut']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['selon', 'paysage', 'decoupage', 'publicprive', 'differ', 'femme', 'comme', 'quantite', 'daide', 'contrat', 'destination', 'college', 'detective', 'ainsi', 'forme', 'contrat', 'lier', 'lobtention', 'subvention', 'contrat', 'obtention', 'fraise', 'dinscription', 'enseignement', 'fourniture', 'supergrand', 'varier']
#
# Document : Canada (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['college', 'priver', 'payanter', 'quantite', 'fraise', 'supergrand', 'etre', 'obstacle', 'mixte', 'social', 'quantite', 'subvention', 'contrat', 'plafonner']
#
# Document : France (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', 'Francois-Anatole_Thibault', 'lecol', 'contrat', 'gratuit', 'jusqua', 'propos', 'enseignement', 'obligatoire', 'dans', 'fraise', 'varier', 'souvent', 'exiger', 'college', 'detective', 'supergrand', 'tuyau', 'exclur', 'lacce', 'ecolier', 'phratrie', 'obtention', 'precaire', 'ecstasy', 'lencontre', 'regle', 'daccessibilite', 'viser', 'leducation', 'femme']
#
# Document : Sources (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', 'ce', 'regle', 'partiellement', 'entierete', 'issu', 'supplement', '<<', 'dechiffrer', 'code', 'leducation', 'gamine', 'femme', 'savoir', 'recherche_appliquee', 'ingenieri', 'mathematique', 'stem', '>>', 'unesco', 'projet', 'endroit', 'generateur', 'responsable', 'probleme', 'sou', 'cc', 'bysa', 'igo']
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', 'philippe', 'aries', 'dir', 'georges', 'duby', 'dir', 'p', 'Brown', 'evelyn', 'patlagean', 'michel', 'rouche', 'yvon', 'thebert', 'paul', 'veyne', 'description', 'faune', 'priver', 'avion', 'lempire', 'police_romaine', 'lan', 'mil', 'pari', 'redactrices_en_chef', 'huis', 'penis', 'isbn']
#
# Document : Notes et références (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<PERSON>', '<PERSON>', '<LOCATION>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<LOCATION>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '|', 'monde', '|', 'forme', 'educatio', 'gaffiot', 'latinfrancer', '|', 'mialaret', 'gramme', 'savoir', 'formation', 'puf', 'saisje', 'no', 'e', 'redactrices_en_chef', '|', 'httpswwwcairninforevueletelemaque', 'supplement', 'Hypertext_Markup_Language', '|', 'dessu', 'philipp', '<<', "qu'", 'estce', 'enseignemer', 'quelque', 'forme', 'prescription', '>>', 'revue', 'Daniel_Chester_French', 'enseignement', 'rechercher', 'formation', 'ens', 'redactrices_en_chef', 'no', '', 'ER', 'juillet', 'penis', '-', 'isbn', 'issn', 'doi', 'rfp', 'lire', 'ligne', 'consulter', 'novembre', '|', 'aries', 'penis', '|', 'jeanjacque', 'rousseau', 'emil', 'leducation', 'lire', 'wikisource', 'penis', '|', 'pdf', 'projet', 'officiel', 'leducation', 'forme', 'femme', 'forme', 'savoir-faire', 'methodologique', 'sociale', 'viser', '|', 'Sarah', 'currier', 'sheila', 'macneill', 'lisa', 'corley', 'lorna', 'Campbell', 'helen', 'beetham', 'dictionnaire', 'decrire', 'avancee', 'pedagogique', 'obtention', 'ligne', 'explorer', 'cadrage', 'numero', 'ametist', 'ametist', 'lire', 'ligne', '|', 'Benjamin', 'rougir', 'David', 'r', 'krathwohl', 'the', 'nomenclature', 'of', 'educational', 'goal', 'by', 'avoir', 'committee', 'of', 'college', 'and', 'university', 'explorer', 'new', 'York', 'longmans', '|', 'Sarah', 'mcneil', '<<', 'blooms', 'taxonomy', 'of', 'the', 'cognitif', 'domain', '>>', 'instructional', 'design', 'university', 'of', 'houston', 'consulter', 'jan', '<<', 'work', 'the', 'cognitif', 'domain', 'was', 'completed', 'in', 'and', 'is', 'commonly', 'referred', 'to', 'blooms', 'taxonomy', 'of', 'the', 'cognitif', 'domain', 'although', 'there', 'were', 'other', 'authors', 'englehart', 'e', 'furst', 'w', 'hill', 'and', 'krathwohl', '>>', '|', 'wolf', 'marcus', 'extrusion', 'math', 'estelle', 'mal', 'mental', 'ed', 'trouver', '|', 'Marc', 'bris', 'progeniture', 'savoir', 'lire', '...', 'ni', 'comte', 'stock', '|', 'tiehi', '|', '<<', 'majority', 'of', 'children', 'live', 'with', 'two', 'biological', 'parent', '>>', 'archiv', 'Avril', 'consulte', 'juillet', '|', "La_Tragedie_d'Hamlet", 'Tyndale', 'shakespeare', 'scene', 'iii', '|', 'college', 'sain', 'comme', 'penis', 'dapprentissage', '|', 'George_du_Maurier', 'zacharopoulos', 'francesco', 'sella', 'baron', 'cohen', 'kadosh', '<<', 'the', 'impact', 'of', 'avoir', 'lack', 'of', 'mathematical', 'education', 'brain', 'developmer', 'and', 'avenir', 'attainment', '>>', 'pnas', 'juin', 'lire', 'ligne', 'consulter', 'San_Pedro_Sula', 'doi', 'pna', '|', 'administration_federale', 'courtier', 'special', 'messager_sagittaire', 'ensemble', 'voie', 'proposition', 'acharnement', 'contre', 'progeniture', 'venir', 'terme', 'acharnement', 'college', 'combler', 'repartition', 'entrer', 'standard', 'pratique', 'pari', 'onu', 'lire', 'ligne', 'p', '|', 'pierart', 'g', 'betrisey', 'tetreault', 'margotcattin', 'robot', 'margotcattin', 'penis', 'linclusion', 'scolaire', 'progeniture', 'defaut', 'tamias', 'romand', 'proposition', 'gouvernement', 'contrat', 'in', 'numero', 'xxi', 'copulation', 'airhm', 'Quebec', 'pp', 'quebec', 'imprimerie', 'college', 'Quebec', '|', '<<', 'defining', 'quality', 'in', 'education', '>>', 'right', 'to', 'education', 'initiativ', 'consulter', 'juillet', '|', '<<', 'contradicting', 'commitment', 'how', 'the', 'achievemer', 'of', 'education', 'for', 'all', 'is', 'being', 'undermined', 'by', 'the', 'international', 'monetary', 'fund', '>>', 'right', 'to', 'education', 'initiativ', 'consulter', 'juillet', '|', '<<', 'repor ...
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['autre', 'propos', 'wikimedia']
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['formation', 'wikimedia', 'commonseducation', 'wiktionnaireeducation', 'wikiversityeducation', 'wikibookseducation', 'wikisourceeducation', 'wikiquoteeducation', 'wikinews']
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<PERSON>', '<LOCATION>', 'Dylan_Thomas', 'koninck', 'original', 'ignorance', 'specificite', 'raffinement', 'pari', 'puf', 'intervention', 'philosophique', 'reediter', 'traduire', 'portuger', 'thomas', 'koninck', 'gouvernement', 'leducation', 'traite', 'devenir', 'homo_sapiens', 'introduction', 'federico', 'mayor', 'zaragoza', 'postface', 'e', 'mohamed', 'achaari', 'alain', 'chanlat', 'abdelkarim', 'errouaki', 'pari', 'puf', 'Themis', 'penis', 'erny', 'ethnologie', 'leducation', 'ed', 'lharmattan', 'penis', 'description', 'leducation', 'revue', 'Jessye_Norman', 'baillargeon', 'lordre', 'moins', 'supergrand', 'description', 'actualite', 'lanarchisme', 'agone', 'lux', 'redactrices_en_chef']
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', 'emil', 'formation', 'jeanjacque', 'rousseau', 'wikisource', 'leducation', 'progeniture', 'plutarqu', 'pedagogue', 'specialise', 'gregory', 'degenaer', 'redactrices_en_chef', 'ash']
#
# Document : Articles connexes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', '<PERSON>', '<LOCATION>', 'obtention', 'autoformation', 'cateches', 'college', 'college', 'manoir', 'economie', 'leducation', 'formation', 'lenvironnement', 'pousser', 'immobilisation', 'formation', 'pousser', 'formation', 'populaire', 'formation', 'socioculturel', 'lenseignemer', 'agricole', 'france', 'formation', 'specialise', 'enseignement', 'train', 'continuer', 'description', 'leducation', 'journee', 'international', 'leducation', 'enseignement', 'reciprocite', 'lernen', 'durch', 'lehren', 'ldl', 'espace', 'deducation', 'mixte', 'social', 'france', 'unesco', 'gerance', 'etat', 'unir', 'leducation', 'savoir', 'raffinement', 'empreinte', 'formation', 'enseignement', 'plasticiter', 'neuronal', 'psychologie', 'pousser', 'calendrier', 'denseignement']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : []
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', '<LOCATION>', '<PERSON>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', '<LOCATION>', 'avenue', 'respecter', 'documentation', 'the', 'encyclopedier', 'of', 'savoir', 'fiction', 'avenue', 'respecter', 'bien-etre', 'medical', 'subject', 'heading', 'notice', 'tableau_associatif', 'encyclopedie', 'docteur', 'britannica', 'den', 'lunettes_de_soleil', 'dansk', 'encyklopaedi', 'dictionnair', 'historique', 'tamias', 'encyclopedia', 'of', 'cleveland', 'history', 'encyclopedia', 'of', 'the', 'great', 'plain', 'gran', 'enciclopedia', 'aragonesa', 'gran', 'enciclopedia', 'catalana', 'handbook', 'of', 'texa', 'onlin', 'universali', 'Utah', 'history', 'encyclopedia', 'the', 'west', 'virginia', 'encyclopedia', 'notice', 'dautorite', 'lccn', 'gnd', 'japonais', 'Espagne', 'Israel', 'tchequi', 'Lettonie', 'forme', 'analyse_qualitative', 'gouvernement', 'educatif', 'ocde', 'education', 'docteur', 'planifier', 'leducation', 'construir', 'lavenir', 'institut', 'international', 'conception', 'leducation', 'unesco', 'pousser', 'curriculum', 'cadre', 'scolaire', 'mondial', 'hstreasure', 'institut', 'decouverte', 'linnovation', 'leducation', 'irie', 'policier', 'leducation', 'veine_porte', 'policier', 'lenfer', 'humanium', 'procureur', 'leducation', 'Quebec', 'intervention', 'educatif', 'clarification', 'conceptuel', 'enjeux', 'social', 'yve', 'lenoir', 'canader', 'veine_porte', 'lenseignemer', 'federation', 'walloniebruxelles', 'belgiqu']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['the', 'encyclopedier', 'of', 'savoir', 'fiction']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', 'medical', 'subject', 'heading']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', '<LOCATION>', '<PERSON>', 'britannicer', 'den', 'lunettes_de_soleil', 'dansk', 'encyklopaedi', 'dictionnair', 'historique', 'tamias', 'encyclopedia', 'of', 'cleveland', 'history', 'encyclopedia', 'of', 'the', 'great', 'plain', 'gran', 'enciclopedia', 'aragonesa', 'gran', 'enciclopedia', 'catalana', 'handbook', 'of', 'texa', 'onlin', 'universali', 'Utah', 'history', 'encyclopedia', 'the', 'west', 'virginia', 'encyclopedia']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', 'lccn', 'gnd', 'japonais', 'Espagne', 'Israel', 'tchequi', 'Lettonie']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['raffinement', 'ensemble', 'raffinement', 'legitimite', 'raffinement', 'Lot', 'raffinement', 'populaire', 'contreculture', 'sousculture', 'capitale', 'culturel', 'tradition', 'raffinement', 'oral', 'civilisation', 'raffinement', 'ethologi']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['socialisation', 'formation', 'acculturation', 'acculturation', 'transculturation', 'rayonnemer', 'culturel', 'hegemonie', 'culturel', 'ethnocide']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<PERSON>', 'evolutionnisme', 'diffusionnisme', 'fonctionnalism', 'culturalisme', 'ligne', 'penis', 'bourdieu', 'structuralisme']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['anthropologie', 'anthropologie', 'culturel', 'anthropologie', 'psychanalytique', 'astronomie', 'culturel', 'trouble_de_la_personnalite', 'culturel', 'ethnomedecine', 'ethnographie', 'ethnologie', 'ethnopsychiatrie', 'ethnopsychanalyse', 'ethnopharmacologie', 'ethnobiologie', 'ethnozoologie', 'ethnoentomologie', 'ethnobotanique', 'ethnoornithologie', 'ethnoichthyologie', 'ethnoherpetologie', 'ethnoprimatologie', 'ethnomycologie', 'ethnolichenologie', 'ethnoecologie', 'ethnohistoir', 'ethnoarcheologie', 'ethnomathematique', 'ethologie', 'ecologie', 'culturel', 'anthropologie', 'ecologique', 'geographie', 'culturel', 'neuroscience', 'culturel', 'explorer', 'culturel', 'description', 'culturel', 'culturologie', 'hypothese', 'raffinement', 'neuroculture', 'bioculture', 'explorer', 'culturel', 'comparaison', 'psychologie', 'culturel', 'psychologie', 'interculturel', 'psychologie', 'interculturel', 'pousser', 'analyse_qualitative', 'culturel', 'economie', 'culturel', 'cartographi', 'culturel', 'culturomiqu', 'obtention', 'interculturel', 'radicalisme', 'culturel', 'sociologie', 'raffinement', 'semiologie', 'raffinement', 'sociologie', 'gouvernement', 'raffinement', 'theologie', 'raffinement', 'explorer', 'raffinement', 'populaire', 'propos', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens prétraités : ['<LOCATION>', 'veine_porte', 'formation', 'veine_porte', 'guilde', 'veine_porte', 'raffinement', 'veine_porte', 'policier', 'veine_porte', 'sociologie']

# %% [markdown]
# Calcul de TF

# %%
from collections import Counter

# fonction pour calculer TF (nombre d'occurrences d'un mot dans un document spécifique) pour chaque document
def calculate_tf_occurrences(processed_documents):
    tf_documents = []
    for doc in processed_documents:
        # Compter le nombre d'occurrences des tokens dans le document
        token_counts = Counter(doc['tokens'])

        tf_documents.append({
            'url': doc['url'],
            'title': doc['title'],
            'tf': token_counts  # stocker les occurrences directement
        })

    return tf_documents

tf_documents = calculate_tf_occurrences(processed_documents)

# %% [markdown]
# affichage de tf

# %%
# fonction pour afficher uniquement les TF en nombre d'occurrences
def display_tf(tf_documents):
    print("\nTerm Frequency (Nombre d'occurrences) pour chaque document :\n")
    for doc in tf_documents:
        print(f"Document : {doc['title']} (URL: {doc['url']})")
        print("TF :")
        for token, tf_value in doc['tf'].items():
            print(f"   {token}: {tf_value}")
        print("\n")

display_tf(tf_documents)
# Out:
# Streaming output truncated to the last 5000 lines.
#    brique: 2
#    pierre: 1
#    dur: 1
#    etat: 1
#    industrie_mecanique: 1
#    specifique: 1
#    comme: 4
#    pierre_a_fusil: 1
#    responsabilite: 1
#    etre: 3
#    ceinture: 1
#    percuteur: 2
#    egalement: 1
#    facon: 2
#    detacher: 2
#    demolition: 1
#    ce: 1
#    bill: 1
#    rendement: 1
#    cor: 1
#    tranchant: 1
#    duree: 1
#    tailler: 2
#    leclat: 2
#    avoir: 1
#    femme: 1
#    deux: 1
#    supergrand: 3
#    grace: 2
#    forme: 2
#    caillou: 1
#    mutation: 1
#    racloir: 1
#    premiere_vitesse: 3
#    homo_sapiens: 1
#    chasseurscueilleur: 1
#    executer: 1
#    differents: 1
#    job: 1
#    dont: 1
#    entaille: 1
#    viande: 2
#    fissure: 1
#    pomme: 1
#    acceder: 1
#    osseux: 1
#    coiffure: 1
#    louverture: 1
#    walnut: 1
#    depouillemer: 1
#    carcasse: 1
#    faune: 2
#    recuperer: 1
#    cacher: 1
#    sequence: 1
#    dautre: 1
#    materiel: 1
#    tension: 2
#    los: 1
#    relativement: 1
#    numero: 2
#    elabore: 1
#    techniquement: 1
#    impliquer: 1
#    controle: 1
#    dun: 2
#    important: 1
#    parametre: 1
#    compilation: 2
#    respecter: 1
#    force: 1
#    gifle: 1
#    biais: 1
#    percussion: 1
#    etc: 2
#    hors: 1
#    portee: 1
#    tout: 1
#    espece: 1
#    lexception: 1
#    lhomme: 1
#    lacheuleen: 1
#    conservation: 3
#    1000000: 1
#    danner: 1
#    original: 2
#    methodologie: 1
#    haut: 2
#    apparaitre: 1
#    maturation_moleculaire: 1
#    traduire: 1
#    doutil: 1
#    complique: 1
#    biface: 1
#    hachereau: 1
#    dans: 2
#    Paleolithique: 2
#    caracteriser: 1
#    abstraction: 1
#    debitage: 2
#    levalloi: 1
#    permission: 2
#    accueil: 1
#    declat: 1
#    predeterminer: 1
#    depens: 1
#    nucleus: 1
#    environ: 1
#    lame: 1
#    generalise: 1
#    Burin: 1
#    scrapeur: 1
#    technique: 1
#    retouche: 1
#    attester: 1
#    des: 1
#    middle: 1
#    ston: 1
#    age: 1
#    afrique: 1
#    Etats_confederes_d'Amerique: 1
#    retoucher: 1
#    certain: 1
#    crete: 2
#    missile: 1
#    Moi: 1
#    temoignage: 1
#    laurier_sauce: 1
#    nerf: 1
#
#
# Document : Paléolithique (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <LOCATION>: 2
#    <PERSON>: 1
#    trouver: 2
#    lexploitation: 1
#    angle: 4
#    devenir: 1
#    levolution: 1
#    technologique: 1
#    sexualite: 1
#    homo_sapiens: 1
#    datte: 1
#    exact: 1
#    inconnu: 1
#    controle: 1
#    do: 1
#    danimau: 1
#    brule: 1
#    domaine: 1
#    cradle: 1
#    of: 1
#    humankind: 1
#    cinquantaine: 1
#    kilometre: 1
#    louest: 1
#    johannesburg: 1
#    sugger: 1
#    domestication: 1
#    apparaitre: 1
#    obtention: 1
#    dun: 1
#    1000000: 1
#    danner: 1
#    avant: 2
#    cadeau: 2
#    democratie: 1
#    esprit: 1
#    quasi: 1
#    unanime: 1
#    considerer: 1
#    homo: 1
#    erectu: 1
#    avoir: 1
#    controler: 1
#    alentours: 1
#    alimenter: 1
#    biseau: 1
#    egalement: 1
#    copie_conforme: 1
#    permission: 1
#    premiere_vitesse: 1
#    male: 1
#    chef: 1
#    nutriment: 1
#    den: 1
#    ameliorer: 1
#    digestibilite: 1
#    valeur: 2
#    conservation: 1
#    nutritif: 1
#    diversifier: 1
#    changer: 1
#    disponibilite: 1
#    possible: 1
#
#
# Document : Paléolithique (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    dautre: 1
#    avancee: 1
#    technologique: 1
#    faire: 1
#    pendant: 1
#    Paleolithique: 1
#    epoque: 1
#    ou: 1
#    apparu: 1
#    habillement: 2
#    lhabitation: 1
#    ladoption: 1
#    respectivement: 1
#    deux: 1
#    pratique: 1
#    supergrand: 1
#    etre: 1
#    exactement: 1
#    dater: 1
#    lui: 1
#    lun: 1
#    lautre: 1
#    opinion: 1
#    cler: 1
#    lhistoire: 1
#    avancer: 1
#    lhumanite: 1
#    adapter: 1
#    barbe_de_trois_jours: 1
#    cacher: 1
#    faune: 2
#    chasseur: 1
#    cooperant: 1
#    homo_sapiens: 1
#    evoluer: 1
#    obtention: 2
#    indifferemmer: 1
#    domaine: 1
#    froid: 1
#
#
# Document : Du Néolithique à l'Antiquité classique (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    lascension: 1
#    technologique: 1
#    lhomme: 1
#    sest: 1
#    accelerer: 1
#    lors: 1
#    age: 2
#    neolithique: 1
#    <<: 1
#    original: 1
#    penis: 2
#    >>: 1
#    linvention: 1
#    hache: 1
#    culture: 1
#    avancee: 1
#    considerable: 1
#    car: 1
#    avoir: 2
#    permission: 2
#    defrichement: 1
#    grand: 2
#    gamme_musicale: 1
#    biseau: 1
#    surface: 1
#    grande_route: 1
#    future: 1
#    cosmos: 1
#    exploitation: 1
#    trouver: 1
#    lagriculture: 1
#    lalimentation: 1
#    dun: 1
#    obtention: 3
#    population: 1
#    aussi: 1
#    conversion: 1
#    vers: 1
#    facon: 3
#    faune: 3
#    sedentaire: 1
#    augmenter: 1
#    numero: 1
#    denfant: 1
#    supergrand: 2
#    etre: 1
#    simultanement: 1
#    elever: 1
#    voir: 1
#    progeniture: 3
#    navaient: 1
#    travailleur: 1
#    detr: 1
#    transporteur: 1
#    comme: 1
#    ceter: 1
#    type: 1
#    panache: 1
#    nomade: 1
#    outre: 1
#    contribuer: 1
#    job: 1
#    agricole: 1
#    constant: 1
#    chasseurcueilleur: 1
#
#
# Document : Du Néolithique à l'Antiquité classique (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <LOCATION>: 1
#    laugmentation: 1
#    population: 1
#    priorite: 1
#    coutume: 1
#    disponible: 1
#    autoriser: 1
#    elargissement: 1
#    specialisation: 2
#    job: 2
#    contre: 1
#    debris: 1
#    clarifier: 1
#    raison: 1
#    yak: 1
#    carrefour: 1
#    neolithique: 1
#    evoluer: 1
#    vers: 2
#    premiere_vitesse: 2
#    New_York: 1
#    comme: 2
#    uruk: 1
#    grand: 1
#    civilisation: 1
#    Shumer: 1
#    gouvernement: 1
#    cependant: 1
#    lemergence: 1
#    structure: 2
#    social: 1
#    obtention: 2
#    hierarchique: 1
#    echanger: 1
#    guerre: 1
#    entrer: 1
#    raffinement: 1
#    adjacent: 1
#    travailleur: 1
#    daction: 1
#    collectif: 1
#    surmonter: 1
#    defi: 1
#    environnemental: 1
#    Moi: 1
#    turcie: 1
#    barrage: 1
#    femme: 1
#    jeu: 1
#    verticille: 1
#    ce: 1
#    changer: 1
#
#
# Document : Du Néolithique à l'Antiquité classique (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 2
#    avancer: 1
#    continuel: 1
#    amener: 1
#    ulterieurement: 1
#    cas: 1
#    portee: 1
#    ventilation: 1
#    avoir: 1
#    fournir: 1
#    capacite: 1
#    degeler: 1
#    forger: 1
#    dabord: 1
#    metal: 4
#    obtention: 1
#    accessible: 1
#    celui: 2
#    cadeau: 1
#    personnalite: 1
#    sou: 1
#    forme: 1
#    relativement: 1
#    nettoyer: 1
#    premiere_vitesse: 3
#    ainsi: 1
#    job: 1
#    lor: 1
#    laiton: 6
#    largent: 1
#    plomb: 1
#    certain: 1
#    salut: 1
#    penis: 3
#    pomme: 1
#    biseau: 2
#    apparu: 1
#    rapidement: 1
#    probablement: 1
#    grace: 1
#    duree: 1
#    vers: 2
#    declenchement: 1
#    neolithique: 1
#    environ: 2
#    av: 3
#    jc: 3
#    trouver: 3
#    naturellement: 1
#    grand: 1
#    quantique: 1
#    assez: 2
#    communement: 1
#    minerai: 1
#    transforme: 1
#    facilement: 1
#    quand: 1
#    brule: 1
#    laide: 1
#    angle: 1
#    alimenter: 1
#    copie_conforme: 1
#    long: 1
#    coutume: 1
#    finira: 1
#    tuyau: 1
#    Moi: 2
#    bronze: 1
#    consommation: 1
#    dalliage: 1
#    chaine: 1
#    lacier: 1
#    dater: 1
#    dil: 1
#    conservation: 1
#    dans: 1
#
#
# Document : Époque contemporaine (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <LOCATION>: 1
#    malgre: 1
#    progres: 1
#    important: 1
#    lever: 1
#    dizaine: 1
#    lenseignement: 1
#    recherche_appliquee: 2
#    n': 1
#    universellement: 1
#    disponible: 1
#    inequation: 1
#    entrer: 2
#    sexualite: 2
#    persister: 1
#    notamment: 1
#    cas: 1
#    repartition: 1
#    lutte: 1
#    commission: 1
#    consommation: 1
#    enseignement: 1
#    haut: 2
#    femme: 3
#    representer: 1
#    eleve: 1
#    inscrire: 1
#    domaine: 1
#    explorer: 2
#    lier: 1
#    stem: 2
#    quitter: 1
#    rigueur: 1
#    facon: 1
#    disproportionner: 1
#    durer: 2
#    conversion: 1
#    vers: 1
#    echange: 1
#    coutume: 1
#    cycle_par_seconde: 1
#    vocation: 1
#
#
# Document : Époque contemporaine (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <LOCATION>: 3
#    explorer: 1
#    constater: 3
#    deuxieme: 1
#    cycle_par_seconde: 1
#    secondaire: 1
#    garcon: 3
#    propos: 2
#    vocation: 1
#    domaine: 1
#    recherche_appliquee: 3
#    obtention: 2
#    ambitieux: 1
#    gamine: 3
#    decouverte: 1
#    mener: 1
#    parmi: 1
#    adolescent: 1
#    paysage: 1
#    ameriqu: 1
#    nord: 1
#    europe: 1
#    avoir: 2
#    certaine: 1
#    bill: 1
#    enclin: 1
#    valoriser: 1
#    mathematique: 1
#    savoir: 2
#    forme: 1
#    estimateur: 1
#    aussi: 1
#    option: 1
#    interagir: 1
#    salut: 1
#    lancer: 1
#    comme: 1
#
#
# Document : Sens originel (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    lun: 1
#    disparite: 1
#    medius: 1
#    entrer: 1
#    savoir: 2
#    personnalite: 3
#    recherche_appliquee: 1
#    lobjet: 2
#    detude: 2
#    premiere_vitesse: 1
#    relativement: 1
#    immuable: 1
#    alors: 1
#    minute: 1
#    technique: 2
#    perpetuel: 1
#    elargissement: 1
#    linvention: 1
#    lamelioration: 1
#    propos: 1
#    introduction: 1
#    exclusif: 1
#    respecter: 1
#    nature: 1
#    supergrand: 1
#    forme: 1
#    etre: 1
#    modifier: 1
#    inventer: 1
#    lhomme: 1
#    sans: 1
#    perdre: 1
#    specificite: 1
#    intrinseque: 1
#
#
# Document : Sens dérivés (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    lamelioration: 1
#    linvention: 1
#    technique: 2
#    faire: 1
#    facon: 1
#    strict: 1
#    jeu: 1
#    lobjet: 1
#    recherche_appliquee: 1
#    celui: 1
#    decouverte: 1
#
#
# Document : Sens dérivés (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    certain: 1
#    propos: 1
#    neanmoins: 1
#    apparue: 1
#    lusage: 1
#    Moi: 1
#
#
# Document : Sens dérivés (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    borne: 1
#    technologique: 1
#    lorsque: 1
#    propos: 1
#    viande: 1
#    technique: 1
#    subit: 1
#    changer: 1
#    medius: 1
#    virement: 1
#    recherche_appliquee: 2
#    original: 1
#
#
# Document : Autres espèces animales (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    lutilisation: 1
#    prototechnologie: 1
#    egalement: 1
#    marque: 1
#    certain: 1
#    espece: 1
#    faune: 1
#    rien: 1
#    homo_sapiens: 1
#
#
# Document : Autres espèces animales (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    <LOCATION>: 1
#    lusage: 1
#    doutil: 2
#    autrefoi: 1
#    considerer: 1
#    comme: 4
#    marque: 1
#    definir: 1
#    sexualite: 1
#    homo: 1
#    ce: 1
#    opinion: 1
#    avoir: 1
#    remplacer: 1
#    apres: 1
#    trouver: 1
#    evidence: 1
#    dutilisation: 1
#    parmi: 1
#    pan_troglodytes: 3
#    dautre: 1
#    hierarque: 1
#    dauphin: 1
#    corneille: 1
#    cas: 1
#    investigateur: 1
#    observer: 1
#    ereme: 1
#    grace: 2
#    penis: 2
#    piedestal: 1
#    decouverte: 1
#    nutriment: 1
#    pilon: 1
#    acheter: 1
#    temoignage: 1
#    parasite: 1
#    lecorce: 1
#    Liane: 1
#    sonde: 1
#    attraper: 1
#    isoptera: 1
#    lafrique: 1
#    louest: 1
#    utilisent: 1
#    marteau_de_president: 1
#    enclume: 1
#    jailbreak: 1
#    walnut: 1
#    femme: 1
#    sapajou: 1
#    boa: 1
#    vista: 1
#    Altamira: 1
#
#
# Document : Autres espèces animales (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    lutilisation: 1
#    doutil: 1
#    nest: 1
#    Moi: 1
#    forme: 1
#    dutilisation: 1
#    recherche_appliquee: 2
#    faune: 1
#    cas: 1
#    turcie: 1
#    haut-de-forme: 1
#    construit: 1
#    rameau: 1
#    grosse: 1
#    penis: 1
#    impact: 1
#    determiner: 1
#    habitat: 1
#    fluvial: 1
#    ecosysteme: 1
#
#
# Document : Notes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    ce: 1
#    regle: 1
#    partiellement: 1
#    entierete: 1
#    issu: 1
#    supplement: 1
#    <<: 1
#    dechiffrer: 1
#    code: 1
#    leducation: 1
#    gamine: 1
#    femme: 1
#    savoir: 1
#    recherche_appliquee: 1
#    ingenieri: 1
#    mathematique: 1
#    stem: 1
#    >>: 1
#    unesco: 1
#    projet: 1
#    endroit: 1
#    generateur: 1
#    responsable: 1
#    probleme: 1
#    sou: 1
#    cc: 1
#    bysa: 1
#    igo: 1
#
#
# Document : Références (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 31
#    <LOCATION>: 9
#    |: 46
#    asma: 1
#    mhalla: 1
#    <<: 32
#    technopolitiqu: 1
#    yak: 1
#    recherche_appliquee: 3
#    faire: 1
#    armee: 1
#    >>: 32
#    wwwseuilcom: 1
#    consulter: 19
#    Octobre: 7
#    jacques: 1
#    ellul: 2
#    bluff: 3
#    technologique: 2
#    centre: 1
#    national: 1
#    avenue: 1
#    textuel: 1
#    lexical: 1
#    cnrs: 1
#    georg: 1
#    elli: 1
#    memoir: 1
#    of: 22
#    Jacob: 1
#    bigelow: 1
#    cambridge: 3
#    mas: 1
#    john: 1
#    wilson: 1
#    David: 1
#    f: 1
#    sang_bleu: 1
#    the: 18
#    theologie: 1
#    technology: 4
#    divinity: 1
#    man: 3
#    and: 10
#    spirit: 1
#    fiction: 1
#    new: 3
#    York: 1
#    penguin: 1
#    book: 1
#    jacque: 1
#    penis: 23
#    lerobertcom: 1
#    novembre: 2
#    mother: 1
#    male: 1
#    -: 7
#    1000000: 1
#    year: 1
#    ago: 2
#    bbc: 3
#    San_Pedro_Sula: 1
#    human: 6
#    evolution: 2
#    history: 6
#    channel: 1
#    may: 6
#    Wade: 1
#    nicholas: 1
#    early: 4
#    voice: 1
#    leap: 1
#    to: 2
#    language: 1
#    york: 1
#    time: 1
#    juillet: 1
#    ancestors: 1
#    antichambre: 1
#    homo: 1
#    sapiens: 1
#    smithsonian: 1
#    hopital_psychiatrique: 1
#    decembre: 2
#    ancient: 2
#    tool: 4
#    factory: 1
#    uncovered: 1
#    news: 3
#    fevrier: 4
#    jean: 1
#    heinzelin: 1
#    jd: 1
#    clark: 1
#    white: 1
#    w: 5
#    hart: 1
#    p: 1
#    reindeer: 1
#    gramme: 2
#    woldegabriel: 1
#    beyene: 1
#    e: 4
#    vrber: 1
#    environment: 1
#    behavior: 1
#    millionyearold: 1
#    bouri: 1
#    hominid: 5
#    savoir: 12
#    avion: 13
#    no: 13
#    : 12
#    Avril: 3
#    pmid: 3
#    doi: 10
#    mc: 1
#    pherron: 1
#    al: 1
#    personnalite: 3
#    CV: 1
#    Anglais: 1
#    hominidescom: 1
#    australopithecus: 1
#    utilisaientil: 1
#    thomas: 2
#    plummer: 1
#    flaked: 1
#    stone: 3
#    old: 1
#    bone: 1
#    biological: 1
#    cultural: 3
#    at: 2
#    dawn: 1
#    yearbook: 1
#    physical: 1
#    anthropology: 6
#    pierre: 1
#    repercussion: 1
#    delagne: 1
#    avoir: 7
#    brugal: 1
#    jp: 1
#    feibel: 1
#    kibunjia: 1
#    mourre: 2
#    v: 2
#    texier: 1
#    pj: 1
#    fabrication: 1
#    technical: 1
#    skill: 1
#    myr: 1
#    in: 6
#    west: 1
#    turkana: 1
#    Kenya: 1
#    viller: 1
#    henshilwood: 1
#    cs: 1
#    us: 3
#    pressure: 1
#    flaking: 1
#    lithic: 1
#    artifact: 1
#    blombo: 1
#    oenotheque: 1
#    south: 2
#    africa: 1
#    haviland: 1
#    Tyndale: 1
#    challeng: 1
#    Australie: 1
#    thomson: 2
#    guilde: 2
#    ed: 2
#    isbn: 7
#    lccn: 3
#    crump: 1
#    brief: 1
#    londre: 1
#    constabl: 1
#    robinson: 1
#    fossil: 1
#    site: 1
#    sterkfontein: 1
#    swartkrans: 1
#    kromdraai: 1
#    environ: 1
#    unesco: 3
#    consulte: 1
#    Mythologie_romaine: 1
#    age: 1
#    world: 2
#    steven: 1
#    r: 2
#    jame: 1
#    fire: 2
#    lower: 1
#    middle: 1
#    pleistocene: 1
#    current: 3
#    lire: 10
#    ligne: 11
#    payer: 2
#    ann: 2
#    b: 1
#    stahl: 1
#    dietary: 1
#    selection: 1
#    before: 1
#    richard: 2
#    cordal: 1
#    asia: 1
#    andamanese: 1
#    genetic: 2
#    evidence: 2
#    for: 4
#    dans: 3
#    dispersal: 1
#    out: 1
#    africer: 1
#    american: 1
#    revue: 4
#    pmcid: 1
#    pdf: 1
#    first: 1
#    baby: 1
#    bome: 1
#    skeletal: 1
#    show: 1
#    abrupt: 1
#    worldwid: 1
#    increase: 2
#    birth: 1
#    briseur_de_greve: 1
#    during: 2
#    neolithic: 2
#    period: 1
#    daily: 1
#    jan: 2
#    sussman: 1
#    lolo: 1
#    child: 1
#    transporteur: 1
#    family: 1
#    size: 1
#    population: 1
#    university: 2
#    Lincoln_Park: 1
#    press: 2
#    ferraro: 1
#    Gary: 1
#    applied: 1
#    perspectif: 1
#    belmont: 1
#    calif: 1
#    patterson: 1
#    gordon: 1
#    essentials: 1
#    piscataway: 1
#    research: 2
#    education: 3
#    relation: 1
#    poche: 1
#    alan: 1
#    cramb: 1
#    short: 1
#    metals: 1
#    carnegie: 1
#    mellon: 1
#    hugh: 1
#    chisholm: 1
#    encyclopaedia: 1
#    britannicer: 1
#    soumission: 1
#    skills: 1
#    digital: 2
#    oecd: 1
#    economy: 1
#    papers: 1
#    juin: 3
#    issn: 2
#    jlwz: 1
#    z: 1
#    wnwen: 1
#    dechiffrer: 1
#    code: 1
#    formation: 1
#    gamine: 1
#    femme: 1
#    ingenieri: 1
#    mathematique: 1
#    stem: 1
#    pari: 1
#    supplement: 1
#    vaino: 4
#    K: 3
#    rannikmae: 2
#    holbrook: 2
#    factors: 2
#    explaining: 2
#    gymnasium: 2
#    students': 2
#    related: 2
#    career: 2
#    voie: 2
#    baltic: 2
#    pp: 1
#    swarat: 1
#    ortony: 1
#    revell: 1
#    activity: 1
#    matter: 1
#    understanding: 1
#    studer: 1
#    interest: 1
#    school: 1
#    teaching: 1
#    tea: 1
#    oakley: 1
#    toolmaker: 1
#    bibcode: 2
#    natur: 1
#    u: 1
#    CDI: 2
#    sagan: 1
#    carl: 1
#    druyan: 1
#    leakey: 1
#    consommation: 1
#    doutil: 1
#    pan_troglodytes: 1
#    archiv: 3
#    Sept: 3
#    saint_Paul: 1
#    rincon: 1
#    dauphin: 1
#    utilisent: 1
#    parasite: 1
#    apprise: 1
#    mere: 1
#    crow: 1
#    find: 2
#    food: 1
#    nbc: 1
#    rutz: 1
#    weir: 1
#    aa: 1
#    kacelnik: 1
#    camera: 1
#    video: 1
#    oiseau_aquatique: 1
#    ereme: 1
#    sci: 1
#    mcgrew: 1
#    chimpanzee: 1
#    material: 1
#    raffinement: 1
#    ua: 1
#    univ: 1
#    Christophe: 1
#    boesch: 2
#    hedwige: 1
#    mental: 1
#    map: 1
#    wild: 1
#    chimpanzees: 1
#    an: 1
#    analysis: 1
#    hammer: 1
#    transport: 1
#    nut: 1
#    cracking: 1
#    hierarque: 1
#    er: 1
#    bf: 1
#    vi: 1
#    it: 2
#    dolozi: 2
#    enus: 1
#    authorfullname: 1
#    nutcracking: 1
#    monkeys: 1
#    right: 1
#    job: 1
#    scientist: 1
#    muller: 1
#    watling: 1
#    Salto_del_Angel: 1
#    turcie: 1
#    haut-de-forme: 1
#    --: 1
#    river: 1
#    flow: 1
#    eighth: 1
#    international: 1
#    conference: 1
#    fluvial: 1
#    hydraulics: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    autre: 1
#    propos: 1
#    wikimedia: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    recherche_appliquee: 1
#    wiktionnairetechnologie: 1
#    wikibookstechnologie: 1
#    wikinews: 1
#
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 6
#    <LOCATION>: 5
#    gilbert: 1
#    simondon: 1
#    linvention: 1
#    technique: 3
#    huis: 1
#    pari: 3
#    jeanclaude: 2
#    ane: 2
#    mach: 1
#    cadre: 1
#    description: 1
#    depuis: 1
#    vuibert: 1
#    penis: 5
#    isbn: 5
#    oclc: 4
#    marque: 1
#    lhumain: 1
#    gouvernement: 1
#    lharmattan: 1
#    coll: 1
#    <<: 1
#    prelude: 1
#    philosophique: 1
#    >>: 1
#    lire: 1
#    ligne: 1
#    yve: 1
#    lasfargu: 1
#    halte: 1
#    ridiculite: 1
#    technologique: 1
#    parier: 1
#    redactrices_en_chef: 1
#    dorganisation: 1
#    David: 1
#    sang_bleu: 1
#    the: 3
#    theologie: 1
#    of: 3
#    technology: 1
#    divinity: 1
#    man: 1
#    and: 1
#    spirit: 1
#    fiction: 1
#    new: 1
#    York: 1
#    penguin: 1
#    book: 1
#    re: 1
#    ed: 1
#    francoi: 1
#    jarrige: 1
#    dompter: 1
#    promether: 1
#    technologier: 1
#    socialisme: 1
#    lage: 1
#    romantique: 1
#    besancon: 1
#    imprimerie: 1
#    universitaire: 1
#    franchecomte: 1
#    issn: 1
#    doi: 1
#    bookspufc: 1
#
#
# Document : Articles connexes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    savoir-faire: 1
#    technique: 4
#    economie: 1
#    savoir: 1
#    formation: 1
#    note: 1
#    recherche_appliquee: 5
#    gymnase: 1
#    institut: 1
#    universitaire: 1
#    college: 1
#    description: 1
#    neoluddisme: 1
#    standardisation: 1
#    standard: 1
#    Chinook: 1
#    industriel: 1
#    norm: 1
#    original: 1
#    gouvernement: 1
#    transportation: 1
#    roberval: 1
#    avancer: 2
#    revival: 1
#    technologique: 1
#    rotation: 1
#    numerique: 1
#    technocritiqu: 1
#
#
# Document : Articles connexes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    recherche_appliquee: 3
#    gymnase: 1
#    institut: 1
#    universitaire: 1
#    college: 1
#
#
# Document : Articles connexes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    standard: 1
#    Chinook: 1
#    industriel: 1
#    norm: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 6
#    <LOCATION>: 2
#    notice: 2
#    dautorite: 1
#    bnf: 1
#    forme: 1
#    lccn: 1
#    gnd: 1
#    japonais: 1
#    Israel: 1
#    tchequi: 1
#    Lettonie: 1
#    avenue: 2
#    respecter: 2
#    bien-etre: 1
#    history: 1
#    of: 2
#    modern: 1
#    biomedicine: 1
#    medical: 1
#    subject: 1
#    heading: 1
#    documentation: 1
#    the: 1
#    encyclopedier: 1
#    savoir: 1
#    fiction: 1
#    tableau_associatif: 1
#    encyclopedie: 1
#    docteur: 1
#    britannica: 1
#    den: 1
#    lunettes_de_soleil: 1
#    dansk: 1
#    encyklopaedi: 1
#    dizionario: 1
#    di: 1
#    storia: 1
#    gran: 1
#    enciclopedia: 1
#    catalana: 1
#    store: 1
#    norsk: 1
#    leksikon: 1
#    treccani: 1
#    recherche_appliquee: 3
#    cassette: 1
#    langue_ethnique: 3
#    Daniel_Chester_French: 1
#    informatiser: 1
#    securite-incendie: 2
#    lencyclopedie: 3
#    lagora: 3
#    ou: 2
#    indiquer: 2
#    lintroducteur: 2
#    construction: 3
#    Anglais: 2
#    john: 1
#    bigelow: 2
#    millenarism: 1
#    extraction: 1
#    millenariste: 1
#    Jacob: 1
#    incoherence: 1
#    litterature: 1
#    commentaire: 1
#    gouvernement: 1
#    contemporain: 1
#    michel: 1
#    puech: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    bnf: 1
#    forme: 1
#    lccn: 1
#    gnd: 1
#    japonais: 1
#    Israel: 1
#    Republique_tcheque: 1
#    Lettonie: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    history: 1
#    of: 1
#    modern: 1
#    biomedicine: 1
#    medical: 1
#    subject: 1
#    heading: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    the: 1
#    encyclopedier: 1
#    of: 1
#    savoir: 1
#    fiction: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 2
#    britannicer: 1
#    den: 1
#    lunettes_de_soleil: 1
#    dansk: 1
#    encyklopaedi: 1
#    dizionario: 1
#    di: 1
#    storia: 1
#    gran: 1
#    enciclopedia: 1
#    catalana: 1
#    store: 1
#    norsk: 1
#    leksikon: 1
#    treccani: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    affichage: 2
#    sans: 1
#    ecran: 1
#    esprit: 1
#    haute: 1
#    autostereoscopie: 1
#    diode: 1
#    electroluminescent: 1
#    engrais_organique: 1
#    lentill: 1
#    verres_de_contact: 1
#    bionique: 1
#    monde: 1
#    virtuel: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    Agribusiness: 2
#    specifique: 1
#    urbain: 1
#    aquaponie: 1
#    exploitation: 1
#    vertical: 1
#    hydroponie: 1
#    bastingage: 1
#    vegetaliser: 1
#    administration_federale: 1
#    genetiquement: 1
#    modifier: 1
#    viand: 1
#    in: 1
#    vitro: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    senseur: 1
#    donde: 1
#    gravitationnel: 1
#    lisa: 1
#    ligo: 1
#    virgo: 1
#    interferometre: 2
#    astronomique: 1
#    optique: 1
#    long: 2
#    piedestal: 2
#    interferometrie: 1
#    tres: 1
#    event: 1
#    perspective: 1
#    telescope: 1
#    halca: 1
#    hypertelescope: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    lisa: 1
#    ligo: 1
#    virgo: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    interferometr: 1
#    optique: 1
#    long: 2
#    piedestal: 2
#    interferometrie: 1
#    tres: 1
#    event: 1
#    perspective: 1
#    telescope: 1
#    halca: 1
#    hypertelescope: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    event: 1
#    perspective: 1
#    telescope: 1
#    halca: 1
#    hypertelescope: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    pyrosequencage: 1
#    sequencage: 5
#    GSM: 1
#    unique: 1
#    ligation: 2
#    doligonucleotides: 1
#    nanopore: 1
#    semiconducteur: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    biophotoniqu: 1
#    electrophorese: 2
#    capillaire: 2
#    spectre: 1
#    Lot: 1
#    SI: 1
#    imagerie: 1
#    moleculaire: 1
#    separation: 1
#    chip: 1
#    optofluidiqu: 1
#    optogenetiqu: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    ampakine: 1
#    bioimpression: 1
#    biologie: 1
#    resume: 1
#    biostase: 1
#    GSM: 1
#    tenor: 1
#    cryoconservation: 1
#    cryogenisation: 1
#    Salto_del_Angel: 2
#    biomedical: 1
#    genetique: 1
#    technique: 1
#    hopital: 1
#    interfac: 1
#    neuronal: 1
#    direct: 1
#    interference: 1
#    arn: 1
#    disque: 1
#    regeneratif: 1
#    nanomedecin: 1
#    robot: 1
#    medical: 1
#    strategie: 1
#    for: 1
#    engineered: 1
#    negligibl: 1
#    senescence: 1
#    therapie: 2
#    genique: 1
#    photodynamique: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    cristallographie: 1
#    seriel: 1
#    femtoseconde: 1
#    laboratoire: 1
#    demolition: 1
#    microfluidiqu: 1
#    spectrometri: 2
#    alpha: 1
#    Lot: 1
#    bic: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    opinion: 2
#    odorat: 1
#    electronique: 1
#    optoelectronique: 1
#    spintroniqu: 1
#    plastronique: 1
#    optroniqu: 1
#    textile: 1
#    intelligent: 1
#    atomtroniqu: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    estimateur: 2
#    quantite: 2
#    cryptanalyse: 1
#    optique: 1
#    sciences_de_l'information: 1
#    ubiquitaire: 1
#    habilete: 2
#    artificiel: 2
#    reseau_informatique: 1
#    neurone: 1
#    memoir: 1
#    cbram: 1
#    fram: 1
#    millipede: 1
#    mram: 1
#    nram: 1
#    pram: 1
#    rram: 1
#    xpoint: 1
#    ambiant: 1
#    net: 1
#    theme: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    reseau_informatique: 1
#    cellule_nerveuse: 1
#    artificiel: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    cbram: 1
#    fram: 1
#    millipede: 1
#    mram: 1
#    nram: 1
#    pram: 1
#    rram: 1
#    xpoint: 1
#    habilete: 1
#    ambiant: 1
#    net: 1
#    theme: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    laser: 1
#    cristallographie: 1
#    r: 3
#    x: 3
#    diffusion: 1
#    spectroscopie: 2
#    electronique: 1
#    spectrometri: 1
#    gamma: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    domotiqu: 1
#    exosquelette: 1
#    motoriser: 1
#    microrobotiqu: 1
#    nanorobot: 1
#    robotique: 2
#    essaim: 1
#    molle: 1
#    cobotiqu: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    <PERSON>: 1
#    hyperloop: 1
#    lancer: 1
#    spatial: 1
#    sans: 1
#    fuser: 1
#    propulsion: 1
#    laser: 1
#    catapulte: 1
#    reutilisable: 1
#    jetpack: 1
#    voie_ferree: 1
#    sustentation: 1
#    magnetique: 1
#    <<_fomites_>>: 2
#    autonome: 1
#    moto: 1
#    auto: 2
#    dupe: 1
#    opinion: 1
#    strati: 1
#    spacetrain: 1
#    hydrogene: 1
#    ecall: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Technologie)
# TF :
#    veine_porte: 1
#    recherche_appliquee: 1
#
#
# Document : Références (URL: https://fr.wikipedia.org/wiki/Économie)
# TF :
#    |: 1
#    httpspsychologiesavoirfrpsychologieeconomiepsychiqu: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Économie)
# TF :
#    <PERSON>: 1
#    economie: 2
#    porter: 1
#    attribuer: 1
#    universite: 1
#    aborder: 1
#    proposition: 1
#    gouvernement: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Économie)
# TF :
#    femme: 2
#    regle: 1
#    debut: 1
#    <<: 2
#    economie: 2
#    >>: 2
#    supplement: 1
#    ligne: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Économie)
# TF :
#    <LOCATION>: 1
#    veine_porte: 1
#    economie: 1
#
#
# Document : Les Éducation, instruction ou enseignement (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    propos: 1
#    <<: 3
#    formation: 1
#    >>: 3
#    directement: 1
#    issu: 1
#    Latin: 1
#    educatio: 1
#    facon: 1
#    luimem: 1
#    spin-off: 1
#    exducere: 1
#    ducere: 1
#    signifier: 1
#    tuyau: 1
#    guider: 1
#    commander: 1
#    ex-mari: 1
#    hors: 1
#    faire: 2
#    rendement: 1
#    grunge: 1
#    developper: 1
#    etre: 1
#    vivre: 1
#    convier: 1
#    cependant: 1
#    noter: 1
#    disparite: 1
#    pointer: 1
#    mialaret: 2
#    entrer: 1
#    deux: 1
#    etymologie: 1
#    educare: 1
#    aliment: 1
#    educere: 1
#    elever: 2
#    saisir: 1
#    bois_musique: 1
#    instance: 1
#    lier: 1
#    notion: 1
#    deducation: 1
#    dont: 1
#    conciliation: 1
#    problematique: 1
#    pedagogique: 1
#    medius: 1
#    nourrirremplir: 1
#    savoir-faire: 2
#    cestadire: 1
#    maximiser: 1
#    potentialite: 1
#    humain: 1
#    selon: 1
#    emil: 1
#    durkheim: 1
#    leducation: 1
#    socialisation: 1
#    methodique: 1
#    progeniture: 1
#    generation: 2
#    enseigner: 1
#    cest: 1
#    transmettre: 1
#    avenir: 1
#    corpus: 1
#    valeur: 1
#    faune: 1
#    social: 1
#
#
# Document : Les Éducation, instruction ou enseignement (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    falloir: 1
#    distinguer: 1
#    enseignement: 3
#    formation: 1
#    construction: 1
#    flanc: 1
#    referer: 1
#    plutot: 1
#    preciser: 1
#    course: 1
#    dun: 1
#    cycle_par_seconde: 1
#    detud: 1
#    specifique: 1
#    cas: 1
#    lenseignemer: 1
#    haut: 1
#
#
# Document : Les Éducation, instruction ou enseignement (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    leducation: 1
#    borne: 1
#    linstruction: 1
#    stricto: 1
#    sensu: 1
#    respecter: 1
#    seulement: 1
#    nettoyer: 1
#    savoir: 1
#    savoirfaire: 1
#    viser: 1
#    egalement: 1
#    assurer: 1
#    chaque: 1
#    humain: 1
#    pousser: 1
#    femme: 1
#    capacite: 1
#    forme: 1
#    intellectuel: 1
#    moral: 1
#    technique: 1
#    ainsi: 1
#    ce: 1
#    formation: 1
#    permission: 1
#    daffronter: 1
#    faune: 1
#    travailleur: 1
#    gerer: 1
#    citoyenne: 1
#    responsable: 1
#    guilde: 1
#    lequel: 1
#    evoluer: 1
#
#
# Document : Les Éducation, instruction ou enseignement (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    pratique: 1
#    conservation: 1
#    consensu: 1
#    considerer: 1
#    certain: 1
#    savoir: 4
#    viande: 1
#    faire: 1
#    jeu: 1
#    bagage: 1
#    minimum: 2
#    citoyenne: 1
#    quinversement: 1
#    nest: 1
#    denseignement: 1
#    possible: 1
#    sans: 1
#    nettoyer: 1
#    contrat: 1
#    comme: 1
#    lalphabet: 1
#    cas: 1
#    capacite: 1
#    relationnel: 1
#    donc: 1
#    deducation: 3
#    enseignement: 2
#    formation: 1
#    souvent: 1
#    confondre: 1
#    disparite: 1
#    subtil: 1
#    rester: 1
#    piedestal: 1
#    argument: 1
#    depuis: 2
#    duree: 1
#    littrer: 1
#    acte_notarie: 1
#    opinion: 1
#    compilation: 1
#    dexempl: 1
#    forme: 1
#    voir: 1
#    littre: 1
#    propos: 1
#    <<: 1
#    falloir: 1
#    remarquer: 1
#    linstruction: 1
#    senseigne: 1
#    leducation: 4
#    sapprend: 1
#    autre: 1
#    facon: 1
#    daction: 1
#    passe: 1
#    quel: 1
#    quil: 1
#    >>: 1
#    declenchement: 1
#    xxe: 1
#    cent: 1
#    designer: 1
#    aujourdhui: 1
#    france: 1
#    cosmos: 1
#    departemer: 1
#    universitaire: 1
#    lexpression: 1
#    semploi: 1
#    pluriel: 1
#    specificite: 1
#    setudier: 1
#    emprunter: 1
#    plusieurs: 1
#    rigueur: 1
#    homo_sapiens: 1
#    sociologie: 1
#    psychologie: 1
#    biologie: 1
#    economie: 1
#    gouvernement: 1
#
#
# Document : Influences de l'histoire, des cultures et des croyances et théories implicites (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    leducation: 1
#    influence: 1
#    lenvironnement: 1
#    historique: 1
#    culturel: 1
#    ainsi: 1
#    hypothese: 1
#    explicite: 1
#    implicite: 1
#    motiver: 1
#    pedagogue: 1
#    parent: 1
#    instructeur: 1
#    etc: 1
#
#
# Document : Influences de l'histoire, des cultures et des croyances et théories implicites (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    selon: 1
#    lhistorien: 1
#    paul: 1
#    veyne: 1
#    <<: 1
#    exceptionnel: 1
#    lhistoire: 1
#    leducation: 3
#    preparer: 1
#    lenfer: 1
#    faune: 1
#    effigie: 1
#    guilde: 1
#    abaissement: 1
#    germinal: 1
#    obtention: 1
#    souvent: 1
#    lhistoir: 1
#    celui: 1
#    opinion: 2
#    lon: 2
#    sest: 1
#    acte_notarie: 1
#    lenfance: 2
#    sexplique: 1
#    office: 1
#    social: 1
#    age: 1
#    deguise: 1
#    lembellir: 1
#    faire: 1
#    incarner: 1
#    apotheose: 1
#    lhumanite: 1
#    >>: 1
#
#
# Document : Influences de l'histoire, des cultures et des croyances et théories implicites (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    <PERSON>: 3
#    europe: 1
#    cent: 1
#    lumiere_visible: 1
#    philosophe: 1
#    john: 1
#    locke: 1
#    jeanjacque: 1
#    rousseau: 2
#    publier: 1
#    reserver: 1
#    tres: 1
#    influent: 1
#    reposer: 1
#    propos: 1
#    different: 1
#    lenfance: 1
#    printemps: 1
#    defenseur: 1
#    parfois: 1
#    opposer: 1
#    parent: 1
#    ainsi: 1
#    ecrivaitil: 1
#
#
# Document : Influences de l'histoire, des cultures et des croyances et théories implicites (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <<: 1
#    ...: 1
#    rever: 1
#    bien_de_consommation_courante: 1
#    cest: 2
#    rarement: 1
#    proposer: 1
#    quil: 1
#    responsabilite: 1
#    apprendre: 1
#    desirer: 1
#    chasser: 1
#    trouver: 1
#    rassembler: 1
#    portee: 1
#    faire: 1
#    naitre: 1
#    adroitemer: 1
#    souhait: 1
#    fournir: 1
#    facon: 1
#    satisfaire: 1
#    >>: 1
#
#
# Document : Influences de l'histoire, des cultures et des croyances et théories implicites (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    --: 1
#    jeanjacque: 1
#    rousseau: 1
#    emil: 1
#    leducation: 1
#    comptabiliser: 1
#    e: 1
#    penis: 1
#
#
# Document : Influences de l'histoire, des cultures et des croyances et théories implicites (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    lock: 1
#    plusieurs: 1
#    dizaine: 1
#    auparavant: 1
#    surface: 1
#    facon: 1
#    leducation: 1
#    raisonner: 1
#    progeniture: 1
#
#
# Document : Savoir, savoir-faire, savoir-être (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    schematiquement: 1
#    supergrand: 1
#    distinguer: 1
#    quatre: 1
#    grand: 1
#    domaine: 1
#    educatif: 1
#    savoir: 1
#    savoirfaire: 1
#    letre: 1
#    savoiretre: 1
#
#
# Document : Savoir, savoir-faire, savoir-être (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    savoir: 2
#    correspond: 1
#    savoir-faire: 3
#    intellectuel: 1
#    decouverte: 1
#    formation: 1
#    respecter: 1
#    propos: 1
#    trouver: 1
#    facon: 1
#    pedagogique: 1
#    permission: 1
#    apprenant: 1
#    dacquerir: 1
#    remarque: 1
#    lectur: 1
#    ecrit: 1
#    mathematique: 1
#    lhomme: 1
#    lenvironnement: 1
#    metaconnaissance: 1
#    ...: 1
#
#
# Document : Savoir, savoir-faire, savoir-être (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    savoirfaire: 2
#    correspondre: 1
#    savoir-faire: 3
#    pratique: 5
#    controle: 1
#    lexperience: 1
#    lexercice: 1
#    dun: 2
#    artisanal: 1
#    artistique: 1
#    soumission: 1
#    intellectuel: 2
#    femme: 1
#    sacquierer: 1
#    lapprentissage: 1
#    dautomatisme: 1
#    conduite: 1
#    decouverte: 1
#    formation: 1
#    respecter: 1
#    propos: 1
#    trouver: 1
#    dappliquer: 1
#    facon: 1
#    pedagogique: 1
#    permission: 1
#    apprenant: 1
#    dacquerir: 1
#    qualification: 1
#
#
# Document : Savoir, savoir-faire, savoir-être (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    savoiretr: 2
#    correspond: 1
#    capacite: 2
#    rendement: 1
#    bill: 2
#    exothermique: 2
#    adapter: 2
#    guilde: 1
#    homo_sapiens: 1
#    lenvironnement: 2
#    ce: 1
#    sacquiert: 1
#    jeu: 1
#    savoir-faire: 1
#    savoir: 1
#    savoirfaire: 1
#    specifique: 1
#    decouverte: 1
#    formation: 1
#    respecter: 2
#    savoiretre: 1
#    propos: 3
#    trouver: 1
#    facon: 1
#    pedagogique: 1
#    permission: 1
#    apprenant: 1
#    dacquerir: 1
#    mieux: 1
#    controle: 1
#    daction: 1
#    administration_federale: 1
#    proteger: 1
#    hygien: 1
#    empathi: 1
#    regard: 1
#    travailleur: 1
#    conduite: 1
#    adequat: 1
#    collectif: 1
#    entraid: 1
#    soi: 1
#    maitris: 1
#    gouvernement: 1
#    lutte: 1
#    ...: 1
#    concept: 1
#    parfois: 1
#    contester: 1
#    car: 1
#    impliquer: 1
#    ajustement: 1
#    lessence: 1
#    specificite: 1
#    lindividu: 1
#
#
# Document : Savoir, savoir-faire, savoir-être (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    letre: 2
#    correspondre: 1
#    letat: 2
#    biologique: 1
#    psychique: 2
#    dun: 1
#    humain: 1
#    decouverte: 1
#    formation: 1
#    respecter: 1
#    lexistence: 1
#    propos: 1
#    trouver: 1
#    facon: 1
#    pedagogique: 1
#    permission: 1
#    etat: 1
#    educatif: 1
#    favoriser: 1
#    datteindre: 1
#    detr: 1
#    optimal: 1
#    responsabilite: 1
#    bien-etre: 1
#    bienetre: 1
#    raison: 1
#    commission: 1
#    expiation: 1
#    travailleur: 1
#    nature: 1
#    allegresse: 1
#    plaisir: 1
#    espace: 1
#    percept: 1
#    gratitude: 1
#    valeur: 1
#    justice: 1
#    unite: 1
#    authenticite: 1
#    capacite: 1
#    abandon: 1
#    difference: 1
#    reconfort: 1
#    creativite: 1
#    cur: 1
#    etc: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    coutume: 1
#    robert: 1
#    mill: 1
#    victoire: 1
#    disent: 1
#    lon: 1
#    supergrand: 1
#    distinguer: 1
#    cinq: 1
#    grand: 1
#    male: 1
#    dapprentissage: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    obtention: 5
#    conduite: 1
#    verbal: 1
#    lexical: 1
#    conceptuel: 1
#    categoriel: 1
#    projet: 1
#    declaration: 1
#    specificite: 1
#    socioemotif: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    obtention: 1
#    conduite: 1
#    lon: 1
#    lancer: 1
#    courammer: 1
#    savoirfaire: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    obtention: 4
#    verbal: 1
#    lexical: 2
#    celui: 1
#    correspondre: 1
#    lapprentissage: 1
#    lalphabet: 1
#    missive: 2
#    doigt: 2
#    orthograph: 1
#    propos: 2
#    impliquent: 1
#    investigateur: 1
#    lancer: 1
#    souvenir: 1
#    stocker: 1
#    numero: 1
#    etc: 1
#    sagit: 1
#    souvent: 2
#    savoir-faire: 1
#    verbalisable: 1
#    lait: 1
#    controle: 1
#    langue_ethnique: 1
#    nont: 1
#    importance: 1
#    soi: 1
#    responsabilite: 1
#    etre: 1
#    apprendre: 1
#    coeur: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    obtention: 1
#    conceptuel: 1
#    celui: 1
#    impliquer: 1
#    inclusion: 1
#    viser: 1
#    faire: 1
#    comprendre: 1
#    apprendre: 1
#    notion: 1
#    opinion: 1
#    segment: 1
#    dobjet: 1
#    lapprener: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    obtention: 4
#    projet: 1
#    declaration: 2
#    specificite: 3
#    viser: 1
#    apprendre: 1
#    yak: 1
#    resolution: 1
#    strate: 1
#    moins: 1
#    important: 1
#    celer: 1
#    supergrand: 1
#    passereau: 1
#    lapprentissage: 1
#    dalgorithme: 1
#    applicable: 1
#    certain: 1
#    cas: 1
#    evolue: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    obtention: 1
#    verbal: 1
#    lexical: 1
#    conceptuel: 1
#    categoriel: 1
#    ainsi: 1
#    celui: 1
#    projet: 1
#    declaration: 1
#    englober: 1
#    concept: 1
#    savoir: 1
#
#
# Document : Taxonomie de Robert Mills Gagné (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    obtention: 1
#    socioemotionnel: 1
#    quant: 1
#    correspondent: 1
#    savoiretre: 1
#
#
# Document : Taxonomie de Bloom (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    taxonomie: 1
#    rougir: 1
#    modelisme: 1
#    enseignement: 1
#    proposer: 1
#    nomenclature: 1
#    quantite: 1
#    dacquisition: 1
#    savoir-faire: 1
#
#
# Document : Taxonomie de Bloom (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    Benjamin: 1
#    rougir: 1
#    bien_de_consommation_courante: 1
#    quil: 1
#    nen: 1
#    Moi: 1
#    Jehovah: 1
#    universitaire: 1
#    Etats-Unien: 1
#    participer: 1
#    lieue: 1
#    souvent: 1
#    reconnaitre: 1
#    comme: 1
#    <<: 1
#    Pere: 1
#    >>: 1
#    ce: 1
#    penis: 1
#
#
# Document : Construire son savoir (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    enseignement: 3
#    moderne: 1
#    considerer: 1
#    transmittance: 1
#    courrier: 1
#    biseau: 1
#    responsabilite: 1
#    laisser: 1
#    centre_d'achats: 1
#    ou: 1
#    leleve: 1
#    construction: 2
#    rien: 1
#    creer: 1
#    savoir: 3
#    luimeme: 1
#    cas: 1
#    selon: 1
#    ce: 1
#    propos: 1
#    sembler: 2
#    obtention: 2
#    important: 2
#    quun: 1
#    elever: 1
#    capable: 1
#    notion: 1
#    domaine: 2
#    den: 1
#    identifier: 1
#    conge: 1
#    dune_de_sable: 1
#    consideration: 1
#    dun: 1
#    dictionnair: 1
#    plutot: 1
#    connaitre: 2
#    cur: 1
#    femme: 1
#    sans: 1
#    attribution: 1
#    ni: 1
#    performance: 1
#    consulter: 1
#    net: 1
#    tableau_associatif: 1
#    soimeme: 1
#    repertoire: 1
#    etendre: 1
#    dictionnaire: 1
#    epellation: 1
#    correct: 1
#
#
# Document : Critiques (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    notion: 1
#    contester: 1
#    parfois: 2
#    propos: 1
#    tres: 1
#    dur: 1
#    terroriste: 1
#    intellectuel: 1
#    dressage: 1
#    formatage: 1
#    cenacle: 1
#    iufm: 1
#    ...: 2
#    instructeur: 1
#    dit: 1
#    traditionaliste: 1
#    voir: 2
#    leducation: 1
#    comme: 2
#    <<: 3
#    transmittance: 1
#    savoir-faire: 1
#    >>: 3
#    avertissement: 1
#    lancer: 1
#    symetrie: 1
#    etat: 2
#    lechec: 1
#    scolaire: 1
#    social: 2
#    actuellement: 1
#    imputer: 1
#    cadre: 1
#    opposant: 1
#    denoncer: 1
#    artificielle: 1
#    inefficace: 1
#    stressant: 1
#    structure: 2
#    ecolier: 1
#    dun: 1
#    savoir: 1
#    supposer: 2
#    monde: 1
#    quantite: 1
#    haut: 1
#    universitaire: 1
#    voire: 1
#    doctoral: 1
#    cas: 2
#    numero: 1
#    dune_de_sable: 1
#    operation_militaire: 1
#    aussi: 1
#    biseau: 1
#    soustraction: 1
#    primaire: 1
#    methodologie: 1
#    ensembliste: 1
#    quand: 1
#    portee: 1
#    speculation: 1
#    inconsiderer: 1
#    respecter: 1
#    code: 1
#    grande_route: 1
#    autre: 1
#    potentiellement: 1
#    dangereux: 1
#    soutenir: 1
#    progeniture: 1
#    supergrand: 1
#    responsabilite: 1
#    rien: 1
#    moins: 2
#    plaisir: 1
#    raison: 1
#    apprendre: 1
#    coeur: 1
#    lien: 1
#    si: 1
#    prescription: 1
#    sinon: 1
#    domaine: 1
#    lalphabet: 1
#    depot: 1
#    generation: 1
#    clef: 1
#    regle: 1
#    femme: 1
#    type: 1
#    grammatical: 1
#    mathematique: 1
#    forme: 1
#    contestataire: 1
#    serrure: 1
#    accuser: 1
#    avancee: 1
#    retrograde: 1
#    reactionnaire: 1
#    encore: 1
#    tort: 1
#    opinion: 1
#
#
# Document : Critiques (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    notion: 1
#    egalement: 1
#    critiquer: 1
#    psychologue: 1
#    dorientation: 1
#    cognitiviste: 1
#
#
# Document : Éducation formelle et éducation non formelle en France (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    notion: 1
#    resultent: 1
#    projet: 1
#    international: 1
#    om: 1
#    unesco: 1
#    notamment: 1
#    Francois-Anatole_Thibault: 1
#    grondement: 1
#    specifique: 1
#
#
# Document : Éducation formelle et éducation non formelle en France (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    <LOCATION>: 1
#    leducation: 1
#    formel: 1
#    lecole: 1
#    luniversite: 1
#    nest: 1
#    bien_que: 1
#    sen: 1
#    falloir: 1
#    lunique: 1
#    respecter: 3
#    deducation: 2
#    cest: 1
#    ainsi: 1
#    premiere_vitesse: 1
#    informateur: 1
#    debris: 1
#    phratrie: 2
#    lentourage: 1
#    femme: 1
#    enjeu: 1
#    <<: 1
#    elevage: 2
#    social: 5
#    >>: 1
#    celer: 1
#    impliquer: 1
#    france: 1
#    bourdieu: 1
#    passeron: 1
#    preuve: 1
#    cadre: 2
#    scolaire: 1
#    corriger: 1
#    inequation: 1
#    avoir: 1
#    cur: 1
#    renforcer: 1
#    acte_notarie: 1
#    incapacite: 1
#    sadresser: 1
#    population: 2
#    devenir: 1
#    tres: 1
#    heterogene: 1
#    culturellement: 1
#    socialemer: 1
#    strate: 2
#    mal: 1
#    culturel: 1
#    supergrand: 1
#    contrairement: 1
#    aiser: 1
#    compenser: 1
#    ce: 1
#    vertige: 1
#    educatif: 1
#    mieux: 1
#    adapter: 1
#    code: 1
#    consommation: 1
#    guilde: 1
#    obtention: 2
#    aisee: 1
#    financierement: 1
#    profiter: 1
#    dun: 1
#    grand: 1
#    lutte: 1
#    raffinement: 1
#    quel: 1
#    transmettre: 1
#    progeniture: 1
#    quil: 1
#    acceder: 1
#    haut: 1
#    lechell: 1
#
#
# Document : Éducation formelle et éducation non formelle en France (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    outre: 1
#    flanc: 1
#    fonction: 1
#    deducation: 1
#    dinstruction: 1
#    cadre: 2
#    educatif: 1
#    contester: 1
#    operer: 1
#    structure: 1
#    survie: 1
#    voie: 1
#    vers: 2
#    job: 1
#    haute: 1
#    vocation: 1
#    administratif: 1
#    lelev: 1
#    recevoir: 1
#    enseignement: 1
#    gratuit: 1
#    payer: 1
#    ce: 1
#    gratuite: 1
#    mutation: 1
#    viande: 1
#    relativement: 2
#    mode_passif: 1
#    <<: 2
#    fabrication: 1
#    scolaire: 2
#    >>: 2
#    lecole: 1
#    exiger: 1
#    leleve: 1
#    quil: 1
#    sintegre: 1
#    linstitution: 1
#    grace: 1
#    controle: 1
#    dun: 2
#    certain: 1
#    numero: 1
#    savoir-faire: 1
#    piedestal: 1
#    dont: 1
#    lensemble: 1
#    nest: 1
#    toujours: 1
#    formaliser: 1
#    dautr: 1
#    symetrie: 1
#    supergrand: 1
#    transmettre: 1
#    quun: 2
#    corpus: 1
#    rationaliser: 1
#    faire: 1
#    limpass: 1
#    grand: 1
#    jeu: 1
#    milieu: 1
#    rotir: 1
#    culturel: 1
#    humour: 1
#    facon: 1
#    tabou: 1
#    propos: 1
#    rien: 1
#    verbal: 1
#    etc: 1
#    enfin: 1
#    malgre: 1
#    avancer: 1
#    train: 1
#    continuer: 1
#    dur: 1
#    quoique: 1
#    breve: 1
#    faune: 1
#    humain: 1
#
#
# Document : Éducation formelle et éducation non formelle en France (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    femme: 1
#    cas: 1
#    apparaitre: 1
#    utile: 1
#    certain: 1
#    delargir: 1
#    remarque: 1
#    leducation: 3
#    sans: 1
#    reduire: 1
#    forme: 2
#    scolaire: 1
#    ainsi: 1
#    rien: 1
#    formel: 2
#    apporter: 1
#    savoir-faire: 1
#    specifique: 1
#    lindividu: 1
#    celuici: 1
#    supergrand: 1
#    acquerir: 1
#    notamment: 1
#    delivrer: 1
#    lolo: 1
#    gerance: 1
#    petit: 1
#
#
# Document : Éducation formelle et éducation non formelle en France (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    malgre: 1
#    tout: 1
#    celer: 1
#    leducation: 2
#    avoir: 1
#    permission: 1
#    historiquement: 1
#    Francois-Anatole_Thibault: 1
#    grand: 1
#    jeu: 2
#    strate: 2
#    defavoriser: 1
#    dacceder: 1
#    regle: 1
#    de_l'arithmetique: 1
#    certain: 1
#    voie: 1
#    flux: 1
#    vers: 1
#    professionnalisation: 1
#    precoce: 1
#    dun: 1
#    petit: 1
#    contradictoire: 1
#    finalite: 1
#    raffinement: 1
#    ensemble: 1
#    ecolier: 1
#    epanouissement: 1
#    guilde: 1
#    bien_que: 1
#    citoyenne: 1
#    dautre: 1
#    supergrand: 1
#    faciliter: 1
#    contraire: 1
#    ce: 1
#    integration: 1
#    faune: 1
#    social: 1
#    professionnalisme: 1
#    propos: 1
#    femme: 1
#    aussi: 1
#    viande: 1
#
#
# Document : Éducation familiale (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    ce: 1
#    formation: 2
#    generalement: 1
#    accomplir: 1
#    parent: 2
#    lenfer: 1
#    bien_de_consommation_courante: 1
#    opinion: 1
#    guilde: 1
#    egalement: 1
#    verticille: 1
#    nombreux: 1
#    type: 1
#    orphelin: 1
#    progeniture: 1
#    abandonner: 1
#    recevoir: 1
#    familial: 1
#    symetrie: 1
#    nonbiologique: 1
#    autre: 1
#    supergrand: 1
#    etre: 2
#    adopter: 1
#    elever: 1
#    phratrie: 1
#    daccueil: 1
#    endroit: 1
#    orphelinat: 1
#
#
# Document : Éducation familiale (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 2
#    <LOCATION>: 1
#    comme: 1
#    cas: 1
#    voici: 1
#    male: 1
#    La_Tragedie_d'Hamlet: 1
#    Tyndale: 1
#    shakespeare: 1
#    yak: 1
#    polonius: 1
#    transmettre: 1
#    quelque: 1
#    lever: 1
#    principe: 1
#    deducation: 1
#    fils: 1
#    laert: 1
#    quand: 1
#    celuici: 1
#    decider: 1
#    conge: 1
#    france: 1
#
#
# Document : Éducation familiale (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    <LOCATION>: 2
#    <<: 1
#    encore: 1
#    Hera: 1
#    laert: 1
#    cor: 2
#    quel: 1
#    hont: 1
#    tempete: 2
#    asseoir: 1
#    lepaule: 1
#    niqab: 1
#    lon: 1
#    attente: 1
#    voici: 1
#    grace: 2
#    rassembler: 1
#    patte: 2
#    esprit: 1
#    laerte: 1
#    rasibus: 1
#    graf: 1
#    souvenir: 1
#    quelque: 1
#    principe: 1
#    refus: 1
#    lexpression: 1
#    gouvernement: 1
#    lexecution: 1
#    tout: 1
#    opinion: 1
#    irreflechi: 1
#    aliment: 1
#    nullement: 1
#    vulgaire: 1
#    quand: 1
#    adopter: 1
#    eprouver: 1
#    allier: 2
#    accrochele: 1
#    am: 1
#    crampon: 1
#    dacier: 1
#    durci: 1
#    verres_de_contact: 1
#    premiere_vitesse: 2
#    partenaire: 1
#    fraise: 1
#    eclore: 1
#    denichera: 1
#    gardetoi: 1
#    dentrer: 1
#    duree: 1
#    dedans: 1
#    comportetoi: 1
#    facon: 1
#    ladversair: 1
#    detention: 1
#    prete: 1
#    loreill: 1
#    femme: 2
#    propos: 1
#    progeniture: 1
#    numero: 2
#    prend: 1
#    lopinion: 1
#    chacun: 1
#    qualification: 1
#    tribulation: 1
#    parier: 1
#    aussi: 2
#    couteus: 1
#    echange: 1
#    permission: 1
#    sans: 1
#    etre: 2
#    fantasy: 1
#    excentrique: 1
#    riche: 1
#    voyant: 1
#    car: 2
#    habillement: 1
#    reveler: 1
#    souvent: 2
#    lhomm: 1
#    Francois-Anatole_Thibault: 1
#    Dhakhan: 1
#    specificite: 1
#    rang: 1
#    sou: 1
#    theme: 1
#    aromatiser: 1
#    obtention: 2
#    exquis: 1
#    digne: 1
#    ni: 2
#    emprunteur: 1
#    preteur: 1
#    calque: 1
# ...
#    privilegier: 1
#    raffinement: 1
#    ensemble: 1
#    theme: 1
#    celui: 1
#    proposer: 1
#    train: 1
#    operationnel: 1
#    humain: 1
#    avoir: 2
#    priori: 1
#    obtention: 1
#    mobilisable: 1
#    echange: 1
#    coutume: 1
#    speculation: 1
#    alternatif: 1
#    signalisation: 1
#    donc: 1
#    developper: 1
#    annee: 1
#    Canadiens_francais: 1
#    michael: 1
#    spence: 1
#    retrouver: 1
#    opinion: 1
#    similaire: 1
#    verticille: 1
#    filtrage: 1
#    assigner: 1
#    cadre: 1
#    kenneth: 1
#    arrow: 1
#
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    leducation: 1
#    domaine: 1
#    effectuer: 1
#    college: 2
#    contrat: 1
#    detective: 1
#    linstruction: 1
#    residence: 1
#    egalement: 1
#    possible: 1
#    debris: 1
#    minorite: 1
#    cependant: 1
#    tension: 1
#    developper: 1
#
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    lhypothese: 1
#    lexistence: 2
#    dun: 3
#    <<: 1
#    echange: 2
#    educatif: 1
#    >>: 1
#    tuyau: 1
#    instabilite: 1
#    decoupage: 1
#    social: 1
#    ecolier: 1
#    gerance: 3
#    scolaire: 1
#    evoquer: 1
#    composant: 2
#    favoriser: 1
#    symetrie: 2
#    capitale: 2
#    financier: 1
#    ex-mari: 1
#    habitat: 1
#    circonscription: 1
#    aiser: 1
#    proche: 1
#    college: 1
#    considerer: 1
#    comme: 1
#    specificite: 1
#    etou: 1
#    option: 1
#    payer: 1
#    fraise: 1
#    pedagogique: 1
#    acceder: 2
#    certain: 1
#    priver: 1
#    dautr: 1
#    culturel: 1
#    savoir-faire: 1
#    projet: 1
#    meilleur: 1
#    strate: 1
#    notamment: 1
#    la_soupe_au_canard: 1
#    doptier: 1
#    savoir: 1
#    deux: 1
#    supergrand: 1
#    etre: 1
#    cumulatif: 1
#
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    sembler: 1
#    plusieurs: 1
#    paysage: 1
#    largent: 1
#    important: 1
#    reussite: 1
#    educatif: 1
#    donne: 1
#    option: 1
#    dacceder: 1
#    recommandation: 1
#    Moi: 1
#    course: 1
#    nuit: 1
#    visiter: 1
#    philologie: 1
#    pratique: 1
#    culturel: 1
#    permission: 1
#    payer: 1
#    fraise: 1
#    dentrer: 1
#    gerance: 1
#    selectif: 1
#    primaire: 1
#    secondaire: 1
#    haut: 1
#
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    selon: 1
#    paysage: 1
#    decoupage: 1
#    publicprive: 1
#    differ: 1
#    femme: 1
#    comme: 1
#    quantite: 1
#    daide: 1
#    contrat: 3
#    destination: 1
#    college: 1
#    detective: 1
#    ainsi: 1
#    forme: 1
#    lier: 1
#    lobtention: 1
#    subvention: 1
#    obtention: 1
#    fraise: 1
#    dinscription: 1
#    enseignement: 1
#    fourniture: 1
#    supergrand: 1
#    varier: 1
#
#
# Document : Canada (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    college: 1
#    priver: 1
#    payanter: 1
#    quantite: 2
#    fraise: 1
#    supergrand: 1
#    etre: 1
#    obstacle: 1
#    mixte: 1
#    social: 1
#    subvention: 1
#    contrat: 1
#    plafonner: 1
#
#
# Document : France (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    Francois-Anatole_Thibault: 1
#    lecol: 1
#    contrat: 1
#    gratuit: 1
#    jusqua: 1
#    propos: 1
#    enseignement: 1
#    obligatoire: 1
#    dans: 1
#    fraise: 1
#    varier: 1
#    souvent: 1
#    exiger: 1
#    college: 1
#    detective: 1
#    supergrand: 1
#    tuyau: 1
#    exclur: 1
#    lacce: 1
#    ecolier: 1
#    phratrie: 1
#    obtention: 1
#    precaire: 1
#    ecstasy: 1
#    lencontre: 1
#    regle: 1
#    daccessibilite: 1
#    viser: 1
#    leducation: 1
#    femme: 1
#
#
# Document : Sources (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    ce: 1
#    regle: 1
#    partiellement: 1
#    entierete: 1
#    issu: 1
#    supplement: 1
#    <<: 1
#    dechiffrer: 1
#    code: 1
#    leducation: 1
#    gamine: 1
#    femme: 1
#    savoir: 1
#    recherche_appliquee: 1
#    ingenieri: 1
#    mathematique: 1
#    stem: 1
#    >>: 1
#    unesco: 1
#    projet: 1
#    endroit: 1
#    generateur: 1
#    responsable: 1
#    probleme: 1
#    sou: 1
#    cc: 1
#    bysa: 1
#    igo: 1
#
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 4
#    philippe: 1
#    aries: 1
#    dir: 2
#    georges: 1
#    duby: 1
#    p: 1
#    Brown: 1
#    evelyn: 1
#    patlagean: 1
#    michel: 1
#    rouche: 1
#    yvon: 1
#    thebert: 1
#    paul: 1
#    veyne: 1
#    description: 1
#    faune: 1
#    priver: 1
#    avion: 1
#    lempire: 1
#    police_romaine: 1
#    lan: 1
#    mil: 1
#    pari: 1
#    redactrices_en_chef: 1
#    huis: 1
#    penis: 1
#    isbn: 1
#
#
# Document : Notes et références (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 16
#    <PERSON>: 21
#    |: 38
#    monde: 1
#    forme: 5
#    educatio: 1
#    gaffiot: 1
#    latinfrancer: 1
#    mialaret: 1
#    gramme: 1
#    savoir: 4
#    formation: 9
#    puf: 1
#    saisje: 1
#    no: 2
#    e: 2
#    redactrices_en_chef: 2
#    httpswwwcairninforevueletelemaque: 1
#    supplement: 1
#    Hypertext_Markup_Language: 1
#    dessu: 1
#    philipp: 1
#    <<: 13
#    qu': 1
#    estce: 1
#    enseignemer: 1
#    quelque: 1
#    prescription: 1
#    >>: 13
#    revue: 4
#    Daniel_Chester_French: 2
#    enseignement: 2
#    rechercher: 1
#    ens: 1
#    : 1
#    ER: 1
#    juillet: 6
#    penis: 7
#    -: 2
#    isbn: 2
#    issn: 2
#    doi: 3
#    rfp: 1
#    lire: 8
#    ligne: 7
#    consulter: 11
#    novembre: 1
#    aries: 1
#    jeanjacque: 1
#    rousseau: 1
#    emil: 1
#    leducation: 2
#    wikisource: 1
#    pdf: 2
#    projet: 1
#    officiel: 1
#    femme: 3
#    savoir-faire: 1
#    methodologique: 1
#    sociale: 1
#    viser: 1
#    Sarah: 2
#    currier: 1
#    sheila: 1
#    macneill: 1
#    lisa: 1
#    corley: 1
#    lorna: 1
#    Campbell: 1
#    helen: 1
#    beetham: 1
#    dictionnaire: 1
#    decrire: 1
#    avancee: 1
#    pedagogique: 1
#    obtention: 1
#    explorer: 2
#    cadrage: 1
#    numero: 3
#    ametist: 2
#    Benjamin: 1
#    rougir: 1
#    David: 1
#    r: 1
#    krathwohl: 2
#    the: 12
#    nomenclature: 1
#    of: 13
#    educational: 1
#    goal: 1
#    by: 2
#    avoir: 4
#    committee: 1
#    college: 5
#    and: 5
#    university: 2
#    new: 1
#    York: 1
#    longmans: 1
#    mcneil: 1
#    blooms: 2
#    taxonomy: 2
#    cognitif: 3
#    domain: 3
#    instructional: 1
#    design: 1
#    houston: 1
#    jan: 1
#    work: 1
#    was: 1
#    completed: 1
#    in: 3
#    is: 2
#    commonly: 1
#    referred: 1
#    to: 8
#    although: 1
#    there: 1
#    were: 1
#    other: 1
#    authors: 1
#    englehart: 1
#    furst: 1
#    w: 1
#    hill: 1
#    wolf: 1
#    marcus: 1
#    extrusion: 1
#    math: 1
#    estelle: 1
#    mal: 1
#    mental: 1
#    ed: 1
#    trouver: 1
#    Marc: 1
#    bris: 1
#    progeniture: 3
#    ...: 1
#    ni: 1
#    comte: 1
#    stock: 1
#    tiehi: 1
#    majority: 1
#    children: 1
#    live: 1
#    with: 1
#    two: 1
#    biological: 1
#    parent: 1
#    archiv: 1
#    Avril: 1
#    consulte: 1
#    La_Tragedie_d'Hamlet: 1
#    Tyndale: 1
#    shakespeare: 1
#    scene: 1
#    iii: 1
#    sain: 1
#    comme: 1
#    dapprentissage: 1
#    George_du_Maurier: 1
#    zacharopoulos: 1
#    francesco: 1
#    sella: 1
#    baron: 1
#    cohen: 1
#    kadosh: 1
#    impact: 1
#    lack: 1
#    mathematical: 1
#    education: 10
#    brain: 1
#    developmer: 1
#    avenir: 1
#    attainment: 1
#    pnas: 1
#    juin: 1
#    San_Pedro_Sula: 2
#    pna: 1
#    administration_federale: 2
#    courtier: 1
#    special: 3
#    messager_sagittaire: 1
#    ensemble: 1
#    voie: 2
#    proposition: 2
#    acharnement: 2
#    contre: 1
#    venir: 1
#    terme: 1
#    combler: 1
#    repartition: 1
#    entrer: 1
#    standard: 1
#    pratique: 1
#    pari: 2
#    onu: 1
#    p: 1
#    pierart: 1
#    g: 1
#    betrisey: 1
#    tetreault: 1
#    margotcattin: 2
#    robot: 1
#    linclusion: 1
#    scolaire: 2
#    defaut: 1
#    tamias: 1
#    romand: 1
#    gouvernement: 1
#    contrat: 3
#    xxi: 1
#    copulation: 1
#    airhm: 1
#    Quebec: 2
#    pp: 1
#    quebec: 1
#    imprimerie: 1
#    defining: 1
#    quality: 1
#    right: 7
#    initiativ: 4
#    contradicting: 1
#    commitment: 1
#    how: 1
#    achievemer: 1
#    for: 1
#    all: 1
#    being: 1
#    undermined: 1
#    international: 2
#    monetary: 1
#    fund: 1
#    report: 2
#    rapporteur: 2
#    person: 1
#    dans: 1
#    detention: 1
#    post: 1
#    unesco: 2
#    dechiffrer: 1
#    code: 1
#    gamine: 1
#    recherche_appliquee: 1
#    ingenieri: 1
#    mathematique: 1
#    stem: 1
#    gerance: 1
#    etat: 1
#    unir: 1
#    raffinement: 1
#    avantpropo: 1
#    bill: 1
#    Dakar: 1
#    tout: 1
#    maintien: 1
#    allegeance: 1
#    collectif: 1
#    propos: 2
#    theme: 2
#    controle: 1
#    lept: 1
#    b: 1
#    tomasevski: 1
#    k: 1
#    annuel: 1
#    policier: 3
#    presenter: 1
#    coutume: 1
#    declaration: 1
#    commerce: 1
#    ecn: 1
#    male: 1
#    cinquantehuitiem: 1
#    session: 1
#    lenfant: 1
#    regle: 1
#    Jacob: 1
#    mincer: 1
#    schooling: 1
#    experience: 1
#    earning: 1
#    national: 1
#    economic: 1
#    research: 1
#    minc: 1
#    september: 1
#    dominiqu: 1
#    glasman: 1
#    Montserrat: 1
#    bongrand: 1
#    phratrie: 1
#    prospection: 1
#    sociologique: 1
#    prodige: 1
#    emergent: 1
#    pedagogie: 1
#    Bernard: 1
#    cornu: 1
#    segmer: 1
#    echange: 1
#    sevres: 1
#    er: 1
#    decembre: 1
#    rie: 1
#    Sept: 3
#    webjournal: 1
#    thomas: 1
#    piketty: 1
#    opinion: 1
#    souhaiteil: 1
#    mixte: 2
#    social: 2
#    blog: 1
#    cosmos: 1
#    jeanfrancois: 1
#    landry: 1
#    federation: 1
#    autonome: 1
#    lenseignemer: 2
#    appui: 1
#    detective: 1
#    rassembler: 1
#    Myth: 1
#    Octobre: 1
#    may: 1
#    arnaud: 1
#    parienty: 1
#    school: 1
#    clientele: 1
#    priver: 1
#    obstacle: 1
#    cafepedagogiquenet: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    autre: 1
#    propos: 1
#    wikimedia: 1
#
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    formation: 1
#    wikimedia: 1
#    commonseducation: 1
#    wiktionnaireeducation: 1
#    wikiversityeducation: 1
#    wikibookseducation: 1
#    wikisourceeducation: 1
#    wikiquoteeducation: 1
#    wikinews: 1
#
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 5
#    <LOCATION>: 1
#    Dylan_Thomas: 1
#    koninck: 2
#    original: 1
#    ignorance: 1
#    specificite: 1
#    raffinement: 1
#    pari: 2
#    puf: 2
#    intervention: 1
#    philosophique: 1
#    reediter: 1
#    traduire: 1
#    portuger: 1
#    thomas: 1
#    gouvernement: 1
#    leducation: 3
#    traite: 1
#    devenir: 1
#    homo_sapiens: 1
#    introduction: 1
#    federico: 1
#    mayor: 1
#    zaragoza: 1
#    postface: 1
#    e: 1
#    mohamed: 1
#    achaari: 1
#    alain: 1
#    chanlat: 1
#    abdelkarim: 1
#    errouaki: 1
#    Themis: 1
#    penis: 2
#    erny: 1
#    ethnologie: 1
#    ed: 1
#    lharmattan: 1
#    description: 2
#    revue: 1
#    Jessye_Norman: 1
#    baillargeon: 1
#    lordre: 1
#    moins: 1
#    supergrand: 1
#    actualite: 1
#    lanarchisme: 1
#    agone: 1
#    lux: 1
#    redactrices_en_chef: 1
#
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    <PERSON>: 1
#    emil: 1
#    formation: 1
#    jeanjacque: 1
#    rousseau: 1
#    wikisource: 1
#    leducation: 1
#    progeniture: 1
#    plutarqu: 1
#    pedagogue: 1
#    specialise: 1
#    gregory: 1
#    degenaer: 1
#    redactrices_en_chef: 1
#    ash: 1
#
#
# Document : Articles connexes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 2
#    <PERSON>: 1
#    obtention: 1
#    autoformation: 1
#    cateches: 1
#    college: 2
#    manoir: 1
#    economie: 1
#    leducation: 4
#    formation: 6
#    lenvironnement: 1
#    pousser: 3
#    immobilisation: 1
#    populaire: 1
#    socioculturel: 1
#    lenseignemer: 1
#    agricole: 1
#    france: 2
#    specialise: 1
#    enseignement: 3
#    train: 1
#    continuer: 1
#    description: 1
#    journee: 1
#    international: 1
#    reciprocite: 1
#    lernen: 1
#    durch: 1
#    lehren: 1
#    ldl: 1
#    espace: 1
#    deducation: 1
#    mixte: 1
#    social: 1
#    unesco: 1
#    gerance: 1
#    etat: 1
#    unir: 1
#    savoir: 1
#    raffinement: 1
#    empreinte: 1
#    plasticiter: 1
#    neuronal: 1
#    psychologie: 1
#    calendrier: 1
#    denseignement: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 2
#    <LOCATION>: 7
#    avenue: 2
#    respecter: 2
#    documentation: 1
#    the: 3
#    encyclopedier: 1
#    of: 4
#    savoir: 1
#    fiction: 1
#    bien-etre: 1
#    medical: 1
#    subject: 1
#    heading: 1
#    notice: 2
#    tableau_associatif: 1
#    encyclopedie: 1
#    docteur: 2
#    britannica: 1
#    den: 1
#    lunettes_de_soleil: 1
#    dansk: 1
#    encyklopaedi: 1
#    dictionnair: 1
#    historique: 1
#    tamias: 1
#    encyclopedia: 4
#    cleveland: 1
#    history: 2
#    great: 1
#    plain: 1
#    gran: 2
#    enciclopedia: 2
#    aragonesa: 1
#    catalana: 1
#    handbook: 1
#    texa: 1
#    onlin: 1
#    universali: 1
#    Utah: 1
#    west: 1
#    virginia: 1
#    dautorite: 1
#    lccn: 1
#    gnd: 1
#    japonais: 1
#    Espagne: 1
#    Israel: 1
#    tchequi: 1
#    Lettonie: 1
#    forme: 1
#    analyse_qualitative: 1
#    gouvernement: 1
#    educatif: 2
#    ocde: 1
#    education: 1
#    planifier: 1
#    leducation: 5
#    construir: 1
#    lavenir: 1
#    institut: 2
#    international: 1
#    conception: 1
#    unesco: 1
#    pousser: 1
#    curriculum: 1
#    cadre: 1
#    scolaire: 1
#    mondial: 1
#    hstreasure: 1
#    decouverte: 1
#    linnovation: 1
#    irie: 1
#    policier: 2
#    veine_porte: 2
#    lenfer: 1
#    humanium: 1
#    procureur: 1
#    Quebec: 1
#    intervention: 1
#    clarification: 1
#    conceptuel: 1
#    enjeux: 1
#    social: 1
#    yve: 1
#    lenoir: 1
#    canader: 1
#    lenseignemer: 1
#    federation: 1
#    walloniebruxelles: 1
#    belgiqu: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    the: 1
#    encyclopedier: 1
#    of: 1
#    savoir: 1
#    fiction: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    medical: 1
#    subject: 1
#    heading: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 2
#    <LOCATION>: 1
#    britannicer: 1
#    den: 1
#    lunettes_de_soleil: 1
#    dansk: 1
#    encyklopaedi: 1
#    dictionnair: 1
#    historique: 1
#    tamias: 1
#    encyclopedia: 4
#    of: 3
#    cleveland: 1
#    history: 2
#    the: 2
#    great: 1
#    plain: 1
#    gran: 2
#    enciclopedia: 2
#    aragonesa: 1
#    catalana: 1
#    handbook: 1
#    texa: 1
#    onlin: 1
#    universali: 1
#    Utah: 1
#    west: 1
#    virginia: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    lccn: 1
#    gnd: 1
#    japonais: 1
#    Espagne: 1
#    Israel: 1
#    tchequi: 1
#    Lettonie: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    raffinement: 6
#    ensemble: 1
#    legitimite: 1
#    Lot: 1
#    populaire: 1
#    contreculture: 1
#    sousculture: 1
#    capitale: 1
#    culturel: 1
#    tradition: 1
#    oral: 1
#    civilisation: 1
#    ethologi: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    socialisation: 1
#    formation: 1
#    acculturation: 2
#    transculturation: 1
#    rayonnemer: 1
#    culturel: 2
#    hegemonie: 1
#    ethnocide: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <PERSON>: 1
#    evolutionnisme: 1
#    diffusionnisme: 1
#    fonctionnalism: 1
#    culturalisme: 1
#    ligne: 1
#    penis: 1
#    bourdieu: 1
#    structuralisme: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    anthropologie: 4
#    culturel: 14
#    psychanalytique: 1
#    astronomie: 1
#    trouble_de_la_personnalite: 1
#    ethnomedecine: 1
#    ethnographie: 1
#    ethnologie: 1
#    ethnopsychiatrie: 1
#    ethnopsychanalyse: 1
#    ethnopharmacologie: 1
#    ethnobiologie: 1
#    ethnozoologie: 1
#    ethnoentomologie: 1
#    ethnobotanique: 1
#    ethnoornithologie: 1
#    ethnoichthyologie: 1
#    ethnoherpetologie: 1
#    ethnoprimatologie: 1
#    ethnomycologie: 1
#    ethnolichenologie: 1
#    ethnoecologie: 1
#    ethnohistoir: 1
#    ethnoarcheologie: 1
#    ethnomathematique: 1
#    ethologie: 1
#    ecologie: 1
#    ecologique: 1
#    geographie: 1
#    neuroscience: 1
#    explorer: 3
#    description: 1
#    culturologie: 1
#    hypothese: 1
#    raffinement: 6
#    neuroculture: 1
#    bioculture: 1
#    comparaison: 1
#    psychologie: 3
#    interculturel: 4
#    pousser: 1
#    analyse_qualitative: 1
#    economie: 1
#    cartographi: 1
#    culturomiqu: 1
#    obtention: 1
#    radicalisme: 1
#    sociologie: 2
#    semiologie: 1
#    gouvernement: 1
#    theologie: 1
#    populaire: 1
#    propos: 1
#
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# TF :
#    <LOCATION>: 1
#    veine_porte: 5
#    formation: 1
#    guilde: 1
#    raffinement: 1
#    policier: 1
#    sociologie: 1

# %% [markdown]
# affichage de df

# %%
from collections import Counter

# fonction pour calculer la fréquence des documents (DF)
def calculate_df(processed_documents):
    df_counter = Counter()

    for doc in processed_documents:
        # obtenir les mots uniques de chaque document
        unique_tokens = set(doc['tokens'])

        # mettre à jour le compteur DF pour chaque mot unique
        df_counter.update(unique_tokens)

    return df_counter

df = calculate_df(processed_documents)

# %% [markdown]
# affichage de df

# %%
# fonction pour afficher la fréquence des documents (DF)
def display_df(df):
    print("\nDocument Frequency (DF) pour chaque mot :\n")
    for token, df_value in df.items():
        print(f"   {token}: {df_value}")

display_df(df)
# Out:
# Streaming output truncated to the last 5000 lines.
#    imprimerie: 10
#    dreyfu: 4
#    autoriser: 3
#    qua: 3
#    parure: 1
#    Inde: 2
#    syndicat_du_crime: 1
#    maroc: 5
#    lecole: 8
#    gratuit: 5
#    imminentee: 1
#    lexterieur: 2
#    Tunisie: 4
#    accorder: 4
#    lalgerie: 1
#    panama: 2
#    separer: 3
#    la_soupe_au_canard: 5
#    cellesci: 2
#    larmee: 2
#    reconstruction_apres_la_guerre_de_Secession: 2
#    eviter: 1
#    gauche: 5
#    suffire: 2
#    obtenant: 1
#    securite: 1
#    remilitarisation: 1
#    lalsacelorraine: 1
#    daout: 1
#    lunaison: 2
#    tripleententee: 1
#    compensation: 1
#    prevoir: 3
#    banque: 1
#    victime: 2
#    partisan: 4
#    russe: 2
#    immobilisation: 2
#    solidite: 2
#    quer: 1
#    lallemagn: 2
#    juste: 1
#    tardif: 1
#    lespoir: 1
#    maindoeuvre: 3
#    productivite: 2
#    laborieux: 1
#    lautomobil: 1
#    exterieur: 2
#    tranchee: 1
#    deficit: 1
#    mal: 7
#    presence: 2
#    populaire: 13
#    pallier: 1
#    davantguerre: 1
#    declarer: 5
#    republiquee: 1
#    pein: 1
#    sajout: 1
#    avant: 13
#    larriver: 2
#    dimmigration: 1
#    sourcils: 5
#    lacier: 2
#    linterieur: 1
#    cicatrisere: 1
#    precedentn: 1
#    sorganis: 1
#    envahir: 1
#    plein: 3
#    Shoah: 1
#    antisemite: 1
#    mort: 3
#    traditionaliste: 2
#    psychologique: 1
#    fiasco: 2
#    loccupation: 1
#    allier: 8
#    lepuration: 1
#    de: 1
#    Vichy: 4
#    petain: 1
#    conservateur: 2
#    collabore: 1
#    Urd_;_Wyrd: 1
#    larmistice: 1
#    sonn: 1
#    leuropee: 1
#    philipp: 2
#    debarquement: 1
#    wehrmacht: 1
#    signant: 1
#    juillet: 13
#    marechal: 1
#    resistance: 3
#    cooperation: 2
#    gaulle: 5
#    europeennee: 1
#    fourastier: 2
#    leconomist: 3
#    glorieusese: 1
#    ladoption: 4
#    femmese: 1
#    souvre: 2
#    structure: 14
#    loi_organique: 11
#    dindochin: 1
#    modernisation: 1
#    jean: 15
#    lapresguerre: 1
#    Camp_de_refugies: 2
#    lafrique: 3
#    lasie: 1
#    decolonisation: 2
#    dalgeri: 2
#    choisir: 2
#    fissure: 2
#    patte: 4
#    estudiantin: 1
#    demissionner: 1
#    nucleaire: 10
#    cependant: 18
#    depeindre: 1
#    conserver: 3
#    lechec: 2
#    petit: 5
#    son: 7
#    regionalisation: 2
#    plus: 1
#    lindependance: 3
#    achever: 1
#    inspiration: 2
#    investir: 1
#    dissolution: 1
#    gaullisme: 1
#    ER: 6
#    etatsunis: 1
#    poursuit: 1
#    pompidoue: 1
#    cinquieme: 10
#    georges: 3
#    quun: 4
#    droite: 4
#    socialisme: 5
#    relancee: 1
#    institutionse: 1
#    mandat: 1
#    legalis: 1
#    lionel: 2
#    lorsquun: 1
#    mitterrand: 2
#    civilee: 1
#    inedit: 2
#    lage: 4
#    adopter: 9
#    valery: 1
#    tipi: 1
#    jospin: 2
#    destainge: 1
#    centredroit: 3
#    inverser: 1
#    jusquela: 3
#    symboliquement: 1
#    avortement: 3
#    veil: 1
#    version: 3
#    acter: 1
#    chirac: 2
#    saggrav: 1
#    gouvernemente: 1
#    legislatif: 6
#    amener: 4
#    labaissement: 1
#    cohabitation: 1
#    giscard: 1
#    postgaullist: 1
#    linterruption: 2
#    reproduire: 1
#    nappartient: 1
#    parti: 11
#    lelimination: 3
#    dirak: 1
#    raffarin: 2
#    ratification: 1
#    fillon: 2
#    journaliste: 3
#    diriger: 2
#    lextrem: 1
#    pen: 2
#    manque: 4
#    precedent: 2
#    sarkozy: 2
#    jeanmarie: 2
#    des: 9
#    douverture: 1
#    postulant: 5
#    villepin: 2
#    nicolas: 2
#    penis: 64
#    unique: 6
#    citoyenne: 6
#    rupture: 3
#    prince-electeur: 3
#    leconomie: 13
#    pourvoyeur: 1
#    republiqu: 3
#    virage: 1
#    emmanuel: 3
#    hausse: 5
#    primaire: 8
#    hollande: 1
#    piaule: 3
#    consul: 1
#    cabinet: 1
#    holland: 3
#    suivre: 3
#    noce: 4
#    nettoyer: 7
#    lissu: 1
#    socialliberal: 1
#    duo: 4
#    tuyau: 5
#    fiscalite: 2
#    adjoint: 1
#    macron_-: 5
#    messager_sagittaire: 5
#    prolonger: 2
#    meurtriere: 1
#    terroriste: 2
#    dattentat: 1
#    durgence: 3
#    decret: 2
#    vigipirate: 3
#    covid: 3
#    budgetaire: 3
#    imposer: 1
#    massive: 1
#    hygiene: 3
#    soutenir: 7
#    pandemie: 2
#    endiguement: 2
#    democratisation: 2
#    indivisible: 1
#    gerance: 20
#    fixer: 1
#    decentraliser: 1
#    roman: 2
#    observer: 6
#    semipresidentiel: 2
#    presidentialiser: 1
#    constitutionnaliste: 1
#    constitutionk: 1
#    reprisesk: 1
#    amender: 1
#    verticille: 16
#    birepresentatifn: 1
#    type: 9
#    frottement: 1
#    nationalek: 2
#    uninominal: 3
#    senateur: 3
#    departementsk: 1
#    senatk: 1
#    direct: 6
#    lassemble: 1
#    decouper: 1
#    representative: 1
#    majoritaire: 3
#    dernierk: 1
#    republiquek: 1
#    gouvernementk: 1
#    cadre: 25
#    toursk: 1
#    mefiance: 1
#    dissoudre: 1
#    nappartiennent: 1
#    promulguer: 1
#    cohabitationk: 1
#    romanocivilist: 1
#    recours: 4
#    innocent: 1
#    cassationk: 1
#    partiesn: 1
#    bravoure: 5
#    tradition: 9
#    rejuger: 1
#    accuser: 2
#    exactitude: 1
#    constitutionnelk: 1
#    conformite: 2
#    intercommunal: 1
#    departemental: 2
#    prefetk: 1
#    ager: 1
#    elusn: 1
#    saccroitk: 1
#    generalement: 6
#    detablissement: 1
#    dirige: 1
#    francaisek: 1
#    englober: 2
#    intervenir: 1
#    cantonsk: 1
#    lemergence: 4
#    collaboration: 4
#    municipalk: 1
#    administrer: 1
#    gerant_municipal: 3
#    jan: 11
#    collectivite: 11
#    communek: 1
#    courtier: 5
#    savoir-faire: 21
#    sajoutent: 1
#    dalsace: 3
#    regionalk: 1
#    recentek: 1
#    larrondissement: 1
#    recemment: 3
#    prefet: 1
#    regionk: 1
#    deconcentrer: 1
#    poursuivre: 2
#    vall: 2
#    faiblesk: 1
#    laction: 2
#    marche: 1
#    posteriori: 1
#    lavenir: 2
#    fonctionnaire: 6
#    devolution: 4
#    robot: 9
#    proposer: 6
#    evoluer: 6
#    superposition: 1
#    informateur: 5
#    lacte: 1
#    defferre: 1
#    decoupage: 4
#    pencher: 1
#    scolaire: 16
#    grisonner: 1
#    relativement: 11
#    voisin: 3
#    procede: 2
#    restee: 1
#    globalemer: 1
#    dancienne: 1
#    juridique: 3
#    mayotten: 1
#    loi: 2
#    ultramarine: 1
#    ultraperipherique: 2
#    applique: 2
#    metropolitaine: 1
#    conserve: 1
#    specialisation: 5
#    generis: 1
#    lautonomie: 1
#    sui: 1
#    naccueiller: 1
#    citoyennete: 1
#    wallisetfutuner: 1
#    futuna: 1
#    wallis: 1
#    epr: 1
#    hor: 1
#    dem: 1
#    gdr: 1
#    ad: 1
#    liot: 1
#    ldr: 1
#    lfinfp: 1
#    soc: 1
#    rn: 1
#    eco: 1
#    dextrem: 1
#    progressif: 1
#    consequent: 2
#    lelectorat: 1
#    tripolarisation: 1
#    francaisn: 1
#    arrierek: 1
#    centriste: 2
#    communiste: 3
#    formationsn: 1
#    cur: 9
#    frequent: 1
#    politiquen: 1
#    prevaloir: 1
#    labstention: 1
#    laudience: 2
#    droiten: 1
#    bipolarisation: 1
#    delecteur: 1
#    pigiste: 1
#    fn: 2
#    rassemblement: 2
#    eelv: 1
#    pcf: 1
#    union: 7
#    insoumis: 1
#    lr: 1
#    limmigration: 5
#    nationaliste: 2
#    udi: 1
#    centregauch: 2
#    opposer: 2
#    participer: 5
#    ecologistesn: 1
#    extremedroite: 1
#    ecosocialiste: 1
#    vert: 2
#    souverainiste: 1
#    rpr: 1
#    ecologie: 3
#    centregauche: 3
#    ps: 3
#    modem: 1
#    populiste: 1
#    ump: 2
#    ensuite: 2
#    reunir: 3
#    europhile: 1
#    l'elimination: 2
#    recomposition: 1
#    Marches_''pl''_&lt;!---_(''gender?'')_---&gt;: 2
#    socialeliberal: 1
#    presidence: 4
#    francoi: 2
#    auparaver: 1
#    poc: 1
#    Breton: 1
#    palima: 1
#    environnementaliste: 2
#    corse: 2
#    unir: 5
#    importance: 7
#    pe: 1
#    martiniquais: 1
#    ppm: 1
#    kanak: 1
#    independantiste: 1
#    rdm: 1
#    socialdemocrat: 1
#    provencal: 2
#    mim: 1
#    progressiste: 2
#    Martinique: 1
#    udb: 1
#    alliance: 1
#    un_tandem_de_choc: 4
#    partit: 1
#    extremegauch: 1
#    melanesien: 1
#    huiraatirer: 1
#    corsicer: 1
#    peripherique_informatique: 1
#    biais: 2
#    tavini: 1
#    regionaliste: 1
#    flnk: 1
#    autonomiste: 1
#    simplement: 2
#    occitaniste: 1
#    dentre: 1
#    PIB: 17
#    linverse: 1
#    locdea: 1
#    tau|taux: 21
#    developpe: 2
#    locde: 7
#    retenue: 6
#    obligatoireser: 1
#    dix: 5
#    nettement: 1
#    dexcedent: 1
#    realiser: 3
#    frais: 11
#    na: 3
#    euro: 6
#    standard: 9
#    lannee: 3
#    emprunt: 3
#    piba: 1
#    structurel: 1
#    constance: 1
#    poor: 1
#    Chinoise: 3
#    mathematiques: 3
#    fitch: 1
#    aer: 1
#    Tresor_public: 2
#    Chinook: 4
#    AAA: 1
#    lagence: 6
#    accelerer: 2
#    moody: 2
#    maximal: 1
#    rabaisser: 1
#    saluer: 2
#    Avril: 9
#    relever: 1
#    lamelioration: 4
#    aa: 2
#    estimer: 4
#    demmanuel: 1
#    revoir: 1
#    chance: 3
#    dagong: 2
#    stable: 3
#    lente: 1
#    reconnaitre: 8
#    poster: 3
#    edan: 1
#    permanence: 2
#    nonproliferation: 2
#    md: 1
#    artillerie: 3
#    sipri: 1
#    lotan: 9
#    larme: 2
#    financieremer: 1
#    lune: 1
#    dotee: 1
#    operation_militaire: 5
#    darmement: 4
#    juridiquement: 1
#    metamorphose: 2
#    act: 1
#    Britten: 3
#    maitrise: 3
#    mdEUR: 2
#    retraite: 1
#    budget: 4
#    darme: 3
#    uni: 11
#    mobiliser: 1
#    oublier: 1
#    professionnalisme: 8
#    positionner: 2
#    priorite: 8
#    international: 28
#    emirat: 2
#    sortir: 3
#    Djibouti: 2
#    citoyenneter: 1
#    lespace: 6
#    journee: 3
#    denviron: 5
#    divoir: 3
#    senegaln: 1
#    sahel: 1
#    doperation: 1
#    deployer: 2
#    centrafricaine: 1
#    liban: 3
#    remplacer: 3
#    irak: 1
#    gendarmerie_nationale: 2
#    prepositionner: 2
#    Republique_gabonaise: 2
#    alphabet_arabe: 3
#    Mali: 2
#    tchad: 2
#    critiquer: 3
#    exporteur: 4
#    gras: 5
#    gramme: 4
#    WTO: 1
#    OTAN: 4
#    ocde: 4
#    latlantique: 3
#    francophonie: 8
#    balancing: 1
#    faciliter: 2
#    darret: 1
#    Pere: 3
#    francoallemand: 3
#    ambigu: 1
#    robert: 4
#    etrangere: 8
#    positionnement: 2
#    monnet: 1
#    deviter: 1
#    schuman: 1
#    guepe: 1
#    visavis: 3
#    refus: 2
#    nationalk: 1
#    receveur: 2
#    bonte: 4
#    profonde: 4
#    debatd: 1
#    applicable: 2
#    quactuellement: 1
#    dauter: 2
#    benefique: 1
#    payeur: 1
#    nombreuxk: 1
#    europeennek: 1
#    francaised: 1
#    maastricht: 1
#    peser: 2
#    europeenned: 1
#    parier: 5
#    suppression: 2
#    dindependanc: 1
#    traduire: 4
#    disrael: 1
#    bienveillance: 1
#    arabomusulman: 1
#    consulaire: 1
#    diplomatique: 3
#    ambassade: 2
#    laid: 1
#    distribuer: 1
#    via: 1
#    brut: 6
#    dafriquen: 1
#    enormite: 1
#    degal: 1
#    rouget: 1
#    vertical: 2
#    marseillais: 2
#    acharnement: 4
#    chanson: 3
#    lhymne: 1
#    lisle: 1
#    cotation: 2
#    officieux: 2
#    Physiognomonie: 1
#    timbresposte: 1
#    bonnet: 1
#    marianne: 2
#    tronc: 1
#    orne: 1
#    phrygien: 1
#    deuron: 1
#    fichier_ascii: 3
#    consommation: 20
#    formater: 1
#    figurer: 3
#    moderniser: 2
#    rappeler: 1
#    sadapter: 2
#    entete: 1
#    charter: 4
#    dhabitant: 3
#    insee: 3
#    mondialeref: 1
#    obsolete: 1
#    dapres: 6
#    linstitut: 4
#    intervalle: 1
#    ailleursi: 1
#    recensement: 3
#    Polyedre_regulier: 1
#    humain: 7
#    accrue: 1
#    natalite: 1
#    marqueei: 1
#    cartel: 1
#    letranger: 6
#    parent: 14
#    nouveaune: 1
#    fertilite: 4
#    deurostat: 1
#    doutr: 1
#    saillie: 2
#    Caledonie: 1
#    exclure: 2
#    esperer: 2
#    bome: 2
#    communement: 2
#    baby: 2
#    generation: 7
#    pyramide: 1
#    approcher: 1
#    larrivee: 2
#    monden: 2
#    jouir: 2
#    xxie: 7
#    passereau: 13
#    bon-papa: 1
#    lesperance: 1
#    afrique: 6
#    pascal: 5
#    lhistorien: 3
#    blanchard: 1
#    grandsparent: 1
#    accueill: 2
#    larabie: 1
#    proportionnellemer: 2
#    saoudite: 2
#    canada: 1
#    re: 3
#    immigre: 7
#    dimmigrer: 3
#    denfant: 3
#    resider: 2
#    dimmigre: 1
#    inse: 5
#    restrictif: 1
#    dau: 2
#    devant: 4
#    sixieme: 6
#    augment: 3
#    damerique: 1
#    doceanie: 1
#    lexcedent: 1
#    doigt: 9
#    disposaient: 1
#    dasie: 1
#    ethnicite: 2
#    donc: 4
#    dafrique: 1
#    turque: 2
#    michel: 7
#    dorigin: 3
#    majoritairement: 2
#    tribalat: 2
#    vietnamien: 2
#    maghrebin: 1
#    percevoir: 3
#    diplomesi: 1
#    travail: 5
#    francei: 3
#    pauvretei: 1
#    hippolyte: 2
#    nonimmigresi: 1
#    migrant: 2
#    dalbi: 1
#    demploi: 2
#    distinction: 6
#    victimer: 1
#    etroit: 1
#    indeterminer: 2
#    integrisme: 1
#    banning: 2
#    convergence: 2
#    religieuxi: 2
#    tourne: 2
#    certaine: 4
#    immigrer: 2
#    datei: 1
#    pourtant: 1
#    minoritaire: 3
#    assister: 2
#    visible: 2
#    lirland: 1
#    fecond: 1
#    lisland: 1
#    conjoncturel: 1
#    indicateur_de_vitesse: 2
#    final: 2
#    metropolitainei: 1
#    solidarnosc: 1
#    pratiquer: 4
#    dunion: 1
#    mariagei: 2
#    souple: 1
#    planifier: 2
#    PAC: 2
#    Planning_familial: 1
#    concubinage: 1
#    legalisation: 3
#    grandissant: 2
#    autrefoi: 2
#    offense: 2
#    assimiler: 1
#    forfait: 1
#    homosexuel: 1
#    heterosexuel: 1
#    xviiie: 11
#    Syndicat_de_salaries: 4
#    parallelement: 2
#    depenaliser: 1
#    lhomophobie: 1
#    progressivemer: 2
#    lhomosexualite: 1
#    esc: 1
#    significativement: 2
#    repercussion: 7
#    evolue: 3
#    dactivite: 4
#    legislativesi: 1
#    lecart: 2
#    doctorant: 1
#    Pronunciamento: 2
#    metier: 2
#    symetrie_miroir: 1
#    accompagner: 1
#    iep: 1
#    salarial: 3
#    netaient: 1
#    dhomme: 1
#    hebdomadaire: 4
#    mieux: 4
#    peuple: 1
#    philologie: 3
#    officiellement: 1
#    congo: 3
#    interlocuteur: 5
#    active: 1
#    celleci: 2
#    soixantequinze: 1
#    nayer: 2
#    larticle: 1
#    Bernard: 2
#    argot: 1
#    polyglotte: 1
#    cerquiglini: 2
#    lorganisme: 1
#    officialiser: 1
#    endroit: 11
#    anglicisme: 1
#    abusif: 2
#    moral: 2
#    universite: 3
#    lacademie: 3
#    cardinal: 1
#    inquiet: 1
#    historique: 13
#    strictement: 1
#    separation: 3
#    lalsacemosell: 1
#    decoule: 1
#    neter: 1
#    derogation: 3
#    vereniging: 1
#    israelite: 1
#    salarie: 1
#    subventionner: 1
#    laicite: 3
#    laic: 2
#    apostolique: 1
#    judaisme: 1
#    temoignage: 5
#    agnostique: 1
#    lislam: 1
#    rameau: 8
#    Bouddhisme: 1
#    Armenienne: 1
#    neoapostoliqu: 1
#    ...: 10
#    mormon: 1
#    jehovah: 1
#    protestantisme: 2
#    urne: 3
#    lantiquite: 3
#    moyenorient: 1
#    alevisme: 1
#    bahaisme: 1
#    interroger: 1
#    differents: 2
#    mennonite: 1
#    voie_ferree: 3
#    ather: 1
#    Maghreb: 2
#    hindouism: 1
#    insuffisant: 1
#    Inferno: 1
#    dinfluence: 2
#    nassistent: 1
#    langagier: 1
#    fervent: 1
#    assidu: 1
#    differemment: 1
#    sevalue: 1
#    lobeissance: 1
#    xix: 4
#    lautre: 2
#    principe: 4
#    disent: 2
#    pensent: 1
#    croyant: 1
#    ipso: 1
#    plutot: 4
#    meilleur: 4
#    compilation: 3
#    gratuitei: 1
#    gaine: 8
#    commandement: 2
#    revenir: 4
#    linstruction: 4
#    territorialesn: 1
#    coussin: 1
#    lecol: 2
#    maternel: 4
#    but: 2
#    elementaire: 3
#    lenseignemer: 11
#    fondamental: 5
#    lecriture: 1
#    derouler: 2
#    civique: 1
#    lapprentissage: 6
#    socialisation: 3
#    texte: 2
#    eveil: 1
#    gymnase: 7
#    cycle_par_seconde: 4
#    baccalaureat: 2
#    lenseignement: 4
#    daptitude: 1
#    priver: 13
#    dassociation: 1
#    dispenser: 3
#    lyce: 1
#    confessionnel: 1
#    ecolier: 7
#    scolariser: 2
#    technologique: 13
#    diplome: 3
#    capa: 1
#    finau: 1
#    cohabiter: 1
#    montrer: 5
#    mecaniciens-dentistes: 2
#    lon: 7
#    strate: 7
#    repertoire: 4
#    documentation: 7
#    lissue: 1
#    preparatoire: 1
#    scolarisation: 1
#    inequation: 9
#    cadresi: 1
#    ouvrieri: 1
#    considerable: 2
#    supprimer: 1
#    elargissement: 5
#    diplomer: 1
#    admettre: 1
#    dadministration: 1
#    douvrier: 1
#    pisa: 2
#    decever: 1
#    tonalite: 1
#    prejuge: 1
#    lenquete: 3
#    lillettrisme: 2
#    educatif: 14
#    laccroissement: 1
#    saccentuent: 1
#    influer: 1
#    dacce: 2
#    mathematique: 12
#    indigent: 3
#    obtiennent: 1
#    issus: 1
#    satisfaire: 3
#    juge: 3
#    note: 3
#    procureur: 7
#    pedagogique: 11
#    verrouillage: 1
#    sociauxd: 1
#    complementairesa: 1
#    loin: 3
#    importanter: 1
#    famillea: 1
#    complique: 5
#    daffiliesa: 1
#    systemea: 1
#    cmu: 1
#    preretraite: 2
#    dependre: 1
#    entretien: 4
#    mutuelle: 2
#    couvertur: 1
#    minimum: 3
#    menagesa: 1
#    socialesa: 1
#    laugmentation: 2
#    ajuste: 1
#    termen: 1
#    populationa: 1
#    rapidementer: 1
#    vieillissement: 1
#    financer: 3
#    maitriser: 1
#    successif: 1
#    verser: 1
#    territorialeser: 1
#    inseeer: 1
#    disponible: 6
#    bien-etre: 11
#    Haram: 1
#    elevei: 1
#    Danemark: 11
#    aide: 1
#    medical: 8
#    mondei: 1
#    morbidite: 1
#    pibi: 1
#    docteur: 9
#    prematurer: 1
#    sous-vetement: 1
#    consommer: 2
#    vin: 5
#    adulte: 4
#    lanse: 1
#    illicite: 1
#    drogue: 2
#    demeurer: 1
#    toxicomaniesi: 1
#    questionnaire: 2
#    lobservatoire: 1
#    assis: 1
#    intense: 1
#    consomme: 1
#    dalcool: 1
#    usager: 1
#    tabagismei: 1
#    optimal: 2
#    cannabis: 2
#    irlandaisi: 1
#    miracle: 2
#    queleve: 1
#    consomm: 1
#    suicidaire: 1
#    comparable: 2
#    dantidepresseur: 1
#    mental: 5
#    labu: 1
#    agitation: 1
#    ny: 1
#    tf: 4
#    encadrer: 2
#    pressek: 1
#    francepress: 1
#    press: 2
#    AFP: 1
#    associated: 1
#    reuter: 1
#    hava: 1
#    reuni: 1
#    angle: 8
#    aujourdhui: 7
#    segment: 3
#    figaro: 2
#    vente: 6
#    francen: 1
#    diffuser: 4
#    dexemplairer: 1
#    dinformation: 1
#    europe: 12
#    novembredecembre: 2
#    inter: 1
#    ligne_de_transmission: 1
#    media: 5
#    sans_fil: 4
#    TNT: 1
#    numerique: 5
#    concertation: 3
#    televisie: 3
#    gare_routiere: 2
#    planete: 2
#    lapparition: 1
#    nrj: 1
#    hertzien: 1
#    chainer: 1
#    proprieter: 1
#    Rawalpindi: 1
#    democratiser: 1
#    lacce: 3
#    dinternet: 1
#    vraiment: 2
#    dutilisateurs: 1
#    remonter: 4
#    categorisation: 5
#    lagarder: 1
#    lensembl: 2
#    annoncer: 3
#    new: 6
#    associatif: 2
#    detective: 7
#    decouter: 1
#    player: 1
#    plateform: 2
#    rejoindre: 1
#    inde: 1
#    paume: 2
#    titrer: 1
#    remportee: 1
#    dhiver: 2
#    Vancouver: 1
#    serie: 1
#    chamonix: 1
#    rigueur: 3
#    modernen: 1
#    lescrim: 1
#    deter: 1
#    albertville: 1
#    palmares: 2
#    olympique: 3
#    sportive: 5
#    preponderer: 1
#    cyclisme: 1
#    coiffure: 2
#    notable: 3
#    tournoi: 2
#    davis: 1
#    ballon: 3
#    judo: 1
#    basket-ball: 1
#    gamine: 11
#    golf: 1
#    skiable: 1
#    lequitation: 1
#    licencier: 1
#    natation: 1
#    lautriche: 1
#    dentr: 1
#    licencie: 1
#    ski: 2
#    handball: 1
#    setablisser: 1
#    bpjep: 1
#    salarier: 3
#    delivre: 1
#    rolandgarro: 1
#    ponctuel: 2
#    leuro: 2
#    letre: 3
#    lesport: 1
#    esport: 1
#    vitality: 1
#    concours: 3
#    sinteresse: 1
#    regarder: 2
#    lassociation: 1
#    desport: 2
#    team: 1
#    performante: 1
#    coq: 3
#    manifestant: 1
#    terme: 4
#    Strand: 1
#    developpei: 1
#    contestataire: 2
#    impliquer: 7
#    K: 2
#    publici: 1
#    dassociationsi: 1
#    sen: 2
#    sil: 1
#    syndicalisation: 1
#    politiquesk: 1
#    inegalitaire: 1
#    extraction: 4
#    inverse: 1
#    Asiatique: 1
#    confondre: 3
#    cacher: 4
#    rapporter: 1
#    etatique: 1
#    remettre: 2
#    intervention: 4
#    milliardaire: 2
#    chine: 8
#    millionnaire: 2
#    Etats-Unien: 10
#    forbe: 2
#    palourde: 7
#    world: 5
#    database: 2
#    aiser: 3
#    capter: 1
#    inequality: 2
#    captaient: 1
#    quoiqu: 1
#    lentement: 1
#    depargne: 1
#    depargn: 1
#    dachat: 1
#    menagesd: 1
#    accroitre: 1
#    mensuel: 3
#    median: 3
#    selever: 3
#    vieilless: 1
#    pauvreter: 1
#    monetaire: 2
#    legerement: 2
#    moindre: 1
#    selev: 2
#    amplitude: 1
#    rente: 1
#    chomeur: 2
#    pauvrete: 1
#    idh: 1
#    chambre_de_compensation: 5
#    lidh: 1
#    gini: 2
#    lindic: 2
#    lindice: 3
#    residence: 4
#    trimestre: 3
#    denombrer: 1
#    sansabri: 1
#    touch: 1
#    heyer: 1
#    variation: 1
#    emploii: 1
#    eric: 1
#    esperance: 1
#    pourvoir: 2
#    reinsertion: 1
#    difficiled: 1
#    emploisi: 1
#    activemer: 1
#    bit: 1
#    activer: 1
#    cestadir: 1
#    rechercher: 2
#    tranch: 1
#    interim: 1
#    representaient: 1
#    determiner: 2
#    cdd: 1
#    CDI: 2
#    briquet: 3
#    go: 1
#    repli: 1
#    lignee: 1
#    ininterrompu: 1
#    quasi: 2
#    danner: 6
#    moderateur: 1
#    qualifie: 1
#    factbook: 3
#    Central_Intelligence_Agency: 2
#    lagriculture: 8
#    Tertiaire: 1
#    composaient: 1
#    manufacturier: 1
#    commercial: 2
#    agricoleb: 1
#    occidentaleb: 1
#    territoirei: 1
#    aoc: 2
#    mutation: 4
#    dexod: 1
#    industrialiser: 2
#    label: 1
#    identification: 1
#    aligner: 1
#    saccentueb: 1
#    biologique: 3
#    pacb: 1
#    lemploi: 2
#    preserver: 3
#    bio: 1
#    mecaniser: 1
#    terroirb: 1
#    dagriculture: 1
#    dexploitatier: 1
#    coexploitant: 1
#    associer: 4
#    operateur: 1
#    dexploitation: 1
#    surplus: 2
#    genereusement: 1
#    pac: 2
#    degager: 1
#    lanner: 2
#    rendement: 8
#    agroalimentaire: 3
#    quota: 5
#    appui: 4
#    subvention: 4
#    lait: 3
#    avachi: 1
#    diholoside: 2
#    surimi: 1
#    doeuf: 1
#    grain: 2
#    foetus: 2
#    bar: 4
#    bette: 2
#    frite: 2
#    bovine: 1
#    actinidia_deliciosa: 1
#    soja: 1
#    etoupe: 1
#    pognon: 1
#    walnut: 5
#    helianthe: 1
#    bouquet: 1
#    dartichauts: 1
#    moutarde: 1
#    sec: 1
#    frer: 1
#    dabricot: 1
#    fibre: 1
#    dorge: 1
#    raisin: 1
#    triticale: 1
#    citronnier: 1
#    lin: 1
#    entiere: 1
#    truffe: 1
#    colzer: 1
#    jute: 1
#    brocoli: 1
#    fongus: 1
#    feve: 1
#    aveline: 1
#    doeuilletter: 1
#    allium_porrum: 1
#    pois: 1
#    depinard: 1
#    lonuaa: 1
#    chouxfleur: 1
#    sarrasin: 1
#    chicorer: 1
#    bleuet: 1
#    touriste: 4
#    touristique: 7
#    tavernier: 1
#    tourisme: 5
#    darriver: 1
#    departemer: 2
#    lieux: 1
#    culturel: 26
#    lattrer: 2
#    etc: 10
#    gastronomique: 2
#    renouvelement: 7
#    hotellerie: 1
#    lequipement: 1
#    daccueil: 2
#    temperer: 1
#    thailande: 1
#    interieur: 3
#    selevent: 1
#    londre: 3
#    musee: 1
#    Bangkok: 2
#    visiteur: 5
#    louvre: 2
#    mausolee: 6
#    lagglomeration: 1
#    notredame: 3
#    quagglomeration: 1
#    visite: 3
#    muser: 6
#    villecentre: 1
#    dazurb: 1
#    pompidoumetz: 1
#    tourismeb: 1
#    Disneyland: 1
#    colmar: 1
#    futuroscope: 1
#    attirer: 2
#    naturelb: 1
#    disneyland: 1
#    reputer: 1
#    skiablec: 1
#    saintmichel: 2
#    daffaire: 4
#    rocamadour: 1
#    frequente: 1
#    Eiffel: 4
#    payant: 2
#    unterlinden: 1
#    louvr: 1
#    hautkoenigsbourg: 1
#    balneaire: 1
#    iledefrance: 2
#    transportation: 8
#    lirruption: 1
#    timide: 1
#    francaisej: 1
#    bouleverser: 2
#    lartisanat: 2
#    producteursj: 1
#    centresvillesj: 1
#    alimentaire: 2
#    dimposer: 1
#    tertiarisation: 1
#    exportation: 5
#    sexplique: 4
#    delocalisation: 1
#    dynamique: 4
#    chaussur: 1
#    naval: 3
#    courrier: 3
#    faste: 4
#    reconversionb: 1
#    aerospatial: 1
#    dindustrie: 1
#    electronique: 5
#    apothicairesses: 2
#    chuterb: 1
#    cosmetique: 2
#    siderurgi: 1
#    douloureuse: 1
#    b: 14
#    onereuseb: 1
#    industrielleb: 1
#    faire_la_queue: 1
#    paysb: 1
#    nordpasdecalai: 2
#    edf: 2
#    dentreprise: 1
#    japon: 2
#    citation: 7
#    top: 2
#    loreal: 2
#    fortun: 1
#    domainesb: 1
#    michelin: 3
#    axer: 2
#    SUR: 2
#    bnp: 2
#    predominant: 1
#    pariba: 2
#    arquus: 1
#    blinder: 1
#    crocus_sativus: 1
#    militaroindustriel: 1
#    spectr: 1
#    <<_fomites_>>: 3
#    larmement: 1
#    thale: 1
#    nexter: 1
#    dger: 1
#    airbus: 2
#    laviation: 2
#    mbder: 1
#    group: 3
#    aviation: 1
#    dassault: 2
#    comique: 3
#    rafal: 1
#    porteavion: 1
#    chariot: 2
#    leclerc: 1
#    lelectricite: 1
#    graveline: 1
#    implanter: 2
#    lhydroelectrique: 1
#    denergie: 1
#    exploiter: 1
#    nen: 2
#    carboner: 1
#    franceb: 1
#    nationaleb: 1
#    moteur_a_reaction: 1
#    treize: 1
#    dalgerie: 1
#    consommei: 1
#    raffinerie: 1
#    delectricite: 1
#    puissante: 1
#    huile_vegetale: 2
#    energetique: 3
#    renouvelable: 2
#    embarqu: 1
#    missile: 3
#    spoutnik: 1
#    arian: 3
#    detude: 3
#    megere: 2
#    realisation: 3
#    asterix: 1
#    decolle: 1
#    sonde: 3
#    exploite: 1
#    cnes: 1
#    dhammaguir: 1
#    catapulte: 3
#    diamant: 1
#    soviet: 1
#    algeri: 1
#    veroniqu: 1
#    soyouz: 1
#    felicette: 2
#    rosetter: 1
#    Mythologie_romaine: 3
#    dexploration: 1
#    galileo: 1
#    bepicolombo: 1
#    express: 1
#    interplanetaire: 1
#    viser: 6
#    fortiori: 1
#    faibleh: 1
#    publich: 1
#    developpementh: 1
#    decouverte: 15
#    moyennement: 1
#    infrer: 1
#    fondamentaleh: 1
#    mediocresh: 1
#    deposer: 1
#    minatec: 1
#    nanosciences: 1
#    nanotechnologier: 1
#    jouxter: 1
#    sciences_de_l'information: 2
#    appliquer: 1
#    microelectronique: 1
#    cnrs: 3
#    leti: 1
#    linra: 1
#    investigateur: 3
#    linria: 1
#    agronomi: 1
#    laboratoire: 2
#    publicsh: 1
#    cea: 1
#    lauelangevin: 1
#    competitivite: 2
#    radiation: 1
#    facility: 1
#    leuropean: 1
#    synchrotron: 1
#    radioastronomie: 1
#    pole_celeste: 2
#    instrument: 2
#    millimetrique: 1
#    cern: 1
#    circonscription: 4
#    parisla: 2
#    letendue: 1
#    dassurance: 1
#    lencadrer: 1
#    politique: 2
#    bancaire: 1
#    concentration: 3
#    interrupteur: 2
#    dixieme: 1
#    exploitation: 3
#    neuvieme: 1
#    cac: 2
#    boursier: 1
#    indice: 3
#    sanofi: 1
#    performance: 5
#    refleter: 2
#    lvmh: 2
#    activement: 1
#    deuronext: 1
#    coter: 1
#    euronext: 2
#    filial: 1
#    ponderer: 1
#    capital: 1
#    Fonds_monetaire_international: 1
#    estimee: 1
#    nominal: 1
#    tarifaire: 1
#    agora: 3
#    dimposition: 1
#    freedom: 2
#    lheritage: 1
#    competitive: 1
#    docilite: 1
#    of: 13
#    charge: 1
#    denseignant: 1
#    rigide: 1
#    competitiveness: 2
#    economic: 2
#    foundation: 2
#    report: 3
#    partenaire: 2
#    lobliger: 1
#    linsuffisance: 1
#    minier: 1
#    importerd: 1
#    extravertieer: 1
#    lepuisement: 1
#    dimportation: 1
#    limportance: 1
#    dexportation: 1
#    importateur: 2
#    lomc: 1
#    enregistre: 1
#    dimportante: 1
#    dollara: 1
#    horairesa: 1
#    salourdit: 1
#    eurostat: 2
#    balance: 1
#    deficitaire: 1
#    creuseer: 1
#    linvestissement: 1
#    linnovation: 2
#    recommandation: 4
#    reussir: 1
#    loctroi: 1
#    artiste: 4
#    cinema: 5
#    accessible: 2
#    gratitude: 3
#    promotion: 1
#    historiquer: 1
#    refug: 1
#    responsable: 4
#    immeuble: 3
#    lintermediaire: 1
#    maison: 4
#    civilisationnel: 1
#    jardin: 1
#    basilique: 1
#    cathedral: 2
#    trait_de_caractere: 1
#    architectural: 3
#    colloque: 1
#    inscrire: 6
#    lallemagnen: 1
#    recenser: 1
#    lunesco: 4
#    classique: 7
#    cathedrale: 2
#    architecture_gothique: 2
#    saline: 1
#    saintsavinsurgartempe: 1
#    dapresguerre: 1
#    romane: 1
#    larchitecture: 1
#    gard: 2
#    inscrit: 2
#    Nancy: 1
#    darchitecture: 1
#    fontenay: 1
#    chefsdoeuvre: 1
#    stanisla: 1
#    labbaye: 1
#    darcetsenans: 1
#    reconstruire: 1
#    chartre: 1
#    carcassonne: 1
#    xviie: 10
#    monumer: 1
#    baroque: 6
#    chenonceau: 1
#    davignon: 2
#    chefd': 1
#    saintemilion: 1
#    architecte: 2
#    porter: 6
#    feu: 1
#    icone: 2
#    cordouan: 1
#    montreuil: 1
#    contemporain: 10
#    Gabriel: 1
#    dinteret: 1
#    ledou: 1
#    violletleduc: 1
#    hardouinmansart: 1
#    androuet: 1
#    Mansart: 2
#    panier: 2
#    lentretien: 1
#    faconner: 2
#    lescot: 1
#    neoclassique: 2
#    mobilier: 1
#    perret: 1
#    clocher: 1
#    Garnier: 1
#    vau: 1
#    delorm: 1
#    corbusier: 1
#    privilegier: 2
#    francaisef: 1
#    fiction: 8
#    formerf: 1
#    beauxart: 2
#    ecstasy: 5
#    rejouissance: 1
#    sieclem: 2
#    attester: 2
#    commander: 2
#    chastelf: 1
#    prehistoirem: 1
#    sacref: 1
#    iie: 2
#    quemerger: 1
#    neoclassicisme: 1
#    boucherie: 1
#    lapparat: 1
#    greuze: 1
#    classicisme: 2
#    puget: 1
#    lexpression: 4
#    chardin: 1
#    lordre: 3
#    ingre: 1
#    poussin: 1
#    houdonm: 1
#    fouquet: 1
#    coysevox: 1
#    fragonard: 1
#    watteau: 1
#    David: 5
#    decorateur: 1
#    gobiidae: 1
#    italiennesm: 1
#    sculpteur: 1
#    individuel: 2
#    girardon: 1
#    cubisme: 1
#    realisme: 2
#    nerf: 3
#    matisse: 1
#    gogh: 1
#    courbet: 1
#    seurat: 1
#    gauguin: 1
#    picasso: 1
#    sculpture: 1
#    cezanne: 1
#    monet: 1
#    nawak: 2
#    rodin: 1
#    gericault: 1
#    derain: 1
#    neoimpressionnisme: 1
#    fauvisme: 1
#    manet: 1
#    limpressionnism: 1
#    dega: 1
#    vlaminck: 1
#    romantisme: 2
#    braque: 1
#    revolutionner: 2
#    delacroi: 1
#    representantsm: 1
#    duchamp: 1
#    renaissancem: 1
#    rabelais: 1
#    lessayist: 1
#    romancier: 3
#    poete: 4
#    possible: 6
#    villonm: 1
#    ronsard: 1
#    paysm: 1
#    bellay: 1
#    missive: 4
#    cantique: 1
#    vain: 1
#    troye: 1
#    citer: 5
#    montaigne: 2
#    retablir: 1
#    boileau: 1
#    corneill: 3
#    source: 1
#    laclo: 1
#    diderot: 2
#    marival: 2
#    lumiere_visible: 9
#    generateur: 5
#    sattachent: 1
#    raisonm: 1
#    rousseau: 5
#    prohibesm: 1
#    moliere: 5
#    fabuliste: 1
#    philosophe: 3
#    beaumarcher: 1
#    auteur_dramatique: 3
#    fustiger: 1
#    Francois_Marie_Arouet: 1
#    prevost: 1
#    aborder: 2
#    Montesquieu: 1
#    lamartin: 1
#    theoricien: 1
#    mallarmem: 1
#    Victor_Hugo: 3
#    vigny: 1
#    durkheim: 2
#    Stendhal: 1
#    musset: 1
#    dumas: 1
#    chateaubriand: 1
#    flaubert: 1
#    memorialist: 1
#    zoler: 1
#    baudelair: 1
#    balzac: 1
#    rimbaud: 1
#    deleuze: 1
#    giraudoux: 1
#    Camus: 1
#    cocteau: 1
#    lacan: 1
#    saintexupery: 1
#    levistrauss: 1
#    apollinaire: 2
#    vian: 1
#    gid: 1
#    sarraute: 1
#    ionescom: 1
#    derrider: 1
#    prevert: 1
#    sagan: 2
#    beauvoir: 1
#    sartr: 1
#    Foucault: 1
#    ricoeur: 1
#    guattari: 1
#    eluard: 1
#    bourdieu: 3
#    dura: 1
#    essayiste: 1
#    yourcenar: 1
#    Louis_Aragon: 1
#    celin: 1
#    gracq: 1
#    proust: 1
#    patrick: 1
#    michon: 1
#    badiou: 1
#    eliette: 1
#    ericemmanuel: 1
#    emergent: 2
#    angot: 1
#    erik: 1
#    despente: 1
#    christin: 1
#    quignard: 1
#    schmitt: 1
#    orsenna: 1
#    Yes: 1
#    clezio: 1
#    jmg: 1
#    modiano: 1
#    didihuberman: 1
#    abecassi: 1
#    ranciere: 1
#    houellebecq: 1
#    Nobel: 2
#    laureat: 1
#    seize: 1
#    editer: 1
#    instrumental: 1
#    circus: 1
#    dramaturgie: 8
#    rue: 2
#    lopera: 3
#    lesprit: 1
#    Marionnette: 1
#    danse: 7
#    musical: 3
#    academique: 1
#    inventer: 3
#    orchestral: 1
#    dedifice: 1
#    quon: 1
#    Amazone: 1
#    grevin: 1
#    achevent: 1
#    cocasserie: 3
#    Elections_au_Senegal: 1
#    dellarte: 1
#    garnier: 1
#    senrichit: 1
#    apporter: 4
#    comediefrancaise: 1
#    humaniste: 1
#    commedia: 1
#    comedien: 2
#    tragedie: 2
#    pathelin: 1
#    jodelle: 1
#    liturgique: 1
#    hedelin: 1
#    etienn: 1
#    victor: 2
#    regnard: 1
#    lacteur: 1
#    stanislavski: 1
#    beaumarchai: 1
#    romantique: 4
#    susciter: 1
#    scribe: 1
#    talma: 1
#    maeterlinck: 1
#    francoisjoseph: 1
#    emile: 2
#    bataill: 1
#    declenchent: 1
#    Cromwell: 1
#    codifier: 2
#    nouveaute: 1
#    dhernani: 1
#    Careful_with_That_Axe: 2
#    Zola: 1
#    chekhov: 1
#    naturalisme: 1
#    symbolisme: 1
#    lugnepoe: 1
#    ibsen: 1
#    dominer: 1
#    technique: 15
#    experimental: 2
#    saccorder: 1
#    profondement: 2
#    artaud: 1
#    jarry: 1
#    davantgarde: 1
#    Ionesco: 1
#    labsurde: 1
#    cerner: 1
#    antonin: 1
#    dalfred: 1
#    voit: 1
#    dadaisme: 1
#    Simeon: 1
#    Andre#Sens_et_origine_du_nom: 2
#    malral: 1
#    partout: 1
#    florian: 1
#    mnouchkin: 1
#    vilar: 1
#    provint: 1
#    claud: 1
#    regy: 1
#    bernardmarie: 1
#    zeller: 1
#    lecoq: 1
#    lagarce: 1
#    mjc: 1
#    kolte: 1
#    jeanluc: 4
#    christian: 3
#    sacd: 1
#    sexprim: 1
#    ceremonie: 1
#    devenement: 2
#    thoinot: 1
#    vehicule: 2
#    lorchesographie: 1
#    arbeau: 1
#    livre_de_classe: 2
#    methodologie: 7
#    Ballet: 5
#    tonneau: 1
#    comediesballet: 2
#    beaujoyeul: 1
#    Balthazar: 1
#    barreau: 2
#    medici: 1
#    operaballet: 1
#    Victorino_de_la_Plaza: 3
#    dame: 1
#    lully: 3
#    lyrique: 1
#    beauchamp: 1
#    daction: 6
#    encombrer: 1
#    gluck: 1
#    indication: 1
#    lancetr: 1
#    jouent: 1
#    noverre: 1
#    petipa: 1
#    juan: 2
#    jeangeorger: 1
#    ecrire: 1
#    codification: 1
#    talon: 1
#    mariu: 1
#    corset: 1
#    bournonville: 1
#    perruque: 1
#    balletpantomime: 1
#    vestri: 1
#    martha: 1
#    laban: 1
#    piner: 1
#    loie: 1
#    Isadora_Duncan: 1
#    delsarte: 1
#    jaquesdalcroze: 1
#    isadora: 1
#    Cunningham: 1
#    rudolf: 1
#    fuller: 1
#    merce: 1
#    definissent: 1
#    nikolai: 1
#    bausch: 1
#    graham: 1
#    alwin: 1
#    quadrille: 1
#    reguler: 1
#    commerage: 1
#    acrobatique: 1
#    gregorien: 1
#    ancre: 1
#    rayonnement: 1
#    troubadour: 1
#    trouvere: 1
#    ars: 1
#    antiqua: 1
#    monodique: 1
#    polyphonique: 1
#    nova: 1
#    risset: 1
#    gounod: 1
#    betsy: 1
#    berlioz: 2
#    henry: 1
#    xenakis: 1
#    faure: 2
#    ravel: 1
#    messiaen: 1
#    menuisier: 1
#    dutilleux: 1
#    chopin: 1
#    bizet: 2
#    bouler: 1
#    olivier: 2
#    iannis: 1
#    Couperin: 1
#    jeanclaude: 3
#    jolas: 1
#    compositeurs: 1
#    hersant: 1
#    bayl: 1
#    debussy: 2
#    Beatrice: 1
#    jeanbaptiste: 2
#    claude: 3
#    die: 1
#    Hector: 1
#    machaut: 1
#    fin: 1
#    explos: 1
#    roc: 1
#    hip_hop: 3
#    musichall: 1
#    prunella_modularis: 3
#    baker: 1
#    trenet: 1
#    maitre-chanteur: 3
#    Republique_de_Maurice: 4
#    mistinguett: 1
#    merchandising: 3
#    vraie: 1
#    sablon: 1
#    reellement: 1
#    importe: 1
#    edith: 3
#    manoir: 5
#    chantre: 1
#    josephine: 1
#    infime: 1
#    jusquau: 3
#    peste: 1
#    lentredeuxguerre: 1
#    mireill: 1
#    pop: 1
#    illegal: 1
#    ressentir: 1
#    streaming: 1
#    telechargement: 2
#    seffondrent: 1
#    Ascension: 1
#    solaar: 2
#    honorabilite: 2
#    signer: 1
#    mc: 3
#    aznavour: 2
#    mylene: 2
#    Yule: 1
#    guide: 3
#    rossi: 2
#    hallyday: 2
#    tragique: 1
#    baiser: 1
#    rebelle: 1
#    auteurcompositeurinterprete: 1
#    farmer: 2
#    spectaculaire: 1
#    my: 2
#    franci: 1
#    poesie: 2
#    auteurcompositeurinterpret: 1
#    francoarmenien: 1
#    twist: 1
#    auteurecompositriceinterpret: 1
#    sardou: 2
#    incitation: 1
#    tino: 2
#    dhabitude: 1
#    dalida: 1
#    cabrel: 2
#    veritable: 3
#    pepe: 1
#    rai: 1
#    clip: 1
#    gainsbourg: 2
#    adjudicateur: 1
#    brassen: 2
#    jeanjacque: 6
#    sentimental: 1
#    boite: 1
#    goldman: 2
#    George_du_Maurier: 4
#    concert: 1
#    way: 2
#    serge: 2
#    rosace: 1
#    rocker: 1
#    artister: 1
#    johnny: 1
#    francis: 2
#    dalider: 1
#    limposition: 1
#    tige: 2
#    levenement: 1
#    dexception: 1
#    hollywoodien: 1
#    mondialn: 1
#    mediatiser: 1
#    longsmetrage: 1
#    film: 4
#    prestigieux: 1
#    sexprime: 1
#    vadrouille: 1
#    specifiquement: 1
#    colt: 1
#    the: 10
#    artist: 1
#    miserable: 1
#    emmanuelle: 1
#    fune: 1
#    gerard: 4
#    melies: 2
#    Godard: 2
#    bienvenu: 1
#    chti: 1
#    haine: 1
#    depardieu: 2
#    besson: 1
#    marai: 1
#    fabuleux: 1
#    luc: 1
#    Ismael: 1
#    dauteur: 1
#    damelie: 1
#    realisateur: 1
#    diner: 2
#    demeure: 1
#    tautou: 2
#    audrey: 3
#    marion: 1
#    binoche: 1
#    montand: 1
#    juliette: 1
#    huppert: 1
#    jeanpaul: 2
#    truffaut: 1
#    yve: 4
#    Elisabeth: 2
#    delon: 1
#    cotillard: 1
#    isabelle: 2
#    funes: 1
#    belmondo: 1
#    dujardin: 1
#    gabin: 1
#    deneuv: 1
#    adjani: 1
#    allouer: 1
#    cinematographique: 2
#    castex: 2
#    planifie: 1
#    milan: 1
#    York: 4
#    revendiquer: 1
#    quand: 6
#    insuffler: 1
#    exclusivite: 1
#    eriger: 1
#    aromatiser: 2
#    preponderant: 1
#    garantir: 1
#    couture: 2
#    inaugurer: 1
#    rykiel: 1
#    couturiere: 1
#    sonia: 1
#    yves: 2
#    conglomerat: 1
#    rompt: 1
#    kering: 1
#    geante: 1
#    pretaporter: 1
#    lacroix: 1
#    mugler: 1
#    montana: 1
#    chef: 3
#    subit: 2
#    laurent: 1
#    elitiste: 1
#    marketing: 1
#    parfumerie: 1
#    lexpansion: 2
#    Claude: 1
#    coty: 1
#    laccent: 2
#    gaultier: 1
#    thierry: 2
#    siecleg: 1
#    gastronomie: 2
#    roquefort: 1
#    preparation: 3
#    fromage: 2
#    Champagne-Ardenne: 1
#    camembert: 1
#    quell: 1
#    lechalote: 1
#    essentiellement: 1
#    regionalesg: 1
#    perigourdin: 1
#    cassoulet: 1
#    choucroute: 1
#    ravioli: 1
#    provenceg: 1
#    foie: 1
#    tapenade: 1
#    alsacien: 1
#    languedocien: 1
#    resolumer: 1
#    rillettes: 1
#    lhuil: 1
#    tracer: 1
#    malbouffe: 1
#    bourguignon: 1
#    mans: 1
#    terrienne: 1
#    sestomper: 1
#    mondialiseeg: 1
#    discute: 1
#    culinaire: 1
#    jonction: 1
#    quiche: 1
#    lailg: 1
#    perigord: 1
#    biere: 1
#    viticole: 1
#    brassicole: 1
#    lalsace: 1
#    salad: 1
#    lhumanite: 3
#    froide: 1
#    acquisition: 1
#    chaude: 1
#    garni: 1
#    completer: 1
#    representatif: 2
#    lentree: 1
#    lappellation: 1
#    volaill: 1
#    immateriel: 2
#    dou: 1
#    soupe: 1
#    dominical: 1
#    elaborer: 1
#    desservir: 1
#    dessert: 1
#    luniversite: 3
#    lepoqu: 1
#    posa: 1
#    combustion: 1
#    decouvrir: 2
#    sadi: 1
#    Sadi_Carnot: 1
#    loxygene: 1
#    industrie_mecanique: 3
#    Augustin_d'Hippone: 1
#    biologiste: 1
#    resta: 1
#    loptique: 1
#    renaitre: 3
#    blaise: 1
#    microbiologie: 1
#    lavoisier: 1
#    dalembert: 1
#    fluide: 1
#    fresnel: 1
#    buffon: 1
#    thermodynamique: 1
#    lacquisition: 1
#    descarte: 1
#    curi: 1
#    Antoine_Henri_Becquerel: 1
#    codecouvreur: 1
#    virologue: 1
#    radioactivite: 1
#    Mathematicien: 2
#    ellemem: 1
#    physicien: 1
#    Virus_informatique: 1
#    Marie_Stuart: 1
#    poincarer: 1
#    Luc: 1
#    Syndrome_d'immunodeficience_acquise: 1
#    montagnier: 1
#    reste: 1
#    langevin: 1
#    nobel: 1
#    primee: 1
#    fields: 2
#    recompense: 1
#    Abel: 2
#    cosmonaute: 1
#    pesquet: 1
#    Dylan_Thomas: 2
#    etou: 2
#    langue_vehiculaire: 1
#    denseignement: 4
#    mondel: 1
#    fiscall: 1
#    vocation: 5
#    lelaboration: 1
#    linfluence: 2
#    finesse: 2
#    lelite: 1
#    africain: 4
#    sieclel: 1
#    lalliance: 1
#    rfi: 2
#    communer: 1
#    entretenir: 1
#    tv: 4
#    : 4
#    voyageurskm: 1
#    chin: 1
#    anneela: 1
#    requisition: 1
#    apparent: 1
#    retablissement: 1
#    stuttgart: 1
#    mag: 2
#    Jacob: 5
#    rmiste: 1
#    nc: 1
#    virement: 2
#    tipp: 1
#    boroughs: 1
#    ieom: 1
#    municipal: 1
#    menu: 1
#    litige: 1
#    exemplaire: 1
#    nathan: 1
#    contredire: 1
#    presque: 1
#    eur: 1
#    departementalisation: 1
#    yt: 1
#    encyclopaedia: 2
#    pf: 1
#    desquel: 1
#    ditalie: 1
#    hospitalisation: 1
#    marchandiser: 1
#    trahir: 1
#    Egypte: 2
#    pm: 1
#    marieann: 1
#    candeur: 1
#    distinct: 1
#    quotient: 1
#    birepresentatif: 1
#    Pontianak: 2
#    code: 9
#    Nigeria: 1
#    contester: 4
#    jeanne: 1
#    poliakov: 1
#    decompte: 1
#    prefecture: 1
#    familial: 3
#    Francfort-sur-le-Main: 1
#    systematiquement: 1
#    cohendet: 1
#    afd: 2
#    ouestfrance: 1
#    xpf: 1
#    coubertin: 1
#    sensu: 2
#    Madrid: 1
#    dair: 1
#    anti-semitisme: 1
#    subordonner: 1
#    pierr: 1
#    lequipe: 1
#    hexagone: 1
#    exprimer: 1
#    origin: 1
#    mq: 1
#    effroi: 1
#    laire: 1
#    robinson: 2
#    Senegal: 2
#    Roman: 8
#    Barcelone: 1
#    plaignante: 1
#    entite: 1
#    is: 2
#    navire-citerne: 1
#    histoire: 1
#    idee: 2
#    parasite: 3
#    ir: 1
#    stricto: 2
#    wf: 1
#    cesser: 1
#    leon: 3
#    espagnole: 1
#    cassation: 1
#    arc: 1
#    estadir: 2
#    dheure: 1
#    qualifier: 1
#    froissart: 1
#    pourvoi: 1
#    electoral: 2
#    Australie: 6
#    Milan: 1
#    gp: 1
#    tva: 1
#    redactrices_en_chef: 8
#    copulation: 3
#    exterminer: 1
#    capituler: 1
#    prochain: 1
#    juridictionnel: 1
#    gf: 1
#    limiter: 1
#    effectivement: 2
#    judaica: 1
#    |: 20
#    totalitarisme: 1
#    tonneskm: 1
#    duverger: 1
#    csg: 1
#    r: 5
#    prononcer: 1
#    subsaharien: 1
#    malheureuse: 1
#    rf: 1
#    exactemer: 1
#    economiegestion: 1
#    abdelmalki: 1
#    coll: 12
#    Livre_de_Daniel: 2
#    sefi: 1
#    sandretto: 1
#    oclc: 2
#    isbn: 19
#    dufourt: 1
#    lahsen: 1
#    vincent: 1
#    adoumier: 1
#    jeanmichel: 2
#    dir: 4
#    daudel: 1
#    hachette: 1
#    geographie: 5
#    escarra: 1
#    doi: 5
#    hu: 1
#    didier: 1
#    f: 4
#    dalloz: 1
#    ed: 10
#    annie: 1
#    augusta: 1
#    industriesservice: 1
#    cadar: 1
#    sirey: 1
#    badower: 1
#    economica: 2
#    bauchet: 1
#    poche: 3
#    pref: 3
#    carpentier: 1
#    mayeur: 1
#    tranoy: 1
#    goff: 1
#    lebrun: 1
#    preface: 2
#    flammarion: 1
#    chastel: 1
#    beignet: 1
#    vermillon: 1
#    dumay: 1
#    raymond: 1
#    pirott: 1
#    depot: 2
#    aub: 1
#    thomas: 4
#    clerc: 1
#    dechiffrer: 5
#    maurin: 1
#    lccn: 9
#    denis: 1
#    observatoir: 2
#    habitude: 1
#    cler: 4
#    Larousse: 4
#    francoscopie: 1
#    mermet: 1
#    universitaire: 8
#    saisje: 2
#    pactet: 1
#    armand: 2
#    pitte: 1
#    cursu: 2
#    colin: 2
#    jeanrobert: 1
#    eclaireur: 2
#    Hera: 4
#    didentification: 1
#    aop: 1
#    archiv: 4
#    casser: 1
#    etui: 1
#    consulte: 4
#    variante: 2
#    ispf: 1
#    linao: 1
#    consulter: 5
#    delectriciter: 1
#    ressort: 1
#    caroline: 1
#    Bakersfield: 1
#    dga: 1
#    mastercard: 1
#    gallimard: 1
#    how: 2
#    dufour: 1
#    passenger: 1
#    europe': 1
#    perseefr: 1
#    nehlig: 1
#    catherin: 1
#    brutal: 1
#    natoint: 1
#    martin: 1
#    linternautecom: 1
#    formation: 30
#    terr: 1
#    haegel: 1
#    ccip: 1
#    edffr: 1
#    memory: 1
#    yal: 1
#    w: 3
#    anthony: 1
#    april: 1
#    ced: 1
#    taylor: 1
#    detail: 1
#    sup: 1
#    alexandra: 1
#    threat: 1
#    asterisque: 1
#    fondationalliancefrorg: 1
#    mess: 2
#    leurop: 1
#    grev: 1
#    lepolitiquecom: 1
#    rlp: 1
#    daring: 1
#    aesthetik: 1
#    oecdorg: 1
#    elever: 5
#    hilberg: 1
#    romain: 1
#    alsacienmosellan: 1
#    uhnw: 1
#    departementale: 1
#    disponibilite: 3
#    average: 1
#    cairninfo: 1
#    monti: 1
#    parcattractionloisirsfr: 1
#    bank: 1
#    mazouer: 1
#    esty: 1
#    dynamite: 1
#    alphabetique: 1
#    reseauxpeertopeer: 1
#    energie_electrique: 1
#    flown: 1
#    fou: 1
#    fonctio: 1
#    bipartisme: 1
#    eetimescom: 1
#    pleiad: 1
#    lci: 1
#    inseefr: 1
#    fichage: 1
#    justin: 1
#    archemuseeetarchivesnet: 1
#    more: 1
#    gho: 1
#    tim: 1
#    intitule: 1
#    minister: 1
#    ceder: 1
#    vietnam: 1
#    agestandardized: 1
#    dependance: 2
#    geoscience: 1
#    universellement: 2
#    plateforme: 1
#    immigration: 2
#    algue: 1
#    secretariat: 1
#    paraitre: 1
#    guennoc: 1
#    emery: 1
#    nor: 1
#    market: 1
#    ann: 2
#    dave: 1
#    weekly: 1
#    otanrussie: 2
#    bouthier: 1
#    klau: 1
#    schoopfr: 1
#    compendium: 3
#    delicate: 1
#    category: 1
#    invisible: 1
#    ravir: 1
#    legacie: 1
#    alway: 1
#    designation: 1
#    reintroduce: 1
#    puf: 3
#    integrale: 1
#    bernard: 1
#    saramago: 1
#    neither: 1
#    bettencourt: 1
#    space: 1
#    revue: 4
#    with: 2
#    and: 4
#    perser: 1
#    otto: 1
#    noin: 1
#    penal: 2
#    jacquin: 1
#    attack: 1
#    was: 2
#    ecrivain: 1
#    lenvironnement: 5
#    rfffr: 1
#    trad: 1
#    hargreaves: 1
#    nouvelle: 1
#    foret: 1
#    recensemer: 1
#    thuilier: 1
#    lover: 1
#    cerdicnr: 1
#    Dominique: 1
#    chiffrescle: 1
#    jeanbenoit: 1
#    fontil: 1
#    arme: 1
#    chefdoeuvre: 1
#    estell: 1
#    cliver: 1
#    hannah: 1
#    legifrance: 1
#    metz: 1
#    lasserre: 1
#    tourismeguyanecom: 1
#    julia: 1
#    conduite: 7
#    institut: 5
#    classemer: 1
#    ap: 1
#    decelerer: 1
#    hours: 1
#    meyer: 1
#    unemployment: 1
#    performancepubliquegouvfr: 1
#    late: 1
#    sedentarite: 1
#    seleve: 1
#    marian: 1
#    commerce: 2
#    info: 1
#    edouard: 1
#    superieur: 1
#    organization: 1
#    macroeconomic: 1
#    wolfram: 1
#    iataorg: 1
#    constituante: 1
#    apartheid: 1
#    prioritaire: 1
#    maki_mococo: 1
#    fixation: 1
#    HI: 1
#    japd: 1
#    only: 1
#    hotelclubcom: 1
#    dennis: 1
#    francoise: 1
#    lexpres: 1
#    rd: 1
#    mercredi: 1
#    wealth: 1
#    big: 1
#    echo: 1
#    elysee: 1
#    archeologie: 1
#    information: 1
#    baiss: 1
#    honore: 1
#    eclairer: 1
#    reynie: 1
#    juriglobeca: 1
#    citie: 1
#    having: 1
#    Estuaire: 1
#    lieue: 4
#    metrage: 1
#    grosse: 2
#    bfm: 1
#    charlie: 1
#    inquieter: 1
#    mensuration: 1
#    often: 1
#    schwab: 1
#    roest: 1
#    haven: 1
#    Patrice: 1
#    issn: 4
#    ceinture: 2
#    Testicule: 1
#    bibliotheque: 1
#    prospection: 2
#    ale: 1
#    expenditure: 1
#    aero: 1
#    droitpublicnet: 1
#    orbite_geostationnaire: 1
#    inconscier: 1
#    ameliore: 1
#    francaisdumondecom: 1
#    dgempdirem: 1
#    maturation_moleculaire: 2
#    aberration: 1
#    i': 1
#    easyboursecom: 1
#    seek: 1
#    nathalie: 1
#    barlow: 1
#    franglais: 1
#    lalimentation: 2
#    tasty: 1
#    borge: 1
#    chronologie: 2
#    some: 1
#    ina: 1
#    Chester_Alan_Arthur: 1
#    wendling: 1
#    lespac: 1
#    why: 1
#    transiter: 1
#    under: 1
#    colonialism: 1
#    renaud: 1
#    it: 2
#    richer: 1
#    paolo: 1
#    hebdo: 1
#    mathieu: 1
#    volum: 1
#    fayard: 1
#    monumentalite: 1
#    statistic: 2
#    called: 1
#    eppeurostateceuropeeu: 1
#    transferer: 1
#    polluer: 1
#    legal: 2
#    mielcarek: 1
#    bruno: 1
#    max: 1
#    entierement: 1
#    crh: 1
#    planseismefr: 1
#    constitutioneuropeenneinfo: 1
#    companion: 1
#    jenik: 1
#    enseignementsuprecherchegouvfr: 1
#    activiter: 1
#    kafker: 1
#    lenergie: 1
#    bruce: 1
#    policy: 1
#    eceuropaeu: 1
#    small: 1
#    lisa: 4
#    economy: 2
#    mckie: 1
#    gamme_musicale: 2
#    cautre: 1
#    ined: 1
#    sylvie: 1
#    g: 2
#    ftcom: 1
#    alimagri: 1
#    freddy: 1
#    souvenir: 4
#    tableal: 1
#    eytan: 1
#    eps: 1
#    gallica: 1
#    repressif: 1
#    gross: 1
#    sportsreferencecom: 1
#    reediter: 2
#    arcane: 1
#    Port-Vila: 1
#    ocean_atlantique: 1
#    resonat: 1
#    simard: 1
#    domestic: 1
#    work: 2
#    barere: 1
#    analyser: 1
#    morgan: 1
#    clientele: 2
#    cassette: 2
#    paid: 1
#    economiegouvfr: 1
#    carry: 1
#    spaak: 1
#    assumer: 2
#    frequentation: 1
#    scheduled: 1
#    law: 1
#    blasted: 1
#    outlook: 1
#    tone: 1
#    stpierreetmiqueloncom: 1
#    for: 5
#    poch: 1
#    people: 1
#    ouvertesfr: 1
#    siegel: 1
#    statsoecdorg: 1
#    culturegouvfr: 1
#    preliminaire: 1
#    ratings: 1
#    theyll: 1
#    hazgui: 1
#    briseur_de_greve: 2
#    milza: 1
#    liaison: 1
#    serg: 1
#    manuals: 1
#    unie: 1
#    aisamorg: 1
#    canalacademiecom: 1
#    tricoire: 1
#    employed: 1
#    lascau: 1
#    severino: 1
#    emc: 1
#    julie: 1
#    reciprocite: 2
#    recherche_appliquee: 18
#    thibaudet: 1
#    manifester: 1
#    levequ: 1
#    raul: 1
#    avion: 3
#    buton: 1
#    natura: 1
#    ema: 1
#    sauty: 1
#    family: 2
#    bibliothequ: 1
#    agency: 1
#    bellanger: 1
#    conduct: 1
#    shomfr: 1
#    made: 1
#    guillet: 1
#    moving: 1
#    mobile: 1
#    seed: 1
#    regourd: 1
#    alec: 1
#    nouvelobscom: 1
#    goueset: 1
#    lidentite: 1
#    mauvais: 1
#    appearance: 1
#    annet: 1
#    video: 2
#    prehistoire_;_prehistoire: 1
#    infographiesagriculturegouvfr: 1
#    fr: 1
#    said: 1
#    hautefeuill: 1
#    estil: 1
#    reevaluer: 1
#    strike: 1
#    linternaute: 1
#    ar: 1
#    chapter: 1
#    our: 1
#    und: 1
#    Florence: 1
#    attribution: 2
#    no: 3
#    latex: 1
#    or: 1
#    educationgouvfr: 1
#    influenced: 1
#    viepubliquefr: 1
#    televiser: 1
#    estce: 2
#    excedentaire: 1
#    irascibilite: 1
#    modelisme: 3
#    independent: 1
#    negocier: 1
#    Waterbury: 1
#    scolariter: 1
#    albi: 1
#    kelly: 1
#    certitude: 1
#    statsuisunescoorg: 1
#    societe_d'assurance: 1
#    tallandier: 1
#    pocketbook: 1
#    defensegouvfr: 1
#    croix: 1
#    beaute: 1
#    acdijonfr: 1
#    parisian: 1
#    grunberg: 1
#    genev: 1
#    repere: 1
#    nadeau: 1
#    Walter: 1
#    alarum: 1
#    sansdomicile: 1
#    Key: 1
#    eeckhout: 1
#    opendemocracynet: 1
#    selected: 1
#    postcolonialism: 1
#    institutionnel: 1
#    far: 1
#    sciencespo: 1
#    roser: 1
#    official: 1
#    baster: 1
#    touteleuropeeu: 1
#    zonage: 1
#    nordsieck: 1
#    suicid: 1
#    enus: 2
#    list: 1
#    to: 5
#    health: 1
#    read: 1
#    credit: 1
#    mona: 1
#    sagesser: 1
#    Israel: 9
#    folio: 1
#    innovation: 1
#    trial: 1
#    francepresse: 1
#    dejean: 1
#    single: 1
#    sodomie: 1
#    demographieresponsableorg: 1
#    casual: 1
#    ptom: 1
#    february: 1
#    historiques: 1
#    burnouf: 1
#    lead: 1
#    tlfqulavalca: 1
#    emil: 5
#    Cris: 1
#    liledefrance: 1
#    audiovisuel: 1
#    olympic: 1
#    pol: 1
#    endagongcreditcom: 1
#    enjeu: 2
#    taff: 1
#    teixera: 1
#    montaign: 1
#    aeroportfr: 1
#    dalbums: 1
#    puy: 1
#    pantomime: 1
#    gerd: 1
#    hamel: 1
#    legislative: 1
#    usual: 1
#    rentrer: 1
#    equipementgouvfr: 1
#    francophonieorg: 1
#    talk: 1
#    everything: 1
#    country: 1
#    lim: 1
#    consister: 1
#    cinquante: 1
#    dominiqu: 3
#    jacquart: 1
#    radioplayer: 1
#    darro: 1
#    stopper: 1
#    derai: 1
#    eston: 1
#    european: 1
#    environmental: 1
#    notreenvironnementgouvfr: 1
#    fautil: 1
#    same: 1
#    barometer: 1
#    telegramme: 1
#    farright: 1
#    abstention: 1
#    sexiste: 1
#    presidentialisation: 1
#    existetil: 1
#    worked: 1
#    autant: 1
#    sherbinin: 1
#    pollueur: 1
#    radioprotection: 1
#    senatfr: 1
#    dance: 1
#    see: 1
#    mediametriefr: 1
#    civilist: 1
#    entreprisesgouvfr: 1
#    york: 2
#    mastercard': 1
#    fabrique: 1
#    picollec: 1
#    crumley: 1
#    death: 1
#    infographie: 1
#    charentemaritimegouvfr: 1
#    lichfield: 1
#    dupaquier: 1
#    Palmer: 1
#    times: 1
#    memofr: 1
#    heros: 1
#    julien: 1
#    septembr: 1
#    women: 1
#    incertitud: 1
#    piccarreta: 1
#    notifier: 1
#    conster: 1
#    parodi: 1
#    Emilie: 1
#    ecf: 1
#    estimate: 1
#    sit: 1
#    pharmaceutique: 1
#    lascauxculturefr: 1
#    Terre: 1
#    estelle: 2
#    mastercardcom: 1
#    asnfr: 1
#    lacroi: 1
#    gallicafr: 1
#    write: 1
#    timecom: 1
#    logement: 1
#    lefigarofr: 1
#    quotation: 1
#    gdp: 1
#    developpemer: 1
#    valley: 1
#    vaccination: 1
#    medaill: 1
#    pastorello: 1
#    amphitheatre: 1
#    bruxelle: 1
#    solidaire: 1
#    wid: 1
#    franceinfo: 1
#    raison: 4
#    edition: 1
#    Simon_le_Zelote: 1
#    imen: 1
#    nutriment: 3
#    saintpauletamsterdam: 1
#    ch: 1
#    observatoire: 1
#    ladocumentationfrancaisefr: 1
#    jose: 1
#    apercevoir: 1
#    than: 1
#    business: 1
#    that: 1
#    sga: 1
#    weo: 1
#    zachary: 1
#    verboeckhoven: 1
#    chalon: 1
#    laetitia: 1
#    diplomatiegouvfr: 1
#    first: 2
#    lorangerie: 1
#    enrichir: 1
#    matter: 2
#    smet: 1
#    solomos: 1
#    cie: 1
#    center: 1
#    monde: 4
# ...
#    stahl: 1
#    activity: 1
#    camera: 1
#    asma: 1
#    education: 3
#    wwwseuilcom: 1
#    channel: 1
#    jd: 1
#    material: 1
#    carl: 1
#    evolution: 1
#    ancient: 1
#    find: 1
#    chisholm: 1
#    white: 1
#    cracking: 1
#    papers: 1
#    wilson: 1
#    authorfullname: 1
#    henshilwood: 1
#    revell: 1
#    challeng: 1
#    eighth: 1
#    jacque: 1
#    hammer: 1
#    v: 1
#    lower: 1
#    cultural: 1
#    lithic: 1
#    mcgrew: 1
#    technical: 1
#    an: 1
#    genetic: 1
#    old: 1
#    calif: 1
#    metals: 1
#    right: 2
#    texier: 1
#    hominidescom: 1
#    explaining: 1
#    nicholas: 1
#    africa: 1
#    size: 1
#    Salto_del_Angel: 2
#    natur: 1
#    perspectif: 1
#    conference: 1
#    uncovered: 1
#    ancestors: 1
#    Christophe: 1
#    bouri: 1
#    chimpanzee: 1
#    kacelnik: 1
#    druyan: 1
#    research: 2
#    voice: 1
#    show: 1
#    blombo: 1
#    leap: 1
#    anthropology: 1
#    hart: 1
#    bibcode: 1
#    before: 1
#    skeletal: 1
#    Lincoln_Park: 1
#    transport: 1
#    cs: 1
#    toolmaker: 1
#    language: 1
#    river: 1
#    millionyearold: 1
#    nut: 1
#    patterson: 1
#    digital: 1
#    feibel: 1
#    beyene: 1
#    daily: 1
#    nbc: 1
#    biological: 2
#    students': 1
#    fire: 1
#    rincon: 1
#    belmont: 1
#    kibunjia: 1
#    mourre: 1
#    technopolitiqu: 1
#    applied: 1
#    divinity: 2
#    sussman: 1
#    history: 5
#    book: 2
#    pj: 1
#    plummer: 1
#    steven: 1
#    asia: 1
#    flow: 1
#    CV: 1
#    dolozi: 1
#    dispersal: 1
#    spirit: 2
#    britannicer: 3
#    human: 1
#    pressure: 1
#    mother: 1
#    neolithic: 1
#    turkana: 1
#    fossil: 1
#    jame: 1
#    watling: 1
#    thomson: 1
#    elli: 1
#    hugh: 1
#    dawn: 1
#    clark: 1
#    dietary: 1
#    south: 1
#    yearbook: 1
#    stone: 1
#    brief: 1
#    memoir: 2
#    interest: 1
#    georg: 1
#    rannikmae: 1
#    teaching: 1
#    australopithecus: 1
#    piscataway: 1
#    hominid: 1
#    africer: 1
#    selection: 1
#    ferraro: 1
#    apprise: 1
#    jlwz: 1
#    increase: 1
#    pleistocene: 1
#    current: 1
#    univ: 1
#    smithsonian: 1
#    factors: 1
#    analysis: 1
#    ago: 1
#    weir: 1
#    vrber: 1
#    jp: 1
#    heinzelin: 1
#    crow: 1
#    artifact: 1
#    cordal: 1
#    career: 1
#    west: 3
#    factory: 1
#    lexical: 4
#    Kenya: 1
#    andamanese: 1
#    monkeys: 1
#    oakley: 1
#    haviland: 1
#    utilisaientil: 1
#    gymnasium: 1
#    payer: 4
#    time: 1
#    boesch: 1
#    kromdraai: 1
#    physical: 1
#    mas: 1
#    chimpanzees: 1
#    penguin: 2
#    during: 1
#    flaked: 1
#    gordon: 1
#    muller: 1
#    viller: 1
#    pmid: 1
#    brugal: 1
#    environment: 1
#    worldwid: 1
#    studer: 1
#    hydraulics: 1
#    leakey: 1
#    child: 1
#    sterkfontein: 1
#    abrupt: 1
#    out: 1
#    pp: 2
#    myr: 1
#    swarat: 1
#    Gary: 2
#    american: 1
#    vaino: 1
#    Wade: 1
#    early: 1
#    cramb: 1
#    tool: 1
#    delagne: 1
#    bbc: 1
#    armee: 1
#    year: 1
#    skills: 1
#    rutz: 1
#    bf: 1
#    mhalla: 1
#    richard: 1
#    tea: 1
#    antichambre: 1
#    pmcid: 1
#    wnwen: 1
#    holbrook: 1
#    related: 1
#    constabl: 1
#    woldegabriel: 1
#    hedwige: 1
#    cambridge: 1
#    oenotheque: 1
#    scientist: 1
#    birth: 1
#    period: 1
#    bone: 1
#    map: 1
#    carnegie: 1
#    short: 1
#    wikibookstechnologie: 1
#    wiktionnairetechnologie: 1
#    dompter: 1
#    franchecomte: 1
#    lharmattan: 2
#    halte: 1
#    lhumain: 1
#    lasfargu: 1
#    bookspufc: 1
#    vuibert: 1
#    technologier: 1
#    mach: 1
#    promether: 1
#    gilbert: 1
#    dorganisation: 1
#    simondon: 1
#    jarrige: 1
#    ridiculite: 1
#    ane: 1
#    philosophique: 2
#    technocritiqu: 1
#    roberval: 1
#    neoluddisme: 1
#    norm: 2
#    standardisation: 1
#    revival: 1
#    litterature: 1
#    commentaire: 1
#    biomedicine: 2
#    treccani: 2
#    encyclopedier: 4
#    securite-incendie: 1
#    puech: 1
#    informatiser: 1
#    lintroducteur: 1
#    lagora: 1
#    millenarism: 1
#    modern: 2
#    catalana: 4
#    incoherence: 1
#    store: 2
#    verres_de_contact: 2
#    ecran: 1
#    affichage: 1
#    autostereoscopie: 1
#    lentill: 1
#    diode: 1
#    electroluminescent: 1
#    virtuel: 1
#    engrais_organique: 1
#    bionique: 1
#    hydroponie: 1
#    aquaponie: 1
#    viand: 1
#    vegetaliser: 1
#    genetiquement: 1
#    vitro: 1
#    interferometrie: 2
#    virgo: 2
#    halca: 3
#    optique: 3
#    astronomique: 1
#    hypertelescope: 3
#    event: 3
#    donde: 1
#    gravitationnel: 1
#    interferometre: 1
#    ligo: 2
#    senseur: 1
#    telescope: 3
#    perspective: 3
#    interferometr: 1
#    GSM: 2
#    pyrosequencage: 1
#    doligonucleotides: 1
#    ligation: 1
#    semiconducteur: 1
#    sequencage: 1
#    nanopore: 1
#    SI: 1
#    capillaire: 1
#    imagerie: 1
#    biophotoniqu: 1
#    optofluidiqu: 1
#    electrophorese: 1
#    chip: 1
#    spectre: 1
#    moleculaire: 1
#    optogenetiqu: 1
#    senescence: 1
#    strategie: 1
#    neuronal: 2
#    interfac: 1
#    photodynamique: 1
#    negligibl: 1
#    ampakine: 1
#    cryoconservation: 1
#    regeneratif: 1
#    biostase: 1
#    tenor: 1
#    bioimpression: 1
#    engineered: 1
#    biomedical: 1
#    genetique: 1
#    arn: 1
#    genique: 1
#    nanomedecin: 1
#    cryogenisation: 1
#    therapie: 1
#    biologie: 2
#    interference: 1
#    hopital: 1
#    femtoseconde: 1
#    bic: 1
#    alpha: 1
#    cristallographie: 2
#    spectrometri: 2
#    seriel: 1
#    microfluidiqu: 1
#    intelligent: 1
#    optoelectronique: 1
#    optroniqu: 1
#    spintroniqu: 1
#    odorat: 1
#    atomtroniqu: 1
#    plastronique: 1
#    nram: 2
#    cbram: 2
#    mram: 2
#    pram: 2
#    xpoint: 2
#    ambiant: 2
#    neurone: 1
#    rram: 2
#    ubiquitaire: 1
#    fram: 2
#    cryptanalyse: 1
#    millipede: 2
#    cellule_nerveuse: 1
#    laser: 2
#    gamma: 1
#    spectroscopie: 1
#    microrobotiqu: 1
#    exosquelette: 1
#    nanorobot: 1
#    cobotiqu: 1
#    essaim: 1
#    domotiqu: 1
#    motoriser: 1
#    molle: 1
#    hydrogene: 1
#    hyperloop: 1
#    sustentation: 1
#    strati: 1
#    autonome: 2
#    ecall: 1
#    propulsion: 1
#    moto: 1
#    magnetique: 1
#    spacetrain: 1
#    fuser: 1
#    jetpack: 1
#    httpspsychologiesavoirfrpsychologieeconomiepsychiqu: 1
#    spin-off: 1
#    educatio: 2
#    mialaret: 2
#    aliment: 2
#    notion: 6
#    ex-mari: 2
#    pointer: 1
#    noter: 1
#    saisir: 1
#    ducere: 1
#    guider: 1
#    convier: 1
#    maximiser: 1
#    methodique: 1
#    corpus: 2
#    exducere: 1
#    conciliation: 1
#    educere: 1
#    transmettre: 5
#    deducation: 10
#    problematique: 1
#    educare: 1
#    etymologie: 1
#    enseigner: 2
#    instance: 1
#    nourrirremplir: 1
#    detud: 1
#    referer: 1
#    preciser: 1
#    daffronter: 1
#    littrer: 1
#    quinversement: 1
#    bagage: 1
#    lalphabet: 3
#    remarquer: 1
#    littre: 1
#    subtil: 1
#    dexempl: 1
#    consensu: 1
#    setudier: 1
#    passe: 2
#    relationnel: 1
#    sapprend: 1
#    senseigne: 1
#    psychologie: 3
#    pluriel: 1
#    semploi: 1
#    motiver: 1
#    pedagogue: 2
#    hypothese: 4
#    implicite: 1
#    explicite: 1
#    veyne: 2
#    lenfer: 5
#    lembellir: 1
#    deguise: 1
#    preparer: 2
#    lenfance: 3
#    germinal: 1
#    incarner: 1
#    apotheose: 1
#    ecrivaitil: 1
#    influent: 1
#    locke: 1
#    reposer: 1
#    adroitemer: 1
#    desirer: 1
#    rever: 1
#    rarement: 1
#    souhait: 2
#    apprendre: 5
#    lock: 1
#    auparavant: 1
#    raisonner: 1
#    savoiretre: 3
#    schematiquement: 1
#    correspond: 2
#    dacquerir: 3
#    metaconnaissance: 1
#    lectur: 1
#    ecrit: 2
#    apprenant: 3
#    lexercice: 1
#    dautomatisme: 1
#    artisanal: 1
#    dappliquer: 1
#    lexperience: 1
#    sacquierer: 1
#    lindividu: 3
#    proteger: 1
#    maitris: 1
#    adequat: 2
#    empathi: 1
#    savoiretr: 1
#    hygien: 1
#    sacquiert: 1
#    soi: 2
#    ajustement: 2
#    lessence: 1
#    entraid: 1
#    expiation: 1
#    authenticite: 1
#    allegresse: 1
#    bienetre: 1
#    creativite: 1
#    reconfort: 1
#    plaisir: 2
#    datteindre: 1
#    psychique: 1
#    dapprentissage: 2
#    mill: 1
#    conceptuel: 4
#    categoriel: 2
#    verbal: 4
#    socioemotif: 1
#    courammer: 1
#    orthograph: 1
#    verbalisable: 1
#    coeur: 2
#    impliquent: 1
#    stocker: 1
#    inclusion: 4
#    lapprener: 1
#    dobjet: 1
#    resolution: 1
#    dalgorithme: 1
#    socioemotionnel: 1
#    dacquisition: 1
#    rougir: 3
#    taxonomie: 1
#    nomenclature: 2
#    Jehovah: 1
#    Benjamin: 2
#    capable: 1
#    luimeme: 1
#    soimeme: 1
#    laisser: 1
#    dictionnaire: 2
#    leleve: 2
#    transmittance: 3
#    correct: 1
#    epellation: 1
#    iufm: 1
#    sinon: 1
#    stressant: 1
#    denoncer: 1
#    reactionnaire: 1
#    retrograde: 1
#    avertissement: 1
#    supposer: 1
#    artificielle: 1
#    doctoral: 1
#    soustraction: 1
#    dit: 1
#    opposant: 1
#    inconsiderer: 1
#    grammatical: 1
#    imputer: 1
#    dangereux: 1
#    formatage: 1
#    cenacle: 1
#    dressage: 1
#    inefficace: 1
#    ensembliste: 1
#    cognitiviste: 1
#    dorientation: 1
#    psychologue: 1
#    grondement: 1
#    resultent: 1
#    om: 1
#    corriger: 1
#    formel: 2
#    aisee: 1
#    incapacite: 1
#    heterogene: 1
#    socialemer: 1
#    financierement: 1
#    lunique: 1
#    passeron: 1
#    elevage: 1
#    culturellement: 1
#    lentourage: 1
#    compenser: 1
#    sadresser: 1
#    profiter: 1
#    rationaliser: 1
#    linstitution: 1
#    gratuite: 1
#    formaliser: 1
#    limpass: 1
#    dinstruction: 1
#    operer: 1
#    exiger: 3
#    mode_passif: 1
#    tabou: 1
#    sintegre: 1
#    lelev: 1
#    delivrer: 1
#    delargir: 1
#    dacceder: 2
#    epanouissement: 1
#    contraire: 2
#    contradictoire: 1
#    integration: 2
#    historiquement: 1
#    precoce: 1
#    finalite: 1
#    professionnalisation: 1
#    defavoriser: 2
#    orphelin: 1
#    accomplir: 1
#    abandonner: 1
#    orphelinat: 1
#    nonbiologique: 1
#    La_Tragedie_d'Hamlet: 2
#    laert: 2
#    polonius: 1
#    shakespeare: 2
#    voici: 2
#    asseoir: 1
#    Dhakhan: 1
#    prete: 1
#    exquis: 1
#    voyant: 1
#    loyal: 1
#    deloyal: 1
#    hont: 1
#    denichera: 1
#    ladversair: 1
#    ga: 1
#    au_revoir: 1
#    digne: 1
#    excentrique: 1
#    emousser: 1
#    assaisonn: 1
#    loreill: 1
#    dacier: 1
#    vulgaire: 1
#    lhomm: 1
#    dentrer: 2
#    gardetoi: 1
#    eprouver: 1
#    durci: 1
#    preteur: 1
#    fantasy: 1
#    crampon: 1
#    toimeme: 1
#    nullement: 1
#    k: 2
#    envers: 1
#    accrochele: 1
#    lemprunt: 1
#    rasibus: 1
#    lepaule: 1
#    calque: 1
#    attente: 1
#    lexecution: 1
#    dedans: 1
#    eclore: 1
#    emprunteur: 1
#    prend: 1
#    niqab: 1
#    comportetoi: 1
#    irreflechi: 1
#    laerte: 1
#    am: 1
#    lopinion: 1
#    couteus: 1
#    infailliblement: 1
#    interaction: 1
#    parental: 2
#    pourtois: 1
#    linkup: 1
#    encourager: 3
#    actualiser: 1
#    terrisse: 1
#    eduquer: 2
#    initiation: 1
#    proposant: 1
#    afin: 1
#    prerequis: 1
#    doeuvre: 1
#    enfantine: 1
#    socioeconomique: 1
#    rudiment: 1
#    eventuellement: 1
#    ladolescence: 1
#    puberter: 1
#    savoirvivre: 1
#    marginalemer: 1
#    concentrer: 1
#    enfance: 2
#    oral: 2
#    collectivement: 1
#    racialisme: 1
#    dasservissement: 1
#    dessentiel: 1
#    soumis: 1
#    normal: 1
#    inculcation: 1
#    xenophobie: 1
#    endoctrinement: 1
#    opposition: 1
#    code_de_deontologie: 1
#    ulterieur: 1
#    Inhibiteur: 1
#    neurotransmetteurs: 1
#    malleabilite: 1
#    gyrus: 1
#    gaba: 1
#    dinhibiteur: 1
#    montr: 1
#    ladolescent: 1
#    frontal: 1
#    dacid: 1
#    induire: 1
#    gaminobutyriqu: 1
#    crucial: 1
#    efficace: 1
#    sure: 2
#    inclusif: 2
#    sur: 1
#    jury: 1
#    sert: 1
#    interculturel: 2
#    eliminer: 2
#    audela: 1
#    terrain_vague: 1
#    cavalerie: 1
#    Nombre_reel: 1
#    progre: 1
#    handicap: 1
#    accompagnemer: 1
#    refonte: 1
#    racial: 1
#    lenfant: 2
#    Dakar: 3
#    signataire: 1
#    reaffirmer: 1
#    formuler: 1
#    lan: 2
#    jomtien: 1
#    leadership: 1
#    design: 2
#    lonu: 2
#    ept: 1
#    restriction: 1
#    vulnerable: 1
#    equitable: 1
#    veiller: 2
#    reussite: 2
#    lettrure: 1
#    ethnique: 2
#    huile: 1
#    quantifiable: 1
#    Son_Excellence: 1
#    jusqu': 1
#    meme: 1
#    navigant: 1
#    rediger: 1
#    lept: 2
#    enumerer: 1
#    rapporteur: 2
#    minimal: 1
#    communauter: 1
#    acceptabilite: 1
#    salubrite: 1
#    sage: 1
#    eradiquer: 1
#    adaptabilite: 1
#    enseignemer: 2
#    refugie: 1
#    extrascolaire: 1
#    suivant: 1
#    garanti: 1
#    duquel: 1
#    degalite: 1
#    sienne: 1
#    depassement: 1
#    lepanouissement: 1
#    damitier: 1
#    aborigene: 1
#    fondamentale: 1
#    inculquer: 1
#    etudier: 1
#    becker: 1
#    salairer: 1
#    equation: 1
#    employeur: 1
#    investissement: 1
#    mincer: 2
#    avantageux: 1
#    operationnel: 1
#    kenneth: 1
#    signalisation: 1
#    alternatif: 1
#    assigner: 1
#    michael: 1
#    mobilisable: 1
#    Canadiens_francais: 1
#    filiere: 1
#    arrow: 1
#    priori: 1
#    spence: 1
#    filtrage: 1
#    effectuer: 1
#    cumulatif: 1
#    doptier: 1
#    evoquer: 1
#    lhypothese: 1
#    selectif: 1
#    daide: 1
#    fourniture: 1
#    lobtention: 1
#    publicprive: 1
#    dinscription: 1
#    differ: 1
#    plafonner: 1
#    payanter: 1
#    daccessibilite: 1
#    exclur: 1
#    precaire: 1
#    lencontre: 1
#    rouche: 1
#    Brown: 1
#    yvon: 1
#    patlagean: 1
#    duby: 1
#    mil: 1
#    thebert: 1
#    aries: 2
#    lack: 1
#    earning: 1
#    children: 1
#    sociologique: 1
#    math: 1
#    ens: 1
#    jeanfrancois: 1
#    were: 1
#    bris: 1
#    francesco: 1
#    dessu: 1
#    commonly: 1
#    souhaiteil: 1
#    ametist: 1
#    tiehi: 1
#    cinquantehuitiem: 1
#    attainment: 1
#    currier: 1
#    arnaud: 1
#    cognitif: 1
#    Marc: 1
#    pedagogie: 1
#    completed: 1
#    achievemer: 1
#    airhm: 1
#    cafepedagogiquenet: 1
#    krathwohl: 1
#    lorna: 1
#    brain: 1
#    all: 1
#    margotcattin: 1
#    glasman: 1
#    hill: 1
#    sociale: 1
#    contradicting: 1
#    being: 1
#    cohen: 1
#    houston: 1
#    post: 1
#    furst: 1
#    segmer: 1
#    domain: 1
#    person: 1
#    rie: 1
#    parienty: 1
#    blooms: 1
#    referred: 1
#    beetham: 1
#    sain: 1
#    committee: 1
#    commitment: 1
#    developmer: 1
#    goal: 1
#    marcus: 1
#    tetreault: 1
#    sella: 1
#    mathematical: 1
#    mcneil: 1
#    cornu: 1
#    although: 1
#    defining: 1
#    undermined: 1
#    instructional: 1
#    sevres: 1
#    quebec: 1
#    taxonomy: 1
#    experience: 1
#    onu: 1
#    blog: 1
#    englehart: 1
#    latinfrancer: 1
#    live: 1
#    wikisource: 2
#    betrisey: 1
#    stock: 1
#    zacharopoulos: 1
#    longmans: 1
#    Myth: 1
#    kadosh: 1
#    webjournal: 1
#    pna: 1
#    corley: 1
#    minc: 1
#    authors: 1
#    decrire: 1
#    httpswwwcairninforevueletelemaque: 1
#    ecn: 1
#    gaffiot: 1
#    extrusion: 1
#    romand: 1
#    sheila: 1
#    cadrage: 1
#    rfp: 1
#    bongrand: 1
#    linclusion: 1
#    pnas: 1
#    monetary: 1
#    piketty: 1
#    methodologique: 1
#    two: 1
#    tomasevski: 1
#    Sarah: 1
#    Hypertext_Markup_Language: 1
#    there: 1
#    combler: 1
#    avantpropo: 1
#    landry: 1
#    majority: 1
#    educational: 1
#    initiativ: 1
#    helen: 1
#    macneill: 1
#    quality: 1
#    september: 1
#    Campbell: 1
#    pierart: 1
#    other: 1
#    schooling: 1
#    wikiquoteeducation: 1
#    wiktionnaireeducation: 1
#    commonseducation: 1
#    wikiversityeducation: 1
#    wikibookseducation: 1
#    wikisourceeducation: 1
#    ignorance: 1
#    abdelkarim: 1
#    chanlat: 1
#    lux: 1
#    actualite: 1
#    achaari: 1
#    postface: 1
#    agone: 1
#    mayor: 1
#    Themis: 1
#    federico: 1
#    zaragoza: 1
#    koninck: 1
#    erny: 1
#    portuger: 1
#    Jessye_Norman: 1
#    lanarchisme: 1
#    errouaki: 1
#    ethnologie: 2
#    mohamed: 1
#    baillargeon: 1
#    gregory: 1
#    plutarqu: 1
#    degenaer: 1
#    ash: 1
#    specialise: 2
#    ldl: 1
#    lernen: 1
#    autoformation: 1
#    lehren: 1
#    socioculturel: 1
#    plasticiter: 1
#    cateches: 1
#    durch: 1
#    construir: 1
#    universali: 2
#    encyclopedia: 2
#    lenoir: 1
#    curriculum: 1
#    irie: 1
#    Utah: 2
#    enjeux: 1
#    aragonesa: 2
#    cleveland: 2
#    onlin: 2
#    clarification: 1
#    humanium: 1
#    conception: 1
#    texa: 2
#    handbook: 2
#    virginia: 2
#    great: 2
#    hstreasure: 1
#    plain: 2
#    ethologi: 1
#    sousculture: 1
#    contreculture: 1
#    legitimite: 1
#    rayonnemer: 1
#    acculturation: 1
#    hegemonie: 1
#    transculturation: 1
#    ethnocide: 1
#    structuralisme: 1
#    evolutionnisme: 1
#    culturalisme: 1
#    diffusionnisme: 1
#    fonctionnalism: 1
#    ethnomycologie: 1
#    astronomie: 1
#    ethnopsychiatrie: 1
#    ethnolichenologie: 1
#    ethnoecologie: 1
#    bioculture: 1
#    ethnoichthyologie: 1
#    ethnozoologie: 1
#    ethnobotanique: 1
#    ethnoornithologie: 1
#    culturologie: 1
#    anthropologie: 1
#    ethnomathematique: 1
#    ethologie: 1
#    semiologie: 1
#    ethnoherpetologie: 1
#    ethnopharmacologie: 1
#    ethnoentomologie: 1
#    neuroculture: 1
#    cartographi: 1
#    ethnographie: 1
#    ethnopsychanalyse: 1
#    culturomiqu: 1
#    ethnobiologie: 1
#    trouble_de_la_personnalite: 1
#    ethnoarcheologie: 1
#    ethnomedecine: 1
#    psychanalytique: 1
#    radicalisme: 1
#    ethnohistoir: 1
#    neuroscience: 1
#    ethnoprimatologie: 1

# %%
# fonction pour calculer le nombre total de mots dans tous les documents
def calculate_total_word_count(processed_documents):
    total_word_count = sum(len(doc['tokens']) for doc in processed_documents)
    return total_word_count

total_word_count = calculate_total_word_count(processed_documents)

print("Nombre total de mots dans tous les documents :", total_word_count)
# Out:
# Nombre total de mots dans tous les documents : 30862

# %% [markdown]
# **creation d'un index inversé**
#
# {
#     "mot1": {
#         "Document1": fréquence1,
#         "Document2": fréquence2
#     },
#     "mot2": {
#         "Document1": fréquence3,
#         "Document3": fréquence4
#     },
#     ...
# }

# %%
# fonction pour créer un index inversé avec les mots comme clés principaux
def create_word_index(tf_documents):
    word_index = {}

    # parcourir chaque document et chaque mot avec sa fréquence
    for doc in tf_documents:
        title = doc['title']
        for word, count in doc['tf'].items():
            # si le mot n'est pas dans l'index, l'ajouter avec un dictionnaire vide
            if word not in word_index:
                word_index[word] = {}
            # ajouter ou mettre à jour le document et le nombre d'occurrences pour le mot
            word_index[word][title] = count

    return word_index

word_index = create_word_index(tf_documents)

print("Index des mots :")
print(word_index)
# Out:
# Index des mots :
# {'<LOCATION>': {'Wikipédia': 1, 'Article labellisé du jour': 1, 'Actualités': 1, 'Éphéméride du 9 novembre': 3, 'Toponymie': 1, 'Localisation, frontières et superficie': 2, 'Géologie, topographie et hydrographie': 1, 'Climat': 2, 'Paysages et environnement': 1, "Préservation de l'environnement": 1, 'Répartition spatiale des hommes et des activités': 4, 'Axes de communication et de transports': 2, 'Histoire': 2, 'Préhistoire, protohistoire et Antiquité': 4, 'Naissance, crises et transformations du royaume de France au Moyen Âge': 4, 'De la Renaissance à la monarchie absolue (XVIe au XVIIIe\xa0siècle)': 5, 'Révolutions, républiques, monarchies et empires (1789-1914)': 5, 'La France dans les deux guerres mondiales (1914-1945)': 2, 'La Libération, gaullisme et crise politique (1945-1968)': 3, 'Depuis Mai 68': 1, 'Politique et administration': 3, 'Organisation des pouvoirs': 2, 'Découpage territorial et décentralisation': 1, "France d'outre-mer": 1, 'Tendances politiques, partis et élections': 4, 'Finances publiques': 3, 'Défense': 7, 'Appartenance à des organisations internationales': 3, 'Politique étrangère et diplomatie': 1, 'Symboles républicains': 1, 'Démographie': 1, 'Immigration, population étrangère et minorités visibles': 4, 'Famille, sexualité et égalité des sexes': 2, 'Langues': 2, 'Religions': 1, 'Éducation': 1, 'Santé et protection sociale': 2, 'Médias': 1, 'Sport': 2, 'Engagement associatif, syndical et politique': 1, 'Discrimination': 5, 'Économie': 1, 'Revenus de la population et développement humain': 1, 'Emploi': 1, "Principaux secteurs d'activité": 3, "Place de la France dans l'économie mondiale": 1, 'Culture': 1, 'Architecture': 6, 'Arts visuels et plastiques': 1, 'Littérature et poésie': 3, 'Arts du spectacle': 1, 'Musique': 3, 'Cinéma': 4, 'Mode': 3, 'Gastronomie': 2, 'Philosophie et science': 1, 'Influence internationale': 3, 'Notes': 56, 'Références': 9, 'Annexes': 2, 'Liens externes': 1, 'Le concept de technology selon Jacob Bigelow': 1, 'Critique du mot': 1, 'Paléolithique': 2, "Du Néolithique à l'Antiquité classique": 1, 'Époque contemporaine': 3, 'Autres espèces animales': 1, 'Bibliographie': 1, 'Voir aussi': 1, 'Les Éducation, instruction ou enseignement': 1, "Influences de l'histoire, des cultures et des croyances et théories implicites": 1, 'Taxonomie de Robert Mills Gagné': 1, 'Taxonomie de Bloom': 1, 'Éducation formelle et éducation non formelle en France': 1, 'Éducation familiale': 2, 'Éducation parentale': 1, 'Inclusion scolaire': 4, "Les objectifs de l'Éducation pour Tous": 4, "Interprétation du droit à l'éducation": 6, 'France': 1, 'Notes et références': 16, 'Articles connexes': 2}, 'lencyclopedie': {'Wikipédia': 1, 'Philosophie et science': 1, 'Liens externes': 3}, 'ouvrir': {'Wikipédia': 1, 'Toponymie': 1, 'La Libération, gaullisme et crise politique (1945-1968)': 1, 'Famille, sexualité et égalité des sexes': 1, 'Médias': 1, 'Liens externes': 1, 'Un droit reconnu au niveau international': 1}, 'supergrand': {'Wikipédia': 1, 'Le saviez-vous\xa0?': 2, 'Présentation': 1, 'Comment contribuer\xa0?': 1, 'Éphéméride du 9 novembre': 1, 'Géologie, topographie et hydrographie': 1, "Préservation de l'environnement": 1, 'Préhistoire, protohistoire et Antiquité': 1, 'Naissance, crises et transformations du royaume de France au Moyen Âge': 1, 'De la Renaissance à la monarchie absolue (XVIe au XVIIIe\xa0siècle)': 1, 'Révolutions, républiques, monarchies et empires (1789-1914)': 1, 'La France dans les deux guerres mondiales (1914-1945)': 1, 'La Libération, gaullisme et crise politique (1945-1968)': 3, 'Organisation des pouvoirs': 2, 'Découpage territorial et décentralisation': 1, "France d'outre-mer": 1, 'Appartenance à des organisations internationales': 1, 'Langues': 1, 'Sport': 1, 'Revenus de la population et développement humain': 2, 'Architecture': 1, 'Arts visuels et plastiques': 2, 'Littérature et poésie': 1, 'Musique': 1, 'Gastronomie': 1, 'Philosophie et science': 1, 'Notes': 2, 'Références': 2, 'Lien ...

# %% [markdown]
# Filtrage des mots avec faibles frèquences en utilisant dess seuils de tf et de df  --> chaque document contient uniquement les mots dépassant les seuils de TF et DF.
# {
#     "mot": {
#         "titre_document": fréquence du mot dans le_document,
#         "titre_document_suivant": fréquence du mot dans le document_suivant,
#         ...
#     },
#     ...
# }

# %%
from collections import Counter

def create_mot_index(processed_documents):
    mot_index = {}

    # parcourt de chaque document et compter les occurrences de chaque mot
    for doc in processed_documents:
        title = doc['title']  # nom du document pour l'indexation
        token_counts = Counter(doc['tokens'])  # compter les occurrences des tokens dans le document

        # Construction l'index avec les mots comme clés principaux
        for token, count in token_counts.items():
            if token not in mot_index:
                mot_index[token] = {}
            mot_index[token][title] = count  # Associer le document et la fréquence du mot

    return mot_index

# Générer mot_index à partir des documents traités
mot_index = create_mot_index(processed_documents)

# %%
# fonction pour filtrer les mots en fonction de TF et DF
def filtrer_mots_df_tf(mot_index, seuil_tf=2, seuil_df=2):

    index_filtré = {}

    for mot, docs in mot_index.items():
        # calculer DF : nombre de documents dans lesquels le mot apparaît
        df = len(docs)

        # filtrer les mots selon le seuil de DF
        if df >= seuil_df:
            # Filtrer les occurrences du mot dans chaque document selon le seuil de TF
            docs_filtrés = {doc: tf for doc, tf in docs.items() if tf >= seuil_tf}

            # Si le mot a encore des occurrences après filtrage TF, on le conserve
            if docs_filtrés:
                index_filtré[mot] = docs_filtrés

    return index_filtré

# appliquer la fonction pour filtrer l'index des mots selon les seuils souhaités
index_filtré = filtrer_mots_df_tf(mot_index, seuil_tf=2, seuil_df=2)

# Afficher le dictionnaire filtré
print("Dictionnaire filtré selon les seuils TF et DF :")
print(index_filtré)
# Out:
# Dictionnaire filtré selon les seuils TF et DF :
# {'<LOCATION>': {'Éphéméride du 9 novembre': 3, 'Localisation, frontières et superficie': 2, 'Climat': 2, 'Répartition spatiale des hommes et des activités': 4, 'Axes de communication et de transports': 2, 'Histoire': 2, 'Préhistoire, protohistoire et Antiquité': 4, 'Naissance, crises et transformations du royaume de France au Moyen Âge': 4, 'De la Renaissance à la monarchie absolue (XVIe au XVIIIe\xa0siècle)': 5, 'Révolutions, républiques, monarchies et empires (1789-1914)': 5, 'La France dans les deux guerres mondiales (1914-1945)': 2, 'La Libération, gaullisme et crise politique (1945-1968)': 3, 'Politique et administration': 3, 'Organisation des pouvoirs': 2, 'Tendances politiques, partis et élections': 4, 'Finances publiques': 3, 'Défense': 7, 'Appartenance à des organisations internationales': 3, 'Immigration, population étrangère et minorités visibles': 4, 'Famille, sexualité et égalité des sexes': 2, 'Langues': 2, 'Santé et protection sociale': 2, 'Sport': 2, 'Discrimination': 5, "Principaux secteurs d'activité": 3, 'Architecture': 6, 'Littérature et poésie': 3, 'Musique': 3, 'Cinéma': 4, 'Mode': 3, 'Gastronomie': 2, 'Influence internationale': 3, 'Notes': 56, 'Références': 9, 'Annexes': 2, 'Paléolithique': 2, 'Époque contemporaine': 3, 'Éducation familiale': 2, 'Inclusion scolaire': 4, "Les objectifs de l'Éducation pour Tous": 4, "Interprétation du droit à l'éducation": 6, 'Notes et références': 16, 'Articles connexes': 2}, 'lencyclopedie': {'Liens externes': 3}, 'supergrand': {'Le saviez-vous\xa0?': 2, 'La Libération, gaullisme et crise politique (1945-1968)': 3, 'Organisation des pouvoirs': 2, 'Revenus de la population et développement humain': 2, 'Arts visuels et plastiques': 2, 'Notes': 2, 'Références': 2, "Du Néolithique à l'Antiquité classique": 2}, 'ameliorer': {"Les objectifs de l'Éducation pour Tous": 3}, 'veine_porte': {'Liens externes': 5}, 'regle': {'Politique et administration': 2, 'Découpage territorial et décentralisation': 3, 'Emploi': 2, 'Références': 7, 'Étymologie': 2, "Droit à l'éducation": 5}, 'proposition': {'Références': 2, 'Notes et références': 2}, '<PERSON>': {'Actualités': 6, 'Le saviez-vous\xa0?': 3, 'Éphéméride du 9 novembre': 3, 'Histoire': 2, 'De la Renaissance à la monarchie absolue (XVIe au XVIIIe\xa0siècle)': 3, 'Révolutions, républiques, monarchies et empires (1789-1914)': 2, 'La France dans les deux guerres mondiales (1914-1945)': 3, 'La Libération, gaullisme et crise politique (1945-1968)': 6, 'Découpage territorial et décentralisation': 2, 'Défense': 2, 'Appartenance à des organisations internationales': 2, 'Démographie': 2, 'Santé et protection sociale': 2, 'Engagement associatif, syndical et politique': 2, 'Architecture': 9, 'Arts visuels et plastiques': 2, 'Littérature et poésie': 6, 'Arts du spectacle': 6, 'Musique': 8, 'Mode': 7, 'Références': 31, 'Le concept de technology selon Jacob Bigelow': 2, 'Critique du mot': 2, "Du Néolithique à l'Antiquité classique": 2, "Interprétation du droit à l'éducation": 2, "Investir dans l'éducation": 2, 'Notes et références': 21}, 'deux': {'Géologie, topographie et hydrographie': 2, 'Depuis Mai 68': 3, 'Notes': 2, 'Références': 4}, 'presenter': {'Religions': 2}, 'comme': {'Notes': 3, 'Paléolithique': 4, "Du Néolithique à l'Antiquité classique": 2, 'Autres espèces animales': 4, 'Critiques': 2}, 'celui': {'Axes de communication et de transports': 2, 'Notes': 3, 'Références': 3, "Du Néolithique à l'Antiquité classique": 2}, 'prendre': {'Musique': 2}, 'may': {'La Libération, gaullisme et crise politique (1945-1968)': 2, 'Références': 6}, 'grace': {"Principaux secteurs d'activité": 2, 'Paléolithique': 2, 'Autres espèces animales': 2, 'Éducation familiale': 2}, 'entrer': {'Axes de communication et de transports': 2, 'De la Renaissance à la monarchie absolue (XVIe au XVIIIe\xa0siècle)': 2, 'Depuis Mai 68': 4, 'Découpage territorial et décentralisation': 3, 'Famille, sexualité et égalité des sexes': 2, 'Revenus de la population et développement humai ...

# %% [markdown]
# **{
#     "mot": {
#         "titre_document": fréquence du mot dans le document,
#         "titre_document_suivant": fréquence du mot dans le document suivant,
#         ...
#     },
#     ...
# }**

# %%
# fonction pour afficher les documents filtrés sous forme détaillée
def afficher_documents_filtrés_détaillé(documents_filtrés, processed_documents):
    print("\nDocuments après filtrage :\n")

    # parcourt chaque document dans les documents prétraités pour récupérer l'URL et le titre
    for doc in processed_documents:
        title = doc['title']
        url = doc['url']

        # vérifie si le document existe dans les documents filtrés
        if title in documents_filtrés:
            tokens_filtrés = [mot for mot, count in documents_filtrés[title]]  # Extraire seulement les mots sans les occurrences
            print(f"Document : {title} (URL: {url})")
            print(f"Tokens filtrés : {tokens_filtrés}\n")
        else:
            # Si le document n'a pas de mots filtrés, on affiche un message vide
            print(f"Document : {title} (URL: {url})")
            print("Tokens filtrés : []\n")

afficher_documents_filtrés_détaillé(documents_filtrés, processed_documents)
# Out:
# Documents après filtrage :
#
# Document : Wikipédia (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : []
#
# Document : Wikipédia (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : []
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['local', 'bluster', 'scientifique', 'canvass', 'contenir']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'presidentiel', 'election', 'guerre', 'civil', 'john']
#
# Document : Le saviez-vous ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['pouvoir', '<PERSON>', 'etatsuni', 'parmi']
#
# Document : Le saviez-vous ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['pouvoir', '<PERSON>', 'etatsuni', 'parmi']
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['projet', 'contenu', 'sou']
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['projet', 'contenu', 'sou']
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['projet', 'contenu', 'sou']
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['contenu', 'notamment']
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['contenu', 'notamment']
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['contenu', 'notamment']
#
# Document : Éphéméride du 9 novembre (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'berlin', 'bosnieherzegovine']
#
# Document : Éphéméride du 9 novembre (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'berlin', 'bosnieherzegovine']
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : []
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : []
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Tokens filtrés : []
#
# Document : Toponymie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['nom', 'franc', 'signifier']
#
# Document : Toponymie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['nom', 'franc', 'signifier']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'kilometre', 'francais', 'locean', 'amerique', 'taaf', 'superficie', 'setablit', 'grand']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['deux', 'bluster', 'haute', 'cote', 'francais', 'territoire', 'locean', 'guyane', 'polynesie', 'indien', 'reunion', 'ile', 'taaf', 'plaine', 'quatre', 'lier', 'continental', 'formation', 'tahiti', 'actif', 'ensemble', 'barriere']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'present', 'france', 'massif', 'sud', 'ainsi', 'aquitain', 'parisien', 'vallee', 'rhone', 'plaine', 'autour', 'chaud', 'degre', 'climat', 'car', 'corse', 'temperature', 'moyenne']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'present', 'france', 'massif', 'sud', 'ainsi', 'aquitain', 'parisien', 'vallee', 'rhone', 'plaine', 'autour', 'chaud', 'degre', 'climat', 'car', 'corse', 'temperature', 'moyenne']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'present', 'france', 'massif', 'sud', 'ainsi', 'aquitain', 'parisien', 'vallee', 'rhone', 'plaine', 'autour', 'chaud', 'degre', 'climat', 'car', 'corse', 'temperature', 'moyenne']
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'present', 'france', 'massif', 'sud', 'ainsi', 'aquitain', 'parisien', 'vallee', 'rhone', 'plaine', 'autour', 'chaud', 'degre', 'climat', 'car', 'corse', 'temperature', 'moyenne']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['plus', 'qualite', 'bear', 'europeen', 'mondial', 'lallemagne', 'massif', 'posseder', 'e', 'lunion', 'loire', 'alsac', 'quant', 'moyenne', 'ecologique', 'routier', 'eau', 'mauvais', 'carbone', 'equivaloir', 'co', 'emission', 'rapport', 'gaz', 'effet', 'serre', 'plastique']
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['mettre', 'depuis', 'surface', 'reseau', 'million', 'parc', 'site', 'special']
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['mettre', 'depuis', 'surface', 'reseau', 'million', 'parc', 'site', 'special']
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['mettre', 'depuis', 'surface', 'reseau', 'million', 'parc', 'site', 'special']
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'bear', 'separate', 'habkm', 'souvent', 'faible', 'urbain', 'principale']
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'bear', 'separate', 'habkm', 'souvent', 'faible', 'urbain', 'principale']
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'bear', 'separate', 'habkm', 'souvent', 'faible', 'urbain', 'principale']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'celui', 'entrer', 'faire', 'ligne', 'aerien', 'premiere', 'depuis', 'projet', 'permettre', 'francais', 'france', 'europeen', 'pari', '--', 'parisien', 'reseau', 'important', 'societe', 'million', 'regional', 'lyon', 'environ', 'marseill', 'lessentiel', 'route', 'sncf', 'grace', 'metro', 'toulous', 'aeroport', 'accueillir', 'maritime', 'port', 'velo', 'cycliste', 'eurovelo']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'celui', 'entrer', 'faire', 'ligne', 'aerien', 'premiere', 'depuis', 'projet', 'permettre', 'francais', 'france', 'europeen', 'pari', '--', 'parisien', 'reseau', 'important', 'societe', 'million', 'regional', 'lyon', 'environ', 'marseill', 'lessentiel', 'route', 'sncf', 'grace', 'metro', 'toulous', 'aeroport', 'accueillir', 'maritime', 'port', 'velo', 'cycliste', 'eurovelo']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'celui', 'entrer', 'faire', 'ligne', 'aerien', 'premiere', 'depuis', 'projet', 'permettre', 'francais', 'france', 'europeen', 'pari', '--', 'parisien', 'reseau', 'important', 'societe', 'million', 'regional', 'lyon', 'environ', 'marseill', 'lessentiel', 'route', 'sncf', 'grace', 'metro', 'toulous', 'aeroport', 'accueillir', 'maritime', 'port', 'velo', 'cycliste', 'eurovelo']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'celui', 'entrer', 'faire', 'ligne', 'aerien', 'premiere', 'depuis', 'projet', 'permettre', 'francais', 'france', 'europeen', 'pari', '--', 'parisien', 'reseau', 'important', 'societe', 'million', 'regional', 'lyon', 'environ', 'marseill', 'lessentiel', 'route', 'sncf', 'grace', 'metro', 'toulous', 'aeroport', 'accueillir', 'maritime', 'port', 'velo', 'cycliste', 'eurovelo']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'celui', 'entrer', 'faire', 'ligne', 'aerien', 'premiere', 'depuis', 'projet', 'permettre', 'francais', 'france', 'europeen', 'pari', '--', 'parisien', 'reseau', 'important', 'societe', 'million', 'regional', 'lyon', 'environ', 'marseill', 'lessentiel', 'route', 'sncf', 'grace', 'metro', 'toulous', 'aeroport', 'accueillir', 'maritime', 'port', 'velo', 'cycliste', 'eurovelo']
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'celui', 'entrer', 'faire', 'ligne', 'aerien', 'premiere', 'depuis', 'projet', 'permettre', 'francais', 'france', 'europeen', 'pari', '--', 'parisien', 'reseau', 'important', 'societe', 'million', 'regional', 'lyon', 'environ', 'marseill', 'lessentiel', 'route', 'sncf', 'grace', 'metro', 'toulous', 'aeroport', 'accueillir', 'maritime', 'port', 'velo', 'cycliste', 'eurovelo']
#
# Document : Histoire (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'siecle', 'france']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'nordest', 'premiere', 'break_water', 'siecle', 'gaule', 'romaine', 'doutremer', 'dont', 'humain', 'connaitre', 'moitie', 'paleolithique', 'iv', 'grec', 'romain', 'periode', 'jusquen', 'recevoir']
#
# Document : Naissance, crises et transformations du royaume de France au Moyen Âge (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'trois', 'crise', 'francais', 'siecle', 'france', 'occidental', 'egalement', 'peu', 'lempire', 'roi', 'charlemagn', 'comte']
#
# Document : Naissance, crises et transformations du royaume de France au Moyen Âge (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'trois', 'crise', 'francais', 'siecle', 'france', 'occidental', 'egalement', 'peu', 'lempire', 'roi', 'charlemagn', 'comte']
#
# Document : Naissance, crises et transformations du royaume de France au Moyen Âge (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'trois', 'crise', 'francais', 'siecle', 'france', 'occidental', 'egalement', 'peu', 'lempire', 'roi', 'charlemagn', 'comte']
#
# Document : Naissance, crises et transformations du royaume de France au Moyen Âge (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'trois', 'crise', 'francais', 'siecle', 'france', 'occidental', 'egalement', 'peu', 'lempire', 'roi', 'charlemagn', 'comte']
#
# Document : Naissance, crises et transformations du royaume de France au Moyen Âge (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plus', 'trois', 'crise', 'francais', 'siecle', 'france', 'occidental', 'egalement', 'peu', 'lempire', 'roi', 'charlemagn', 'comte']
#
# Document : De la Renaissance à la monarchie absolue (XVIe au XVIIIe siècle) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'entrer', 'faire', '<<', '>>', 'premiere', 'guerre', 'crise', 'france', 'confront', 'roi', 'reprendre', 'louis', 'religion', 'construire']
#
# Document : De la Renaissance à la monarchie absolue (XVIe au XVIIIe siècle) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'entrer', 'faire', '<<', '>>', 'premiere', 'guerre', 'crise', 'france', 'confront', 'roi', 'reprendre', 'louis', 'religion', 'construire']
#
# Document : De la Renaissance à la monarchie absolue (XVIe au XVIIIe siècle) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'entrer', 'faire', '<<', '>>', 'premiere', 'guerre', 'crise', 'france', 'confront', 'roi', 'reprendre', 'louis', 'religion', 'construire']
#
# Document : De la Renaissance à la monarchie absolue (XVIe au XVIIIe siècle) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'entrer', 'faire', '<<', '>>', 'premiere', 'guerre', 'crise', 'france', 'confront', 'roi', 'reprendre', 'louis', 'religion', 'construire']
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'plus', 'crise', 'republique', 'france', 'venir', 'tandis', 'e', '--', 'peu', 'national', 'politique', 'charle', 'defaite', 'aout', 'garde', 'convention', 'drapeau', 'x']
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'plus', 'crise', 'republique', 'france', 'venir', 'tandis', 'e', '--', 'peu', 'national', 'politique', 'charle', 'defaite', 'aout', 'garde', 'convention', 'drapeau', 'x']
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'plus', 'crise', 'republique', 'france', 'venir', 'tandis', 'e', '--', 'peu', 'national', 'politique', 'charle', 'defaite', 'aout', 'garde', 'convention', 'drapeau', 'x']
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'plus', 'crise', 'republique', 'france', 'venir', 'tandis', 'e', '--', 'peu', 'national', 'politique', 'charle', 'defaite', 'aout', 'garde', 'convention', 'drapeau', 'x']
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'plus', 'crise', 'republique', 'france', 'venir', 'tandis', 'e', '--', 'peu', 'national', 'politique', 'charle', 'defaite', 'aout', 'garde', 'convention', 'drapeau', 'x']
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'plus', 'crise', 'republique', 'france', 'venir', 'tandis', 'e', '--', 'peu', 'national', 'politique', 'charle', 'defaite', 'aout', 'garde', 'convention', 'drapeau', 'x']
#
# Document : La France dans les deux guerres mondiales (1914-1945) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'civil', 'crise', 'break_water', 'lors', 'francais', 'allemand', 'lallemagne', 'troisieme', 'moins', '--', 'economique', 'juin', 'annee', 'politique', 'tuer']
#
# Document : La France dans les deux guerres mondiales (1914-1945) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'civil', 'crise', 'break_water', 'lors', 'francais', 'allemand', 'lallemagne', 'troisieme', 'moins', '--', 'economique', 'juin', 'annee', 'politique', 'tuer']
#
# Document : La France dans les deux guerres mondiales (1914-1945) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'civil', 'crise', 'break_water', 'lors', 'francais', 'allemand', 'lallemagne', 'troisieme', 'moins', '--', 'economique', 'juin', 'annee', 'politique', 'tuer']
#
# Document : La Libération, gaullisme et crise politique (1945-1968) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'mai', 'plus', 'president', 'general', 'donner', 'crise', 'republique', 'france', 'large', 'national', 'spatial', 'periode', 'confront', 'lassemblee', 'entame', 'gaulle']
#
# Document : La Libération, gaullisme et crise politique (1945-1968) (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<PERSON>', 'mai', 'plus', 'president', 'general', 'donner', 'crise', 'republique', 'france', 'large', 'national', 'spatial', 'periode', 'confront', 'lassemblee', 'entame', 'gaulle']
#
# Document : Depuis Mai 68 (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', 'deux', 'entrer', 'non', 'plus', '<<', '>>', 'lelection', 'premiere', 'depuis', 'republique', 'francais', 'jeune', 'peu', 'loi', 'situation', 'lhistoire', 'politique', 've', 'periode', 'elu', 'an', 'socialiste', 'mitterrand', 'gouvernement', 'droite', 'monnaie', 'tour', 'candidat', 'primaire', 'sanitaire']
#
# Document : Depuis Mai 68 (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', 'deux', 'entrer', 'non', 'plus', '<<', '>>', 'lelection', 'premiere', 'depuis', 'republique', 'francais', 'jeune', 'peu', 'loi', 'situation', 'lhistoire', 'politique', 've', 'periode', 'elu', 'an', 'socialiste', 'mitterrand', 'gouvernement', 'droite', 'monnaie', 'tour', 'candidat', 'primaire', 'sanitaire']
#
# Document : Depuis Mai 68 (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', 'deux', 'entrer', 'non', 'plus', '<<', '>>', 'lelection', 'premiere', 'depuis', 'republique', 'francais', 'jeune', 'peu', 'loi', 'situation', 'lhistoire', 'politique', 've', 'periode', 'elu', 'an', 'socialiste', 'mitterrand', 'gouvernement', 'droite', 'monnaie', 'tour', 'candidat', 'primaire', 'sanitaire']
#
# Document : Depuis Mai 68 (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', 'deux', 'entrer', 'non', 'plus', '<<', '>>', 'lelection', 'premiere', 'depuis', 'republique', 'francais', 'jeune', 'peu', 'loi', 'situation', 'lhistoire', 'politique', 've', 'periode', 'elu', 'an', 'socialiste', 'mitterrand', 'gouvernement', 'droite', 'monnaie', 'tour', 'candidat', 'primaire', 'sanitaire']
#
# Document : Depuis Mai 68 (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', 'deux', 'entrer', 'non', 'plus', '<<', '>>', 'lelection', 'premiere', 'depuis', 'republique', 'francais', 'jeune', 'peu', 'loi', 'situation', 'lhistoire', 'politique', 've', 'periode', 'elu', 'an', 'socialiste', 'mitterrand', 'gouvernement', 'droite', 'monnaie', 'tour', 'candidat', 'primaire', 'sanitaire']
#
# Document : Politique et administration (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<<', '>>', 'republique', 'article', 'france']
#
# Document : Organisation des pouvoirs (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<<', 'haute', '>>', 'senat', 'premiere', 'definir', 'regime', 'france', 'forme', 'dont', 'juridiction', 'national', 'chef', 'droit', 'ordre', 'judiciaire', 'lassemblee', 'disposer', 'parlement', 'chambre']
#
# Document : Organisation des pouvoirs (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<<', 'haute', '>>', 'senat', 'premiere', 'definir', 'regime', 'france', 'forme', 'dont', 'juridiction', 'national', 'chef', 'droit', 'ordre', 'judiciaire', 'lassemblee', 'disposer', 'parlement', 'chambre']
#
# Document : Organisation des pouvoirs (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<<', 'haute', '>>', 'senat', 'premiere', 'definir', 'regime', 'france', 'forme', 'dont', 'juridiction', 'national', 'chef', 'droit', 'ordre', 'judiciaire', 'lassemblee', 'disposer', 'parlement', 'chambre']
#
# Document : Organisation des pouvoirs (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<<', 'haute', '>>', 'senat', 'premiere', 'definir', 'regime', 'france', 'forme', 'dont', 'juridiction', 'national', 'chef', 'droit', 'ordre', 'judiciaire', 'lassemblee', 'disposer', 'parlement', 'chambre']
#
# Document : Organisation des pouvoirs (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', '<<', 'haute', '>>', 'senat', 'premiere', 'definir', 'regime', 'france', 'forme', 'dont', 'juridiction', 'national', 'chef', 'droit', 'ordre', 'judiciaire', 'lassemblee', 'disposer', 'parlement', 'chambre']
#
# Document : Découpage territorial et décentralisation (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', '<PERSON>', 'dune', 'entrer', 'appeler', 'plus', 'representer', 'avoir', 'conseil', 'metropolitain', 'territoire', 'doutremer', 'statut', 'territorial', 'departement', 'communicate', 'tel', 'dont', 'separate', 'lui', 'letat', 'nombre', 'neanmoins', 'gouvernement', 'diriger', 'collectivite', 'competence', 'cooperation', 'decentralisation']
#
# Document : Découpage territorial et décentralisation (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['pouvoir', '<PERSON>', 'dune', 'entrer', 'appeler', 'plus', 'representer', 'avoir', 'conseil', 'metropolitain', 'territoire', 'doutremer', 'statut', 'territorial', 'departement', 'communicate', 'tel', 'dont', 'separate', 'lui', 'letat', 'nombre', 'neanmoins', 'gouvernement', 'diriger', 'collectivite', 'competence', 'cooperation', 'decentralisation']
#
# Document : France d'outre-mer (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['faire', 'partie', 'europeen', 'territoire', 'doutremer', 'wallisetfutuna', 'bien', 'region', 'tres', 'habitant', 'letat', 'collectivite']
#
# Document : France d'outre-mer (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['faire', 'partie', 'europeen', 'territoire', 'doutremer', 'wallisetfutuna', 'bien', 'region', 'tres', 'habitant', 'letat', 'collectivite']
#
# Document : France d'outre-mer (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['faire', 'partie', 'europeen', 'territoire', 'doutremer', 'wallisetfutuna', 'bien', 'region', 'tres', 'habitant', 'letat', 'collectivite']
#
# Document : France d'outre-mer (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['faire', 'partie', 'europeen', 'territoire', 'doutremer', 'wallisetfutuna', 'bien', 'region', 'tres', 'habitant', 'letat', 'collectivite']
#
# Document : France d'outre-mer (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['faire', 'partie', 'europeen', 'territoire', 'doutremer', 'wallisetfutuna', 'bien', 'region', 'tres', 'habitant', 'letat', 'collectivite']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'plusieurs', 'republicain', 'president', 'republique', 'france', 'europeen', 'martiniqu', '--', 'toutefois', 'actif', 'bretagne', 'liberation', 'politique', 'democratique', 'tendre', 'ministre', 'mouvement', 'gauche', 'populaire', 'socialiste', 'candidat', 'parti', 'laudience', 'communiste', 'presidence', 'ecologiste']
#
# Document : Finances publiques (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', 'plus', 'representer', 'novembre', 'france', 'atteindre', 'eleve', 'economique', 'limite', 'deficit', 'public', 'agence', 'add_together', 'attribuer', 'budgetaire', 'baisse', 'pib', 'critere', 'pacte', 'notation', 'observe', 'aa', 'lagence', 'perspective']
#
# Document : Finances publiques (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', 'plus', 'representer', 'novembre', 'france', 'atteindre', 'eleve', 'economique', 'limite', 'deficit', 'public', 'agence', 'add_together', 'attribuer', 'budgetaire', 'baisse', 'pib', 'critere', 'pacte', 'notation', 'observe', 'aa', 'lagence', 'perspective']
#
# Document : Finances publiques (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', 'plus', 'representer', 'novembre', 'france', 'atteindre', 'eleve', 'economique', 'limite', 'deficit', 'public', 'agence', 'add_together', 'attribuer', 'budgetaire', 'baisse', 'pib', 'critere', 'pacte', 'notation', 'observe', 'aa', 'lagence', 'perspective']
#
# Document : Finances publiques (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'pouvoir', 'plus', 'representer', 'novembre', 'france', 'atteindre', 'eleve', 'economique', 'limite', 'deficit', 'public', 'agence', 'add_together', 'attribuer', 'budgetaire', 'baisse', 'pib', 'critere', 'pacte', 'notation', 'observe', 'aa', 'lagence', 'perspective']
#
# Document : Défense (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'consacrer', 'homme', 'lun', 'milliard', 'national', 'cadre', 'militaire', 'cinq', 'nucleaire', 'membre', 'commandement', 'wedge']
#
# Document : Défense (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'consacrer', 'homme', 'lun', 'milliard', 'national', 'cadre', 'militaire', 'cinq', 'nucleaire', 'membre', 'commandement', 'wedge']
#
# Document : Défense (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'consacrer', 'homme', 'lun', 'milliard', 'national', 'cadre', 'militaire', 'cinq', 'nucleaire', 'membre', 'commandement', 'wedge']
#
# Document : Appartenance à des organisations internationales (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'plus', 'faire', 'francais', 'conseil', 'france', 'partie', 'europeen', 'leurope', 'lunion', '--', 'lorganisation', 'droit', 'international', 'gramme']
#
# Document : Appartenance à des organisations internationales (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'plus', 'faire', 'francais', 'conseil', 'france', 'partie', 'europeen', 'leurope', 'lunion', '--', 'lorganisation', 'droit', 'international', 'gramme']
#
# Document : Appartenance à des organisations internationales (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'plus', 'faire', 'francais', 'conseil', 'france', 'partie', 'europeen', 'leurope', 'lunion', '--', 'lorganisation', 'droit', 'international', 'gramme']
#
# Document : Politique étrangère et diplomatie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['francais', 'developpement', 'annee', 'politique', 'visavis']
#
# Document : Politique étrangère et diplomatie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['francais', 'developpement', 'annee', 'politique', 'visavis']
#
# Document : Politique étrangère et diplomatie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['francais', 'developpement', 'annee', 'politique', 'visavis']
#
# Document : Symboles républicains (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['representer', 'revolution', 'republique', 'francais', 'nouveau']
#
# Document : Symboles républicains (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['representer', 'revolution', 'republique', 'francais', 'nouveau']
#
# Document : Symboles républicains (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['representer', 'revolution', 'republique', 'francais', 'nouveau']
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<PERSON>', 'plus', 'bluster', 'avoir', 'hors', 'moins', 'age', 'million', 'demographique', 'population', 'naitre', 'compete', 'recensement', 'nurture', 'nail']
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<PERSON>', 'plus', 'bluster', 'avoir', 'hors', 'moins', 'age', 'million', 'demographique', 'population', 'naitre', 'compete', 'recensement', 'nurture', 'nail']
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<PERSON>', 'plus', 'bluster', 'avoir', 'hors', 'moins', 'age', 'million', 'demographique', 'population', 'naitre', 'compete', 'recensement', 'nurture', 'nail']
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<PERSON>', 'plus', 'bluster', 'avoir', 'hors', 'moins', 'age', 'million', 'demographique', 'population', 'naitre', 'compete', 'recensement', 'nurture', 'nail']
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<PERSON>', 'plus', 'bluster', 'avoir', 'hors', 'moins', 'age', 'million', 'demographique', 'population', 'naitre', 'compete', 'recensement', 'nurture', 'nail']
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<PERSON>', 'plus', 'bluster', 'avoir', 'hors', 'moins', 'age', 'million', 'demographique', 'population', 'naitre', 'compete', 'recensement', 'nurture', 'nail']
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'non', 'plus', 'nombreux', 'personne', 'bear', 'france', 'lallemagne', 'lespagne', 'hors', 'lunion', 'add_together', 'migratoire', 'population', 'royaumeuni', 'sexe', 'revenu', 'enfant', 'definition', 'dimmigrer', 'immigre', 'immigrer']
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'non', 'plus', 'nombreux', 'personne', 'bear', 'france', 'lallemagne', 'lespagne', 'hors', 'lunion', 'add_together', 'migratoire', 'population', 'royaumeuni', 'sexe', 'revenu', 'enfant', 'definition', 'dimmigrer', 'immigre', 'immigrer']
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'non', 'plus', 'nombreux', 'personne', 'bear', 'france', 'lallemagne', 'lespagne', 'hors', 'lunion', 'add_together', 'migratoire', 'population', 'royaumeuni', 'sexe', 'revenu', 'enfant', 'definition', 'dimmigrer', 'immigre', 'immigrer']
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'non', 'plus', 'nombreux', 'personne', 'bear', 'france', 'lallemagne', 'lespagne', 'hors', 'lunion', 'add_together', 'migratoire', 'population', 'royaumeuni', 'sexe', 'revenu', 'enfant', 'definition', 'dimmigrer', 'immigre', 'immigrer']
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'non', 'plus', 'nombreux', 'personne', 'bear', 'france', 'lallemagne', 'lespagne', 'hors', 'lunion', 'add_together', 'migratoire', 'population', 'royaumeuni', 'sexe', 'revenu', 'enfant', 'definition', 'dimmigrer', 'immigre', 'immigrer']
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'non', 'plus', 'nombreux', 'personne', 'bear', 'france', 'lallemagne', 'lespagne', 'hors', 'lunion', 'add_together', 'migratoire', 'population', 'royaumeuni', 'sexe', 'revenu', 'enfant', 'definition', 'dimmigrer', 'immigre', 'immigrer']
#
# Document : Famille, sexualité et égalité des sexes (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'entrer', 'representer', 'femme', 'personne', 'francais', 'homme', 'partie', 'egalement', 'ainsi', 'peu', 'moitie', 'lui', 'partir', 'dig', 'copulate', 'candidat', 'effectif', 'enfant', 'heure', 'mieux']
#
# Document : Famille, sexualité et égalité des sexes (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'entrer', 'representer', 'femme', 'personne', 'francais', 'homme', 'partie', 'egalement', 'ainsi', 'peu', 'moitie', 'lui', 'partir', 'dig', 'copulate', 'candidat', 'effectif', 'enfant', 'heure', 'mieux']
#
# Document : Famille, sexualité et égalité des sexes (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'entrer', 'representer', 'femme', 'personne', 'francais', 'homme', 'partie', 'egalement', 'ainsi', 'peu', 'moitie', 'lui', 'partir', 'dig', 'copulate', 'candidat', 'effectif', 'enfant', 'heure', 'mieux']
#
# Document : Famille, sexualité et égalité des sexes (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'entrer', 'representer', 'femme', 'personne', 'francais', 'homme', 'partie', 'egalement', 'ainsi', 'peu', 'moitie', 'lui', 'partir', 'dig', 'copulate', 'candidat', 'effectif', 'enfant', 'heure', 'mieux']
#
# Document : Langues (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'faire', 'sein', 'francais', 'langue', 'partie', 'dont', 'regional', 'public', 'parler', 'francophonie']
#
# Document : Langues (URL: https://fr.wikipedia.org/wiki/France)
# Tokens filtrés : ['<LOCATION>', 'faire', 'sein', 'francais', 'langue', 'partie', 'dont', 'regional', 'public', 'parler', 'francophonie']
#
# ...
# Tokens filtrés : ['chez', 'personne', 'district', 'leducation', 'tant', 'lapprentissage', 'mathematique', 'cerebral']
#
# Document : Inclusion scolaire (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'bluster', 'autre', 'contre', 'jeune', '-', 'politique', 'compete', 'experience', 'honour', 'scolaire', 'systeme', 'violence', 'enfant', 'ecole']
#
# Document : Inclusion scolaire (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'bluster', 'autre', 'contre', 'jeune', '-', 'politique', 'compete', 'experience', 'honour', 'scolaire', 'systeme', 'violence', 'enfant', 'ecole']
#
# Document : Inclusion scolaire (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'bluster', 'autre', 'contre', 'jeune', '-', 'politique', 'compete', 'experience', 'honour', 'scolaire', 'systeme', 'violence', 'enfant', 'ecole']
#
# Document : Inclusion scolaire (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'bluster', 'autre', 'contre', 'jeune', '-', 'politique', 'compete', 'experience', 'honour', 'scolaire', 'systeme', 'violence', 'enfant', 'ecole']
#
# Document : Droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lors', 'article', 'mondial', 'forme', 'droit', 'tout', 'leducation', 'convention', 'lelimination', 'international', 'discrimination', 'relatif']
#
# Document : Droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lors', 'article', 'mondial', 'forme', 'droit', 'tout', 'leducation', 'convention', 'lelimination', 'international', 'discrimination', 'relatif']
#
# Document : Droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lors', 'article', 'mondial', 'forme', 'droit', 'tout', 'leducation', 'convention', 'lelimination', 'international', 'discrimination', 'relatif']
#
# Document : Droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lors', 'article', 'mondial', 'forme', 'droit', 'tout', 'leducation', 'convention', 'lelimination', 'international', 'discrimination', 'relatif']
#
# Document : Les objectifs de l'Éducation pour Tous (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'ameliorer', 'bluster', 'qualite', 'objectif', 'sou', 'notamment', 'free-base', 'assurer', 'compete', 'programme', 'primaire', 'competence', 'enfant', 'aspect', 'enseignement', 'adulte', 'fille', 'courant', 'acces', 'ici', 'education']
#
# Document : Les objectifs de l'Éducation pour Tous (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'ameliorer', 'bluster', 'qualite', 'objectif', 'sou', 'notamment', 'free-base', 'assurer', 'compete', 'programme', 'primaire', 'competence', 'enfant', 'aspect', 'enseignement', 'adulte', 'fille', 'courant', 'acces', 'ici', 'education']
#
# Document : Les objectifs de l'Éducation pour Tous (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'ameliorer', 'bluster', 'qualite', 'objectif', 'sou', 'notamment', 'free-base', 'assurer', 'compete', 'programme', 'primaire', 'competence', 'enfant', 'aspect', 'enseignement', 'adulte', 'fille', 'courant', 'acces', 'ici', 'education']
#
# Document : Interprétation du droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'bluster', 'age', 'droit', 'liberte', 'enfant', 'discrimination', 'enseignement', 'acces', 'education', 'enseignemer']
#
# Document : Interprétation du droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', '<PERSON>', 'bluster', 'age', 'droit', 'liberte', 'enfant', 'discrimination', 'enseignement', 'acces', 'education', 'enseignemer']
#
# Document : Un droit reconnu au niveau international (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['entrer', 'bluster', 'bear', 'valeur', 'national', 'honour', 'lenfer']
#
# Document : Un droit reconnu au niveau international (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['entrer', 'bluster', 'bear', 'valeur', 'national', 'honour', 'lenfer']
#
# Document : Investir dans l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<PERSON>', 'avoir', 'leducation', 'educatif', 'put_on', 'theorie']
#
# Document : Investir dans l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<PERSON>', 'avoir', 'leducation', 'educatif', 'put_on', 'theorie']
#
# Document : Investir dans l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<PERSON>', 'avoir', 'leducation', 'educatif', 'put_on', 'theorie']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lexistence', 'rag', 'separate', 'public', 'capital', 'acceder', 'marche', 'facteur']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lexistence', 'rag', 'separate', 'public', 'capital', 'acceder', 'marche', 'facteur']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lexistence', 'rag', 'separate', 'public', 'capital', 'acceder', 'marche', 'facteur']
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lexistence', 'rag', 'separate', 'public', 'capital', 'acceder', 'marche', 'facteur']
#
# Document : Canada (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['montant']
#
# Document : France (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : []
#
# Document : Sources (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : []
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['pari', 'of', 'histoire', 'technique', 'jeanclaude', 'the', 'thomas', 'oclc', 'dir', 'puf']
#
# Document : Notes et références (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'query', '<PERSON>', 'ligne', '<<', '>>', 'avoir', 'lire', 'er', 'train', 'francais', 'pari', 'monde', 'e', 'rapport', 'public', 'special', '-', 'droit', 'leducation', 'social', 'aout', 'septembre', 'juillet', 'scolaire', 'international', 'violence', 'enfant', 'definition', 'ecole', 'lenseignemer', 'bureau', 'report', 'of', 'the', '|', 'p', 'edition', 'isbn', 'doi', 'consulter', 'and', 'pdf', 'unesco', 'no', 'in', 'numero', 'revue', 'science', 'to', 'issn', 'education', 'by', 'quebec', 'university', 'pedagogie', 'blossom', 'rapporteur', 'mixite']
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['bluster', '<<', '>>', 'economique']
#
# Document : Voir aussi (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['bluster', '<<', '>>', 'economique']
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['pari', 'of', 'histoire', 'technique', 'jeanclaude', 'the', 'thomas', 'oclc', 'dir', 'puf']
#
# Document : Bibliographie (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['pari', 'of', 'histoire', 'technique', 'jeanclaude', 'the', 'thomas', 'oclc', 'dir', 'puf']
#
# Document : Articles connexes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['<LOCATION>', 'france', 'developpement', 'leducation', 'ecole', 'enseignement', 'technique', 'education', 'technologie', 'progres']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']
#
# Document : Liens externes (URL: https://fr.wikipedia.org/wiki/Éducation)
# Tokens filtrés : ['lencyclopedie', 'portail', 'local', 'etude', 'er', 'premiere', 'bear', 'contre', 'conseil', 'defense', 'free-base', 'gaule', 'homme', 'langue', 'terme', 'officiel', 'loire', 'constitutif', 'hanker', 'ou', 'regional', 'ressource', 'site', 'voiture', 'metro', 'maritime', 'compete', 'agriculture', 'groupe', 'carolingien', 'leducation', 'domaine', 'anglais', 'louis', 'indiquer', 'x', 'janvier', 'participation', 'britannique', 'operation', 'otan', 'charte', 'congo', 'enseignement', 'educatif', 'relatif', 'tourisme', 'culturel', 'vehicule', 'of', 'the', 'souverainete', 'institut', 'dependance', 'penal', 'norvegien', 'bigelow', 'robotique', 'history', 'genie', 'psychologie', 'interculturel']

# %% [markdown]
# **{
#     "titre_document": {
#         "url": "url_du_document",
#         "positions": {
#             "mot1": [position1, position2, ...],
#             "mot2": [position1, position2, ...],
#             ...
#         }
#     },
#     "titre_document_suivant": {
#         "url": "url_du_document_suivant",
#         "positions": {
#             "mot3": [position1, position2, ...],
#             "mot4": [position1, position2, ...],
#             ...
#         }
#     },
#     ...
# }**

# %%
# fonction pour créer un dictionnaire de mots avec leurs positions dans le document
def creer_dictionnaire_positions(processed_documents):
    dictionnaire_positions = {}

    # parcourir chaque document traité
    for doc in processed_documents:
        title = doc['title']
        tokens = doc['tokens']

        # dictionnaire pour stocker les positions des mots pour le document courant
        positions_par_mot = {}

        # parcourir chaque token avec son index dans le document
        for index, token in enumerate(tokens):
            if token not in positions_par_mot:
                positions_par_mot[token] = []
            # Ajouter la position du mot dans la liste des positions
            positions_par_mot[token].append(index)

        # ajouter le dictionnaire de positions du document dans le dictionnaire principal
        dictionnaire_positions[title] = {
            'url': doc['url'],
            'positions': positions_par_mot
        }

    return dictionnaire_positions

# Créer le dictionnaire des positions à partir des documents prétraités
dictionnaire_positions = creer_dictionnaire_positions(processed_documents)

# afficher le dictionnaire des positions
print("Dictionnaire des positions des mots :")
for title, data in dictionnaire_positions.items():
    print(f"\nDocument : {title} (URL: {data['url']})")
    print("Positions des mots :")
    for token, positions in data['positions'].items():
        print(f"   {token}: {positions}")
# Out:
# Dictionnaire des positions des mots :
#
# Document : Wikipédia (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    accueil: [0]
#    democratie: [1]
#    yak: [2]
#    contribuer: [3]
#    veine_porte: [4]
#    thematique: [5]
#    regle: [6]
#    fondateur: [7]
#    resume: [8]
#    laide: [9]
#    place: [10]
#    proposition: [11]
#
# Document : Article labellisé du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    contenir: [0, 3]
#    specificite: [1]
#    humour: [2]
#    survie: [4]
#    programm: [5]
#
# Document : Actualités (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    novembre: [0]
#    wikinews: [1]
#    modifier: [2]
#
# Document : Le saviez-vous ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    archives: [0]
#    propos: [1]
#    programm: [2]
#    modifier: [3]
#
# Document : Présentation (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    redacteur: [0]
#    regle: [1]
#    wikipedia: [2]
#    benevole: [3]
#    coordination: [4]
#    lutte: [5]
#    lolo: [6]
#    dun: [7]
#    democratie: [8]
#    collaboratif: [9]
#    sans: [10]
#    leader: [11]
#
# Document : Comment contribuer ? (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    supplement: [0]
#    propos: [1]
#    servir: [2]
#    centraliser: [3]
#    remarque: [4, 5]
#    permission: [6]
#    ameliorer: [7]
#    regle: [8]
#
# Document : Éphéméride du 9 novembre (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#    ephemerid: [0]
#    detailler: [1]
#    novembre: [2]
#    archive: [3]
#    modifier: [4]
#
# Document : Image labellisée du jour (URL: https://fr.wikipedia.org/wiki/Wikipédia:Accueil_principal)
# Positions des mots :
#
# Document : Toponymie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    premiere_vitesse: [1]
#    occurence: [2]
#    propos: [3]
#    <<: [4]
#    france: [5]
#    >>: [6]
#    langue_ethnique: [7]
#    Daniel_Chester_French: [8]
#    face: [9]
#    xie: [10]
#    cent: [11]
#    notamment: [12]
#    song: [13]
#    roland: [14]
#    vers: [15]
#    construction: [16]
#    Latin: [17]
#    francia: [18]
#    deja: [19]
#    besoin: [20]
#    projet: [21]
#    anterieur: [22]
#    acception: [23]
#    etoile_variable: [24]
#
# Document : Localisation, frontières et superficie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1]
#    Francois-Anatole_Thibault: [2]
#    e: [3]
#    obtention: [4, 13, 25]
#    grand: [5, 14, 26]
#    responsabilite: [6]
#    cosmos: [7]
#    surface: [8]
#    terrestre: [9]
#    cest: [10]
#    aussi: [11]
#    tierce: [12]
#    paysage: [15]
#    deurop: [16]
#    apres: [17]
#    Union_des_Republiques_Socialistes_Sovietiques: [18]
#    lukraine: [19]
#    deuxieme: [20]
#    si: [21]
#    inclure: [22]
#    domaine: [23]
#    ultramarin: [24]
#    lunion: [27]
#    Europeenne: [28]
#
# Document : Géologie, topographie et hydrographie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    Francois-Anatole_Thibault: [1]
#    dispose: [2]
#    1000000: [3]
#    kilometre: [4]
#    carre: [5]
#    deal: [6]
#    bleu_marine: [7]
#    sou: [8]
#    cour: [9]
#    trois: [10]
#    Ocean: [11]
#    outremer: [12]
#    constituer: [13]
#    deuxieme: [14]
#    obtention: [15]
#    vaste: [16]
#    espace: [17]
#    economie: [18]
#    exclusif: [19]
#    cosmos: [20]
#
# Document : Climat (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1]
#    fievre: [2, 22]
#    de_l'arithmetique: [3, 8]
#    Francois-Anatole_Thibault: [4]
#    sest: [5]
#    eleve: [6]
#    grade_universitaire: [7, 17]
#    dizaine: [9]
#    course: [10]
#    xxe: [11]
#    siecleb: [12]
#    juin: [13]
#    verargue: [14]
#    thermometre: [15]
#    atteint: [16]
#    etablir: [18]
#    original: [19]
#    record: [20]
#    absolu: [21]
#    france: [23]
#    metropolitain: [24]
#    depuis: [25]
#    releve: [26]
#    exister: [27]
#
# Document : Paysages et environnement (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    voie: [1]
#    denquet: [2]
#    representation: [3]
#    indique: [4]
#    contamination: [5]
#    lair: [6]
#    representer: [7]
#    prix: [8]
#    annuel: [9]
#    bill: [10]
#    deuro: [11]
#    Francois-Anatole_Thibault: [12]
#
# Document : Préservation de l'environnement (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    surface: [0, 4, 9]
#    quantite: [1]
#    kilometre: [2]
#    representer: [3]
#    terrestre: [5]
#    metropolitain: [6]
#    1000000: [7, 14]
#    dhectare: [8, 15]
#    bleu_marine: [10]
#    espace: [11]
#    economie: [12]
#    exclusif: [13]
#
# Document : Répartition spatiale des hommes et des activités (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    apres: [0]
#    long: [1]
#    Exode: [2]
#    rural: [3]
#    xixe: [4]
#    cent: [5]
#    jusqu: [6]
#    deuxieme: [7]
#    demi: [8]
#    xxe: [9]
#    sieclen: [10]
#    solde: [11]
#    migratoire: [12]
#    paysage: [13]
#    Daniel_Chester_French: [14]
#    redevenir: [15]
#    positif: [16]
#    annee: [17]
#    lessentiel: [18]
#    pousser: [19]
#    urbain: [20, 44]
#    faire: [21]
#    espace: [22, 37]
#    periurbain: [23]
#    obtention: [24, 25]
#    eloigner: [26]
#    lagglomerationcentren: [27]
#    bbs: [28]
#    cidessou: [29]
#    presente: [30]
#    classer: [31]
#    office: [32]
#    population: [33]
#    inclinaison: [34]
#    vingt: [35, 41, 46]
#    principale: [36, 42, 47]
#    dattraction: [38]
#    New_York: [39]
#    cell: [40]
#    unite: [43]
#    celui: [45]
#    salamandre_tachetee: [48]
#
# Document : Axes de communication et de transports (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1]
#    depuis: [2, 72]
#    reseau_informatique: [3, 63]
#    urbain: [4]
#    avenue: [5, 26, 79]
#    cyclable: [6, 21, 27, 87]
#    developper: [7]
#    ainsi: [8]
#    motocyclette: [9, 41, 51]
#    libreservice: [10]
#    plusieurs: [11]
#    New_York: [12]
#    paysi: [13]
#    specificite: [14]
#    amenagement: [15]
#    tres: [16]
#    inegal: [17]
#    selon: [18]
#    district: [19]
#    linfrastructure: [20]
#    faire: [22, 90]
#    pres: [23]
#    kilometre: [24]
#    dont: [25]
#    comptabiliser: [28]
#    velo: [29]
#    veloroute: [30, 60]
#    grande_route: [31, 52]
#    grand: [32]
#    longueur: [33]
#    demi: [34]
#    foyer: [35]
#    posseder: [36]
#    bicyclette: [37]
#    environ: [38, 44]
#    Daniel_Chester_French: [39, 61]
#    grace: [40]
#    voie: [42]
#    domiciletravail: [43]
#    population: [45]
#    ce: [46]
#    lampadaire: [47]
#    symetrie: [48]
#    sexpliqu: [49]
#    vulnerabilite: [50]
#    cycliste: [53, 70]
#    perdre: [54]
#    faune: [55]
#    erratum: [56]
#    dinfrastructure: [57]
#    suffisant: [58]
#    jeu: [59]
#    sintegr: [62]
#    Europeenne: [64, 71, 77]
#    nommer: [65]
#    eurovelo: [66, 80]
#    propos: [67, 74]
#    lancer: [68]
#    federation: [69]
#    integre: [73]
#    rtet: [75]
#    lunion: [76]
#    Francois-Anatole_Thibault: [78, 84]
#    cadeau: [81]
#    permission: [82, 89]
#    connecter: [83]
#    leurope: [85]
#    facon: [86]
#    celer: [88]
#    dell: [91]
#    deuxieme: [92]
#    destination: [93]
#    mondial: [94]
#    cyclotourisme: [95]
#
# Document : Histoire (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 3]
#    <PERSON>: [1, 2]
#    Francois-Anatole_Thibault: [4, 31]
#    metropolitain: [5]
#    flux: [6]
#    occuper: [7]
#    obtention: [8]
#    grand: [9]
#    jeu: [10]
#    lancienne: [11]
#    gaul: [12]
#    celte: [13]
#    conquerir: [14]
#    jules: [15]
#    Atom_Heart_Mother: [16]
#    ier: [17]
#    cent: [18, 30]
#    av: [19]
#    jc: [20]
#    tire: [21]
#    souci: [22]
#    frank: [23]
#    phratrie: [24]
#    germanique: [25]
#    sy: [26]
#    installer: [27]
#    conge: [28]
#    ve: [29]
#    responsabilite: [32]
#    dont: [33]
#    lunification: [34]
#    destrier: [35]
#    lun: [36]
#    premiere_vitesse: [37]
#    paysage: [38]
#    lepoque: [39]
#    moderne: [40]
#    tenter: [41]
#    experimentation: [42]
#    democratique: [43]
#
# Document : Préhistoire, protohistoire et Antiquité (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3]
#    <PERSON>: [4]
#    concerner: [5]
#    Francois-Anatole_Thibault: [6]
#    doutremer: [7, 45]
#    pendant: [8]
#    quoique: [9]
#    guyane: [10]
#    occuper: [11]
#    phratrie: [12]
#    vivre: [13]
#    chasseur: [14]
#    chasseur-cueilleur: [15]
#    saintpierreetmiquelon: [16]
#    recevoir: [17, 31]
#    visiter: [18]
#    paleoesquimau: [19]
#    antille: [20]
#    Daniel_Chester_French: [21]
#    animer: [22]
#    age: [23, 50]
#    precolombien: [24]
#    Guadeloupe: [25]
#    Lot: [26]
#    amerindienne: [27]
#    preceramique: [28]
#    nouvellecaledonie: [29]
#    wallisetfutuna: [30]
#    premiere_vitesse: [32, 35, 39]
#    habitant: [33]
#    vers: [34]
#    civilisation: [36]
#    lapita: [37]
#    developper: [38]
#    millenaire: [40]
#    av: [41]
#    jc: [42]
#    autre: [43]
#    district: [44]
#    sembler: [46]
#    inoccuper: [47]
#    durer: [48]
#    ce: [49]
#
# Document : Naissance, crises et transformations du royaume de France au Moyen Âge (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 2, 3, 4]
#    <PERSON>: [1]
#    xive: [5, 36]
#    cent: [6, 10, 20, 38]
#    premiere_vitesse: [7]
#    demi: [8]
#    xv: [9]
#    voir: [11]
#    Francois-Anatole_Thibault: [12, 31]
#    plonger: [13]
#    coup_de_colere: [14, 35, 66]
#    graf: [15]
#    dont: [16]
#    propos: [17]
#    multiplese: [18]
#    guerre: [19]
#    dans: [21]
#    mener: [22]
#    contre: [23]
#    langleterre: [24]
#    naitre: [25]
#    dun: [26]
#    specificite: [27]
#    sequence: [28]
#    esprit: [29]
#    royaume: [30]
#    ravager: [32]
#    payse: [33]
#    toutefois: [34]
#    xve: [37]
#    nest: [39]
#    seulement: [40]
#    gouvernement: [41]
#    guerrier: [42]
#    aussi: [43]
#    demographique: [44]
#    conge: [45]
#    pest: [46]
#    noir: [47]
#    taire: [48]
#    moins: [49]
#    tierce: [50]
#    population: [51]
#    royaumen: [52]
#    social: [53]
#    revolte: [54]
#    producteur: [55]
#    urbaine: [56]
#    multiplier: [57]
#    egalement: [58, 63]
#    economie: [59]
#    religieusee: [60]
#    si: [61]
#    monarchie: [62]
#    emotion: [64]
#    ce: [65]
#    froid: [67]
#    renforcer: [68]
#    supergrand: [69]
#    echange: [70]
#    sest: [71]
#    deplacer: [72]
#    val: [73]
#    Loire: [74]
#    doter: [75]
#    original: [76]
#    hopital_psychiatrique: [77]
#    rassembler: [78]
#    centre_d'achats: [79]
#    p: [80]
#    impot: [81]
#    permanent: [82]
#    amorcer: [83]
#    salut: [84]
#    facon: [85]
#    age: [86]
#    renaissancee: [87]
#
# Document : De la Renaissance à la monarchie absolue (XVIe au XVIIIe siècle) (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0, 1, 7]
#    <LOCATION>: [2, 3, 4, 5, 6]
#    louis: [8, 12]
#    xv: [9]
#    arrierepetitfil: [10]
#    heritiere: [11]
#    xiv: [13]
#    mener: [14]
#    aussi: [15]
#    plusieurs: [16]
#    guerre: [17, 24]
#    lucre: [18]
#    contrastese: [19]
#    contrat: [20]
#    pari: [21]
#    rassembler: [22]
#    propos: [23]
#    sept: [25]
#    dans: [26]
#    Francois-Anatole_Thibault: [27, 38]
#    abandonn: [28]
#    propriete: [29]
#    Etats-Unis: [30]
#    nord: [31]
#    acquerir: [32]
#    dizaine: [33]
#    lorrain: [34]
#    corsee: [35]
#    pendant: [36]
#    quoique: [37]
#    connaitre: [39]
#    fort: [40]
#    animation: [41]
#    demographique: [42]
#    economie: [43]
#    pousser: [44]
#    fabrication: [45]
#    agricole: [46]
#    saccompagne: [47]
#    dun: [48, 54]
#    protoindustrialisation: [49]
#    notamment: [50]
#    secteur: [51]
#    textile: [52]
#    ainsi: [53]
#    essor: [55]
#    domaine: [56]
#    intellectuel: [57]
#    culturele: [58]
#    toutefois: [59]
#    Pyrenees: [60]
#    xvi: [61]
#    acceder: [62]
#    gouvernement: [63]
#    reveler: [64]
#    incapable: [65]
#    trouver: [66]
#    racine: [67]
#    surendettement: [68]
#    monarchie: [69]
#    responsabilite: [70, 72]
#    convoquer: [71]
#    ensemble: [73]
#    e: [74]
#
# Document : Révolutions, républiques, monarchies et empires (1789-1914) (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3, 4]
#    malgre: [5]
#    emergence: [6]
#    chaotique: [7]
#    tierce: [8]
#    republique: [9, 87]
#    obtention: [10, 94, 95]
#    long: [11]
#    gouvernement: [12, 13, 25, 73]
#    qua: [14]
#    connaitre: [15]
#    Francois-Anatole_Thibault: [16, 43]
#    depuis: [17]
#    e: [18, 41, 54]
#    republicain: [19]
#    rassembler: [20]
#    numero: [21, 22]
#    centre_d'achats: [23]
#    propos: [24]
#    lecole: [26]
#    rendre: [27]
#    gratuit: [28]
#    laique: [29]
#    obligatoire: [30]
#    espace: [31]
#    imprimerie: [32]
#    session: [33]
#    accorder: [34]
#    divorcer: [35]
#    syndicat_du_crime: [36]
#    autoriser: [37]
#    temple: [38]
#    separer: [39]
#    letat: [40]
#    un_point_c'est_tout: [42]
#    doter: [44]
#    dun: [45]
#    vaste: [46]
#    empire: [47]
#    colonial: [48]
#    deuxieme: [49]
#    cosmos: [50]
#    apres: [51]
#    celui: [52]
#    royaumeuni: [53]
#    propriete: [55]
#    Inde: [56]
#    lalgerie: [57]
#    venir: [58, 88]
#    sajouter: [59]
#    ruban: [60]
#    annee: [61]
#    lindochine: [62]
#    protectorat: [63]
#    Tunisie: [64]
#    maroc: [65]
#    lafriqu: [66]
#    equatorial: [67]
#    occidental: [68]
#    madagascar: [69]
#    si: [70]
#    plusieurs: [71]
#    coup_de_colere: [72, 76]
#    succeder: [74]
#    --: [75, 84]
#    boulangiste: [77]
#    outrage: [78, 80]
#    parure: [79]
#    panama: [81]
#    cas: [82]
#    dreyfu: [83]
#    esprit: [85]
#    clef: [86]
#    desormais: [89]
#    lexterieur: [90]
#    ou: [91]
#    guerre: [92]
#    apparaitre: [93]
#    imminentee: [96]
#
# Document : La France dans les deux guerres mondiales (1914-1945) (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 3]
#    <PERSON>: [1, 2, 4]
#    apres: [5]
#    huit: [6]
#    lunaison: [7]
#    sans: [8]
#    lutte: [9, 65]
#    <<: [10]
#    Urd_;_Wyrd: [11]
#    guerre: [12]
#    >>: [13]
#    wehrmacht: [14]
#    envahir: [15]
#    may: [16]
#    nordest: [17]
#    Francois-Anatole_Thibault: [18]
#    marechal: [19]
#    philipp: [20]
#    petain: [21]
#    creance: [22]
#    larmistice: [23]
#    juin: [24, 55]
#    lever: [25]
#    obtenir: [26]
#    plein: [27]
#    supergrand: [28]
#    juillet: [29]
#    signant: [30]
#    ainsi: [31]
#    propos: [32, 58]
#    tierce: [33, 45]
#    republique: [34]
#    emergence: [35]
#    gouvernement: [36, 40, 89]
#    Vichy: [37]
#    celuici: [38]
#    mener: [39]
#    conservateur: [41]
#    traditionaliste: [42]
#    antisemite: [43]
#    collabore: [44]
#    de: [46]
#    toutefois: [47]
#    resistance: [48]
#    sorganis: [49]
#    linterieur: [50]
#    lexterieur: [51]
#    payse: [52]
#    debarquement: [53]
#    allier: [54]
#    Normandie: [56]
#    sonn: [57]
#    loccupation: [59]
#    nazi: [60]
#    declenchement: [61]
#    dissemination: [62]
#    leuropee: [63]
#    quantite: [64]
#    mort: [66, 83]
#    moins: [67, 75]
#    guerrier: [68]
#    Daniel_Chester_French: [69, 82]
#    precedentn: [70]
#    victime: [71, 76]
#    civil: [72, 77]
#    nombreux: [73]
#    --: [74, 86]
#    dont: [78]
#    Juive: [79]
#    installer: [80]
#    district: [81]
#    lors: [84, 96]
#    Shoah: [85]
#    mal: [87]
#    psychologique: [88]
#    responsabilite: [90]
#    fiasco: [91]
#    cooperation: [92]
#    pouvoir: [93]
#    opinion: [94]
#    directoire: [95]
#    lepuration: [97]
#    long: [98]
#    cicatrisere: [99]
#
# Document : La Libération, gaullisme et crise politique (1945-1968) (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0, 1, 2, 4, 7, 8]
#    <LOCATION>: [3, 5, 6]
#    ER: [9]
#    juin: [10]
#    lors: [11]
#    dun: [12, 58]
#    graf: [13]
#    coup_de_colere: [14, 67]
#    gouvernement: [15]
#    lier: [16]
#    guerre: [17]
#    dalgeri: [18]
#    ensemble: [19, 85]
#    gaulle: [20, 41, 86]
#    investir: [21]
#    gouverneur: [22, 34, 118]
#    defenseur: [23]
#    lassemblee: [24, 92]
#    national: [25, 93]
#    fonction: [26]
#    printemps: [27, 98]
#    republique: [28, 32, 119]
#    original: [29]
#    loi_organique: [30]
#    cinquieme: [31]
#    donne: [33]
#    supergrand: [35, 79, 112]
#    plus: [36]
#    general: [37, 99]
#    lutte: [38, 49, 78]
#    son: [39]
#    charle: [40]
#    poursuit: [42]
#    achever: [43]
#    decolonisation: [44]
#    lafrique: [45]
#    affirmer: [46]
#    lindependance: [47]
#    Francois-Anatole_Thibault: [48, 54, 62]
#    etatsunis: [50]
#    ce: [51]
#    propos: [52]
#    doter: [53]
#    nucleaire: [55]
#    civil: [56]
#    guerrier: [57]
#    calendrier: [59]
#    spatial: [60, 65]
#    faire: [61]
#    tierce: [63]
#    domaine: [64]
#    lhistoire: [66]
#    eleve: [68]
#    social: [69]
#    may: [70, 94]
#    reveler: [71]
#    fissure: [72]
#    entrer: [73]
#    inspiration: [74]
#    petit: [75]
#    notamment: [76]
#    estudiantin: [77]
#    depeindre: [80]
#    comme: [81]
#    assez: [82]
#    conservateur: [83]
#    cependant: [84]
#    reprendre: [87]
#    patte: [88]
#    etat: [89]
#    provoquer: [90]
#    dissolution: [91]
#    apres: [95]
#    lequel: [96]
#    Daniel_Chester_French: [97]
#    plupart: [100]
#    presidentiel: [101]
#    demissionner: [102]
#    sequence: [103]
#    lechec: [104]
#    referendum: [105]
#    reformateur: [106]
#    Senat: [107]
#    regionalisation: [108]
#    toutefois: [109]
#    gaullisme: [110]
#    conserver: [111]
#    cinq: [113]
#    dans: [114]
#    obtention: [115]
#    sou: [116]
#    forme: [117]
#    georges: [120]
#    pompidoue: [121]
#
# Document : Depuis Mai 68 (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0]
#    pandemie: [1]
#    covid: [2]
#    provoquer: [3]
#    coup_de_colere: [4]
#    hygiene: [5, 16]
#    medius: [6]
#    important: [7]
#    bassin: [8]
#    economie: [9]
#    gouverneur: [10]
#    emmanuel: [11]
#    macron_-: [12]
#    decret: [13]
#    letat: [14]
#    durgence: [15]
#    imposer: [17]
#    notamment: [18]
#    endiguement: [19]
#    generaliser: [20]
#    population: [21]
#    faire: [22]
#    adopter: [23]
#    bill: [24]
#    budgetaire: [25]
#    massive: [26]
#    soutenir: [27]
#    leconomie: [28]
#
# Document : Politique et administration (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2]
#    Francois-Anatole_Thibault: [3, 26]
#    democratisation: [4]
#    liberal: [5]
#    dont: [6]
#    opinion: [7]
#    conservation: [8]
#    forme: [9]
#    dune_de_sable: [10]
#    republique: [11, 21, 27]
#    pierre_angulaire: [12]
#    lorganisation: [13]
#    gouvernement: [14]
#    administratif: [15]
#    flux: [16]
#    france: [17]
#    fixer: [18]
#    loi_organique: [19]
#    cinquieme: [20]
#    selon: [22]
#    regle: [23, 34]
#    premiere_vitesse: [24]
#    <<: [25, 37]
#    indivisible: [28]
#    laique: [29]
#    democratique: [30]
#    social: [31]
#    >>: [32, 40]
#    depuis: [33]
#    affirmer: [35]
#    outre: [36]
#    gerance: [38]
#    decentraliser: [39]
#
# Document : Organisation des pouvoirs (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    conformite: [0]
#    bill: [1]
#    loi_organique: [2]
#    exactitude: [3]
#    voter: [4]
#    obtention: [5]
#    largement: [6]
#    respecter: [7]
#    hopital_psychiatrique: [8]
#    controler: [9]
#    defenseur: [10]
#    constitutionnelk: [11]
#
# Document : Découpage territorial et décentralisation (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    <PERSON>: [1, 2]
#    comparaison: [3]
#    voisin: [4]
#    Europeenne: [5]
#    Francois-Anatole_Thibault: [6]
#    avoir: [7, 22, 32]
#    duree: [8]
#    marque: [9]
#    fort: [10]
#    centralisation: [11]
#    gouvernement: [12]
#    collectivite: [13, 45, 67]
#    territorial: [14, 46, 68]
#    disposer: [15]
#    supergrand: [16]
#    relativement: [17]
#    faiblesk: [18]
#    neanmoins: [19, 57]
#    ce: [20]
#    etat: [21]
#    beaucoup: [23]
#    evoluer: [24]
#    depuis: [25]
#    declenchement: [26]
#    annee: [27]
#    dabord: [28]
#    bill: [29]
#    defferre: [30]
#    lancer: [31, 83]
#    posteriori: [33]
#    lacte: [34, 84]
#    robot: [35]
#    devolution: [36, 72, 86]
#    pouvoir: [37]
#    entrer: [38, 64, 78]
#    sou: [39]
#    opinion: [40, 74, 79]
#    raffarin: [41]
#    numero: [42]
#    ii: [43]
#    savoir-faire: [44, 65]
#    nombreux: [47]
#    concerner: [48]
#    notamment: [49]
#    gerance: [50]
#    scolaire: [51]
#    transporteur: [52]
#    pousser: [53]
#    economie: [54]
#    laction: [55]
#    social: [56]
#    superposition: [58]
#    multiple: [59]
#    marche: [60]
#    borne: [61]
#    souvent: [62]
#    grisonner: [63]
#    different: [66]
#    informateur: [69]
#    argument: [70]
#    lavenir: [71]
#    lequel: [73]
#    fillon: [75]
#    sest: [76]
#    pencher: [77]
#    vall: [80]
#    poursuivre: [81]
#    procede: [82]
#    iii: [85]
#    proposer: [87]
#    original: [88]
#    decoupage: [89]
#    domaine: [90]
#    fonctionnaire: [91]
#    conge: [92]
#    er: [93]
#    jan: [94]
#    election: [95]
#    regional: [96]
#    decembre: [97]
#
# Document : France d'outre-mer (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    <PERSON>: [1]
#    clipperton: [2]
#    nouvellecaledonie: [3]
#    Tahiti: [4]
#    polynesi: [5]
#    Daniel_Chester_French: [6]
#    saintbarthelemy: [7]
#    saintmartin: [8]
#    saintpierreetmiquelon: [9]
#    futuna: [10]
#    alofi: [11]
#    wallisetfutuna: [12, 14]
#    wallis: [13]
#
# Document : Tendances politiques, partis et élections (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3]
#    <PERSON>: [4]
#    mouvement: [5, 61]
#    independantiste: [6, 51, 62, 66, 73, 101, 111]
#    nationaliste: [7, 48, 99]
#    peripherique_informatique: [8]
#    regionaliste: [9, 36, 42, 67]
#    exister: [10]
#    plusieurs: [11, 97]
#    district: [12]
#    metropolitain: [13]
#    ultramarin: [14]
#    numero: [15]
#    dentre: [16]
#    acquerir: [17]
#    importance: [18]
#    fonctionnaire: [19]
#    biais: [20]
#    dune_de_sable: [21]
#    representation: [22, 23]
#    cadeau: [24]
#    cadre: [25]
#    espace: [26]
#    cas: [27]
#    lunion: [28]
#    democratique: [29, 82]
#    Breton: [30]
#    udb: [31]
#    gauche: [32, 39, 56, 65, 78, 109]
#    centregauche: [33, 110]
#    socialisme: [34, 41, 79, 93, 102]
#    socialdemocrat: [35, 86]
#    autonomiste: [37, 50, 59, 80, 87]
#    Region_Bretagne: [38, 43]
#    environnementaliste: [40, 57]
#    alliance: [44]
#    pe: [45]
#    avoir: [46]
#    corsicer: [47]
#    unir: [49]
#    corse: [52]
#    partit: [53]
#    provencal: [54]
#    poc: [55]
#    occitaniste: [58]
#    un_tandem_de_choc: [60]
#    martiniquais: [63, 76]
#    mim: [64]
#    parti: [68, 74, 98]
#    dissemination: [69, 90]
#    martiniqu: [70, 88]
#    palima: [71]
#    extremegauch: [72]
#    progressiste: [75]
#    ppm: [77]
#    rassemblement: [81]
#    Martinique: [83]
#    rdm: [84]
#    centregauch: [85]
#    sourcils: [89]
#    national: [91]
#    kanak: [92, 100]
#    flnk: [94]
#    constituer: [95]
#    luimem: [96]
#    melanesien: [103]
#    nouvellecaledonie: [104]
#    tavini: [105, 108]
#    huiraatirer: [106]
#    simplement: [107]
#    Polynesie: [112]
#    Daniel_Chester_French: [113]
#
# Document : Finances publiques (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2]
#    jusquen: [3]
#    trois: [4]
#    clef: [5]
#    administration_federale: [6, 61]
#    mathematiques: [7, 12, 26, 62, 71, 74]
#    financier: [8]
#    attribuer: [9, 77]
#    femme: [10]
#    france: [11]
#    maximal: [13]
#    cependant: [14]
#    matiere: [15]
#    abaissement: [16]
#    letat: [17]
#    Tresor_public: [18]
#    contrat: [19, 95]
#    Daniel_Chester_French: [20]
#    sequence: [21]
#    coup_de_colere: [22]
#    economie: [23, 87]
#    lui: [24]
#    revoir: [25, 52]
#    baisse: [27, 40]
#    novembre: [28, 35, 48]
#    moody: [29]
#    rabaisser: [30]
#    marque: [31, 41, 53, 78]
#    AAA: [32, 42, 54]
#    aa: [33, 36, 37, 46, 58]
#    pouvoir: [34, 45, 57]
#    Chinook: [38]
#    poor: [39]
#    aer: [43, 47, 55, 59]
#    jan: [44]
#    enfin: [49]
#    lagence: [50, 73]
#    fitch: [51]
#    juillet: [56]
#    decembre: [60]
#    saluer: [63]
#    lelection: [64]
#    demmanuel: [65]
#    macron_-: [66]
#    presidence: [67]
#    republique: [68]
#    relever: [69]
#    chance: [70, 81]
#    Avril: [72]
#    Chinoise: [75]
#    dagong: [76]
#    conservation: [79]
#    Francois-Anatole_Thibault: [80]
#    stable: [82]
#    estimer: [83]
#    malgre: [84]
#    lamelioration: [85]
#    etat: [86]
#    paysage: [88]
#    reformateur: [89]
#    mener: [90]
#    opinion: [91]
#    reduire: [92]
#    quantite: [93]
#    emprunt: [94]
#    accelerer: [96]
#    tau|taux: [97]
#    pousser: [98]
#    assez: [99]
#    lente: [100]
#
# Document : Défense (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    paysage: [0]
#    ailleurs: [1]
#    tierce: [2]
#    obtention: [3]
#    gras: [4]
#    exporteur: [5]
#    mondial: [6]
#    darmement: [7]
#    respecter: [8]
#    critiquer: [9]
#    rassembler: [10]
#    matiere: [11]
#    plusieurs: [12]
#    gerance: [13]
#    rien: [14]
#    gouvernemental: [15]
#    verticille: [16]
#    jeu: [17]
#    artillerie: [18]
#    different: [19]
#    lutte: [20]
#    international: [21]
#
# Document : Appartenance à des organisations internationales (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2]
#    depuis: [3]
#    contrat: [4]
#    maastricht: [5]
#    domaine: [6, 33]
#    lequel: [7]
#    lunion: [8, 40, 72]
#    Europeenne: [9, 27, 44, 73]
#    avoir: [10]
#    savoir-faire: [11]
#    exclusif: [12]
#    obtention: [13, 14, 24]
#    nombreuxk: [15]
#    grand: [16]
#    jeu: [17, 67]
#    policier: [18, 26, 29]
#    applicable: [19]
#    france: [20]
#    dorigine: [21]
#    europeennek: [22]
#    dauter: [23]
#    quactuellement: [25]
#    bonte: [28]
#    nationalk: [30]
#    Francois-Anatole_Thibault: [31, 60]
#    cinquieme: [32]
#    peser: [34]
#    encore: [35]
#    davantage: [36]
#    scene: [37]
#    mondial: [38]
#    remerciement: [39]
#    europeenned: [41]
#    lunification: [42]
#    echange: [43]
#    linstauration: [45]
#    dun: [46]
#    changer: [47, 51]
#    unique: [48]
#    tirer: [49]
#    profonde: [50]
#    leconomie: [52]
#    francaised: [53]
#    dont: [54]
#    specificite: [55]
#    benefique: [56]
#    faire: [57, 66]
#    debatd: [58]
#    si: [59]
#    premiere_vitesse: [61]
#    receveur: [62]
#    gouvernement: [63]
#    agricole: [64]
#    rotir: [65]
#    paysage: [68]
#    payeur: [69]
#    net: [70]
#    budget: [71]
#
# Document : Politique étrangère et diplomatie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    Francois-Anatole_Thibault: [1]
#    salut: [2]
#    paysage: [3]
#    pousser: [4, 11, 14]
#    notamment: [5]
#    dafriquen: [6]
#    distribuer: [7]
#    via: [8]
#    lagence: [9]
#    Daniel_Chester_French: [10, 19]
#    laid: [12]
#    contrat: [13]
#    representer: [15]
#    profit: [16]
#    national: [17]
#    brut: [18]
#    tau|taux: [20]
#    baisse: [21]
#    subordonne: [22]
#    celui: [23]
#    royaumeuni: [24]
#    lallemagne: [25]
#
# Document : Symboles républicains (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0]
#    depuis: [1]
#    opinion: [2]
#    Daniel_Chester_French: [3, 22]
#    sest: [4]
#    doter: [5]
#    dun: [6]
#    logo: [7, 15]
#    rappeler: [8]
#    pavillon: [9]
#    monnaie: [10]
#    paysage: [11]
#    ainsi: [12]
#    forme: [13]
#    marianne: [14]
#    figurer: [16]
#    entete: [17]
#    femme: [18]
#    fichier_ascii: [19]
#    publier: [20]
#    ladministration: [21]
#    charter: [23]
#    graphique: [24]
#    gouvernemental: [25]
#    moderniser: [26]
#    sadapter: [27]
#    original: [28, 30]
#    formater: [29]
#    consommation: [31]
#    propos: [32]
#
# Document : Démographie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    <PERSON>: [1, 2]
#    outre: [3]
#    structure: [4]
#    pyramide: [5]
#    age: [6, 15, 32]
#    evoluer: [7]
#    depuis: [8]
#    declenchement: [9]
#    xxie: [10]
#    cent: [11]
#    symetrie: [12]
#    population: [13, 45]
#    obtention: [14, 25, 43]
#    augmenter: [16]
#    cas: [17]
#    duree: [18]
#    avancer: [19]
#    lesperance: [20]
#    faune: [21, 28]
#    Francois-Anatole_Thibault: [22]
#    jouir: [23]
#    dune_de_sable: [24]
#    grand: [26]
#    esperer: [27]
#    monden: [29]
#    larrivee: [30]
#    tierce: [31, 52]
#    generation: [33]
#    baby: [34]
#    bome: [35, 41]
#    --: [36]
#    prodige: [37]
#    communement: [38]
#    lancer: [39]
#    bon-papa: [40]
#    numero: [42]
#    dans: [44]
#    Daniel_Chester_French: [46]
#    ainsi: [47]
#    passereau: [48]
#    entrer: [49]
#    responsabilite: [50]
#    approcher: [51]
#    selon: [53]
#    linsee: [54]
#
# Document : Immigration, population étrangère et minorités visibles (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    population: [0, 17, 28]
#    dorigine: [1]
#    immigre: [2, 41]
#    celui: [3]
#    appartenir: [4]
#    minoritaire: [5]
#    visible: [6]
#    parfois: [7]
#    victimer: [8]
#    distinction: [9]
#    francei: [10]
#    cas: [11]
#    indeterminer: [12]
#    respecter: [13]
#    argument: [14]
#    jeu: [15]
#    ce: [16]
#    tourne: [18]
#    vers: [19]
#    integrisme: [20]
#    religieuxi: [21]
#    pourtant: [22]
#    assister: [23]
#    certaine: [24]
#    convergence: [25]
#    facon: [26]
#    faune: [27]
#    immigrer: [29, 36, 50, 59]
#    Daniel_Chester_French: [30]
#    long: [31]
#    datei: [32]
#    tau|taux: [33]
#    travail: [34]
#    moins-que-rien: [35, 57]
#    quelque: [37]
#    1000000: [38]
#    demploi: [39]
#    banning: [40]
#    rien: [42, 58]
#    Europeenne: [43]
#    obtention: [44, 56]
#    dun: [45]
#    consommation: [46]
#    cinq: [47]
#    ailleurs: [48]
#    phratrie: [49]
#    vivre: [51]
#    foyer: [52]
#    assez: [53]
#    etroit: [54]
#    duree: [55]
#
# Document : Famille, sexualité et égalité des sexes (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0]
#    centre_d'achats: [1]
#    femme: [2, 28, 36, 40, 53, 59, 69, 92, 101]
#    guilde: [3]
#    Daniel_Chester_French: [4, 88]
#    avoir: [5]
#    beaucoup: [6]
#    evolue: [7]
#    course: [8]
#    xxe: [9]
#    cent: [10]
#    mouvement: [11]
#    tension: [12]
#    vers: [13]
#    dessiner: [14]
#    fonctionnaire: [15, 66]
#    entrer: [16, 100]
#    sexualite: [17]
#    ce: [18]
#    changer: [19]
#    sest: [20]
#    accompagner: [21]
#    bill: [22]
#    legislativesi: [23]
#    cas: [24]
#    policier: [25]
#    voter: [26]
#    accorder: [27]
#    Pronunciamento: [29]
#    particulierement: [30]
#    cosmos: [31]
#    coutume: [32, 50]
#    ainsi: [33, 64]
#    tau|taux: [34]
#    dactivite: [35]
#    passereau: [37]
#    contre: [38]
#    male: [39, 46, 58, 102]
#    continuer: [41]
#    cependant: [42]
#    job: [43]
#    significativement: [44]
#    moins: [45]
#    selon: [47]
#    locde: [48]
#    quoique: [49]
#    hebdomadaire: [51]
#    facon: [52]
#    repercussion: [54, 57]
#    alors: [55]
#    quil: [56]
#    representer: [60, 73, 76]
#    egalement: [61, 70]
#    demi: [62, 65]
#    doctorant: [63]
#    iep: [67]
#    esc: [68]
#    mieux: [71, 72]
#    gouvernement: [74]
#    lui: [75, 81]
#    representation: [77]
#    parlement: [78]
#    postulant: [79, 83, 84]
#    ressemblance: [80]
#    netaient: [82]
#    obtention: [85]
#    depuis: [86]
#    opinion: [87]
#    composer: [89]
#    symetrie_miroir: [90]
#    dhomme: [91]
#    enfin: [93]
#    metier: [94]
#    compagnie: [95]
#    office: [96]
#    egal: [97]
#    lecart: [98]
#    salarial: [99]
#
# Document : Langues (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 2]
#    <PERSON>: [1]
#    lorganisme: [3]
#    parc: [4]
#    langue_ethnique: [5, 38]
#    Francois-Anatole_Thibault: [6]
#    lacademie: [7]
#    Daniel_Chester_French: [8, 33, 39]
#    hopital_psychiatrique: [9]
#    fonder: [10]
#    officialiser: [11]
#    cardinal: [12]
#    Richelieu: [13]
#    forme: [14]
#    juridique: [15]
#    celui: [16]
#    moins-que-rien: [17]
#    moral: [18]
#    policier: [19]
#    contrat: [20, 30]
#    regle: [21]
#    specifique: [22]
#    endroit: [23]
#    sou: [24]
#    protection: [25]
#    gouverneur: [26]
#    republique: [27]
#    theme: [28]
#    rendre: [29]
#    fevrier: [31]
#    universite: [32]
#    inquiet: [34]
#    consommation: [35]
#    abusif: [36]
#    anglicisme: [37]
#
# Document : Religions (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    Daniel_Chester_French: [0, 10, 18]
#    effigie: [1]
#    plutot: [2]
#    strictement_negatif: [3]
#    theologie: [4, 12]
#    ensemble: [5]
#    selon: [6]
#    urne: [7]
#    ipso: [8]
#    publier: [9]
#    pensent: [11, 19]
#    matiere: [13]
#    obtention: [14]
#    tort: [15]
#    bien_de_consommation_courante: [16]
#    seulement: [17]
#    moins-que-rien: [20]
#    croyant: [21]
#    faire: [22]
#    meilleur: [23]
#    citoyenne: [24]
#
# Document : Éducation (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    premiere_vitesse: [0]
#    note: [1]
#    procureur: [2]
#    leducation: [3]
#    national: [4]
#    avoir: [5]
#    reveler: [6]
#    <<: [7]
#    maintien: [8]
#    pedagogique: [9]
#    >>: [10]
#    pendant: [11]
#    verrouillage: [12]
#    atmosphes: [13]
#    pandemie: [14]
#    covid: [15]
#    positif: [16]
#    selon: [17]
#    lenquete: [18]
#    sept: [19]
#    commandement: [20]
#    dix: [21, 24]
#    huit: [22]
#    parent: [23]
#    juge: [25]
#    satisfaire: [26]
#
# Document : Santé et protection sociale (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1]
#    contrairement: [2]
#    opinion: [3]
#    recevoir: [4]
#    Francois-Anatole_Thibault: [5]
#    consomm: [6]
#    significativement: [7]
#    obtention: [8, 16, 18]
#    dantidepresseur: [9]
#    autre: [10, 20, 33]
#    paysage: [11, 21, 34]
#    tau|taux: [12, 23]
#    suicidaire: [13]
#    ny: [14]
#    rien: [15]
#    particulierement: [17]
#    eleve: [19]
#    developpe: [22]
#    agitation: [24]
#    bien-etre: [25]
#    mental: [26]
#    labu: [27]
#    viande: [28]
#    bien_de_consommation_courante: [29]
#    queleve: [30]
#    comparable: [31]
#    celui: [32]
#    occidental: [35]
#
# Document : Médias (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    juillet: [1]
#    annoncer: [2]
#    plateform: [3]
#    unique: [4]
#    sans_fil: [5, 26, 36, 38, 41, 45, 48]
#    contrat: [6, 31]
#    priver: [7]
#    bien_que: [8]
#    domaine: [9]
#    numerique: [10]
#    rotir: [11]
#    permission: [12]
#    utilisateur: [13]
#    decouter: [14]
#    femme: [15]
#    calendrier: [16]
#    Moi: [17]
#    endroit: [18]
#    sans: [19]
#    aucun: [20]
#    prix: [21]
#    lancer: [22]
#    Avril: [23]
#    sou: [24]
#    souci: [25]
#    player: [27]
#    reunir: [28]
#    gare_routiere: [29]
#    Daniel_Chester_French: [30]
#    detective: [32]
#    dont: [33]
#    lagarder: [34]
#    new: [35]
#    Francois-Anatole_Thibault: [37]
#    Lot: [39]
#    inde: [40]
#    lensembl: [42]
#    representer: [43]
#    laudience: [44]
#    grand: [46]
#    numero: [47]
#    associatif: [49]
#    nayer: [50]
#    rejoindre: [51]
#    propos: [52]
#
# Document : Sport (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0]
#    outre: [1]
#    colorier: [2]
#    pavillon: [3]
#    federation: [4]
#    femme: [5]
#    Daniel_Chester_French: [6]
#    coq: [7]
#    aussi: [8]
#    grace: [9]
#    comme: [10]
#    embleme: [11, 13]
#    n': [12]
#    officiel: [14]
#
# Document : Engagement associatif, syndical et politique (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0, 1]
#    ce: [2]
#    cadeau: [3]
#    ponctuel: [4]
#    evenement: [5]
#    contestataire: [6]
#    traduire: [7]
#    bien_que: [8]
#    sen: [9]
#    falloir: [10]
#    allegeance: [11]
#    important: [12, 24]
#    parti: [13]
#    politiquesk: [14]
#    quant: [15]
#    tau|taux: [16]
#    syndicalisation: [17]
#    obtention: [18, 23, 36]
#    lampadaire: [19]
#    paysage: [20]
#    riche: [21]
#    sil: [22]
#    secteur: [25]
#    publici: [26]
#    ristourne: [27]
#    Daniel_Chester_French: [28]
#    tres: [29]
#    impliquer: [30]
#    atmosphes: [31]
#    associatif: [32]
#    1000000: [33, 38]
#    benevole: [34]
#    penis: [35]
#    dun: [37]
#    dassociationsi: [39]
#    profit: [40]
#    regle: [41]
#    accorder: [42]
#    bill: [43]
#    ER: [44]
#    juillet: [45]
#    K: [46]
#
# Document : Discrimination (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3, 4]
#    <PERSON>: [5]
#    distinction: [6, 50, 70]
#    lier: [7]
#    extraction: [8, 29, 39, 52, 63, 72, 77, 82]
#    ethnicite: [9]
#    colorier: [10, 53]
#    cacher: [11, 54]
#    principalement: [12]
#    declarer: [13, 68]
#    moins-que-rien: [14, 31, 37, 41]
#    controle: [15]
#    immigrer: [16, 21, 67]
#    deux: [17]
#    generation: [18]
#    immigre: [19, 71]
#    progeniture: [20, 58, 66, 76]
#    estimer: [22]
#    avoir: [23]
#    faire: [24]
#    theme: [25, 79]
#    gaine: [26]
#    inegalitaire: [27]
#    cas: [28]
#    tierce: [30]
#    originaire: [32, 42]
#    afrique: [33]
#    hors: [34]
#    Maghreb: [35]
#    contre: [36]
#    femme: [38]
#    confondre: [40]
#    outremer: [43, 57]
#    comte: [44]
#    egalement: [45]
#    parmi: [46, 55]
#    celui: [47]
#    rapporter: [48]
#    obtention: [49, 69, 74]
#    acte_notarie: [51]
#    autochtone: [56]
#    naitre: [59]
#    Francois-Anatole_Thibault: [60]
#    metropolitain: [61]
#    Lot: [62, 81]
#    rien: [64]
#    Europeenne: [65, 83]
#    disparite: [73]
#    eleve: [75]
#    Asiatique: [78]
#    inverse: [80]
#
# Document : Économie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    <PERSON>: [1]
#    leconomie: [2, 26]
#    Francois-Anatole_Thibault: [3]
#    economie: [4]
#    social: [5]
#    echange: [6]
#    fonder: [7]
#    etat: [8]
#    priver: [9]
#    conservation: [10]
#    intervention: [11]
#    etatique: [12]
#    relativement: [13]
#    fort: [14]
#    depuis: [15, 24]
#    propos: [16]
#    minute: [17]
#    guerre: [18]
#    mondial: [19]
#    bien_de_consommation_courante: [20]
#    celleci: [21]
#    remettre: [22]
#    matiere: [23]
#    annee: [25]
#    Daniel_Chester_French: [27]
#    principalement: [28]
#    tourner: [29]
#    vers: [30]
#    domaine: [31]
#    retenue: [32]
#    obligatoire: [33]
#    representer: [34]
#    PIB: [35, 46]
#    tau|taux: [36, 48]
#    obtention: [37, 49]
#    eleve: [38, 50]
#    parmi: [39]
#    paysage: [40]
#    penis: [41]
#    locde: [42, 51]
#    frais: [43]
#    contrat: [44]
#    totaliser: [45]
#    deuxieme: [47]
#
# Document : Revenus de la population et développement humain (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    premiere_vitesse: [1]
#    trimestre: [2]
#    linsee: [3]
#    denombrer: [4]
#    sansabri: [5]
#    france: [6]
#    outre: [7]
#    moins-que-rien: [8]
#    nont: [9]
#    residence: [10]
#    travailleur: [11]
#
# Document : Emploi (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    Francois-Anatole_Thibault: [1]
#    selon: [2]
#    locde: [3]
#    quoique: [4, 37]
#    coutume: [5, 38]
#    hebdomadaire: [6, 39]
#    facon: [7, 40]
#    male: [8]
#    repercussion: [9, 15, 18, 24, 28, 42]
#    doigt: [10, 30]
#    briquet: [11, 20]
#    baisse: [12, 21]
#    depuis: [13, 22, 33]
#    annee: [14, 23]
#    celui: [16]
#    femme: [17]
#    egalement: [19]
#    de_l'arithmetique: [25]
#    Daniel_Chester_French: [26]
#    job: [27]
#    semaine: [29]
#    extremement: [31]
#    stable: [32]
#    falloir: [34]
#    remonter: [35]
#    conservation: [36]
#    haut: [41]
#
# Document : Principaux secteurs d'activité (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 2, 3]
#    <PERSON>: [1]
#    echange: [4, 9]
#    pari: [5, 31]
#    filial: [6]
#    deuronext: [7]
#    depuis: [8]
#    officiel: [10]
#    bill: [11, 23, 38, 45]
#    Francois-Anatole_Thibault: [12]
#    lindic: [13]
#    cac: [14, 37]
#    indice: [15]
#    ponderer: [16]
#    office: [17]
#    capital: [18, 33, 40]
#    boursier: [19, 34, 41]
#    flottant: [20]
#    refleter: [21]
#    performance: [22]
#    obtention: [24, 26, 51]
#    important: [25]
#    activement: [27]
#    marque: [28]
#    coter: [29]
#    euronext: [30]
#    Sept: [32]
#    quantite: [35, 49]
#    constituant: [36, 43]
#    deuro: [39, 46]
#    median: [42]
#    lindice: [44, 54]
#    lvmh: [47]
#    sanofi: [48]
#    trois: [50]
#    gras: [52]
#    compagnie: [53]
#
# Document : Place de la France dans l'économie mondiale (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    Francois-Anatole_Thibault: [1]
#    classer: [2]
#    e: [3]
#    opinion: [4]
#    lindice: [5]
#    mondial: [6]
#    linnovation: [7]
#
# Document : Culture (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    pres: [1]
#    1000000: [2, 24]
#    visiteur: [3]
#    Francois-Anatole_Thibault: [4]
#    premiere_vitesse: [5]
#    destination: [6]
#    touristique: [7]
#    cosmos: [8]
#    grand: [9]
#    jeu: [10]
#    remerciement: [11]
#    nombreux: [12]
#    gerance: [13]
#    culturel: [14, 29]
#    immeuble: [15]
#    historique: [16, 42]
#    implanter: [17]
#    femme: [18]
#    district: [19]
#    directoire: [20]
#    muser: [21]
#    accueillir: [22]
#    obtention: [23, 30]
#    moins-que-rien: [25]
#    chaque: [26]
#    annee: [27]
#    site: [28]
#    important: [31]
#    gerer: [32]
#    opinion: [33]
#    cas: [34]
#    lintermediaire: [35]
#    centre_d'achats: [36]
#    mausolee: [37, 41]
#    national: [38, 43]
#    responsable: [39]
#    denviron: [40]
#
# Document : Architecture (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3, 4, 9]
#    <PERSON>: [5, 6, 7, 8, 10, 11, 12, 13, 14]
#    Francois-Anatole_Thibault: [15, 43, 55]
#    depuis: [16]
#    immeuble: [17]
#    dinteret: [18]
#    historique: [19, 29, 46]
#    architectural: [20, 54]
#    patrimonial: [21]
#    culturel: [22]
#    supergrand: [23]
#    etre: [24]
#    inscrire: [25]
#    classer: [26, 48]
#    ligne: [27]
#    mausolee: [28, 45]
#    letat: [30]
#    certain: [31]
#    bien_de_consommation_courante: [32]
#    mobilier: [33]
#    clocher: [34]
#    assurer: [35]
#    protection: [36]
#    juridique: [37]
#    ainsi: [38]
#    salut: [39]
#    renouvelement: [40]
#    lentretien: [41]
#    decembre: [42]
#    comte: [44]
#    inscrit: [47]
#    dimportant: [49]
#    architecte: [50]
#    Daniel_Chester_French: [51]
#    faconner: [52]
#    patrimoine: [53]
#    europe: [56]
#    femme: [57]
#    un_point_c'est_tout: [58, 73]
#    notamment: [59]
#    montreuil: [60]
#    facon: [61]
#    age: [62]
#    lescot: [63]
#    delorm: [64]
#    androuet: [65]
#    panier: [66]
#    Renaissance: [67]
#    Mansart: [68]
#    vau: [69]
#    hardouinmansart: [70]
#    Gabriel: [71]
#    ledou: [72]
#    classique: [74]
#    neoclassique: [75]
#    violletleduc: [76]
#    Garnier: [77]
#    Eiffel: [78]
#    xixe: [79]
#    cent: [80]
#    Auguste: [81]
#    perret: [82]
#    corbusier: [83]
#    jean: [84]
#    original: [85]
#    lepoque: [86]
#    contemporain: [87]
#
# Document : Arts visuels et plastiques (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    <PERSON>: [1, 2]
#    xixe: [3, 53]
#    xxe: [4]
#    cent: [5]
#    Francois-Anatole_Thibault: [6]
#    nerf: [7]
#    verticille: [8]
#    medius: [9]
#    grand: [10]
#    flux: [11]
#    rotation: [12]
#    artistique: [13]
#    occidental: [14]
#    romantisme: [15]
#    delacroi: [16]
#    gericault: [17]
#    realisme: [18]
#    courbet: [19]
#    limpressionnism: [20]
#    monet: [21]
#    renoir: [22]
#    manet: [23]
#    dega: [24]
#    neoimpressionnisme: [25]
#    seurat: [26]
#    van: [27]
#    gogh: [28]
#    cezanne: [29]
#    gauguin: [30]
#    fauvisme: [31]
#    matisse: [32]
#    derain: [33]
#    vlaminck: [34]
#    cubisme: [35]
#    braque: [36]
#    picasso: [37]
#    briquet: [38]
#    encore: [39]
#    nawak: [40]
#    duchamp: [41]
#    comte: [42]
#    artiste: [43]
#    Daniel_Chester_French: [44]
#    parmi: [45]
#    clef: [46]
#    representantsm: [47]
#    rodin: [48]
#    flanc: [49]
#    revolutionner: [50]
#    sculpture: [51]
#    propos: [52]
#    sieclem: [54]
#
# Document : Littérature et poésie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 2]
#    Francois-Anatole_Thibault: [3, 18]
#    e: [4]
#    paysage: [5]
#    publier: [6]
#    obtention: [7]
#    comptabiliser: [8, 16]
#    cosmos: [9]
#    derriere: [10]
#    chine: [11]
#    etatsuni: [12]
#    royaumeuni: [13]
#    ainsi: [14]
#    original: [15]
#    editer: [17]
#
# Document : Arts du spectacle (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    pratique: [1]
#    danse: [2, 7, 9, 13]
#    Francois-Anatole_Thibault: [3]
#    reguler: [4]
#    federation: [5]
#    Daniel_Chester_French: [6]
#    repartition: [8]
#    montrer: [10]
#    Ballet: [11]
#    commerage: [12]
#    contemporain: [14]
#    guilde: [15]
#    courrier: [16]
#    quadrille: [17]
#    concours: [18]
#    femme: [19]
#    acrobatique: [20]
#
# Document : Musique (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0, 1, 2, 3, 4, 5, 6, 7]
#    personnalite: [8]
#    notable: [9]
#    song: [10]
#    Daniel_Chester_French: [11]
#    tino: [12]
#    rossi: [13]
#    edith: [14]
#    prunella_modularis: [15]
#    George_du_Maurier: [16]
#    brassen: [17]
#    charle: [18]
#    aznavour: [19]
#    serge: [20]
#    gainsbourg: [21]
#    dalider: [22]
#    johnny: [23]
#    hallyday: [24]
#    claude: [25]
#    francois: [26]
#    michel: [27]
#    sardou: [28]
#    jeanjacque: [29]
#    goldman: [30]
#    mylene: [31]
#    farmer: [32]
#    francis: [33]
#    cabrel: [34]
#    mc: [35]
#    solaar: [36]
#
# Document : Cinéma (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0]
#    lors: [1]
#    coup_de_colere: [2]
#    hygiene: [3]
#    france: [4]
#    letat: [5]
#    avoir: [6, 20]
#    faire: [7]
#    inclinaison: [8]
#    relance: [9]
#    bill: [10, 29]
#    deuro: [11, 23, 30, 33]
#    soutenir: [12, 25]
#    secteur: [13, 37]
#    culturel: [14]
#    San_Pedro_Sula: [15]
#    premiere_vitesse: [16]
#    pasteur: [17]
#    jean: [18]
#    castex: [19]
#    annoncer: [21]
#    1000000: [22, 32]
#    grace: [24]
#    cosmos: [26]
#    cinematographique: [27]
#    planifie: [28]
#    ailleurs: [31]
#    deja: [34]
#    allouer: [35]
#    cooperant: [36]
#    montrer: [38]
#    vivre: [39]
#
# Document : Mode (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0, 1, 2, 3, 4, 5, 6]
#    annee: [7, 34, 52, 67]
#    haute: [8]
#    couture: [9, 58]
#    considerer: [10]
#    comme: [11]
#    assez: [12]
#    elitiste: [13]
#    subit: [14]
#    critique: [15]
#    raffinement: [16]
#    petit: [17]
#    couturiere: [18]
#    yves: [19]
#    saint: [20]
#    laurent: [21]
#    rompt: [22]
#    standard: [23]
#    etablir: [24, 45]
#    lancer: [25]
#    dun: [26]
#    pretaporter: [27]
#    inaugurer: [28]
#    lexpansion: [29]
#    facon: [30]
#    Daniel_Chester_French: [31, 59, 70]
#    fabrication: [32, 51]
#    Lot: [33]
#    sonia: [35]
#    rykiel: [36]
#    thierry: [37]
#    mugler: [38]
#    Claude: [39]
#    montana: [40]
#    jeanpaul: [41]
#    gaultier: [42]
#    christian: [43]
#    lacroix: [44]
#    original: [46]
#    cur: [47]
#    rassembler: [48]
#    laccent: [49]
#    marketing: [50]
#    constituer: [53]
#    conglomerat: [54]
#    regrouper: [55]
#    nombreux: [56]
#    manoir: [57]
#    notamment: [60]
#    geante: [61]
#    faste: [62]
#    lvmh: [63]
#    kering: [64]
#    loreal: [65]
#    declenchement: [66, 73]
#    secteur: [68]
#    parfumerie: [69]
#    industrialiser: [71]
#    tout: [72]
#    xxe: [74]
#    cent: [75]
#    francois: [76]
#    coty: [77]
#    chef: [78]
#    mondial: [79]
#
# Document : Gastronomie (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <PERSON>: [0]
#    diner: [1, 36, 38, 39, 57]
#    gastronomique: [2]
#    Daniel_Chester_French: [3]
#    avoir: [4]
#    inscrire: [5]
#    inclinaison: [6]
#    representatif: [7]
#    patrimoine: [8]
#    culturel: [9]
#    immateriel: [10]
#    lhumanite: [11]
#    lunesco: [12]
#    composer: [13]
#    generalement: [14]
#    dune: [15]
#    acquisition: [16, 44]
#    dun: [17, 20]
#    soucoupe: [18]
#    garni: [19]
#    dessert: [21]
#    parfois: [22]
#    completer: [23]
#    fromage: [24, 54]
#    servir: [25]
#    avant: [26]
#    nuit: [27, 65]
#    lentree: [28]
#    souvent: [29]
#    remplacer: [30]
#    soupe: [31, 32]
#    dou: [33]
#    lappellation: [34]
#    <<: [35]
#    >>: [37]
#    dominical: [40]
#    obtention: [41, 50]
#    elaborer: [42]
#    deux: [43]
#    froide: [45]
#    chaude: [46]
#    rotir: [47]
#    viande: [48]
#    volaill: [49]
#    couramment: [51]
#    salad: [52]
#    plaine: [53]
#    desservir: [55]
#    repercussion: [56, 61, 63, 66, 68, 70]
#    ecstasy: [58]
#    un_tandem_de_choc: [59]
#    nord: [60]
#    de_l'arithmetique: [62, 69]
#    Etats_confederes_d'Amerique: [64, 71]
#    Flandre_francaise: [67]
#
# Document : Philosophie et science (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0]
#    <PERSON>: [1]
#    Francois-Anatole_Thibault: [2]
#    egalement: [3]
#    guide: [4]
#    domaine: [5]
#    spatial: [6]
#    district: [7]
#    lancer: [8]
#    catapulte: [9]
#    arian: [10]
#    guyane: [11]
#    Daniel_Chester_French: [12, 16]
#    forme: [13]
#    dix: [14]
#    cosmonaute: [15]
#    dont: [17]
#    lever: [18]
#    datte: [19]
#    Dylan_Thomas: [20]
#    pesquet: [21]
#
# Document : Influence internationale (URL: https://fr.wikipedia.org/wiki/France)
# Positions des mots :
#    <LOCATION>: [0, 1, 3]
#    <PERSON>: [2]
#    controle: [4]
#    culturel: [5]
#    Francois-Anatole_Thibault: [6, 21]
#    letranger: [7, 19]
#    entretenir: [8]
#    representation: [9]
#    diplomatique: [10]
#    reseau_informatique: [11]
#    etendre: [12]
#    lalliance: [13]
#    Daniel_Chester_French: [14, 18]
#    obtention: [15, 20]
#    gerance: [16]
#    scolaire: [17]
#    lorigine: [22]
#    cosmos: [23, 33]
#    media: [24]
#    vocation: [25]
#    international: [26]
#    Moi: [27]
#    sans_fil: [28]
#    rfi: [29]
#    chaine: [30]
#    televisie: [31]
#    tv: [32]
#    communer: [34]
#    plusieurs: [35]
#    paysage: [36]
#    france: [37]
#
# Document : Notes (URL: https://fr.wikipedia.org/wiki/Technologie)
# Positions des mots :
#    <PERSON>: [0]
#    ce: [1]
#    regle: [2]
# ...
#    enfance: [8]
#    prendre: [10]
#    ursides: [11, 32]
#    phratrie: [12]
#    ou: [13]
#    faire: [14]
#    lapprentissage: [15, 36, 48]
#    langue_ethnique: [16, 43]
#    oral: [17]
#    rudiment: [18, 37]
#    savoirvivre: [19]
#    prescription: [20]
#    faune: [21]
#    social: [22]
#    lenfance: [24]
#    conge: [25]
#    denviron: [26]
#    sept: [27]
#    dans: [28]
#    jusqua: [29]
#    puberter: [30]
#    portee: [31]
#    collectif: [33]
#    moins: [34]
#    partiellement: [35]
#    legal: [38]
#    soeur: [39]
#    culturel: [40]
#    dont: [41]
#    eventuellement: [42]
#    ecrite: [44]
#    ladolescence: [46]
#    specialisation: [47]
#    chez: [49]
#    passe: [50]
#    rien: [51]
#    exclusif: [52]
#    collectivement: [53]
#
# Document : Enjeux (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    defaut: [0]
#    deducation: [1]
#    mathematique: [2, 19]
#    induire: [3]
#    chez: [4, 20]
#    adolescent: [5]
#    quantite: [6]
#    dinhibiteur: [7]
#    cerebral: [8, 31]
#    reduire: [9]
#    espace: [10, 35]
#    cler: [11]
#    argument: [12, 18, 38]
#    lapprentissage: [13, 42]
#    propos: [14]
#    explorer: [15]
#    montr: [16]
#    pratique: [17]
#    ladolescent: [21]
#    augmenter: [22]
#    concentration: [23]
#    dacid: [24]
#    gaminobutyriqu: [25]
#    gaba: [26]
#    neurotransmetteurs: [27]
#    Inhibiteur: [28]
#    crucial: [29]
#    malleabilite: [30]
#    gyrus: [32]
#    frontal: [33]
#    facon: [34]
#    esprit: [36]
#    impliquer: [37]
#    declaration: [39]
#    specificite: [40]
#    souvenir: [41]
#
# Document : Inclusion scolaire (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3]
#    tamias: [4]
#    inclusion: [5, 27]
#    scolaire: [6, 25]
#    progeniture: [7, 28]
#    defaut: [8]
#    inscrire: [9]
#    vaste: [10]
#    terrain_vague: [11]
#    reformateur: [12]
#    gouvernement: [13, 18]
#    accompagnemer: [14]
#    moins-que-rien: [15]
#    etat: [16]
#    handicap: [17]
#    faire: [19]
#    integration: [20]
#    cavalerie: [21]
#    lutte: [22]
#    refonte: [23]
#    cadre: [24, 46]
#    partisan: [26]
#    travailleur: [29]
#    specifique: [30]
#    bien_de_consommation_courante: [31]
#    percevoir: [32]
#    comme: [33]
#    Nombre_reel: [34]
#    progre: [35]
#    creer: [36]
#    original: [37]
#    defi: [38]
#    phratrie: [39]
#    gerance: [40]
#    entrer: [41]
#    faune: [42, 44]
#    familial: [43]
#    professionnalisme: [45]
#    detention: [47]
#
# Document : Droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    responsabilite: [0]
#    penis: [1]
#    adopter: [2]
#    opinion: [3]
#    verticille: [4]
#    unesco: [5]
#    encourager: [6]
#    gamine: [7]
#    femme: [8]
#    exercer: [9]
#    leadership: [10]
#    stem: [11]
#    compris: [12]
#    graphique: [13]
#    design: [14]
#
# Document : Les objectifs de l'Éducation pour Tous (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <PERSON>: [0]
#    chaque: [1]
#    annee: [2]
#    navigant: [3]
#    lunesco: [4]
#    rediger: [5]
#    theme: [6]
#    controle: [7]
#    lept: [8]
#    contenir: [9]
#    indicateur_de_vitesse: [10]
#    nombreux: [11]
#    forme: [12]
#    explorer: [13]
#    type: [14]
#
# Document : Interprétation du droit à l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <LOCATION>: [0, 1, 2, 3, 5, 7]
#    <PERSON>: [4, 6]
#    cadeau: [8]
#    lien: [9]
#    responsabilite: [10]
#    rassembler: [11]
#    centre_d'achats: [12]
#    cadre: [13]
#    educatif: [14]
#    numero: [15]
#    suffire: [16]
#    college: [17]
#    veiller: [18]
#    eradiquer: [19]
#    femme: [20, 34, 38, 89]
#    theme: [21]
#    distinction: [22, 43]
#    banning: [23]
#    instrument: [24]
#    international: [25]
#    option: [26]
#    parent: [27]
#    choisir: [28]
#    enseignemer: [29, 57]
#    dispenser: [30]
#    progeniture: [31, 39, 73, 74, 80]
#    disponibilite: [32]
#    l'elimination: [33]
#    obstacle: [35]
#    lutte: [36, 70]
#    formation: [37, 85]
#    age: [40, 65]
#    scolaire: [41]
#    sans: [42]
#    prix: [44]
#    sage: [45]
#    acceptabilite: [46]
#    standard: [47]
#    minimal: [48]
#    specificite: [49]
#    valeur: [50]
#    salubrite: [51]
#    atmosphes: [52]
#    respecter: [53]
#    policier: [54, 63, 90]
#    male: [55]
#    espace: [56, 76]
#    capacite: [58]
#    methodologie: [59]
#    enseignement: [60, 66, 72]
#    adaptabilite: [61]
#    contrat: [62]
#    office: [64]
#    extrascolaire: [67]
#    celui: [68]
#    n': [69]
#    gerance: [71]
#    priver: [75]
#    refugie: [77]
#    moins-que-rien: [78]
#    deplacer: [79]
#    job: [81]
#    communauter: [82]
#    nomade: [83]
#    ajustement: [84]
#    qu': [86]
#    favoriser: [87]
#    coutume: [88]
#    fondamental: [91]
#
# Document : Un droit reconnu au niveau international (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    favoriser: [0]
#    lepanouissement: [1]
#    personnalite: [2]
#    lenfer: [3, 13, 25, 48, 73]
#    pousser: [4]
#    bonte: [5]
#    qualification: [6]
#    mental: [7]
#    forme: [8]
#    femme: [9, 63]
#    bill: [10]
#    potentialite: [11]
#    inculquer: [12, 24, 72]
#    respecter: [14, 26, 33, 74]
#    policier: [15]
#    lhomme: [16]
#    espace: [17]
#    fondamentale: [18]
#    regle: [19]
#    consacrer: [20]
#    charter: [21]
#    etat: [22, 50]
#    uni: [23]
#    parent: [27]
#    coutume: [28]
#    langue_ethnique: [29]
#    valeur: [30, 34]
#    culturel: [31]
#    ainsi: [32]
#    national: [35, 67]
#    paysage: [36, 39]
#    lequel: [37]
#    voir: [38]
#    duquel: [40]
#    supergrand: [41]
#    etre: [42]
#    originaire: [43]
#    civilisation: [44]
#    different: [45]
#    sienne: [46]
#    preparer: [47]
#    assumer: [49]
#    faune: [51]
#    guilde: [52]
#    ouvrir: [53]
#    esprit: [54]
#    inclusion: [55]
#    salle: [56]
#    depassement: [57]
#    degalite: [58]
#    entrer: [59, 62]
#    sexualite: [60]
#    damitier: [61]
#    phratrie: [64]
#    Lot: [65]
#    ethnique: [66]
#    soeur: [68]
#    moins-que-rien: [69]
#    dorigin: [70]
#    aborigene: [71]
#    atmosphes: [75]
#    nature: [76]
#
# Document : Investir dans l'éducation (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <PERSON>: [0, 1]
#    ce: [2]
#    hypothese: [3, 27]
#    douleur: [4]
#    cependant: [5]
#    expliquer: [6]
#    lattrer: [7]
#    filiere: [8]
#    educatif: [9, 43]
#    privilegier: [10]
#    raffinement: [11]
#    ensemble: [12]
#    theme: [13]
#    celui: [14]
#    proposer: [15]
#    train: [16]
#    operationnel: [17]
#    humain: [18]
#    avoir: [19, 29]
#    priori: [20]
#    obtention: [21]
#    mobilisable: [22]
#    echange: [23]
#    coutume: [24]
#    speculation: [25]
#    alternatif: [26]
#    signalisation: [28]
#    donc: [30]
#    developper: [31]
#    annee: [32]
#    Canadiens_francais: [33]
#    michael: [34]
#    spence: [35]
#    retrouver: [36]
#    opinion: [37]
#    similaire: [38]
#    verticille: [39]
#    filtrage: [40]
#    assigner: [41]
#    cadre: [42]
#    kenneth: [44]
#    arrow: [45]
#
# Document : Marché éducatif (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    selon: [0]
#    paysage: [1]
#    decoupage: [2]
#    publicprive: [3]
#    differ: [4]
#    femme: [5]
#    comme: [6]
#    quantite: [7]
#    daide: [8]
#    contrat: [9, 15, 19]
#    destination: [10]
#    college: [11]
#    detective: [12]
#    ainsi: [13]
#    forme: [14]
#    lier: [16]
#    lobtention: [17]
#    subvention: [18]
#    obtention: [20]
#    fraise: [21]
#    dinscription: [22]
#    enseignement: [23]
#    fourniture: [24]
#    supergrand: [25]
#    varier: [26]
#
# Document : Canada (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    college: [0]
#    priver: [1]
#    payanter: [2]
#    quantite: [3, 10]
#    fraise: [4]
#    supergrand: [5]
#    etre: [6]
#    obstacle: [7]
#    mixte: [8]
#    social: [9]
#    subvention: [11]
#    contrat: [12]
#    plafonner: [13]
#
# Document : France (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <LOCATION>: [0]
#    Francois-Anatole_Thibault: [1]
#    lecol: [2]
#    contrat: [3]
#    gratuit: [4]
#    jusqua: [5]
#    propos: [6]
#    enseignement: [7]
#    obligatoire: [8]
#    dans: [9]
#    fraise: [10]
#    varier: [11]
#    souvent: [12]
#    exiger: [13]
#    college: [14]
#    detective: [15]
#    supergrand: [16]
#    tuyau: [17]
#    exclur: [18]
#    lacce: [19]
#    ecolier: [20]
#    phratrie: [21]
#    obtention: [22]
#    precaire: [23]
#    ecstasy: [24]
#    lencontre: [25]
#    regle: [26]
#    daccessibilite: [27]
#    viser: [28]
#    leducation: [29]
#    femme: [30]
#
# Document : Sources (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <PERSON>: [0]
#    ce: [1]
#    regle: [2]
#    partiellement: [3]
#    entierete: [4]
#    issu: [5]
#    supplement: [6]
#    <<: [7]
#    dechiffrer: [8]
#    code: [9]
#    leducation: [10]
#    gamine: [11]
#    femme: [12]
#    savoir: [13]
#    recherche_appliquee: [14]
#    ingenieri: [15]
#    mathematique: [16]
#    stem: [17]
#    >>: [18]
#    unesco: [19]
#    projet: [20]
#    endroit: [21]
#    generateur: [22]
#    responsable: [23]
#    probleme: [24]
#    sou: [25]
#    cc: [26]
#    bysa: [27]
#    igo: [28]
#
# Document : Notes et références (URL: https://fr.wikipedia.org/wiki/Éducation)
# Positions des mots :
#    <LOCATION>: [0, 2, 4, 7, 16, 17, 19, 20, 21, 22, 24, 25, 26, 28, 30, 32]
#    <PERSON>: [1, 3, 5, 6, 8, 9, 10, 11, 12, 13, 14, 15, 18, 23, 27, 29, 31, 33, 34, 35, 36]
#    |: [37, 39, 44, 54, 58, 90, 93, 101, 113, 137, 159, 209, 219, 229, 231, 246, 252, 258, 289, 314, 343, 356, 382, 408, 427, 450, 453, 463, 465, 469, 489, 494, 510, 526, 550, 566, 583, 588]
#    monde: [38]
#    forme: [40, 66, 106, 108, 454]
#    educatio: [41]
#    gaffiot: [42]
#    latinfrancer: [43]
#    mialaret: [45]
#    gramme: [46]
#    savoir: [47, 223, 434, 444]
#    formation: [48, 73, 431, 443, 451, 457, 477, 530, 537]
#    puf: [49]
#    saisje: [50]
#    no: [51, 76]
#    e: [52, 202]
#    redactrices_en_chef: [53, 75]
#    httpswwwcairninforevueletelemaque: [55]
#    supplement: [56]
#    Hypertext_Markup_Language: [57]
#    dessu: [59]
#    philipp: [60]
#    <<: [61, 162, 177, 232, 266, 344, 357, 383, 409, 515, 529, 551, 589]
#    qu': [62]
#    estce: [63]
#    enseignemer: [64]
#    quelque: [65]
#    prescription: [67]
#    >>: [68, 169, 208, 241, 280, 349, 375, 401, 420, 522, 534, 559, 595]
#    revue: [69, 523, 535, 561]
#    Daniel_Chester_French: [70, 524]
#    enseignement: [71, 516]
#    rechercher: [72]
#    ens: [74]
#    : [77]
#    ER: [78]
#    juillet: [79, 245, 355, 381, 407, 426]
#    penis: [80, 92, 100, 256, 322, 488, 541]
#    -: [81, 542]
#    isbn: [82, 446]
#    issn: [83, 543]
#    doi: [84, 287, 544]
#    rfp: [85]
#    lire: [86, 98, 135, 224, 283, 311, 447, 546]
#    ligne: [87, 129, 136, 284, 312, 448, 547]
#    consulter: [88, 175, 285, 354, 380, 406, 425, 548, 564, 581, 597]
#    novembre: [89]
#    aries: [91]
#    jeanjacque: [94]
#    rousseau: [95]
#    emil: [96]
#    leducation: [97, 105]
#    wikisource: [99]
#    pdf: [102, 567]
#    projet: [103]
#    officiel: [104]
#    femme: [107, 433, 452]
#    savoir-faire: [109]
#    methodologique: [110]
#    sociale: [111]
#    viser: [112]
#    Sarah: [114, 160]
#    currier: [115]
#    sheila: [116]
#    macneill: [117]
#    lisa: [118]
#    corley: [119]
#    lorna: [120]
#    Campbell: [121]
#    helen: [122]
#    beetham: [123]
#    dictionnaire: [124]
#    decrire: [125]
#    avancee: [126]
#    pedagogique: [127]
#    obtention: [128]
#    explorer: [130, 155]
#    cadrage: [131]
#    numero: [132, 333, 507]
#    ametist: [133, 134]
#    Benjamin: [138]
#    rougir: [139]
#    David: [140]
#    r: [141]
#    krathwohl: [142, 207]
#    the: [143, 166, 179, 193, 267, 361, 371, 386, 389, 393, 412, 415]
#    nomenclature: [144]
#    of: [145, 151, 165, 173, 192, 234, 269, 272, 363, 385, 397, 411, 504]
#    educational: [146]
#    goal: [147]
#    by: [148, 370]
#    avoir: [149, 270, 470, 496]
#    committee: [150]
#    college: [152, 253, 303, 341, 575]
#    and: [153, 185, 206, 277, 500]
#    university: [154, 172]
#    new: [156]
#    York: [157]
#    longmans: [158]
#    mcneil: [161]
#    blooms: [163, 190]
#    taxonomy: [164, 191]
#    cognitif: [167, 180, 194]
#    domain: [168, 181, 195]
#    instructional: [170]
#    design: [171]
#    houston: [174]
#    jan: [176]
#    work: [178]
#    was: [182]
#    completed: [183]
#    in: [184, 332, 347]
#    is: [186, 367]
#    commonly: [187]
#    referred: [188]
#    to: [189, 351, 377, 391, 395, 403, 417, 422]
#    although: [196]
#    there: [197]
#    were: [198]
#    other: [199]
#    authors: [200]
#    englehart: [201]
#    furst: [203]
#    w: [204]
#    hill: [205]
#    wolf: [210]
#    marcus: [211]
#    extrusion: [212]
#    math: [213]
#    estelle: [214]
#    mal: [215]
#    mental: [216]
#    ed: [217]
#    trouver: [218]
#    Marc: [220]
#    bris: [221]
#    progeniture: [222, 299, 325]
#    ...: [225]
#    ni: [226]
#    comte: [227]
#    stock: [228]
#    tiehi: [230]
#    majority: [233]
#    children: [235]
#    live: [236]
#    with: [237]
#    two: [238]
#    biological: [239]
#    parent: [240]
#    archiv: [242]
#    Avril: [243]
#    consulte: [244]
#    La_Tragedie_d'Hamlet: [247]
#    Tyndale: [248]
#    shakespeare: [249]
#    scene: [250]
#    iii: [251]
#    sain: [254]
#    comme: [255]
#    dapprentissage: [257]
#    George_du_Maurier: [259]
#    zacharopoulos: [260]
#    francesco: [261]
#    sella: [262]
#    baron: [263]
#    cohen: [264]
#    kadosh: [265]
#    impact: [268]
#    lack: [271]
#    mathematical: [273]
#    education: [274, 348, 352, 364, 378, 392, 396, 404, 418, 423]
#    brain: [275]
#    developmer: [276]
#    avenir: [278]
#    attainment: [279]
#    pnas: [281]
#    juin: [282]
#    San_Pedro_Sula: [286, 563]
#    pna: [288]
#    administration_federale: [290, 503]
#    courtier: [291]
#    special: [292, 387, 413]
#    messager_sagittaire: [293]
#    ensemble: [294]
#    voie: [295, 483]
#    proposition: [296, 329]
#    acharnement: [297, 302]
#    contre: [298]
#    venir: [300]
#    terme: [301]
#    combler: [304]
#    repartition: [305]
#    entrer: [306]
#    standard: [307]
#    pratique: [308]
#    pari: [309, 439]
#    onu: [310]
#    p: [313]
#    pierart: [315]
#    g: [316]
#    betrisey: [317]
#    tetreault: [318]
#    margotcattin: [319, 321]
#    robot: [320]
#    linclusion: [323]
#    scolaire: [324, 533]
#    defaut: [326]
#    tamias: [327]
#    romand: [328]
#    gouvernement: [330]
#    contrat: [331, 490, 574]
#    xxi: [334]
#    copulation: [335]
#    airhm: [336]
#    Quebec: [337, 342]
#    pp: [338]
#    quebec: [339]
#    imprimerie: [340]
#    defining: [345]
#    quality: [346]
#    right: [350, 376, 390, 394, 402, 416, 421]
#    initiativ: [353, 379, 405, 424]
#    contradicting: [358]
#    commitment: [359]
#    how: [360]
#    achievemer: [362]
#    for: [365]
#    all: [366]
#    being: [368]
#    undermined: [369]
#    international: [372, 536]
#    monetary: [373]
#    fund: [374]
#    report: [384, 410]
#    rapporteur: [388, 414]
#    person: [398]
#    dans: [399]
#    detention: [400]
#    post: [419]
#    unesco: [428, 462]
#    dechiffrer: [429]
#    code: [430]
#    gamine: [432]
#    recherche_appliquee: [435]
#    ingenieri: [436]
#    mathematique: [437]
#    stem: [438]
#    gerance: [440]
#    etat: [441]
#    unir: [442]
#    raffinement: [445]
#    avantpropo: [449]
#    bill: [455]
#    Dakar: [456]
#    tout: [458]
#    maintien: [459]
#    allegeance: [460]
#    collectif: [461]
#    propos: [464, 578]
#    theme: [466, 474]
#    controle: [467]
#    lept: [468]
#    b: [471]
#    tomasevski: [472]
#    k: [473]
#    annuel: [475]
#    policier: [476, 484, 491]
#    presenter: [478]
#    coutume: [479]
#    declaration: [480]
#    commerce: [481]
#    ecn: [482]
#    male: [485]
#    cinquantehuitiem: [486]
#    session: [487]
#    lenfant: [492]
#    regle: [493]
#    Jacob: [495]
#    mincer: [497]
#    schooling: [498]
#    experience: [499]
#    earning: [501]
#    national: [502]
#    economic: [505]
#    research: [506]
#    minc: [508]
#    september: [509]
#    dominiqu: [511]
#    glasman: [512]
#    Montserrat: [513]
#    bongrand: [514]
#    phratrie: [517]
#    prospection: [518]
#    sociologique: [519]
#    prodige: [520]
#    emergent: [521]
#    pedagogie: [525]
#    Bernard: [527]
#    cornu: [528]
#    segmer: [531]
#    echange: [532]
#    sevres: [538]
#    er: [539]
#    decembre: [540]
#    rie: [545]
#    Sept: [549, 565, 598]
#    webjournal: [552]
#    thomas: [553]
#    piketty: [554]
#    opinion: [555]
#    souhaiteil: [556]
#    mixte: [557, 593]
#    social: [558, 594]
#    blog: [560]
#    cosmos: [562]
#    jeanfrancois: [568]
#    landry: [569]
#    federation: [570]
#    autonome: [571]
#    lenseignemer: [572, 590]
#    appui: [573]
#    detective: [576]
#    rassembler: [577]
#    Myth: [579]
#    Octobre: [580]
#    may: [582]
#    arnaud: [584]
#    parienty: [585]
#    school: [586]
#    clientele: [587]
#    priver: [591]
#    obstacle: [592]
#    cafepedagogiquenet: [596]

# %% [markdown]
# **{mot: {nom_document: [positions]}}**

# %%
# fonction pour créer un dictionnaire {mot: {nom_document: [positions]}}
def creer_dictionnaire_positions_par_mot(processed_documents):
    dictionnaire_positions = {}

    # parcourir chaque document traité
    for doc in processed_documents:
        title = doc['title']
        tokens = doc['tokens']

        # parcourir chaque token avec son index dans le document
        for index, token in enumerate(tokens):
            # Si le mot (token) n'est pas encore dans le dictionnaire, on l'ajoute
            if token not in dictionnaire_positions:
                dictionnaire_positions[token] = {}

            # Si le document courant n'est pas encore associé à ce mot, on l'ajoute
            if title not in dictionnaire_positions[token]:
                dictionnaire_positions[token][title] = []

            # ajouter la position du mot dans la liste des positions pour ce document
            dictionnaire_positions[token][title].append(index)

    return dictionnaire_positions

# créer le dictionnaire des positions par mot à partir des documents prétraités
dictionnaire_positions = creer_dictionnaire_positions_par_mot(processed_documents)

# afficher le dictionnaire des positions par mot
print("Dictionnaire des positions par mot :")
for mot, documents in dictionnaire_positions.items():
    print(f"\nMot : {mot}")
    for doc, positions in documents.items():
        print(f"  Document : {doc}")
        print(f"    Positions : {positions}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Mot : generalise
#   Document : Paléolithique
#     Positions : [158]
#
# Mot : Burin
#   Document : Paléolithique
#     Positions : [163]
#
# Mot : scrapeur
#   Document : Paléolithique
#     Positions : [164]
#
# Mot : middle
#   Document : Paléolithique
#     Positions : [171]
#   Document : Références
#     Positions : [376]
#
# Mot : ston
#   Document : Paléolithique
#     Positions : [172]
#
# Mot : retoucher
#   Document : Paléolithique
#     Positions : [177]
#
# Mot : laurier_sauce
#   Document : Paléolithique
#     Positions : [183]
#
# Mot : exact
#   Document : Paléolithique
#     Positions : [12]
#
# Mot : inconnu
#   Document : Paléolithique
#     Positions : [14]
#
# Mot : do
#   Document : Paléolithique
#     Positions : [16]
#
# Mot : danimau
#   Document : Paléolithique
#     Positions : [17]
#
# Mot : brule
#   Document : Paléolithique
#     Positions : [18]
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [69]
#
# Mot : cradle
#   Document : Paléolithique
#     Positions : [20]
#
# Mot : humankind
#   Document : Paléolithique
#     Positions : [22]
#
# Mot : cinquantaine
#   Document : Paléolithique
#     Positions : [23]
#
# Mot : johannesburg
#   Document : Paléolithique
#     Positions : [26]
#
# Mot : sugger
#   Document : Paléolithique
#     Positions : [27]
#
# Mot : domestication
#   Document : Paléolithique
#     Positions : [28]
#
# Mot : unanime
#   Document : Paléolithique
#     Positions : [40]
#
# Mot : erectu
#   Document : Paléolithique
#     Positions : [43]
#
# Mot : alentours
#   Document : Paléolithique
#     Positions : [47]
#
# Mot : alimenter
#   Document : Paléolithique
#     Positions : [51]
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [72]
#
# Mot : digestibilite
#   Document : Paléolithique
#     Positions : [62]
#
# Mot : nutritif
#   Document : Paléolithique
#     Positions : [66]
#
# Mot : avancee
#   Document : Paléolithique
#     Positions : [1]
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [17]
#   Document : Critiques
#     Positions : [111]
#   Document : Notes et références
#     Positions : [126]
#
# Mot : apparu
#   Document : Paléolithique
#     Positions : [8]
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [41]
#
# Mot : habillement
#   Document : Paléolithique
#     Positions : [9, 27]
#   Document : Éducation familiale
#     Positions : [87]
#
# Mot : lhabitation
#   Document : Paléolithique
#     Positions : [10]
#
# Mot : exactement
#   Document : Paléolithique
#     Positions : [17]
#
# Mot : adapter
#   Document : Paléolithique
#     Positions : [28]
#   Document : Savoir, savoir-faire, savoir-être
#     Positions : [6, 33]
#   Document : Éducation formelle et éducation non formelle en France
#     Positions : [70]
#   Document : Systèmes éducatifs
#     Positions : [11]
#
# Mot : barbe_de_trois_jours
#   Document : Paléolithique
#     Positions : [29]
#
# Mot : indifferemmer
#   Document : Paléolithique
#     Positions : [38]
#
# Mot : lascension
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [0]
#
# Mot : linvention
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [13]
#   Document : Sens originel
#     Positions : [19]
#   Document : Sens dérivés
#     Positions : [1]
#   Document : Bibliographie
#     Positions : [13]
#
# Mot : hache
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [14]
#
# Mot : culture
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [16]
#
# Mot : defrichement
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [22]
#
# Mot : future
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [28]
#
# Mot : sedentaire
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [45]
#
# Mot : simultanement
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [51]
#
# Mot : navaient
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [56]
#
# Mot : ceter
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [62]
#
# Mot : nomade
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [66]
#   Document : Interprétation du droit à l'éducation
#     Positions : [83]
#
# Mot : chasseurcueilleur
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [78]
#
# Mot : clarifier
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [12]
#
# Mot : uruk
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [22]
#
# Mot : Shumer
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [28]
#
# Mot : hierarchique
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [36]
#
# Mot : adjacent
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [43]
#
# Mot : surmonter
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [47]
#
# Mot : turcie
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [52]
#   Document : Autres espèces animales
#     Positions : [10]
#   Document : Références
#     Positions : [864]
#
# Mot : barrage
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [53]
#
# Mot : continuel
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [3]
#
# Mot : ulterieurement
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [5]
#
# Mot : ventilation
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [8]
#
# Mot : forger
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [13]
#
# Mot : metal
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [15, 26, 77, 81]
#
# Mot : largent
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [31]
#   Document : Marché éducatif
#     Positions : [3]
#
# Mot : plomb
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [32]
#
# Mot : probablement
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [45]
#
# Mot : naturellement
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [57]
#
# Mot : quantique
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [59]
#
# Mot : minerai
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [63]
#
# Mot : transforme
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [65]
#
# Mot : facilement
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [67]
#
# Mot : finira
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [78]
#
# Mot : dalliage
#   Document : Du Néolithique à l'Antiquité classique
#     Positions : [90]
#
# Mot : progres
#   Document : Époque contemporaine
#     Positions : [2]
#
# Mot : persister
#   Document : Époque contemporaine
#     Positions : [14]
#
# Mot : commission
#   Document : Époque contemporaine
#     Positions : [21]
#   Document : Savoir, savoir-faire, savoir-être
#     Positions : [29]
#
# Mot : stem
#   Document : Époque contemporaine
#     Positions : [34, 38]
#   Document : Notes
#     Positions : [17]
#   Document : Références
#     Positions : [602]
#   Document : Droit à l'éducation
#     Positions : [11]
#   Document : Sources
#     Positions : [17]
#   Document : Notes et références
#     Positions : [438]
#
# Mot : quitter
#   Document : Époque contemporaine
#     Positions : [36]
#
# Mot : disproportionner
#   Document : Époque contemporaine
#     Positions : [40]
#
# Mot : constater
#   Document : Époque contemporaine
#     Positions : [4, 25, 40]
#
# Mot : garcon
#   Document : Époque contemporaine
#     Positions : [8, 26, 48]
#
# Mot : ambitieux
#   Document : Époque contemporaine
#     Positions : [14]
#
# Mot : adolescent
#   Document : Époque contemporaine
#     Positions : [19]
#   Document : Enjeux
#     Positions : [5]
#
# Mot : ameriqu
#   Document : Époque contemporaine
#     Positions : [21]
#
# Mot : enclin
#   Document : Époque contemporaine
#     Positions : [30]
#
# Mot : valoriser
#   Document : Époque contemporaine
#     Positions : [32]
#
# Mot : estimateur
#   Document : Époque contemporaine
#     Positions : [36]
#   Document : Liens externes
#     Positions : [0, 4]
#
# Mot : option
#   Document : Époque contemporaine
#     Positions : [41]
#   Document : Les objectifs de l'Éducation pour Tous
#     Positions : [34]
#   Document : Interprétation du droit à l'éducation
#     Positions : [26]
#   Document : Marché éducatif
#     Positions : [34, 8]
#
# Mot : interagir
#   Document : Époque contemporaine
#     Positions : [42]
#
# Mot : immuable
#   Document : Sens originel
#     Positions : [12]
#
# Mot : perpetuel
#   Document : Sens originel
#     Positions : [17]
#
# Mot : intrinseque
#   Document : Sens originel
#     Positions : [39]
#
# Mot : apparue
#   Document : Sens dérivés
#     Positions : [3]
#
# Mot : lutilisation
#   Document : Autres espèces animales
#     Positions : [0, 1]
#
# Mot : prototechnologie
#   Document : Autres espèces animales
#     Positions : [1]
#
# Mot : pan_troglodytes
#   Document : Autres espèces animales
#     Positions : [21, 29, 48]
#   Document : Références
#     Positions : [720]
#
# Mot : hierarque
#   Document : Autres espèces animales
#     Positions : [23]
#   Document : Références
#     Positions : [815]
#
# Mot : dauphin
#   Document : Autres espèces animales
#     Positions : [24]
#   Document : Références
#     Positions : [730]
#
# Mot : corneille
#   Document : Autres espèces animales
#     Positions : [25]
#
# Mot : ereme
#   Document : Autres espèces animales
#     Positions : [30]
#   Document : Références
#     Positions : [768]
#
# Mot : pilon
#   Document : Autres espèces animales
#     Positions : [36]
#
# Mot : acheter
#   Document : Autres espèces animales
#     Positions : [37]
#
# Mot : lecorce
#   Document : Autres espèces animales
#     Positions : [42]
#
# Mot : Liane
#   Document : Autres espèces animales
#     Positions : [43]
#
# Mot : attraper
#   Document : Autres espèces animales
#     Positions : [46]
#
# Mot : isoptera
#   Document : Autres espèces animales
#     Positions : [47]
#
# Mot : utilisent
#   Document : Autres espèces animales
#     Positions : [51]
#   Document : Références
#     Positions : [731]
#
# Mot : marteau_de_president
#   Document : Autres espèces animales
#     Positions : [52]
#
# Mot : enclume
#   Document : Autres espèces animales
#     Positions : [53]
#
# Mot : jailbreak
#   Document : Autres espèces animales
#     Positions : [55]
#
# Mot : sapajou
#   Document : Autres espèces animales
#     Positions : [59]
#
# Mot : boa
#   Document : Autres espèces animales
#     Positions : [60]
#
# Mot : vista
#   Document : Autres espèces animales
#     Positions : [61]
#
# Mot : haut-de-forme
#   Document : Autres espèces animales
#     Positions : [11]
#   Document : Références
#     Positions : [865]
#
# Mot : construit
#   Document : Autres espèces animales
#     Positions : [12]
#
# Mot : partiellement
#   Document : Notes
#     Positions : [3]
#   Document : Systèmes éducatifs
#     Positions : [35]
#   Document : Sources
#     Positions : [3]
#
# Mot : ingenieri
#   Document : Notes
#     Positions : [15]
#   Document : Références
#     Positions : [600]
#   Document : Sources
#     Positions : [15]
#   Document : Notes et références
#     Positions : [436]
#
# Mot : probleme
#   Document : Notes
#     Positions : [24]
#   Document : Sources
#     Positions : [24]
#
# Mot : cc
#   Document : Notes
#     Positions : [26]
#   Document : Sources
#     Positions : [26]
#
# Mot : igo
#   Document : Notes
#     Positions : [28]
#   Document : Sources
#     Positions : [28]
#
# Mot : asma
#   Document : Références
#     Positions : [41]
#
# Mot : mhalla
#   Document : Références
#     Positions : [42]
#
# Mot : technopolitiqu
#   Document : Références
#     Positions : [44]
#
# Mot : armee
#   Document : Références
#     Positions : [48]
#
# Mot : wwwseuilcom
#   Document : Références
#     Positions : [50]
#
# Mot : textuel
#   Document : Références
#     Positions : [62]
#
# Mot : lexical
#   Document : Références
#     Positions : [63]
#   Document : Taxonomie de Robert Mills Gagné
#     Positions : [4, 3, 17, 2]
#
# Mot : georg
#   Document : Références
#     Positions : [66]
#
# Mot : elli
#   Document : Références
#     Positions : [67]
#
# Mot : memoir
#   Document : Références
#     Positions : [68]
#   Document : Liens externes
#     Positions : [13]
#
# Mot : cambridge
#   Document : Références
#     Positions : [72, 789, 791]
#
# Mot : mas
#   Document : Références
#     Positions : [73]
#
# Mot : wilson
#   Document : Références
#     Positions : [75]
#
# Mot : divinity
#   Document : Références
#     Positions : [85]
#   Document : Bibliographie
#     Positions : [65]
#
# Mot : spirit
#   Document : Références
#     Positions : [90]
#   Document : Bibliographie
#     Positions : [70]
#
# Mot : penguin
#   Document : Références
#     Positions : [95]
#   Document : Bibliographie
#     Positions : [75]
#
# Mot : book
#   Document : Références
#     Positions : [96]
#   Document : Bibliographie
#     Positions : [76]
#
# Mot : jacque
#   Document : Références
#     Positions : [98]
#
# Mot : lerobertcom
#   Document : Références
#     Positions : [107]
#
# Mot : mother
#   Document : Références
#     Positions : [112]
#
# Mot : year
#   Document : Références
#     Positions : [117]
#
# Mot : ago
#   Document : Références
#     Positions : [118, 268]
#
# Mot : bbc
#   Document : Références
#     Positions : [120, 169, 738]
#
# Mot : human
#   Document : Références
#     Positions : [125, 152, 309, 428, 437, 485]
#
# Mot : evolution
#   Document : Références
#     Positions : [126, 232]
#
# Mot : history
#   Document : Références
#     Positions : [128, 326, 353, 359, 535, 552]
#   Document : Liens externes
#     Positions : [21, 0, 38, 56, 14, 32]
#
# Mot : channel
#   Document : Références
#     Positions : [129]
#
# Mot : Wade
#   Document : Références
#     Positions : [133]
#
# Mot : nicholas
#   Document : Références
#     Positions : [134]
#
# Mot : early
#   Document : Références
#     Positions : [136, 259, 285, 427]
#
# Mot : voice
#   Document : Références
#     Positions : [137]
#
# Mot : leap
#   Document : Références
#     Positions : [139]
#
# Mot : language
#   Document : Références
#     Positions : [141]
#
# Mot : time
#   Document : Références
#     Positions : [146]
#
# Mot : ancestors
#   Document : Références
#     Positions : [153]
#
# Mot : antichambre
#   Document : Références
#     Positions : [154]
#
# Mot : smithsonian
#   Document : Références
#     Positions : [158]
#
# Mot : ancient
#   Document : Références
#     Positions : [164, 534]
#
# Mot : tool
#   Document : Références
#     Positions : [165, 262, 747, 849]
#
# Mot : factory
#   Document : Références
#     Positions : [166]
#
# Mot : uncovered
#   Document : Références
#     Positions : [167]
#
# Mot : heinzelin
#   Document : Références
#     Positions : [176]
#
# Mot : jd
#   Document : Références
#     Positions : [177]
#
# Mot : clark
#   Document : Références
#     Positions : [178]
#
# Mot : white
#   Document : Références
#     Positions : [179]
#
# Mot : hart
#   Document : Références
#     Positions : [181]
#
# Mot : woldegabriel
#   Document : Références
#     Positions : [185]
#
# Mot : beyene
#   Document : Références
#     Positions : [186]
#
# Mot : vrber
#   Document : Références
#     Positions : [188]
#
# Mot : environment
#   Document : Références
#     Positions : [190]
#
# Mot : behavior
#   Document : Références
#     Positions : [192]
#
# Mot : millionyearold
#   Document : Références
#     Positions : [194]
#
# Mot : bouri
#   Document : Références
#     Positions : [195]
#
# Mot : hominid
#   Document : Références
#     Positions : [196, 260, 339, 368, 396]
#
# Mot : pmid
#   Document : Références
#     Positions : [205, 443, 776]
#
# Mot : pherron
#   Document : Références
#     Positions : [210]
#
# Mot : CV
#   Document : Références
#     Positions : [213]
#
# Mot : hominidescom
#   Document : Références
#     Positions : [216]
#
# Mot : australopithecus
#   Document : Références
#     Positions : [217]
#
# Mot : utilisaientil
#   Document : Références
#     Positions : [218]
#
# Mot : plummer
#   Document : Références
#     Positions : [222]
#
# Mot : flaked
#   Document : Références
#     Positions : [224]
#
# Mot : stone
#   Document : Références
#     Positions : [225, 261, 355]
#
# Mot : old
#   Document : Références
#     Positions : [227]
#
# Mot : bone
#   Document : Références
#     Positions : [228]
#
# Mot : biological
#   Document : Références
#     Positions : [229]
#   Document : Notes et références
#     Positions : [239]
#
# Mot : cultural
#   Document : Références
#     Positions : [231, 306, 512]
#
# Mot : dawn
#   Document : Références
#     Positions : [235]
#
# Mot : yearbook
#   Document : Références
#     Positions : [239]
#
# Mot : physical
#   Document : Références
#     Positions : [241]
#
# Mot : anthropology
#   Document : Références
#     Positions : [242, 307, 380, 403, 492, 513]
#
# Mot : delagne
#   Document : Références
#     Positions : [248]
#
# Mot : brugal
#   Document : Références
#     Positions : [250]
#
# Mot : jp
#   Document : Références
#     Positions : [251]
#
# Mot : feibel
#   Document : Références
#     Positions : [252]
#
# Mot : kibunjia
#   Document : Références
#     Positions : [253]
#
# Mot : mourre
#   Document : Références
#     Positions : [254, 278]
#
# Mot : v
#   Document : Références
#     Positions : [255, 279]
#
# Mot : texier
#   Document : Références
#     Positions : [256]
#
# Mot : pj
#   Document : Références
#     Positions : [257]
#
# Mot : technical
#   Document : Références
#     Positions : [265]
#
# Mot : skill
#   Document : Références
#     Positions : [266]
#
# Mot : myr
#   Document : Références
#     Positions : [267]
#
# Mot : west
#   Document : Références
#     Positions : [270]
#   Document : Liens externes
#     Positions : [59, 35]
#
# Mot : turkana
#   Document : Références
#     Positions : [271]
#
# Mot : Kenya
#   Document : Références
#     Positions : [272]
#
# Mot : viller
#   Document : Références
#     Positions : [280]
#
# Mot : henshilwood
#   Document : Références
#     Positions : [282]
#
# Mot : cs
#   Document : Références
#     Positions : [283]
#
# Mot : pressure
#   Document : Références
#     Positions : [288]
#
# Mot : flaking
#   Document : Références
#     Positions : [289]
#
# Mot : lithic
#   Document : Références
#     Positions : [290]
#
# Mot : artifact
#   Document : Références
#     Positions : [291]
#
# Mot : blombo
#   Document : Références
#     Positions : [293]
#
# Mot : oenotheque
#   Document : Références
#     Positions : [294]
#
# Mot : south
#   Document : Références
#     Positions : [295, 417]
#
# Mot : africa
#   Document : Références
#     Positions : [296]
#
# Mot : haviland
#   Document : Références
#     Positions : [303]
#
# Mot : Tyndale
#   Document : Références
#     Positions : [304]
#   Document : Éducation familiale
#     Positions : [8]
#   Document : Notes et références
#     Positions : [248]
#
# Mot : challeng
#   Document : Références
#     Positions : [310]
#
# Mot : thomson
#   Document : Références
#     Positions : [313, 520]
#
# Mot : crump
#   Document : Références
#     Positions : [323]
#
# Mot : brief
#   Document : Références
#     Positions : [325]
#
# Mot : constabl
#   Document : Références
#     Positions : [330]
#
# Mot : fossil
#   Document : Références
#     Positions : [338]
#
# Mot : sterkfontein
#   Document : Références
#     Positions : [342]
#
# Mot : swartkrans
#   Document : Références
#     Positions : [343]
#
# Mot : kromdraai
#   Document : Références
#     Positions : [344]
#
# Mot : steven
#   Document : Références
#     Positions : [364]
#
# Mot : jame
#   Document : Références
#     Positions : [366]
#
# Mot : fire
#   Document : Références
#     Positions : [371, 400]
#
# Mot : lower
#   Document : Références
#     Positions : [374]
#
# Mot : pleistocene
#   Document : Références
#     Positions : [377]
#
# Mot : current
#   Document : Références
#     Positions : [379, 402, 491]
#
# Mot : payer
#   Document : Références
#     Positions : [390, 412]
#   Document : Éducation formelle et éducation non formelle en France
#     Positions : [22]
#   Document : Marché éducatif
#     Positions : [35, 19]
#
# Mot : stahl
#   Document : Références
#     Positions : [394]
#
# Mot : dietary
#   Document : Références
#     Positions : [397]
#
# Mot : selection
#   Document : Références
#     Positions : [398]
#
# Mot : before
#   Document : Références
#     Positions : [399]
#
# Mot : richard
#   Document : Références
#     Positions : [414, 716]
#
# Mot : cordal
#   Document : Références
#     Positions : [415]
#
# Mot : asia
#   Document : Références
#     Positions : [418]
#
# Mot : andamanese
#   Document : Références
#     Positions : [420]
#
# Mot : genetic
#   Document : Références
#     Positions : [423, 438]
#
# Mot : dispersal
#   Document : Références
#     Positions : [429]
#
# Mot : out
#   Document : Références
#     Positions : [430]
#
# Mot : africer
#   Document : Références
#     Positions : [432]
#
# Mot : american
#   Document : Références
#     Positions : [434]
#
# Mot : pmcid
#   Document : Références
#     Positions : [444]
#
# Mot : skeletal
#   Document : Références
#     Positions : [455]
#
# Mot : show
#   Document : Références
#     Positions : [457]
#
# Mot : abrupt
#   Document : Références
#     Positions : [458]
#
# Mot : worldwid
#   Document : Références
#     Positions : [459]
#
# Mot : increase
#   Document : Références
#     Positions : [460, 483]
#
# Mot : birth
#   Document : Références
#     Positions : [462]
#
# Mot : during
#   Document : Références
#     Positions : [464, 487]
#
# Mot : neolithic
#   Document : Références
#     Positions : [465, 489]
#
# Mot : period
#   Document : Références
#     Positions : [466]
#
# Mot : daily
#   Document : Références
#     Positions : [469]
#
# Mot : sussman
#   Document : Références
#     Positions : [474]
#
# Mot : child
#   Document : Références
#     Positions : [478]
#
# Mot : size
#   Document : Références
#     Positions : [481]
#
# Mot : university
#   Document : Références
#     Positions : [493, 558]
#   Document : Notes et références
#     Positions : [154, 172]
#
# Mot : Lincoln_Park
#   Document : Références
#     Positions : [495]
#
# Mot : ferraro
#   Document : Références
#     Positions : [509]
#
# Mot : Gary
#   Document : Références
#     Positions : [510]
#   Document : Investir dans l'éducation
#     Positions : [5]
#
# Mot : applied
#   Document : Références
#     Positions : [515]
#
# Mot : perspectif
#   Document : Références
#     Positions : [516]
#
# Mot : belmont
#   Document : Références
#     Positions : [517]
#
# Mot : calif
#   Document : Références
#     Positions : [518]
#
# Mot : patterson
#   Document : Références
#     Positions : [529]
#
# Mot : gordon
#   Document : Références
#     Positions : [530]
#
# Mot : essentials
#   Document : Références
#     Positions : [532]
#
# Mot : piscataway
#   Document : Références
#     Positions : [536]
#
# Mot : research
#   Document : Références
#     Positions : [537, 678]
#   Document : Notes et références
#     Positions : [506]
#
# Mot : education
#   Document : Références
#     Positions : [538, 629, 655]
#   Document : Notes et références
#     Positions : [274, 348, 352, 364, 378, 392, 396, 404, 418, 423]
#   Document : Liens externes
#     Positions : [76]
#
# Mot : alan
#   Document : Références
#     Positions : [546]
#
# Mot : cramb
#   Document : Références
#     Positions : [548]
#
# Mot : short
#   Document : Références
#     Positions : [551]
#
# Mot : metals
#   Document : Références
#     Positions : [554]
#
# Mot : carnegie
#   Document : Références
#     Positions : [556]
#
# Mot : mellon
#   Document : Références
#     Positions : [557]
#
# Mot : hugh
#   Document : Références
#     Positions : [562]
#
# Mot : chisholm
#   Document : Références
#     Positions : [563]
#
# Mot : britannicer
#   Document : Références
#     Positions : [565]
#   Document : Liens externes
#     Positions : [2, 3]
#
# Mot : skills
#   Document : Références
#     Positions : [571]
#
# Mot : digital
#   Document : Références
#     Positions : [574, 578]
#
# Mot : papers
#   Document : Références
#     Positions : [580]
#
# Mot : jlwz
#   Document : Références
#     Positions : [584]
#
# Mot : wnwen
#   Document : Références
#     Positions : [586]
#
# Mot : vaino
#   Document : Références
#     Positions : [610, 611, 635, 636]
#
# Mot : rannikmae
#   Document : Références
#     Positions : [613, 638]
#
# Mot : holbrook
#   Document : Références
#     Positions : [614, 640]
#
# Mot : factors
#   Document : Références
#     Positions : [616, 642]
#
# Mot : explaining
#   Document : Références
#     Positions : [617, 643]
#
# Mot : gymnasium
#   Document : Références
#     Positions : [618, 644]
#
# Mot : students'
#   Document : Références
#     Positions : [619, 645]
#
# Mot : related
#   Document : Références
#     Positions : [621, 647]
#
# Mot : career
#   Document : Références
#     Positions : [622, 648]
#
# Mot : pp
#   Document : Références
#     Positions : [659]
#   Document : Notes et références
#     Positions : [338]
#
# Mot : swarat
#   Document : Références
#     Positions : [661]
#
# Mot : ortony
#   Document : Références
#     Positions : [662]
#
# Mot : revell
#   Document : Références
#     Positions : [664]
#
# Mot : activity
#   Document : Références
#     Positions : [667]
#
# Mot : understanding
#   Document : Références
#     Positions : [669]
#
# Mot : studer
#   Document : Références
#     Positions : [670]
#
# Mot : interest
#   Document : Références
#     Positions : [671]
#
# Mot : teaching
#   Document : Références
#     Positions : [681]
#
# Mot : tea
#   Document : Références
#     Positions : [687]
#
# Mot : oakley
#   Document : Références
#     Positions : [691]
#
# Mot : toolmaker
#   Document : Références
#     Positions : [695]
#
# Mot : bibcode
#   Document : Références
#     Positions : [706, 779]
#
# Mot : natur
#   Document : Références
#     Positions : [707]
#
# Mot : carl
#   Document : Références
#     Positions : [712]
#
# Mot : druyan
#   Document : Références
#     Positions : [713]
#
# Mot : leakey
#   Document : Références
#     Positions : [715]
#
# Mot : rincon
#   Document : Références
#     Positions : [728]
#
# Mot : apprise
#   Document : Références
#     Positions : [733]
#
# Mot : crow
#   Document : Références
#     Positions : [745]
#
# Mot : find
#   Document : Références
#     Positions : [749, 846]
#
# Mot : nbc
#   Document : Références
#     Positions : [752]
#
# Mot : rutz
#   Document : Références
#     Positions : [758]
#
# Mot : weir
#   Document : Références
#     Positions : [760]
#
# Mot : kacelnik
#   Document : Références
#     Positions : [762]
#
# Mot : camera
#   Document : Références
#     Positions : [765]
#
# Mot : mcgrew
#   Document : Références
#     Positions : [785]
#
# Mot : chimpanzee
#   Document : Références
#     Positions : [786]
#
# Mot : material
#   Document : Références
#     Positions : [787]
#
# Mot : ua
#   Document : Références
#     Positions : [790]
#
# Mot : univ
#   Document : Références
#     Positions : [792]
#
# Mot : Christophe
#   Document : Références
#     Positions : [796]
#
# Mot : boesch
#   Document : Références
#     Positions : [797, 799]
#
# Mot : hedwige
#   Document : Références
#     Positions : [798]
#
# Mot : map
#   Document : Références
#     Positions : [802]
#
# Mot : wild
#   Document : Références
#     Positions : [804]
#
# Mot : chimpanzees
#   Document : Références
#     Positions : [805]
#
# Mot : an
#   Document : Références
#     Positions : [806]
#
# Mot : analysis
#   Document : Références
#     Positions : [807]
#
# Mot : hammer
#   Document : Références
#     Positions : [809]
#
# Mot : transport
#   Document : Références
#     Positions : [810]
#
# Mot : nut
#   Document : Références
#     Positions : [812]
#
# Mot : cracking
#   Document : Références
#     Positions : [813]
#
# Mot : bf
#   Document : Références
#     Positions : [825]
#
# Mot : vi
#   Document : Références
#     Positions : [831]
#
# Mot : dolozi
#   Document : Références
#     Positions : [834, 837]
#
# Mot : authorfullname
#   Document : Références
#     Positions : [842]
#
# Mot : nutcracking
#   Document : Références
#     Positions : [844]
#
# Mot : monkeys
#   Document : Références
#     Positions : [845]
#
# Mot : right
#   Document : Références
#     Positions : [848]
#   Document : Notes et références
#     Positions : [350, 376, 390, 394, 402, 416, 421]
#
# Mot : scientist
#   Document : Références
#     Positions : [855]
#
# Mot : muller
#   Document : Références
#     Positions : [860]
#
# Mot : watling
#   Document : Références
#     Positions : [861]
#
# Mot : Salto_del_Angel
#   Document : Références
#     Positions : [863]
#   Document : Liens externes
#     Positions : [9, 11]
#
# Mot : river
#   Document : Références
#     Positions : [875]
#
# Mot : flow
#   Document : Références
#     Positions : [876]
#
# Mot : eighth
#   Document : Références
#     Positions : [877]
#
# Mot : conference
#   Document : Références
#     Positions : [879]
#
# Mot : hydraulics
#   Document : Références
#     Positions : [881]
#
# Mot : wiktionnairetechnologie
#   Document : Voir aussi
#     Positions : [1]
#
# Mot : wikibookstechnologie
#   Document : Voir aussi
#     Positions : [2]
#
# Mot : gilbert
#   Document : Bibliographie
#     Positions : [11]
#
# Mot : simondon
#   Document : Bibliographie
#     Positions : [12]
#
# Mot : ane
#   Document : Bibliographie
#     Positions : [18, 30]
#
# Mot : mach
#   Document : Bibliographie
#     Positions : [19]
#
# Mot : vuibert
#   Document : Bibliographie
#     Positions : [25]
#
# Mot : lhumain
#   Document : Bibliographie
#     Positions : [32]
#
# Mot : lharmattan
#   Document : Bibliographie
#     Positions : [36, 46]
#
# Mot : philosophique
#   Document : Bibliographie
#     Positions : [40, 15]
#
# Mot : lasfargu
#   Document : Bibliographie
#     Positions : [48]
#
# Mot : halte
#   Document : Bibliographie
#     Positions : [49]
#
# Mot : ridiculite
#   Document : Bibliographie
#     Positions : [50]
#
# Mot : dorganisation
#   Document : Bibliographie
#     Positions : [54]
#
# Mot : jarrige
#   Document : Bibliographie
#     Positions : [83]
#
# Mot : dompter
#   Document : Bibliographie
#     Positions : [84]
#
# Mot : promether
#   Document : Bibliographie
#     Positions : [85]
#
# Mot : technologier
#   Document : Bibliographie
#     Positions : [86]
#
# Mot : franchecomte
#   Document : Bibliographie
#     Positions : [93]
#
# Mot : bookspufc
#   Document : Bibliographie
#     Positions : [98]
#
# Mot : neoluddisme
#   Document : Articles connexes
#     Positions : [16]
#
# Mot : standardisation
#   Document : Articles connexes
#     Positions : [17]
#
# Mot : norm
#   Document : Articles connexes
#     Positions : [21, 3]
#
# Mot : roberval
#   Document : Articles connexes
#     Positions : [27]
#
# Mot : revival
#   Document : Articles connexes
#     Positions : [31]
#
# Mot : technocritiqu
#   Document : Articles connexes
#     Positions : [35]
#
# Mot : modern
#   Document : Liens externes
#     Positions : [23, 2]
#
# Mot : biomedicine
#   Document : Liens externes
#     Positions : [24, 3]
#
# Mot : encyclopedier
#   Document : Liens externes
#     Positions : [32, 1, 13, 1]
#
# Mot : catalana
#   Document : Liens externes
#     Positions : [50, 12, 49, 25]
#
# Mot : store
#   Document : Liens externes
#     Positions : [51, 13]
#
# Mot : treccani
#   Document : Liens externes
#     Positions : [54, 16]
#
# Mot : informatiser
#   Document : Liens externes
#     Positions : [59]
#
# Mot : securite-incendie
#   Document : Liens externes
#     Positions : [60, 72]
#
# Mot : lagora
#   Document : Liens externes
#     Positions : [63, 75, 89]
#
# Mot : lintroducteur
#   Document : Liens externes
#     Positions : [66, 81]
#
# Mot : millenarism
#   Document : Liens externes
#     Positions : [73]
#
# Mot : incoherence
#   Document : Liens externes
#     Positions : [87]
#
# Mot : litterature
#   Document : Liens externes
#     Positions : [90]
#
# Mot : commentaire
#   Document : Liens externes
#     Positions : [91]
#
# Mot : puech
#   Document : Liens externes
#     Positions : [96]
#
# Mot : affichage
#   Document : Liens externes
#     Positions : [0, 3]
#
# Mot : ecran
#   Document : Liens externes
#     Positions : [2]
#
# Mot : autostereoscopie
#   Document : Liens externes
#     Positions : [6]
#
# Mot : diode
#   Document : Liens externes
#     Positions : [7]
#
# Mot : electroluminescent
#   Document : Liens externes
#     Positions : [8]
#
# Mot : engrais_organique
#   Document : Liens externes
#     Positions : [9]
#
# Mot : lentill
#   Document : Liens externes
#     Positions : [10]
#
# Mot : verres_de_contact
#   Document : Liens externes
#     Positions : [11]
#   Document : Éducation familiale
#     Positions : [48]
#
# Mot : bionique
#   Document : Liens externes
#     Positions : [12]
#
# Mot : virtuel
#   Document : Liens externes
#     Positions : [14]
#
# Mot : aquaponie
#   Document : Liens externes
#     Positions : [4]
#
# Mot : hydroponie
#   Document : Liens externes
#     Positions : [7]
#
# Mot : vegetaliser
#   Document : Liens externes
#     Positions : [9]
#
# Mot : genetiquement
#   Document : Liens externes
#     Positions : [11]
#
# Mot : viand
#   Document : Liens externes
#     Positions : [13]
#
# Mot : vitro
#   Document : Liens externes
#     Positions : [15]
#
# Mot : senseur
#   Document : Liens externes
#     Positions : [1]
#
# Mot : donde
#   Document : Liens externes
#     Positions : [2]
#
# Mot : gravitationnel
#   Document : Liens externes
#     Positions : [3]
#
# Mot : ligo
#   Document : Liens externes
#     Positions : [5, 2]
#
# Mot : virgo
#   Document : Liens externes
#     Positions : [6, 3]
#
# Mot : interferometre
#   Document : Liens externes
#     Positions : [7, 9]
#
# Mot : astronomique
#   Document : Liens externes
#     Positions : [8]
#
# Mot : optique
#   Document : Liens externes
#     Positions : [10, 1, 5]
#
# Mot : interferometrie
#   Document : Liens externes
#     Positions : [13, 4]
#
# Mot : event
#   Document : Liens externes
#     Positions : [17, 8, 0]
#
# Mot : perspective
#   Document : Liens externes
#     Positions : [18, 9, 1]
#
# Mot : telescope
#   Document : Liens externes
#     Positions : [19, 10, 2]
#
# Mot : halca
#   Document : Liens externes
#     Positions : [20, 11, 3]
#
# Mot : hypertelescope
#   Document : Liens externes
#     Positions : [21, 12, 4]
#
# Mot : interferometr
#   Document : Liens externes
#     Positions : [0]
#
# Mot : pyrosequencage
#   Document : Liens externes
#     Positions : [0]
#
# Mot : sequencage
#   Document : Liens externes
#     Positions : [1, 4, 6, 9, 11]
#
# Mot : GSM
#   Document : Liens externes
#     Positions : [2, 5]
#
# Mot : ligation
#   Document : Liens externes
#     Positions : [5, 7]
#
# Mot : doligonucleotides
#   Document : Liens externes
#     Positions : [8]
#
# Mot : nanopore
#   Document : Liens externes
#     Positions : [10]
#
# Mot : semiconducteur
#   Document : Liens externes
#     Positions : [12]
#
# Mot : biophotoniqu
#   Document : Liens externes
#     Positions : [0]
#
# Mot : electrophorese
#   Document : Liens externes
#     Positions : [1, 5]
#
# Mot : capillaire
#   Document : Liens externes
#     Positions : [2, 6]
#
# Mot : spectre
#   Document : Liens externes
#     Positions : [3]
#
# Mot : SI
#   Document : Liens externes
#     Positions : [7]
#
# Mot : imagerie
#   Document : Liens externes
#     Positions : [8]
#
# Mot : moleculaire
#   Document : Liens externes
#     Positions : [9]
#
# Mot : chip
#   Document : Liens externes
#     Positions : [11]
#
# Mot : optofluidiqu
#   Document : Liens externes
#     Positions : [12]
#
# Mot : optogenetiqu
#   Document : Liens externes
#     Positions : [13]
#
# Mot : ampakine
#   Document : Liens externes
#     Positions : [0]
#
# Mot : bioimpression
#   Document : Liens externes
#     Positions : [1]
#
# Mot : biologie
#   Document : Liens externes
#     Positions : [2]
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [91]
#
# Mot : biostase
#   Document : Liens externes
#     Positions : [4]
#
# Mot : tenor
#   Document : Liens externes
#     Positions : [6]
#
# Mot : cryoconservation
#   Document : Liens externes
#     Positions : [7]
#
# Mot : cryogenisation
#   Document : Liens externes
#     Positions : [8]
#
# Mot : biomedical
#   Document : Liens externes
#     Positions : [10]
#
# Mot : genetique
#   Document : Liens externes
#     Positions : [12]
#
# Mot : hopital
#   Document : Liens externes
#     Positions : [14]
#
# Mot : interfac
#   Document : Liens externes
#     Positions : [15]
#
# Mot : neuronal
#   Document : Liens externes
#     Positions : [16]
#   Document : Articles connexes
#     Positions : [56]
#
# Mot : interference
#   Document : Liens externes
#     Positions : [18]
#
# Mot : arn
#   Document : Liens externes
#     Positions : [19]
#
# Mot : regeneratif
#   Document : Liens externes
#     Positions : [21]
#
# Mot : nanomedecin
#   Document : Liens externes
#     Positions : [22]
#
# Mot : strategie
#   Document : Liens externes
#     Positions : [25]
#
# Mot : engineered
#   Document : Liens externes
#     Positions : [27]
#
# Mot : negligibl
#   Document : Liens externes
#     Positions : [28]
#
# Mot : senescence
#   Document : Liens externes
#     Positions : [29]
#
# Mot : therapie
#   Document : Liens externes
#     Positions : [30, 32]
#
# Mot : genique
#   Document : Liens externes
#     Positions : [31]
#
# Mot : photodynamique
#   Document : Liens externes
#     Positions : [33]
#
# Mot : cristallographie
#   Document : Liens externes
#     Positions : [0, 1]
#
# Mot : seriel
#   Document : Liens externes
#     Positions : [1]
#
# Mot : femtoseconde
#   Document : Liens externes
#     Positions : [2]
#
# Mot : microfluidiqu
#   Document : Liens externes
#     Positions : [5]
#
# Mot : spectrometri
#   Document : Liens externes
#     Positions : [6, 8, 12]
#
# Mot : alpha
#   Document : Liens externes
#     Positions : [7]
#
# Mot : bic
#   Document : Liens externes
#     Positions : [10]
#
# Mot : odorat
#   Document : Liens externes
#     Positions : [2]
#
# Mot : optoelectronique
#   Document : Liens externes
#     Positions : [4]
#
# Mot : spintroniqu
#   Document : Liens externes
#     Positions : [5]
#
# Mot : plastronique
#   Document : Liens externes
#     Positions : [6]
#
# Mot : optroniqu
#   Document : Liens externes
#     Positions : [7]
#
# Mot : intelligent
#   Document : Liens externes
#     Positions : [9]
#
# Mot : atomtroniqu
#   Document : Liens externes
#     Positions : [10]
#
# Mot : cryptanalyse
#   Document : Liens externes
#     Positions : [2]
#
# Mot : ubiquitaire
#   Document : Liens externes
#     Positions : [7]
#
# Mot : neurone
#   Document : Liens externes
#     Positions : [11]
#
# Mot : cbram
#   Document : Liens externes
#     Positions : [14, 0]
#
# Mot : fram
#   Document : Liens externes
#     Positions : [15, 1]
#
# Mot : millipede
#   Document : Liens externes
#     Positions : [16, 2]
#
# Mot : mram
#   Document : Liens externes
#     Positions : [17, 3]
#
# Mot : nram
#   Document : Liens externes
#     Positions : [18, 4]
#
# Mot : pram
#   Document : Liens externes
#     Positions : [19, 5]
#
# Mot : rram
#   Document : Liens externes
#     Positions : [20, 6]
#
# Mot : xpoint
#   Document : Liens externes
#     Positions : [21, 7]
#
# Mot : ambiant
#   Document : Liens externes
#     Positions : [23, 9]
#
# Mot : cellule_nerveuse
#   Document : Liens externes
#     Positions : [1]
#
# Mot : laser
#   Document : Liens externes
#     Positions : [0, 7]
#
# Mot : spectroscopie
#   Document : Liens externes
#     Positions : [7, 10]
#
# Mot : gamma
#   Document : Liens externes
#     Positions : [13]
#
# Mot : domotiqu
#   Document : Liens externes
#     Positions : [1]
#
# Mot : exosquelette
#   Document : Liens externes
#     Positions : [2]
#
# Mot : motoriser
#   Document : Liens externes
#     Positions : [3]
#
# Mot : microrobotiqu
#   Document : Liens externes
#     Positions : [4]
#
# Mot : nanorobot
#   Document : Liens externes
#     Positions : [5]
#
# Mot : essaim
#   Document : Liens externes
#     Positions : [7]
#
# Mot : molle
#   Document : Liens externes
#     Positions : [9]
#
# Mot : cobotiqu
#   Document : Liens externes
#     Positions : [10]
#
# Mot : hyperloop
#   Document : Liens externes
#     Positions : [1]
#
# Mot : fuser
#   Document : Liens externes
#     Positions : [5]
#
# Mot : propulsion
#   Document : Liens externes
#     Positions : [6]
#
# Mot : jetpack
#   Document : Liens externes
#     Positions : [10]
#
# Mot : sustentation
#   Document : Liens externes
#     Positions : [12]
#
# Mot : magnetique
#   Document : Liens externes
#     Positions : [13]
#
# Mot : autonome
#   Document : Liens externes
#     Positions : [15]
#   Document : Notes et références
#     Positions : [571]
#
# Mot : moto
#   Document : Liens externes
#     Positions : [16]
#
# Mot : strati
#   Document : Liens externes
#     Positions : [21]
#
# Mot : spacetrain
#   Document : Liens externes
#     Positions : [22]
#
# Mot : hydrogene
#   Document : Liens externes
#     Positions : [24]
#
# Mot : ecall
#   Document : Liens externes
#     Positions : [25]
#
# Mot : httpspsychologiesavoirfrpsychologieeconomiepsychiqu
#   Document : Références
#     Positions : [1]
#
# Mot : educatio
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [8]
#   Document : Notes et références
#     Positions : [41]
#
# Mot : spin-off
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [11]
#
# Mot : exducere
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [12]
#
# Mot : ducere
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [13]
#
# Mot : guider
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [16]
#
# Mot : ex-mari
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [18]
#   Document : Marché éducatif
#     Positions : [23]
#
# Mot : convier
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [29]
#
# Mot : noter
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [31]
#
# Mot : pointer
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [33]
#
# Mot : mialaret
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [34, 61]
#   Document : Notes et références
#     Positions : [45]
#
# Mot : etymologie
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [37]
#
# Mot : educare
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [38]
#
# Mot : aliment
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [39]
#   Document : Éducation familiale
#     Positions : [35]
#
# Mot : educere
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [40]
#
# Mot : saisir
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [42]
#
# Mot : instance
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [44]
#
# Mot : notion
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [46]
#   Document : Taxonomie de Robert Mills Gagné
#     Positions : [9]
#   Document : Construire son savoir
#     Positions : [30]
#   Document : Critiques
#     Positions : [0, 0]
#   Document : Éducation formelle et éducation non formelle en France
#     Positions : [1]
#
# Mot : deducation
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [47, 27, 45, 82]
#   Document : Éducation formelle et éducation non formelle en France
#     Positions : [12, 17, 3]
#   Document : Éducation familiale
#     Positions : [16]
#   Document : Systèmes éducatifs
#     Positions : [3]
#   Document : Enjeux
#     Positions : [51, 1]
#   Document : Droit à l'éducation
#     Positions : [13]
#   Document : Articles connexes
#     Positions : [41]
#
# Mot : conciliation
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [49]
#
# Mot : problematique
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [50]
#
# Mot : nourrirremplir
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [53]
#
# Mot : maximiser
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [57]
#
# Mot : methodique
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [67]
#
# Mot : enseigner
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [71]
#   Document : Inclusion scolaire
#     Positions : [36]
#
# Mot : transmettre
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [73]
#   Document : Éducation formelle et éducation non formelle en France
#     Positions : [84, 56]
#   Document : Éducation familiale
#     Positions : [12]
#   Document : Investir dans l'éducation
#     Positions : [17]
#
# Mot : corpus
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [76]
#   Document : Éducation formelle et éducation non formelle en France
#     Positions : [58]
#
# Mot : referer
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [7]
#
# Mot : preciser
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [10]
#
# Mot : detud
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [14]
#
# Mot : daffronter
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [26]
#
# Mot : consensu
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [3]
#
# Mot : bagage
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [10]
#
# Mot : quinversement
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [13]
#
# Mot : lalphabet
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [22]
#   Document : Taxonomie de Robert Mills Gagné
#     Positions : [7]
#   Document : Critiques
#     Positions : [95]
#
# Mot : relationnel
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [25]
#
# Mot : subtil
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [33]
#
# Mot : littrer
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [39]
#
# Mot : dexempl
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [43]
#
# Mot : littre
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [47]
#
# Mot : remarquer
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [51]
#
# Mot : senseigne
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [53]
#
# Mot : sapprend
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [55]
#
# Mot : passe
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [59]
#   Document : Systèmes éducatifs
#     Positions : [50]
#
# Mot : semploi
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [79]
#
# Mot : pluriel
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [80]
#
# Mot : setudier
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [83]
#
# Mot : psychologie
#   Document : Les Éducation, instruction ou enseignement
#     Positions : [90]
#   Document : Articles connexes
#     Positions : [57]
#   Document : Liens externes
#     Positions : [50, 52, 54]
#
# Mot : hypothese
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [6]
#   Document : Investir dans l'éducation
#     Positions : [1, 3, 27]
#   Document : Liens externes
#     Positions : [43]
#
# Mot : explicite
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [7]
#
# Mot : implicite
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [8]
#
# Mot : motiver
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [9]
#
# Mot : pedagogue
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [10]
#   Document : Bibliographie
#     Positions : [10]
#
# Mot : veyne
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [4]
#   Document : Bibliographie
#     Positions : [19]
#
# Mot : preparer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [9]
#   Document : Un droit reconnu au niveau international
#     Positions : [47]
#
# Mot : lenfer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [10]
#   Document : Éducation familiale
#     Positions : [5]
#   Document : Un droit reconnu au niveau international
#     Positions : [3, 3, 13, 25, 48, 73]
#   Document : Liens externes
#     Positions : [102]
#
# Mot : germinal
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [15]
#
# Mot : lenfance
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [25, 30, 19]
#   Document : Systèmes éducatifs
#     Positions : [24]
#
# Mot : deguise
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [33]
#
# Mot : lembellir
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [34]
#
# Mot : incarner
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [36]
#
# Mot : apotheose
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [38]
#
# Mot : locke
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [9]
#
# Mot : influent
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [15]
#
# Mot : reposer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [16]
#
# Mot : ecrivaitil
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [27]
#
# Mot : rever
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [2]
#
# Mot : rarement
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [5]
#
# Mot : apprendre
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [9]
#   Document : Taxonomie de Robert Mills Gagné
#     Positions : [39, 8, 5]
#   Document : Critiques
#     Positions : [85]
#
# Mot : desirer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [11]
#
# Mot : adroitemer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [18]
#
# Mot : souhait
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [19]
#   Document : Éducation parentale
#     Positions : [11]
#
# Mot : lock
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Positions : [1]
#
# Mot : auparavant
# ...
#   Document : Bibliographie
#     Positions : [15]
#
# Mot : yvon
#   Document : Bibliographie
#     Positions : [16]
#
# Mot : thebert
#   Document : Bibliographie
#     Positions : [17]
#
# Mot : mil
#   Document : Bibliographie
#     Positions : [27]
#
# Mot : gaffiot
#   Document : Notes et références
#     Positions : [42]
#
# Mot : latinfrancer
#   Document : Notes et références
#     Positions : [43]
#
# Mot : httpswwwcairninforevueletelemaque
#   Document : Notes et références
#     Positions : [55]
#
# Mot : Hypertext_Markup_Language
#   Document : Notes et références
#     Positions : [57]
#
# Mot : dessu
#   Document : Notes et références
#     Positions : [59]
#
# Mot : ens
#   Document : Notes et références
#     Positions : [74]
#
# Mot : rfp
#   Document : Notes et références
#     Positions : [85]
#
# Mot : wikisource
#   Document : Notes et références
#     Positions : [99]
#   Document : Bibliographie
#     Positions : [6]
#
# Mot : methodologique
#   Document : Notes et références
#     Positions : [110]
#
# Mot : sociale
#   Document : Notes et références
#     Positions : [111]
#
# Mot : Sarah
#   Document : Notes et références
#     Positions : [114, 160]
#
# Mot : currier
#   Document : Notes et références
#     Positions : [115]
#
# Mot : sheila
#   Document : Notes et références
#     Positions : [116]
#
# Mot : macneill
#   Document : Notes et références
#     Positions : [117]
#
# Mot : corley
#   Document : Notes et références
#     Positions : [119]
#
# Mot : lorna
#   Document : Notes et références
#     Positions : [120]
#
# Mot : Campbell
#   Document : Notes et références
#     Positions : [121]
#
# Mot : helen
#   Document : Notes et références
#     Positions : [122]
#
# Mot : beetham
#   Document : Notes et références
#     Positions : [123]
#
# Mot : decrire
#   Document : Notes et références
#     Positions : [125]
#
# Mot : cadrage
#   Document : Notes et références
#     Positions : [131]
#
# Mot : ametist
#   Document : Notes et références
#     Positions : [133, 134]
#
# Mot : krathwohl
#   Document : Notes et références
#     Positions : [142, 207]
#
# Mot : educational
#   Document : Notes et références
#     Positions : [146]
#
# Mot : goal
#   Document : Notes et références
#     Positions : [147]
#
# Mot : committee
#   Document : Notes et références
#     Positions : [150]
#
# Mot : longmans
#   Document : Notes et références
#     Positions : [158]
#
# Mot : mcneil
#   Document : Notes et références
#     Positions : [161]
#
# Mot : blooms
#   Document : Notes et références
#     Positions : [163, 190]
#
# Mot : taxonomy
#   Document : Notes et références
#     Positions : [164, 191]
#
# Mot : cognitif
#   Document : Notes et références
#     Positions : [167, 180, 194]
#
# Mot : domain
#   Document : Notes et références
#     Positions : [168, 181, 195]
#
# Mot : instructional
#   Document : Notes et références
#     Positions : [170]
#
# Mot : houston
#   Document : Notes et références
#     Positions : [174]
#
# Mot : completed
#   Document : Notes et références
#     Positions : [183]
#
# Mot : commonly
#   Document : Notes et références
#     Positions : [187]
#
# Mot : referred
#   Document : Notes et références
#     Positions : [188]
#
# Mot : although
#   Document : Notes et références
#     Positions : [196]
#
# Mot : there
#   Document : Notes et références
#     Positions : [197]
#
# Mot : were
#   Document : Notes et références
#     Positions : [198]
#
# Mot : other
#   Document : Notes et références
#     Positions : [199]
#
# Mot : authors
#   Document : Notes et références
#     Positions : [200]
#
# Mot : englehart
#   Document : Notes et références
#     Positions : [201]
#
# Mot : furst
#   Document : Notes et références
#     Positions : [203]
#
# Mot : hill
#   Document : Notes et références
#     Positions : [205]
#
# Mot : marcus
#   Document : Notes et références
#     Positions : [211]
#
# Mot : extrusion
#   Document : Notes et références
#     Positions : [212]
#
# Mot : math
#   Document : Notes et références
#     Positions : [213]
#
# Mot : Marc
#   Document : Notes et références
#     Positions : [220]
#
# Mot : bris
#   Document : Notes et références
#     Positions : [221]
#
# Mot : stock
#   Document : Notes et références
#     Positions : [228]
#
# Mot : tiehi
#   Document : Notes et références
#     Positions : [230]
#
# Mot : majority
#   Document : Notes et références
#     Positions : [233]
#
# Mot : children
#   Document : Notes et références
#     Positions : [235]
#
# Mot : live
#   Document : Notes et références
#     Positions : [236]
#
# Mot : two
#   Document : Notes et références
#     Positions : [238]
#
# Mot : sain
#   Document : Notes et références
#     Positions : [254]
#
# Mot : zacharopoulos
#   Document : Notes et références
#     Positions : [260]
#
# Mot : francesco
#   Document : Notes et références
#     Positions : [261]
#
# Mot : sella
#   Document : Notes et références
#     Positions : [262]
#
# Mot : cohen
#   Document : Notes et références
#     Positions : [264]
#
# Mot : kadosh
#   Document : Notes et références
#     Positions : [265]
#
# Mot : lack
#   Document : Notes et références
#     Positions : [271]
#
# Mot : mathematical
#   Document : Notes et références
#     Positions : [273]
#
# Mot : brain
#   Document : Notes et références
#     Positions : [275]
#
# Mot : developmer
#   Document : Notes et références
#     Positions : [276]
#
# Mot : attainment
#   Document : Notes et références
#     Positions : [279]
#
# Mot : pnas
#   Document : Notes et références
#     Positions : [281]
#
# Mot : pna
#   Document : Notes et références
#     Positions : [288]
#
# Mot : combler
#   Document : Notes et références
#     Positions : [304]
#
# Mot : onu
#   Document : Notes et références
#     Positions : [310]
#
# Mot : pierart
#   Document : Notes et références
#     Positions : [315]
#
# Mot : betrisey
#   Document : Notes et références
#     Positions : [317]
#
# Mot : tetreault
#   Document : Notes et références
#     Positions : [318]
#
# Mot : margotcattin
#   Document : Notes et références
#     Positions : [319, 321]
#
# Mot : linclusion
#   Document : Notes et références
#     Positions : [323]
#
# Mot : romand
#   Document : Notes et références
#     Positions : [328]
#
# Mot : airhm
#   Document : Notes et références
#     Positions : [336]
#
# Mot : quebec
#   Document : Notes et références
#     Positions : [339]
#
# Mot : defining
#   Document : Notes et références
#     Positions : [345]
#
# Mot : quality
#   Document : Notes et références
#     Positions : [346]
#
# Mot : initiativ
#   Document : Notes et références
#     Positions : [353, 379, 405, 424]
#
# Mot : contradicting
#   Document : Notes et références
#     Positions : [358]
#
# Mot : commitment
#   Document : Notes et références
#     Positions : [359]
#
# Mot : achievemer
#   Document : Notes et références
#     Positions : [362]
#
# Mot : all
#   Document : Notes et références
#     Positions : [366]
#
# Mot : being
#   Document : Notes et références
#     Positions : [368]
#
# Mot : undermined
#   Document : Notes et références
#     Positions : [369]
#
# Mot : monetary
#   Document : Notes et références
#     Positions : [373]
#
# Mot : person
#   Document : Notes et références
#     Positions : [398]
#
# Mot : post
#   Document : Notes et références
#     Positions : [419]
#
# Mot : avantpropo
#   Document : Notes et références
#     Positions : [449]
#
# Mot : tomasevski
#   Document : Notes et références
#     Positions : [472]
#
# Mot : ecn
#   Document : Notes et références
#     Positions : [482]
#
# Mot : cinquantehuitiem
#   Document : Notes et références
#     Positions : [486]
#
# Mot : schooling
#   Document : Notes et références
#     Positions : [498]
#
# Mot : experience
#   Document : Notes et références
#     Positions : [499]
#
# Mot : earning
#   Document : Notes et références
#     Positions : [501]
#
# Mot : minc
#   Document : Notes et références
#     Positions : [508]
#
# Mot : september
#   Document : Notes et références
#     Positions : [509]
#
# Mot : glasman
#   Document : Notes et références
#     Positions : [512]
#
# Mot : bongrand
#   Document : Notes et références
#     Positions : [514]
#
# Mot : sociologique
#   Document : Notes et références
#     Positions : [519]
#
# Mot : pedagogie
#   Document : Notes et références
#     Positions : [525]
#
# Mot : cornu
#   Document : Notes et références
#     Positions : [528]
#
# Mot : segmer
#   Document : Notes et références
#     Positions : [531]
#
# Mot : sevres
#   Document : Notes et références
#     Positions : [538]
#
# Mot : rie
#   Document : Notes et références
#     Positions : [545]
#
# Mot : webjournal
#   Document : Notes et références
#     Positions : [552]
#
# Mot : piketty
#   Document : Notes et références
#     Positions : [554]
#
# Mot : souhaiteil
#   Document : Notes et références
#     Positions : [556]
#
# Mot : blog
#   Document : Notes et références
#     Positions : [560]
#
# Mot : jeanfrancois
#   Document : Notes et références
#     Positions : [568]
#
# Mot : landry
#   Document : Notes et références
#     Positions : [569]
#
# Mot : Myth
#   Document : Notes et références
#     Positions : [579]
#
# Mot : arnaud
#   Document : Notes et références
#     Positions : [584]
#
# Mot : parienty
#   Document : Notes et références
#     Positions : [585]
#
# Mot : cafepedagogiquenet
#   Document : Notes et références
#     Positions : [596]
#
# Mot : commonseducation
#   Document : Voir aussi
#     Positions : [2]
#
# Mot : wiktionnaireeducation
#   Document : Voir aussi
#     Positions : [3]
#
# Mot : wikiversityeducation
#   Document : Voir aussi
#     Positions : [4]
#
# Mot : wikibookseducation
#   Document : Voir aussi
#     Positions : [5]
#
# Mot : wikisourceeducation
#   Document : Voir aussi
#     Positions : [6]
#
# Mot : wikiquoteeducation
#   Document : Voir aussi
#     Positions : [7]
#
# Mot : koninck
#   Document : Bibliographie
#     Positions : [7, 20]
#
# Mot : ignorance
#   Document : Bibliographie
#     Positions : [9]
#
# Mot : portuger
#   Document : Bibliographie
#     Positions : [18]
#
# Mot : federico
#   Document : Bibliographie
#     Positions : [27]
#
# Mot : mayor
#   Document : Bibliographie
#     Positions : [28]
#
# Mot : zaragoza
#   Document : Bibliographie
#     Positions : [29]
#
# Mot : postface
#   Document : Bibliographie
#     Positions : [30]
#
# Mot : mohamed
#   Document : Bibliographie
#     Positions : [32]
#
# Mot : achaari
#   Document : Bibliographie
#     Positions : [33]
#
# Mot : chanlat
#   Document : Bibliographie
#     Positions : [35]
#
# Mot : abdelkarim
#   Document : Bibliographie
#     Positions : [36]
#
# Mot : errouaki
#   Document : Bibliographie
#     Positions : [37]
#
# Mot : Themis
#   Document : Bibliographie
#     Positions : [40]
#
# Mot : erny
#   Document : Bibliographie
#     Positions : [42]
#
# Mot : ethnologie
#   Document : Bibliographie
#     Positions : [43]
#   Document : Liens externes
#     Positions : [11]
#
# Mot : Jessye_Norman
#   Document : Bibliographie
#     Positions : [51]
#
# Mot : baillargeon
#   Document : Bibliographie
#     Positions : [52]
#
# Mot : actualite
#   Document : Bibliographie
#     Positions : [57]
#
# Mot : lanarchisme
#   Document : Bibliographie
#     Positions : [58]
#
# Mot : agone
#   Document : Bibliographie
#     Positions : [59]
#
# Mot : lux
#   Document : Bibliographie
#     Positions : [60]
#
# Mot : plutarqu
#   Document : Bibliographie
#     Positions : [9]
#
# Mot : specialise
#   Document : Bibliographie
#     Positions : [11]
#   Document : Articles connexes
#     Positions : [25]
#
# Mot : gregory
#   Document : Bibliographie
#     Positions : [12]
#
# Mot : degenaer
#   Document : Bibliographie
#     Positions : [13]
#
# Mot : ash
#   Document : Bibliographie
#     Positions : [15]
#
# Mot : autoformation
#   Document : Articles connexes
#     Positions : [4]
#
# Mot : cateches
#   Document : Articles connexes
#     Positions : [5]
#
# Mot : socioculturel
#   Document : Articles connexes
#     Positions : [20]
#
# Mot : lernen
#   Document : Articles connexes
#     Positions : [36]
#
# Mot : durch
#   Document : Articles connexes
#     Positions : [37]
#
# Mot : lehren
#   Document : Articles connexes
#     Positions : [38]
#
# Mot : ldl
#   Document : Articles connexes
#     Positions : [39]
#
# Mot : plasticiter
#   Document : Articles connexes
#     Positions : [55]
#
# Mot : encyclopedia
#   Document : Liens externes
#     Positions : [35, 39, 57, 61, 11, 15, 33, 37]
#
# Mot : cleveland
#   Document : Liens externes
#     Positions : [37, 13]
#
# Mot : great
#   Document : Liens externes
#     Positions : [42, 18]
#
# Mot : plain
#   Document : Liens externes
#     Positions : [43, 19]
#
# Mot : aragonesa
#   Document : Liens externes
#     Positions : [46, 22]
#
# Mot : handbook
#   Document : Liens externes
#     Positions : [50, 26]
#
# Mot : texa
#   Document : Liens externes
#     Positions : [52, 28]
#
# Mot : onlin
#   Document : Liens externes
#     Positions : [53, 29]
#
# Mot : universali
#   Document : Liens externes
#     Positions : [54, 30]
#
# Mot : Utah
#   Document : Liens externes
#     Positions : [55, 31]
#
# Mot : virginia
#   Document : Liens externes
#     Positions : [60, 36]
#
# Mot : construir
#   Document : Liens externes
#     Positions : [80]
#
# Mot : conception
#   Document : Liens externes
#     Positions : [84]
#
# Mot : curriculum
#   Document : Liens externes
#     Positions : [88]
#
# Mot : hstreasure
#   Document : Liens externes
#     Positions : [92]
#
# Mot : irie
#   Document : Liens externes
#     Positions : [97]
#
# Mot : humanium
#   Document : Liens externes
#     Positions : [103]
#
# Mot : clarification
#   Document : Liens externes
#     Positions : [109]
#
# Mot : enjeux
#   Document : Liens externes
#     Positions : [111]
#
# Mot : lenoir
#   Document : Liens externes
#     Positions : [114]
#
# Mot : legitimite
#   Document : Liens externes
#     Positions : [3]
#
# Mot : contreculture
#   Document : Liens externes
#     Positions : [8]
#
# Mot : sousculture
#   Document : Liens externes
#     Positions : [9]
#
# Mot : ethologi
#   Document : Liens externes
#     Positions : [17]
#
# Mot : acculturation
#   Document : Liens externes
#     Positions : [2, 3]
#
# Mot : transculturation
#   Document : Liens externes
#     Positions : [4]
#
# Mot : rayonnemer
#   Document : Liens externes
#     Positions : [5]
#
# Mot : hegemonie
#   Document : Liens externes
#     Positions : [7]
#
# Mot : ethnocide
#   Document : Liens externes
#     Positions : [9]
#
# Mot : evolutionnisme
#   Document : Liens externes
#     Positions : [1]
#
# Mot : diffusionnisme
#   Document : Liens externes
#     Positions : [2]
#
# Mot : fonctionnalism
#   Document : Liens externes
#     Positions : [3]
#
# Mot : culturalisme
#   Document : Liens externes
#     Positions : [4]
#
# Mot : structuralisme
#   Document : Liens externes
#     Positions : [8]
#
# Mot : anthropologie
#   Document : Liens externes
#     Positions : [0, 1, 3, 32]
#
# Mot : psychanalytique
#   Document : Liens externes
#     Positions : [4]
#
# Mot : astronomie
#   Document : Liens externes
#     Positions : [5]
#
# Mot : trouble_de_la_personnalite
#   Document : Liens externes
#     Positions : [7]
#
# Mot : ethnomedecine
#   Document : Liens externes
#     Positions : [9]
#
# Mot : ethnographie
#   Document : Liens externes
#     Positions : [10]
#
# Mot : ethnopsychiatrie
#   Document : Liens externes
#     Positions : [12]
#
# Mot : ethnopsychanalyse
#   Document : Liens externes
#     Positions : [13]
#
# Mot : ethnopharmacologie
#   Document : Liens externes
#     Positions : [14]
#
# Mot : ethnobiologie
#   Document : Liens externes
#     Positions : [15]
#
# Mot : ethnozoologie
#   Document : Liens externes
#     Positions : [16]
#
# Mot : ethnoentomologie
#   Document : Liens externes
#     Positions : [17]
#
# Mot : ethnobotanique
#   Document : Liens externes
#     Positions : [18]
#
# Mot : ethnoornithologie
#   Document : Liens externes
#     Positions : [19]
#
# Mot : ethnoichthyologie
#   Document : Liens externes
#     Positions : [20]
#
# Mot : ethnoherpetologie
#   Document : Liens externes
#     Positions : [21]
#
# Mot : ethnoprimatologie
#   Document : Liens externes
#     Positions : [22]
#
# Mot : ethnomycologie
#   Document : Liens externes
#     Positions : [23]
#
# Mot : ethnolichenologie
#   Document : Liens externes
#     Positions : [24]
#
# Mot : ethnoecologie
#   Document : Liens externes
#     Positions : [25]
#
# Mot : ethnohistoir
#   Document : Liens externes
#     Positions : [26]
#
# Mot : ethnoarcheologie
#   Document : Liens externes
#     Positions : [27]
#
# Mot : ethnomathematique
#   Document : Liens externes
#     Positions : [28]
#
# Mot : ethologie
#   Document : Liens externes
#     Positions : [29]
#
# Mot : neuroscience
#   Document : Liens externes
#     Positions : [36]
#
# Mot : culturologie
#   Document : Liens externes
#     Positions : [42]
#
# Mot : neuroculture
#   Document : Liens externes
#     Positions : [45]
#
# Mot : bioculture
#   Document : Liens externes
#     Positions : [46]
#
# Mot : cartographi
#   Document : Liens externes
#     Positions : [61]
#
# Mot : culturomiqu
#   Document : Liens externes
#     Positions : [63]
#
# Mot : radicalisme
#   Document : Liens externes
#     Positions : [66]
#
# Mot : semiologie
#   Document : Liens externes
#     Positions : [70]

# %% [markdown]
# **un index inversé enrichi {mot: {nom_document: {frequence: positions}}}**

# %%
# Fonction pour créer un index inversé enrichi {mot: {nom_document: {frequence: positions}}}
def creer_index_inverse_enrichi(processed_documents):
    index_inverse_enrichi = {}

    # Parcourir chaque document traité
    for doc in processed_documents:
        title = doc['title']
        tokens = doc['tokens']

        # Dictionnaire temporaire pour stocker les positions par mot pour le document courant
        positions_par_mot = {}

        # Parcourir chaque token avec son index dans le document
        for index, token in enumerate(tokens):
            # Initialiser la liste des positions pour chaque mot dans le document
            if token not in positions_par_mot:
                positions_par_mot[token] = []
            positions_par_mot[token].append(index)

        # Ajouter les informations au dictionnaire principal avec la fréquence et les positions
        for token, positions in positions_par_mot.items():
            if token not in index_inverse_enrichi:
                index_inverse_enrichi[token] = {}

            # Ajouter le document et ses informations de fréquence et positions pour le mot
            index_inverse_enrichi[token][title] = {
                len(positions): positions  # La fréquence (longueur de la liste) et les positions
            }

    return index_inverse_enrichi

# Créer l'index inverse enrichi à partir des documents prétraités
index_inverse_enrichi = creer_index_inverse_enrichi(processed_documents)

# Afficher l'index inverse enrichi
print("Index inversé enrichi des mots :")
for mot, documents in index_inverse_enrichi.items():
    print(f"\nMot : {mot}")
    for doc, info in documents.items():
        frequence = list(info.keys())[0]
        positions = info[frequence]
        print(f"  Document : {doc}")
        print(f"    Fréquence : {frequence}")
        print(f"    Positions : {positions}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   Document : Références
#     Fréquence : 1
#     Positions : [399]
#
# Mot : richard
#   Document : Références
#     Fréquence : 2
#     Positions : [414, 716]
#
# Mot : cordal
#   Document : Références
#     Fréquence : 1
#     Positions : [415]
#
# Mot : asia
#   Document : Références
#     Fréquence : 1
#     Positions : [418]
#
# Mot : andamanese
#   Document : Références
#     Fréquence : 1
#     Positions : [420]
#
# Mot : genetic
#   Document : Références
#     Fréquence : 2
#     Positions : [423, 438]
#
# Mot : dispersal
#   Document : Références
#     Fréquence : 1
#     Positions : [429]
#
# Mot : out
#   Document : Références
#     Fréquence : 1
#     Positions : [430]
#
# Mot : africer
#   Document : Références
#     Fréquence : 1
#     Positions : [432]
#
# Mot : american
#   Document : Références
#     Fréquence : 1
#     Positions : [434]
#
# Mot : pmcid
#   Document : Références
#     Fréquence : 1
#     Positions : [444]
#
# Mot : skeletal
#   Document : Références
#     Fréquence : 1
#     Positions : [455]
#
# Mot : show
#   Document : Références
#     Fréquence : 1
#     Positions : [457]
#
# Mot : abrupt
#   Document : Références
#     Fréquence : 1
#     Positions : [458]
#
# Mot : worldwid
#   Document : Références
#     Fréquence : 1
#     Positions : [459]
#
# Mot : increase
#   Document : Références
#     Fréquence : 2
#     Positions : [460, 483]
#
# Mot : birth
#   Document : Références
#     Fréquence : 1
#     Positions : [462]
#
# Mot : during
#   Document : Références
#     Fréquence : 2
#     Positions : [464, 487]
#
# Mot : neolithic
#   Document : Références
#     Fréquence : 2
#     Positions : [465, 489]
#
# Mot : period
#   Document : Références
#     Fréquence : 1
#     Positions : [466]
#
# Mot : daily
#   Document : Références
#     Fréquence : 1
#     Positions : [469]
#
# Mot : sussman
#   Document : Références
#     Fréquence : 1
#     Positions : [474]
#
# Mot : child
#   Document : Références
#     Fréquence : 1
#     Positions : [478]
#
# Mot : size
#   Document : Références
#     Fréquence : 1
#     Positions : [481]
#
# Mot : university
#   Document : Références
#     Fréquence : 2
#     Positions : [493, 558]
#   Document : Notes et références
#     Fréquence : 2
#     Positions : [154, 172]
#
# Mot : Lincoln_Park
#   Document : Références
#     Fréquence : 1
#     Positions : [495]
#
# Mot : ferraro
#   Document : Références
#     Fréquence : 1
#     Positions : [509]
#
# Mot : Gary
#   Document : Références
#     Fréquence : 1
#     Positions : [510]
#   Document : Investir dans l'éducation
#     Fréquence : 1
#     Positions : [5]
#
# Mot : applied
#   Document : Références
#     Fréquence : 1
#     Positions : [515]
#
# Mot : perspectif
#   Document : Références
#     Fréquence : 1
#     Positions : [516]
#
# Mot : belmont
#   Document : Références
#     Fréquence : 1
#     Positions : [517]
#
# Mot : calif
#   Document : Références
#     Fréquence : 1
#     Positions : [518]
#
# Mot : patterson
#   Document : Références
#     Fréquence : 1
#     Positions : [529]
#
# Mot : gordon
#   Document : Références
#     Fréquence : 1
#     Positions : [530]
#
# Mot : essentials
#   Document : Références
#     Fréquence : 1
#     Positions : [532]
#
# Mot : piscataway
#   Document : Références
#     Fréquence : 1
#     Positions : [536]
#
# Mot : research
#   Document : Références
#     Fréquence : 2
#     Positions : [537, 678]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [506]
#
# Mot : education
#   Document : Références
#     Fréquence : 3
#     Positions : [538, 629, 655]
#   Document : Notes et références
#     Fréquence : 10
#     Positions : [274, 348, 352, 364, 378, 392, 396, 404, 418, 423]
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [76]
#
# Mot : alan
#   Document : Références
#     Fréquence : 1
#     Positions : [546]
#
# Mot : cramb
#   Document : Références
#     Fréquence : 1
#     Positions : [548]
#
# Mot : short
#   Document : Références
#     Fréquence : 1
#     Positions : [551]
#
# Mot : metals
#   Document : Références
#     Fréquence : 1
#     Positions : [554]
#
# Mot : carnegie
#   Document : Références
#     Fréquence : 1
#     Positions : [556]
#
# Mot : mellon
#   Document : Références
#     Fréquence : 1
#     Positions : [557]
#
# Mot : hugh
#   Document : Références
#     Fréquence : 1
#     Positions : [562]
#
# Mot : chisholm
#   Document : Références
#     Fréquence : 1
#     Positions : [563]
#
# Mot : britannicer
#   Document : Références
#     Fréquence : 1
#     Positions : [565]
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : skills
#   Document : Références
#     Fréquence : 1
#     Positions : [571]
#
# Mot : digital
#   Document : Références
#     Fréquence : 2
#     Positions : [574, 578]
#
# Mot : papers
#   Document : Références
#     Fréquence : 1
#     Positions : [580]
#
# Mot : jlwz
#   Document : Références
#     Fréquence : 1
#     Positions : [584]
#
# Mot : wnwen
#   Document : Références
#     Fréquence : 1
#     Positions : [586]
#
# Mot : vaino
#   Document : Références
#     Fréquence : 4
#     Positions : [610, 611, 635, 636]
#
# Mot : rannikmae
#   Document : Références
#     Fréquence : 2
#     Positions : [613, 638]
#
# Mot : holbrook
#   Document : Références
#     Fréquence : 2
#     Positions : [614, 640]
#
# Mot : factors
#   Document : Références
#     Fréquence : 2
#     Positions : [616, 642]
#
# Mot : explaining
#   Document : Références
#     Fréquence : 2
#     Positions : [617, 643]
#
# Mot : gymnasium
#   Document : Références
#     Fréquence : 2
#     Positions : [618, 644]
#
# Mot : students'
#   Document : Références
#     Fréquence : 2
#     Positions : [619, 645]
#
# Mot : related
#   Document : Références
#     Fréquence : 2
#     Positions : [621, 647]
#
# Mot : career
#   Document : Références
#     Fréquence : 2
#     Positions : [622, 648]
#
# Mot : pp
#   Document : Références
#     Fréquence : 1
#     Positions : [659]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [338]
#
# Mot : swarat
#   Document : Références
#     Fréquence : 1
#     Positions : [661]
#
# Mot : ortony
#   Document : Références
#     Fréquence : 1
#     Positions : [662]
#
# Mot : revell
#   Document : Références
#     Fréquence : 1
#     Positions : [664]
#
# Mot : activity
#   Document : Références
#     Fréquence : 1
#     Positions : [667]
#
# Mot : understanding
#   Document : Références
#     Fréquence : 1
#     Positions : [669]
#
# Mot : studer
#   Document : Références
#     Fréquence : 1
#     Positions : [670]
#
# Mot : interest
#   Document : Références
#     Fréquence : 1
#     Positions : [671]
#
# Mot : teaching
#   Document : Références
#     Fréquence : 1
#     Positions : [681]
#
# Mot : tea
#   Document : Références
#     Fréquence : 1
#     Positions : [687]
#
# Mot : oakley
#   Document : Références
#     Fréquence : 1
#     Positions : [691]
#
# Mot : toolmaker
#   Document : Références
#     Fréquence : 1
#     Positions : [695]
#
# Mot : bibcode
#   Document : Références
#     Fréquence : 2
#     Positions : [706, 779]
#
# Mot : natur
#   Document : Références
#     Fréquence : 1
#     Positions : [707]
#
# Mot : carl
#   Document : Références
#     Fréquence : 1
#     Positions : [712]
#
# Mot : druyan
#   Document : Références
#     Fréquence : 1
#     Positions : [713]
#
# Mot : leakey
#   Document : Références
#     Fréquence : 1
#     Positions : [715]
#
# Mot : rincon
#   Document : Références
#     Fréquence : 1
#     Positions : [728]
#
# Mot : apprise
#   Document : Références
#     Fréquence : 1
#     Positions : [733]
#
# Mot : crow
#   Document : Références
#     Fréquence : 1
#     Positions : [745]
#
# Mot : find
#   Document : Références
#     Fréquence : 2
#     Positions : [749, 846]
#
# Mot : nbc
#   Document : Références
#     Fréquence : 1
#     Positions : [752]
#
# Mot : rutz
#   Document : Références
#     Fréquence : 1
#     Positions : [758]
#
# Mot : weir
#   Document : Références
#     Fréquence : 1
#     Positions : [760]
#
# Mot : kacelnik
#   Document : Références
#     Fréquence : 1
#     Positions : [762]
#
# Mot : camera
#   Document : Références
#     Fréquence : 1
#     Positions : [765]
#
# Mot : mcgrew
#   Document : Références
#     Fréquence : 1
#     Positions : [785]
#
# Mot : chimpanzee
#   Document : Références
#     Fréquence : 1
#     Positions : [786]
#
# Mot : material
#   Document : Références
#     Fréquence : 1
#     Positions : [787]
#
# Mot : ua
#   Document : Références
#     Fréquence : 1
#     Positions : [790]
#
# Mot : univ
#   Document : Références
#     Fréquence : 1
#     Positions : [792]
#
# Mot : Christophe
#   Document : Références
#     Fréquence : 1
#     Positions : [796]
#
# Mot : boesch
#   Document : Références
#     Fréquence : 2
#     Positions : [797, 799]
#
# Mot : hedwige
#   Document : Références
#     Fréquence : 1
#     Positions : [798]
#
# Mot : map
#   Document : Références
#     Fréquence : 1
#     Positions : [802]
#
# Mot : wild
#   Document : Références
#     Fréquence : 1
#     Positions : [804]
#
# Mot : chimpanzees
#   Document : Références
#     Fréquence : 1
#     Positions : [805]
#
# Mot : an
#   Document : Références
#     Fréquence : 1
#     Positions : [806]
#
# Mot : analysis
#   Document : Références
#     Fréquence : 1
#     Positions : [807]
#
# Mot : hammer
#   Document : Références
#     Fréquence : 1
#     Positions : [809]
#
# Mot : transport
#   Document : Références
#     Fréquence : 1
#     Positions : [810]
#
# Mot : nut
#   Document : Références
#     Fréquence : 1
#     Positions : [812]
#
# Mot : cracking
#   Document : Références
#     Fréquence : 1
#     Positions : [813]
#
# Mot : bf
#   Document : Références
#     Fréquence : 1
#     Positions : [825]
#
# Mot : vi
#   Document : Références
#     Fréquence : 1
#     Positions : [831]
#
# Mot : dolozi
#   Document : Références
#     Fréquence : 2
#     Positions : [834, 837]
#
# Mot : authorfullname
#   Document : Références
#     Fréquence : 1
#     Positions : [842]
#
# Mot : nutcracking
#   Document : Références
#     Fréquence : 1
#     Positions : [844]
#
# Mot : monkeys
#   Document : Références
#     Fréquence : 1
#     Positions : [845]
#
# Mot : right
#   Document : Références
#     Fréquence : 1
#     Positions : [848]
#   Document : Notes et références
#     Fréquence : 7
#     Positions : [350, 376, 390, 394, 402, 416, 421]
#
# Mot : scientist
#   Document : Références
#     Fréquence : 1
#     Positions : [855]
#
# Mot : muller
#   Document : Références
#     Fréquence : 1
#     Positions : [860]
#
# Mot : watling
#   Document : Références
#     Fréquence : 1
#     Positions : [861]
#
# Mot : Salto_del_Angel
#   Document : Références
#     Fréquence : 1
#     Positions : [863]
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [9, 11]
#
# Mot : river
#   Document : Références
#     Fréquence : 1
#     Positions : [875]
#
# Mot : flow
#   Document : Références
#     Fréquence : 1
#     Positions : [876]
#
# Mot : eighth
#   Document : Références
#     Fréquence : 1
#     Positions : [877]
#
# Mot : conference
#   Document : Références
#     Fréquence : 1
#     Positions : [879]
#
# Mot : hydraulics
#   Document : Références
#     Fréquence : 1
#     Positions : [881]
#
# Mot : wiktionnairetechnologie
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [1]
#
# Mot : wikibookstechnologie
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [2]
#
# Mot : gilbert
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [11]
#
# Mot : simondon
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [12]
#
# Mot : ane
#   Document : Bibliographie
#     Fréquence : 2
#     Positions : [18, 30]
#
# Mot : mach
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [19]
#
# Mot : vuibert
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [25]
#
# Mot : lhumain
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [32]
#
# Mot : lharmattan
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [46]
#
# Mot : philosophique
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [15]
#
# Mot : lasfargu
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [48]
#
# Mot : halte
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [49]
#
# Mot : ridiculite
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [50]
#
# Mot : dorganisation
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [54]
#
# Mot : jarrige
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [83]
#
# Mot : dompter
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [84]
#
# Mot : promether
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [85]
#
# Mot : technologier
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [86]
#
# Mot : franchecomte
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [93]
#
# Mot : bookspufc
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [98]
#
# Mot : neoluddisme
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [16]
#
# Mot : standardisation
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [17]
#
# Mot : norm
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : roberval
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [27]
#
# Mot : revival
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [31]
#
# Mot : technocritiqu
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [35]
#
# Mot : modern
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : biomedicine
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : encyclopedier
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : catalana
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [25]
#
# Mot : store
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : treccani
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [16]
#
# Mot : informatiser
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [59]
#
# Mot : securite-incendie
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [60, 72]
#
# Mot : lagora
#   Document : Liens externes
#     Fréquence : 3
#     Positions : [63, 75, 89]
#
# Mot : lintroducteur
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [66, 81]
#
# Mot : millenarism
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [73]
#
# Mot : incoherence
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [87]
#
# Mot : litterature
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [90]
#
# Mot : commentaire
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [91]
#
# Mot : puech
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [96]
#
# Mot : affichage
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [0, 3]
#
# Mot : ecran
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : autostereoscopie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [6]
#
# Mot : diode
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : electroluminescent
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : engrais_organique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : lentill
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : verres_de_contact
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [11]
#   Document : Éducation familiale
#     Fréquence : 1
#     Positions : [48]
#
# Mot : bionique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : virtuel
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [14]
#
# Mot : aquaponie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : hydroponie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : vegetaliser
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : genetiquement
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [11]
#
# Mot : viand
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : vitro
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [15]
#
# Mot : senseur
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : donde
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : gravitationnel
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : ligo
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : virgo
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : interferometre
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [7, 9]
#
# Mot : astronomique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : optique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : interferometrie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : event
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [0]
#
# Mot : perspective
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : telescope
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : halca
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : hypertelescope
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : interferometr
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [0]
#
# Mot : pyrosequencage
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [0]
#
# Mot : sequencage
#   Document : Liens externes
#     Fréquence : 5
#     Positions : [1, 4, 6, 9, 11]
#
# Mot : GSM
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : ligation
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [5, 7]
#
# Mot : doligonucleotides
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : nanopore
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : semiconducteur
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : biophotoniqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [0]
#
# Mot : electrophorese
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [1, 5]
#
# Mot : capillaire
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [2, 6]
#
# Mot : spectre
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : SI
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : imagerie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : moleculaire
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : chip
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [11]
#
# Mot : optofluidiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : optogenetiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : ampakine
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [0]
#
# Mot : bioimpression
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : biologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [91]
#
# Mot : biostase
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : tenor
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [6]
#
# Mot : cryoconservation
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : cryogenisation
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : biomedical
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : genetique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : hopital
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [14]
#
# Mot : interfac
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [15]
#
# Mot : neuronal
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [16]
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [56]
#
# Mot : interference
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [18]
#
# Mot : arn
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [19]
#
# Mot : regeneratif
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [21]
#
# Mot : nanomedecin
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [22]
#
# Mot : strategie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [25]
#
# Mot : engineered
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [27]
#
# Mot : negligibl
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [28]
#
# Mot : senescence
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [29]
#
# Mot : therapie
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [30, 32]
#
# Mot : genique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [31]
#
# Mot : photodynamique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [33]
#
# Mot : cristallographie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : seriel
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : femtoseconde
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : microfluidiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : spectrometri
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : alpha
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : bic
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : odorat
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : optoelectronique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : spintroniqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : plastronique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [6]
#
# Mot : optroniqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : intelligent
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : atomtroniqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : cryptanalyse
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : ubiquitaire
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : neurone
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [11]
#
# Mot : cbram
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [0]
#
# Mot : fram
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : millipede
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : mram
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : nram
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : pram
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : rram
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [6]
#
# Mot : xpoint
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : ambiant
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : cellule_nerveuse
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : laser
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : spectroscopie
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [7, 10]
#
# Mot : gamma
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : domotiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : exosquelette
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : motoriser
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : microrobotiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : nanorobot
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : essaim
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : molle
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : cobotiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : hyperloop
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : fuser
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : propulsion
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [6]
#
# Mot : jetpack
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : sustentation
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : magnetique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : autonome
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [15]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [571]
#
# Mot : moto
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [16]
#
# Mot : strati
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [21]
#
# Mot : spacetrain
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [22]
#
# Mot : hydrogene
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [24]
#
# Mot : ecall
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [25]
#
# Mot : httpspsychologiesavoirfrpsychologieeconomiepsychiqu
#   Document : Références
#     Fréquence : 1
#     Positions : [1]
#
# Mot : educatio
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [8]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [41]
#
# Mot : spin-off
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [11]
#
# Mot : exducere
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [12]
#
# Mot : ducere
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [13]
#
# Mot : guider
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [16]
#
# Mot : ex-mari
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [18]
#   Document : Marché éducatif
#     Fréquence : 1
#     Positions : [23]
#
# Mot : convier
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [29]
#
# Mot : noter
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [31]
#
# Mot : pointer
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [33]
#
# Mot : mialaret
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 2
#     Positions : [34, 61]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [45]
#
# Mot : etymologie
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [37]
#
# Mot : educare
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [38]
#
# Mot : aliment
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [39]
#   Document : Éducation familiale
#     Fréquence : 1
#     Positions : [35]
#
# Mot : educere
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [40]
#
# Mot : saisir
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [42]
#
# Mot : instance
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [44]
#
# Mot : notion
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [46]
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [9]
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [30]
#   Document : Critiques
#     Fréquence : 1
#     Positions : [0]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [1]
#
# Mot : deducation
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 3
#     Positions : [27, 45, 82]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [3]
#   Document : Éducation familiale
#     Fréquence : 1
#     Positions : [16]
#   Document : Systèmes éducatifs
#     Fréquence : 1
#     Positions : [3]
#   Document : Enjeux
#     Fréquence : 1
#     Positions : [1]
#   Document : Droit à l'éducation
#     Fréquence : 1
#     Positions : [13]
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [41]
#
# Mot : conciliation
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [49]
#
# Mot : problematique
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [50]
#
# Mot : nourrirremplir
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [53]
#
# Mot : maximiser
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [57]
#
# Mot : methodique
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [67]
#
# Mot : enseigner
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [71]
#   Document : Inclusion scolaire
#     Fréquence : 1
#     Positions : [36]
#
# Mot : transmettre
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [73]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [56]
#   Document : Éducation familiale
#     Fréquence : 1
#     Positions : [12]
#   Document : Investir dans l'éducation
#     Fréquence : 1
#     Positions : [17]
#
# Mot : corpus
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [76]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [58]
#
# Mot : referer
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [7]
#
# Mot : preciser
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [10]
#
# Mot : detud
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [14]
#
# Mot : daffronter
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [26]
#
# Mot : consensu
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [3]
#
# Mot : bagage
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [10]
#
# Mot : quinversement
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [13]
#
# Mot : lalphabet
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [22]
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [7]
#   Document : Critiques
#     Fréquence : 1
#     Positions : [95]
#
# Mot : relationnel
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [25]
#
# Mot : subtil
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [33]
#
# Mot : littrer
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [39]
#
# Mot : dexempl
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [43]
#
# Mot : littre
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [47]
#
# Mot : remarquer
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [51]
#
# Mot : senseigne
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [53]
#
# Mot : sapprend
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [55]
#
# Mot : passe
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [59]
#   Document : Systèmes éducatifs
#     Fréquence : 1
#     Positions : [50]
#
# Mot : semploi
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [79]
#
# Mot : pluriel
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [80]
#
# Mot : setudier
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [83]
#
# Mot : psychologie
#   Document : Les Éducation, instruction ou enseignement
#     Fréquence : 1
#     Positions : [90]
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [57]
#   Document : Liens externes
#     Fréquence : 3
#     Positions : [50, 52, 54]
#
# Mot : hypothese
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [6]
#   Document : Investir dans l'éducation
#     Fréquence : 2
#     Positions : [3, 27]
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [43]
#
# Mot : explicite
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [7]
#
# Mot : implicite
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [8]
#
# Mot : motiver
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [9]
#
# Mot : pedagogue
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [10]
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [10]
#
# Mot : veyne
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [4]
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [19]
#
# Mot : preparer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [9]
#   Document : Un droit reconnu au niveau international
#     Fréquence : 1
#     Positions : [47]
#
# Mot : lenfer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [10]
#   Document : Éducation familiale
#     Fréquence : 1
#     Positions : [5]
#   Document : Un droit reconnu au niveau international
#     Fréquence : 5
#     Positions : [3, 13, 25, 48, 73]
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [102]
#
# Mot : germinal
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [15]
#
# Mot : lenfance
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [19]
#   Document : Systèmes éducatifs
#     Fréquence : 1
#     Positions : [24]
#
# Mot : deguise
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [33]
#
# Mot : lembellir
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [34]
#
# Mot : incarner
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [36]
#
# Mot : apotheose
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [38]
#
# Mot : locke
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [9]
#
# Mot : influent
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [15]
#
# Mot : reposer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [16]
#
# Mot : ecrivaitil
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [27]
#
# Mot : rever
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [2]
#
# Mot : rarement
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [5]
#
# Mot : apprendre
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [9]
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [5]
#   Document : Critiques
#     Fréquence : 1
#     Positions : [85]
#
# Mot : desirer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [11]
#
# Mot : adroitemer
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [18]
#
# Mot : souhait
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [19]
#   Document : Éducation parentale
#     Fréquence : 1
#     Positions : [11]
#
# Mot : lock
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [1]
#
# Mot : auparavant
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [4]
#
# Mot : raisonner
#   Document : Influences de l'histoire, des cultures et des croyances et théories implicites
#     Fréquence : 1
#     Positions : [8]
#
# Mot : schematiquement
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [0]
#
# Mot : savoiretre
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [21]
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [4]
#
# Mot : correspond
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [1]
#
# Mot : apprenant
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [27]
#
# Mot : dacquerir
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [28]
#
# Mot : lectur
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [17]
#
# Mot : ecrit
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [18]
#   Document : Les objectifs de l'Éducation pour Tous
#     Fréquence : 1
#     Positions : [129]
#
# Mot : metaconnaissance
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [23]
#
# Mot : lexperience
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [5]
#
# Mot : lexercice
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [6]
#
# Mot : artisanal
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [9]
#
# Mot : sacquierer
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [15]
#
# Mot : dautomatisme
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [20]
#
# Mot : dappliquer
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [28]
#
# Mot : savoiretr
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 2
#     Positions : [0, 55]
#
# Mot : sacquiert
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [12]
#
# Mot : proteger
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [36]
#
# Mot : hygien
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [37]
#
# Mot : empathi
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [38]
#
# Mot : adequat
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [42]
#   Document : Les objectifs de l'Éducation pour Tous
#     Fréquence : 1
#     Positions : [56]
#
# Mot : entraid
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [46]
#
# Mot : soi
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [48]
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [34]
#
# Mot : maitris
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [49]
#
# Mot : ajustement
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [60]
#   Document : Interprétation du droit à l'éducation
#     Fréquence : 1
#     Positions : [84]
#
# Mot : lessence
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [61]
#
# Mot : lindividu
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [63]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [19]
#   Document : Investir dans l'éducation
#     Fréquence : 1
#     Positions : [10]
#
# Mot : psychique
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 2
#     Positions : [5, 33]
#
# Mot : datteindre
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [21]
#
# Mot : bienetre
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [27]
#
# Mot : expiation
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [30]
#
# Mot : allegresse
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [34]
#
# Mot : plaisir
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [35]
#   Document : Critiques
#     Fréquence : 1
#     Positions : [83]
#
# Mot : authenticite
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [42]
#
# Mot : reconfort
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [46]
#
# Mot : creativite
#   Document : Savoir, savoir-faire, savoir-être
#     Fréquence : 1
#     Positions : [47]
#
# Mot : mill
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [3]
#
# Mot : dapprentissage
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [12]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [257]
#
# Mot : verbal
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [1]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [74]
#
# Mot : conceptuel
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [3]
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [110]
#
# Mot : categoriel
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [4]
#
# Mot : socioemotif
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [13]
#
# Mot : courammer
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [4]
#
# Mot : orthograph
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [10]
#
# Mot : impliquent
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [13]
#
# Mot : stocker
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [18]
#
# Mot : verbalisable
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [28]
#
# Mot : coeur
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [40]
#   Document : Critiques
#     Fréquence : 1
#     Positions : [87]
#
# Mot : inclusion
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [4]
#   Document : Inclusion scolaire
#     Fréquence : 2
#     Positions : [5, 27]
#   Document : Un droit reconnu au niveau international
#     Fréquence : 1
#     Positions : [55]
#
# Mot : dobjet
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [12]
#
# Mot : lapprener
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [13]
#
# Mot : resolution
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [7]
#
# Mot : dalgorithme
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [17]
#
# Mot : socioemotionnel
#   Document : Taxonomie de Robert Mills Gagné
#     Fréquence : 1
#     Positions : [1]
#
# Mot : taxonomie
#   Document : Taxonomie de Bloom
#     Fréquence : 1
#     Positions : [1]
#
# Mot : rougir
#   Document : Taxonomie de Bloom
#     Fréquence : 1
#     Positions : [2]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [139]
#
# Mot : nomenclature
#   Document : Taxonomie de Bloom
#     Fréquence : 1
#     Positions : [6]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [144]
#
# Mot : dacquisition
#   Document : Taxonomie de Bloom
#     Fréquence : 1
#     Positions : [8]
#
# Mot : Benjamin
#   Document : Taxonomie de Bloom
#     Fréquence : 1
#     Positions : [1]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [138]
#
# Mot : Jehovah
#   Document : Taxonomie de Bloom
#     Fréquence : 1
#     Positions : [7]
#
# Mot : transmittance
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [4]
#   Document : Critiques
#     Fréquence : 1
#     Positions : [20]
#   Document : Enjeux
#     Fréquence : 1
#     Positions : [9]
#
# Mot : laisser
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [9]
#
# Mot : leleve
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [13]
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [36]
#
# Mot : luimeme
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [18]
#
# Mot : capable
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [28]
#
# Mot : soimeme
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [57]
#
# Mot : dictionnaire
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [60]
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [124]
#
# Mot : epellation
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [61]
#
# Mot : correct
#   Document : Construire son savoir
#     Fréquence : 1
#     Positions : [62]
#
# Mot : dressage
#   Document : Critiques
#     Fréquence : 1
#     Positions : [8]
#
# Mot : formatage
#   Document : Critiques
#     Fréquence : 1
#     Positions : [9]
#
# Mot : cenacle
#   Document : Critiques
#     Fréquence : 1
#     Positions : [10]
#
# Mot : iufm
#   Document : Critiques
#     Fréquence : 1
#     Positions : [11]
#
# Mot : dit
#   Document : Critiques
#     Fréquence : 1
#     Positions : [14]
#
# Mot : avertissement
#   Document : Critiques
#     Fréquence : 1
#     Positions : [23]
#
# Mot : imputer
#   Document : Critiques
#     Fréquence : 1
#     Positions : [31]
#
# Mot : opposant
#   Document : Critiques
#     Fréquence : 1
#     Positions : [33]
#
# Mot : denoncer
#   Document : Critiques
#     Fréquence : 1
#     Positions : [34]
#
# Mot : artificielle
#   Document : Critiques
#     Fréquence : 1
#     Positions : [36]
#
# Mot : inefficace
#   Document : Critiques
#     Fréquence : 1
#     Positions : [37]
#
# Mot : stressant
#   Document : Critiques
#     Fréquence : 1
#     Positions : [38]
#
# Mot : supposer
#   Document : Critiques
#     Fréquence : 2
#     Positions : [45, 65]
#
# Mot : doctoral
#   Document : Critiques
#     Fréquence : 1
#     Positions : [52]
#
# Mot : soustraction
#   Document : Critiques
#     Fréquence : 1
#     Positions : [60]
#
# Mot : ensembliste
#   Document : Critiques
#     Fréquence : 1
#     Positions : [63]
#
# Mot : inconsiderer
#   Document : Critiques
#     Fréquence : 1
#     Positions : [68]
#
# Mot : dangereux
#   Document : Critiques
#     Fréquence : 1
#     Positions : [75]
#
# Mot : sinon
#   Document : Critiques
#     Fréquence : 1
#     Positions : [92]
#
# Mot : grammatical
#   Document : Critiques
#     Fréquence : 1
#     Positions : [103]
#
# Mot : retrograde
#   Document : Critiques
#     Fréquence : 1
#     Positions : [112]
#
# Mot : reactionnaire
#   Document : Critiques
#     Fréquence : 1
#     Positions : [113]
#
# Mot : psychologue
#   Document : Critiques
#     Fréquence : 1
#     Positions : [3]
#
# Mot : dorientation
#   Document : Critiques
#     Fréquence : 1
#     Positions : [4]
#
# Mot : cognitiviste
#   Document : Critiques
#     Fréquence : 1
#     Positions : [5]
#
# Mot : resultent
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [2]
#
# Mot : om
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [5]
#
# Mot : grondement
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [9]
#
# Mot : formel
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 2
#     Positions : [15, 25]
#
# Mot : lunique
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [10]
#
# Mot : lentourage
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [20]
#
# Mot : elevage
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 2
#     Positions : [24, 33]
#
# Mot : passeron
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [31]
#
# Mot : corriger
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [37]
#
# Mot : incapacite
#   Document : Éducation formelle et éducation non formelle en France
#     Fréquence : 1
#     Positions : [45]
#
# Mot : sadresser
# ...
#     Fréquence : 1
#     Positions : [200]
#
# Mot : englehart
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [201]
#
# Mot : furst
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [203]
#
# Mot : hill
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [205]
#
# Mot : marcus
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [211]
#
# Mot : extrusion
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [212]
#
# Mot : math
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [213]
#
# Mot : Marc
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [220]
#
# Mot : bris
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [221]
#
# Mot : stock
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [228]
#
# Mot : tiehi
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [230]
#
# Mot : majority
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [233]
#
# Mot : children
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [235]
#
# Mot : live
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [236]
#
# Mot : two
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [238]
#
# Mot : sain
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [254]
#
# Mot : zacharopoulos
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [260]
#
# Mot : francesco
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [261]
#
# Mot : sella
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [262]
#
# Mot : cohen
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [264]
#
# Mot : kadosh
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [265]
#
# Mot : lack
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [271]
#
# Mot : mathematical
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [273]
#
# Mot : brain
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [275]
#
# Mot : developmer
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [276]
#
# Mot : attainment
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [279]
#
# Mot : pnas
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [281]
#
# Mot : pna
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [288]
#
# Mot : combler
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [304]
#
# Mot : onu
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [310]
#
# Mot : pierart
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [315]
#
# Mot : betrisey
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [317]
#
# Mot : tetreault
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [318]
#
# Mot : margotcattin
#   Document : Notes et références
#     Fréquence : 2
#     Positions : [319, 321]
#
# Mot : linclusion
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [323]
#
# Mot : romand
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [328]
#
# Mot : airhm
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [336]
#
# Mot : quebec
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [339]
#
# Mot : defining
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [345]
#
# Mot : quality
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [346]
#
# Mot : initiativ
#   Document : Notes et références
#     Fréquence : 4
#     Positions : [353, 379, 405, 424]
#
# Mot : contradicting
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [358]
#
# Mot : commitment
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [359]
#
# Mot : achievemer
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [362]
#
# Mot : all
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [366]
#
# Mot : being
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [368]
#
# Mot : undermined
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [369]
#
# Mot : monetary
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [373]
#
# Mot : person
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [398]
#
# Mot : post
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [419]
#
# Mot : avantpropo
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [449]
#
# Mot : tomasevski
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [472]
#
# Mot : ecn
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [482]
#
# Mot : cinquantehuitiem
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [486]
#
# Mot : schooling
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [498]
#
# Mot : experience
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [499]
#
# Mot : earning
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [501]
#
# Mot : minc
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [508]
#
# Mot : september
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [509]
#
# Mot : glasman
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [512]
#
# Mot : bongrand
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [514]
#
# Mot : sociologique
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [519]
#
# Mot : pedagogie
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [525]
#
# Mot : cornu
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [528]
#
# Mot : segmer
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [531]
#
# Mot : sevres
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [538]
#
# Mot : rie
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [545]
#
# Mot : webjournal
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [552]
#
# Mot : piketty
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [554]
#
# Mot : souhaiteil
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [556]
#
# Mot : blog
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [560]
#
# Mot : jeanfrancois
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [568]
#
# Mot : landry
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [569]
#
# Mot : Myth
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [579]
#
# Mot : arnaud
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [584]
#
# Mot : parienty
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [585]
#
# Mot : cafepedagogiquenet
#   Document : Notes et références
#     Fréquence : 1
#     Positions : [596]
#
# Mot : commonseducation
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [2]
#
# Mot : wiktionnaireeducation
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [3]
#
# Mot : wikiversityeducation
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [4]
#
# Mot : wikibookseducation
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [5]
#
# Mot : wikisourceeducation
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [6]
#
# Mot : wikiquoteeducation
#   Document : Voir aussi
#     Fréquence : 1
#     Positions : [7]
#
# Mot : koninck
#   Document : Bibliographie
#     Fréquence : 2
#     Positions : [7, 20]
#
# Mot : ignorance
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [9]
#
# Mot : portuger
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [18]
#
# Mot : federico
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [27]
#
# Mot : mayor
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [28]
#
# Mot : zaragoza
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [29]
#
# Mot : postface
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [30]
#
# Mot : mohamed
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [32]
#
# Mot : achaari
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [33]
#
# Mot : chanlat
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [35]
#
# Mot : abdelkarim
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [36]
#
# Mot : errouaki
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [37]
#
# Mot : Themis
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [40]
#
# Mot : erny
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [42]
#
# Mot : ethnologie
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [43]
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [11]
#
# Mot : Jessye_Norman
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [51]
#
# Mot : baillargeon
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [52]
#
# Mot : actualite
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [57]
#
# Mot : lanarchisme
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [58]
#
# Mot : agone
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [59]
#
# Mot : lux
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [60]
#
# Mot : plutarqu
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [9]
#
# Mot : specialise
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [11]
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [25]
#
# Mot : gregory
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [12]
#
# Mot : degenaer
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [13]
#
# Mot : ash
#   Document : Bibliographie
#     Fréquence : 1
#     Positions : [15]
#
# Mot : autoformation
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : cateches
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : socioculturel
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [20]
#
# Mot : lernen
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [36]
#
# Mot : durch
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [37]
#
# Mot : lehren
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [38]
#
# Mot : ldl
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [39]
#
# Mot : plasticiter
#   Document : Articles connexes
#     Fréquence : 1
#     Positions : [55]
#
# Mot : encyclopedia
#   Document : Liens externes
#     Fréquence : 4
#     Positions : [11, 15, 33, 37]
#
# Mot : cleveland
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : great
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [18]
#
# Mot : plain
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [19]
#
# Mot : aragonesa
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [22]
#
# Mot : handbook
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [26]
#
# Mot : texa
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [28]
#
# Mot : onlin
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [29]
#
# Mot : universali
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [30]
#
# Mot : Utah
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [31]
#
# Mot : virginia
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [36]
#
# Mot : construir
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [80]
#
# Mot : conception
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [84]
#
# Mot : curriculum
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [88]
#
# Mot : hstreasure
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [92]
#
# Mot : irie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [97]
#
# Mot : humanium
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [103]
#
# Mot : clarification
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [109]
#
# Mot : enjeux
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [111]
#
# Mot : lenoir
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [114]
#
# Mot : legitimite
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : contreculture
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : sousculture
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : ethologi
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [17]
#
# Mot : acculturation
#   Document : Liens externes
#     Fréquence : 2
#     Positions : [2, 3]
#
# Mot : transculturation
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : rayonnemer
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : hegemonie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : ethnocide
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : evolutionnisme
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [1]
#
# Mot : diffusionnisme
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [2]
#
# Mot : fonctionnalism
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [3]
#
# Mot : culturalisme
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : structuralisme
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [8]
#
# Mot : anthropologie
#   Document : Liens externes
#     Fréquence : 4
#     Positions : [0, 1, 3, 32]
#
# Mot : psychanalytique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [4]
#
# Mot : astronomie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [5]
#
# Mot : trouble_de_la_personnalite
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [7]
#
# Mot : ethnomedecine
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [9]
#
# Mot : ethnographie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [10]
#
# Mot : ethnopsychiatrie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [12]
#
# Mot : ethnopsychanalyse
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [13]
#
# Mot : ethnopharmacologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [14]
#
# Mot : ethnobiologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [15]
#
# Mot : ethnozoologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [16]
#
# Mot : ethnoentomologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [17]
#
# Mot : ethnobotanique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [18]
#
# Mot : ethnoornithologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [19]
#
# Mot : ethnoichthyologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [20]
#
# Mot : ethnoherpetologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [21]
#
# Mot : ethnoprimatologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [22]
#
# Mot : ethnomycologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [23]
#
# Mot : ethnolichenologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [24]
#
# Mot : ethnoecologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [25]
#
# Mot : ethnohistoir
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [26]
#
# Mot : ethnoarcheologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [27]
#
# Mot : ethnomathematique
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [28]
#
# Mot : ethologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [29]
#
# Mot : neuroscience
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [36]
#
# Mot : culturologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [42]
#
# Mot : neuroculture
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [45]
#
# Mot : bioculture
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [46]
#
# Mot : cartographi
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [61]
#
# Mot : culturomiqu
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [63]
#
# Mot : radicalisme
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [66]
#
# Mot : semiologie
#   Document : Liens externes
#     Fréquence : 1
#     Positions : [70]

# %% [markdown]
# **Laforme générale de l'affichage de l'index inversé enrichi sera :**
# (après calcul de IF-IDF
# Index inversé enrichi des mots :
# Mot : <mot>
#   Document : <nom_du_document>
#     TF : <fréquence_du_mot_dans_le_document>
#     TF-IDF : <valeur_tf_idf>
#     Positions : [<liste_des_positions_du_mot_dans_le_document>]
#
#   Document : <nom_du_document_suivant>
#     TF : <fréquence_du_mot_dans_le_document_suivant>
#     TF-IDF : <valeur_tf_idf>
#     Positions : [<liste_des_positions_du_mot_dans_le_document_suivant>]

# %%
import math

# Fonction pour calculer TF-IDF et enrichir l'index inversé
def calculer_tf_idf(index_inverse, total_documents):
    for mot, documents in index_inverse.items():
        # Calculer DF pour chaque mot (nombre de documents dans lesquels il apparaît)
        df = len(documents)

        # Calculer l'IDF
        idf = math.log(total_documents / df)

        # Mettre à jour chaque document pour ce mot avec la pondération TF-IDF
        for doc, info in documents.items():
            # Accéder directement à la fréquence TF et aux positions
            tf = info['tf']  # Fréquence du mot dans le document
            positions = info['positions']

            # Calculer le TF-IDF
            tf_idf = tf * idf
            index_inverse[mot][doc] = {
                'tf': tf,
                'tf-idf': tf_idf,
                'positions': positions
            }

    return index_inverse

# Calculer TF-IDF pour chaque mot dans chaque document
total_documents = len(processed_documents)
index_inverse_enrichi = calculer_tf_idf(index_inverse_enrichi, total_documents)

# Fonction pour afficher l'index inversé enrichi
def afficher_index_inverse_enrichi(index_inverse_enrichi):
    print("Index inversé enrichi des mots :")
    for mot, documents in index_inverse_enrichi.items():
        print(f"\nMot : {mot}")
        for doc, info in documents.items():
            tf = info['tf']
            tf_idf = info['tf-idf']
            positions = info['positions']
            print(f"  Document : {doc}")
            print(f"    TF : {tf}")
            print(f"    TF-IDF : {tf_idf}")
            print(f"    Positions : {positions}")

# Afficher l'index inversé enrichi
afficher_index_inverse_enrichi(index_inverse_enrichi)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-181-008173795d62> in <cell line: 30>()
#      28 # Calculer TF-IDF pour chaque mot dans chaque document
#      29 total_documents = len(processed_documents)
# ---> 30 index_inverse_enrichi = calculer_tf_idf(index_inverse_enrichi, total_documents)
#      31
#      32 # Fonction pour afficher l'index inversé enrichi
#
# <ipython-input-181-008173795d62> in calculer_tf_idf(index_inverse, total_documents)
#      13         for doc, info in documents.items():
#      14             # Accéder directement à la fréquence TF et aux positions
# ---> 15             tf = info['tf']  # Fréquence du mot dans le document
#      16             positions = info['positions']
#      17
#
# KeyError: 'tf'
